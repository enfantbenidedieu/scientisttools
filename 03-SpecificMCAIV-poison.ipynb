# %% [markdown]
# # Specific Multiple Correspondence Analysis with Instrumental Variables (speMCAIV) - `poison` dataset

# %%
#disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=6):
    dt = (GT(data=data.round(digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %% [markdown]
# ## `poison` dataset

# %%
#decathlon dataset
from scientisttools.datasets import poison
(
    GT(poison.rename_axis("Individuals").reset_index())
    .tab_header(title=html("<b>Poison Dataset</b>"))
    .tab_spanner(label=html("<b>Individuals</b>"),columns="Individuals")
    .tab_spanner(label=html("<b>Dependent<br>variables</b>"),columns=poison.columns.tolist()[2:])
    .tab_spanner(label=html("<b>Instrumental<br>variables</b>"),columns=poison.columns.tolist()[:2])
)
# Out:
# GT(_tbl_data=    Individuals  Age  Time    Sick Sex    Nausea Vomiting Abdominals    Fever  \
# 0             1    9    22  Sick_y   F  Nausea_y  Vomit_n     Abdo_y  Fever_y
# 1             2    5     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 2             3    6    16  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 3             4    9     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 4             5    7    14  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 5             6   72     9  Sick_y   M  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 6             7    5    16  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 7             8   10     8  Sick_y   F  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 8             9    5    20  Sick_y   M  Nausea_y  Vomit_n     Abdo_y  Fever_y
# 9            10   11    12  Sick_y   M  Nausea_n  Vomit_y     Abdo_n  Fever_y
# 10           11    7    17  Sick_y   F  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 11           12   10    16  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_n
# 12           13   36    19  Sick_y   F  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 13           14    9     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 14           15    8     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 15           16    6     6  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 16           17    7    10  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 17           18    5    15  Sick_y   M  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 18           19   11    14  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 19           20   11     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 20           21   10    18  Sick_y   M  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 21           22    8    14  Sick_y   F  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 22           23    8    21  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 23           24   11    13  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_n
# 24           25   45    10  Sick_y   F  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 25           26    9     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 26           27    5    12  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 27           28   85     9  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 28           29   88     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 29           30   79    17  Sick_y   F  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 30           31    9     9  Sick_y   F  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 31           32    6     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 32           33    8     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 33           34    8     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 34           35    7    15  Sick_y   F  Nausea_y  Vomit_n     Abdo_y  Fever_y
# 35           36    9    19  Sick_y   M  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 36           37    9    11  Sick_y   M  Nausea_y  Vomit_n     Abdo_y  Fever_n
# 37           38    6     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 38           39    5    17  Sick_y   M  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 39           40    6    16  Sick_y   M  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 40           41    4    12  Sick_y   M  Nausea_y  Vomit_n     Abdo_y  Fever_y
# 41           42    7     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 42           43   82    20  Sick_y   F  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 43           44    5     4  Sick_y   F  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 44           45    5    20  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 45           46    6    16  Sick_y   M  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 46           47   10     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 47           48   83     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 48           49    8     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 49           50    7    22  Sick_y   F  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 50           51   10     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 51           52   11    17  Sick_y   M  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 52           53    6     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 53           54   10    19  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 54           55    7    14  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_y
#
#       Diarrhae    Potato    Fish    Mayo Courgette    Cheese    Icecream
# 0   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 1   Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_n  Icecream_y
# 2   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 3   Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 4   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 5   Diarrhea_y  Potato_y  Fish_n  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 6   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 7   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 8   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 9   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 10  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 11  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 12  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 13  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 14  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_n  Icecream_y
# 15  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 16  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_n  Icecream_y
# 17  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 18  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 19  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 20  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 21  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_n
# 22  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_n  Cheese_y  Icecream_y
# 23  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 24  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_n  Icecream_y
# 25  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 26  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 27  Diarrhea_y  Potato_y  Fish_y  Mayo_n   Courg_n  Cheese_y  Icecream_y
# 28  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 29  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 30  Diarrhea_y  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 31  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_n  Icecream_y
# 32  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 33  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 34  Diarrhea_y  Potato_n  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 35  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 36  Diarrhea_y  Potato_n  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 37  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_n  Cheese_n  Icecream_y
# 38  Diarrhea_y  Potato_n  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 39  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 40  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 41  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 42  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 43  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_n  Cheese_y  Icecream_n
# 44  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_n  Cheese_y  Icecream_y
# 45  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 46  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_n
# 47  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 48  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 49  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 50  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 51  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 52  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_n  Icecream_n
# 53  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 54  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y  , _body=<great_tables._gt_data.Body object at 0x0000019CAA3D95A0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Age', type=<ColInfoTypeEnum.default: 1>, column_label='Age', column_align='right', column_width=None), ColInfo(var='Time', type=<ColInfoTypeEnum.default: 1>, column_label='Time', column_align='right', column_width=None), ColInfo(var='Sick', type=<ColInfoTypeEnum.default: 1>, column_label='Sick', column_align='left', column_width=None), ColInfo(var='Sex', type=<ColInfoTypeEnum.default: 1>, column_label='Sex', column_align='left', column_width=None), ColInfo(var='Nausea', type=<ColInfoTypeEnum.default: 1>, column_label='Nausea', column_align='left', column_width=None), ColInfo(var='Vomiting', type=<ColInfoTypeEnum.default: 1>, column_label='Vomiting', column_align='left', column_width=None), ColInfo(var='Abdominals', type=<ColInfoTypeEnum.default: 1>, column_label='Abdominals', column_align='left', column_width=None), ColInfo(var='Fever', type=<ColInfoTypeEnum.default: 1>, column_label='Fever', column_align='left', column_width=None), ColInfo(var='Diarrhae', type=<ColInfoTypeEnum.default: 1>, column_label='Diarrhae', column_align='left', column_width=None), ColInfo(var='Potato', type=<ColInfoTypeEnum.default: 1>, column_label='Potato', column_align='left', column_width=None), ColInfo(var='Fish', type=<ColInfoTypeEnum.default: 1>, column_label='Fish', column_align='left', column_width=None), ColInfo(var='Mayo', type=<ColInfoTypeEnum.default: 1>, column_label='Mayo', column_align='left', column_width=None), ColInfo(var='Courgette', type=<ColInfoTypeEnum.default: 1>, column_label='Courgette', column_align='left', column_width=None), ColInfo(var='Cheese', type=<ColInfoTypeEnum.default: 1>, column_label='Cheese', column_align='left', column_width=None), ColInfo(var='Icecream', type=<ColInfoTypeEnum.default: 1>, column_label='Icecream', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019C96AB35B0>, _spanners=Spanners([SpannerInfo(spanner_id='<b>Individuals</b>', spanner_level=0, spanner_label=Html(text='<b>Individuals</b>'), spanner_units=None, spanner_pattern=None, vars=['Individuals'], built=None), SpannerInfo(spanner_id='<b>Dependent<br>variables</b>', spanner_level=0, spanner_label=Html(text='<b>Dependent<br>variables</b>'), spanner_units=None, spanner_pattern=None, vars=['Sick', 'Sex', 'Nausea', 'Vomiting', 'Abdominals', 'Fever', 'Diarrhae', 'Potato', 'Fish', 'Mayo', 'Courgette', 'Cheese', 'Icecream'], built=None), SpannerInfo(spanner_id='<b>Instrumental<br>variables</b>', spanner_level=0, spanner_label=Html(text='<b>Instrumental<br>variables</b>'), spanner_units=None, spanner_pattern=None, vars=['Age', 'Time'], built=None)]), _heading=Heading(title=Html(text='<b>Poison Dataset</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA4D1B70>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', ...

# %% [markdown]
# ## Instanciation and training

# %%
from scientisttools import MCAIV
#instanciation
res_mcaiv = MCAIV(iv=(0,1),excl=(0,2))

# %% [markdown]
# ## `fit` function

# %%
#fit
res_mcaiv.fit(poison)
# Out:
# MCAIV(excl=(0, 2), iv=(0, 1))

# %% [markdown]
# ## `fit_transform` function

# %%
#fit_transform
print_dt(res_mcaiv.fit_transform(poison),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=    Individuals     Dim.1     Dim.2
# 0             1 -0.717646  0.038801
# 1             2  0.633755  0.053442
# 2             3 -0.347296  0.051635
# 3             4  0.630013  0.034918
# 4             5 -0.225717  0.046651
# 5             6  0.019755 -0.255251
# 6             7 -0.346360  0.056266
# 7             8  0.139019  0.031699
# 8             9 -0.591389  0.056972
# 9            10 -0.106945  0.027774
# 10           11 -0.409489  0.047181
# 11           12 -0.351038  0.033111
# 12           13 -0.559136 -0.086767
# 13           14  0.630013  0.034918
# 14           15  0.630949  0.039549
# 15           16  0.265276  0.049870
# 16           17  0.019312  0.045945
# 17           18 -0.285103  0.056090
# 18           19 -0.229459  0.028127
# 19           20  0.628142  0.025656
# 20           21 -0.473553  0.033464
# 21           22 -0.226653  0.042020
# 22           23 -0.655453  0.043256
# 23           24 -0.168202  0.027950
# 24           25 -0.016241 -0.130036
# 25           26  0.630013  0.034918
# 26           27 -0.101331  0.055560
# 27           28  0.007593 -0.315455
# 28           29  0.556101 -0.330937
# 29           30 -0.476852 -0.286256
# 30           31  0.078698  0.036506
# 31           32  0.632820  0.048811
# 32           33  0.630949  0.039549
# 33           34  0.630949  0.039549
# 34           35 -0.286974  0.046828
# 35           36 -0.533874  0.038272
# 36           37 -0.043817  0.036859
# 37           38  0.632820  0.048811
# 38           39 -0.407618  0.056443
# 39           40 -0.347296  0.051635
# 40           41 -0.100396  0.060191
# 41           42  0.631884  0.044180
# 42           43 -0.663430 -0.299620
# 43           44  0.388726  0.054148
# 44           45 -0.591389  0.056972
# 45           46 -0.347296  0.051635
# 46           47  0.629077  0.030287
# 47           48  0.560779 -0.307781
# 48           49  0.630949  0.039549
# 49           50 -0.715775  0.048063
# 50           51  0.629077  0.030287
# 51           52 -0.413231  0.028656
# 52           53  0.632820  0.048811
# 53           54 -0.534810  0.033640
# 54           55 -0.225717  0.046651, _body=<great_tables._gt_data.Body object at 0x0000019CAA73C160>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA656020>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA73F520>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='h ...

# %% [markdown]
# ## Ratio

# %%
#ratio
res_mcaiv.ratio_
# Out:
# 0.25943854980216763

# %% [markdown]
# ## Eigen values

# %%
#PCA eigen values
from scientisttools import get_eig
print_dt(get_eig(res_mcaiv),rowname="Dimensions",title=html("<b>Eigen values</b>"))
# Out:
# GT(_tbl_data=  Dimensions  Eigenvalue  Difference  Proportion  Cumulative
# 0      Dim.1    0.223934    0.212015   94.946367   94.946367
# 1      Dim.2    0.011919         NaN    5.053633  100.000000, _body=<great_tables._gt_data.Body object at 0x0000019CAA73FD30>, _boxhead=Boxhead([ColInfo(var='Dimensions', type=<ColInfoTypeEnum.default: 1>, column_label='Dimensions', column_align='left', column_width=None), ColInfo(var='Eigenvalue', type=<ColInfoTypeEnum.default: 1>, column_label='Eigenvalue', column_align='right', column_width=None), ColInfo(var='Difference', type=<ColInfoTypeEnum.default: 1>, column_label='Difference', column_align='right', column_width=None), ColInfo(var='Proportion', type=<ColInfoTypeEnum.default: 1>, column_label='Proportion', column_align='right', column_width=None), ColInfo(var='Cumulative', type=<ColInfoTypeEnum.default: 1>, column_label='Cumulative', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA73FD00>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Eigen values</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA765CC0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='headi ...

# %% [markdown]
# ## Individuals informations

# %%
#individuals informations
from scientisttools import get_mcaiv_ind
ind = get_mcaiv_ind(res_mcaiv)
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
#individuals factor coordinates
print_dt(ind.coord,rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=    Individuals     Dim.1     Dim.2
# 0             1 -0.717646  0.038801
# 1             2  0.633755  0.053442
# 2             3 -0.347296  0.051635
# 3             4  0.630013  0.034918
# 4             5 -0.225717  0.046651
# 5             6  0.019755 -0.255251
# 6             7 -0.346360  0.056266
# 7             8  0.139019  0.031699
# 8             9 -0.591389  0.056972
# 9            10 -0.106945  0.027774
# 10           11 -0.409489  0.047181
# 11           12 -0.351038  0.033111
# 12           13 -0.559136 -0.086767
# 13           14  0.630013  0.034918
# 14           15  0.630949  0.039549
# 15           16  0.265276  0.049870
# 16           17  0.019312  0.045945
# 17           18 -0.285103  0.056090
# 18           19 -0.229459  0.028127
# 19           20  0.628142  0.025656
# 20           21 -0.473553  0.033464
# 21           22 -0.226653  0.042020
# 22           23 -0.655453  0.043256
# 23           24 -0.168202  0.027950
# 24           25 -0.016241 -0.130036
# 25           26  0.630013  0.034918
# 26           27 -0.101331  0.055560
# 27           28  0.007593 -0.315455
# 28           29  0.556101 -0.330937
# 29           30 -0.476852 -0.286256
# 30           31  0.078698  0.036506
# 31           32  0.632820  0.048811
# 32           33  0.630949  0.039549
# 33           34  0.630949  0.039549
# 34           35 -0.286974  0.046828
# 35           36 -0.533874  0.038272
# 36           37 -0.043817  0.036859
# 37           38  0.632820  0.048811
# 38           39 -0.407618  0.056443
# 39           40 -0.347296  0.051635
# 40           41 -0.100396  0.060191
# 41           42  0.631884  0.044180
# 42           43 -0.663430 -0.299620
# 43           44  0.388726  0.054148
# 44           45 -0.591389  0.056972
# 45           46 -0.347296  0.051635
# 46           47  0.629077  0.030287
# 47           48  0.560779 -0.307781
# 48           49  0.630949  0.039549
# 49           50 -0.715775  0.048063
# 50           51  0.629077  0.030287
# 51           52 -0.413231  0.028656
# 52           53  0.632820  0.048811
# 53           54 -0.534810  0.033640
# 54           55 -0.225717  0.046651, _body=<great_tables._gt_data.Body object at 0x0000019CAA72F250>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA765150>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA72DCF0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='h ...

# %% [markdown]
# ### Individuals contributions

# %%
#individuals contributions
print_dt(ind.contrib,rowname="Individuals",title=html("<b>Individuals contributions</b>"))
# Out:
# GT(_tbl_data=    Individuals     Dim.1      Dim.2
# 0             1  4.181555   0.229657
# 1             2  3.261072   0.435669
# 2             3  0.979302   0.406708
# 3             4  3.222672   0.185987
# 4             5  0.413662   0.331982
# 5             6  0.003169   9.938633
# 6             7  0.974033   0.482934
# 7             8  0.156916   0.153277
# 8             9  2.839645   0.495130
# 9            10  0.092862   0.117669
# 10           11  1.361448   0.339562
# 11           12  1.000521   0.167238
# 12           13  2.538349   1.148429
# 13           14  3.222672   0.185987
# 14           15  3.232250   0.238593
# 15           16  0.571366   0.379376
# 16           17  0.003028   0.322009
# 17           18  0.659965   0.479909
# 18           19  0.427493   0.120679
# 19           20  3.203557   0.100405
# 20           21  1.820765   0.170823
# 21           22  0.417099   0.269342
# 22           23  3.488194   0.285415
# 23           24  0.229710   0.119169
# 24           25  0.002142   2.579386
# 25           26  3.222672   0.185987
# 26           27  0.083369   0.470889
# 27           28  0.000468  15.179808
# 28           29  2.510871  16.706358
# 29           30  1.846221  12.499768
# 30           31  0.050286   0.203296
# 31           32  3.251450   0.363434
# 32           33  3.232250   0.238593
# 33           34  3.232250   0.238593
# 34           35  0.668657   0.334499
# 35           36  2.314171   0.223431
# 36           37  0.015588   0.207247
# 37           38  3.251450   0.363434
# 38           39  1.349034   0.485969
# 39           40  0.979302   0.406708
# 40           41  0.081837   0.552660
# 41           42  3.241843   0.297742
# 42           43  3.573613  13.694093
# 43           44  1.226889   0.447257
# 44           45  2.839645   0.495130
# 45           46  0.979302   0.406708
# 46           47  3.213107   0.139924
# 47           48  2.553292  14.450290
# 48           49  3.232250   0.238593
# 49           50  4.159778   0.352385
# 50           51  3.213107   0.139924
# 51           52  1.386447   0.125266
# 52           53  3.251450   0.363434
# 53           54  2.322289   0.172630
# 54           55  0.413662   0.331982, _body=<great_tables._gt_data.Body object at 0x0000019CAA72D450>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA72D5A0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAC89DCF0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category ...

# %% [markdown]
# ### Individuals squared cosinus (cos2)

# %%
#individuals squared cosinus (cos2)
print_dt(ind.cos2,rowname="Individuals",title=html("<b>Individuals squared cosinus (Cos2)</b>"))
# Out:
# GT(_tbl_data=    Individuals     Dim.1     Dim.2
# 0             1  0.997085  0.002915
# 1             2  0.992939  0.007061
# 2             3  0.978373  0.021627
# 3             4  0.996938  0.003062
# 4             5  0.959034  0.040966
# 5             6  0.005954  0.994046
# 6             7  0.974289  0.025711
# 7             8  0.950578  0.049422
# 8             9  0.990805  0.009195
# 9            10  0.936817  0.063183
# 10           11  0.986899  0.013101
# 11           12  0.991182  0.008818
# 12           13  0.976485  0.023515
# 13           14  0.996938  0.003062
# 14           15  0.996086  0.003914
# 15           16  0.965865  0.034135
# 16           17  0.150146  0.849854
# 17           18  0.962738  0.037262
# 18           19  0.985197  0.014803
# 19           20  0.998335  0.001665
# 20           21  0.995031  0.004969
# 21           22  0.966771  0.033229
# 22           23  0.995664  0.004336
# 23           24  0.973129  0.026871
# 24           25  0.015359  0.984641
# 25           26  0.996938  0.003062
# 26           27  0.768856  0.231144
# 27           28  0.000579  0.999421
# 28           29  0.738473  0.261527
# 29           30  0.735096  0.264904
# 30           31  0.822920  0.177080
# 31           32  0.994086  0.005914
# 32           33  0.996086  0.003914
# 33           34  0.996086  0.003914
# 34           35  0.974064  0.025936
# 35           36  0.994887  0.005113
# 36           37  0.585600  0.414400
# 37           38  0.994086  0.005914
# 38           39  0.981187  0.018813
# 39           40  0.978373  0.021627
# 40           41  0.735593  0.264407
# 41           42  0.995135  0.004865
# 42           43  0.830590  0.169410
# 43           44  0.980966  0.019034
# 44           45  0.990805  0.009195
# 45           46  0.978373  0.021627
# 46           47  0.997687  0.002313
# 47           48  0.768502  0.231498
# 48           49  0.996086  0.003914
# 49           50  0.995511  0.004489
# 50           51  0.997687  0.002313
# 51           52  0.995214  0.004786
# 52           53  0.994086  0.005914
# 53           54  0.996059  0.003941
# 54           55  0.959034  0.040966, _body=<great_tables._gt_data.Body object at 0x0000019CAA6E1AB0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAC89D4B0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals squared cosinus (Cos2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA6E11E0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True,  ...

# %% [markdown]
# ### Additionals informations

# %%
#individuals additionals informations (weight,squared distance to origin, inertia)
print_dt(ind.infos,rowname="Individuals",title=html("<b>Individuals additionals informations <br> (weight, sq. dist., inertia)</b>"))
# Out:
# GT(_tbl_data=    Individuals    Weight  Sq. Dist.   Inertia  % Inertia
# 0             1  0.018182   0.516521  0.009391   3.981841
# 1             2  0.018182   0.404502  0.007355   3.118286
# 2             3  0.018182   0.123281  0.002241   0.950365
# 3             4  0.018182   0.398136  0.007239   3.069209
# 4             5  0.018182   0.053125  0.000966   0.409535
# 5             6  0.018182   0.065543  0.001192   0.505271
# 6             7  0.018182   0.123131  0.002239   0.949214
# 7             8  0.018182   0.020331  0.000370   0.156733
# 8             9  0.018182   0.352987  0.006418   2.721162
# 9            10  0.018182   0.012209  0.000222   0.094116
# 10           11  0.018182   0.169907  0.003089   1.309806
# 11           12  0.018182   0.124324  0.002260   0.958410
# 12           13  0.018182   0.320161  0.005821   2.468107
# 13           14  0.018182   0.398136  0.007239   3.069209
# 14           15  0.018182   0.399660  0.007267   3.080962
# 15           16  0.018182   0.072859  0.001325   0.561663
# 16           17  0.018182   0.002484  0.000045   0.019148
# 17           18  0.018182   0.084430  0.001535   0.650866
# 18           19  0.018182   0.053443  0.000972   0.411988
# 19           20  0.018182   0.395220  0.007186   3.046735
# 20           21  0.018182   0.225372  0.004098   1.737383
# 21           22  0.018182   0.053137  0.000966   0.409632
# 22           23  0.018182   0.431490  0.007845   3.326338
# 23           24  0.018182   0.029073  0.000529   0.224124
# 24           25  0.018182   0.017173  0.000312   0.132386
# 25           26  0.018182   0.398136  0.007239   3.069209
# 26           27  0.018182   0.013355  0.000243   0.102953
# 27           28  0.018182   0.099569  0.001810   0.767576
# 28           29  0.018182   0.418767  0.007614   3.228259
# 29           30  0.018182   0.309330  0.005624   2.384612
# 30           31  0.018182   0.007526  0.000137   0.058018
# 31           32  0.018182   0.402843  0.007324   3.105501
# 32           33  0.018182   0.399660  0.007267   3.080962
# 33           34  0.018182   0.399660  0.007267   3.080962
# 34           35  0.018182   0.084547  0.001537   0.651770
# 35           36  0.018182   0.286487  0.005209   2.208512
# 36           37  0.018182   0.003279  0.000060   0.025274
# 37           38  0.018182   0.402843  0.007324   3.105501
# 38           39  0.018182   0.169338  0.003079   1.305418
# 39           40  0.018182   0.123281  0.002241   0.950365
# 40           41  0.018182   0.013702  0.000249   0.105631
# 41           42  0.018182   0.401229  0.007295   3.093059
# 42           43  0.018182   0.529912  0.009635   4.085065
# 43           44  0.018182   0.154040  0.002801   1.187489
# 44           45  0.018182   0.352987  0.006418   2.721162
# 45           46  0.018182   0.123281  0.002241   0.950365
# 46           47  0.018182   0.396656  0.007212   3.057800
# 47           48  0.018182   0.409202  0.007440   3.154522
# 48           49  0.018182   0.399660  0.007267   3.080962
# 49           50  0.018182   0.514644  0.009357   3.967366
# 50           51  0.018182   0.396656  0.007212   3.057800
# 51           52  0.018182   0.171581  0.003120   1.322712
# 52           53  0.018182   0.402843  0.007324   3.105501
# 53           54  0.018182   0.287153  0.005221   2.213653
# 54           55  0.018182   0.053125  0.000966   0.409535, _body=<great_tables._gt_data.Body object at 0x0000019CAC89C5B0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Weight', type=<ColInfoTypeEnum.default: 1>, column_label='Weight', column_align='right', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None), ColInfo(var='Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='Inertia', column_align='right', column_width=None), ColInfo(var='% Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='% Inertia', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA4D2830>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals additionals informations <br> (weight, sq. dist., inertia)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA67BA30>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_alig ...

# %% [markdown]
# ## Variables informations

# %%
#variables informations
from scientisttools import get_mcaiv_var
var = get_mcaiv_var(res_mcaiv)
var._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Variables coordinates

# %%
#variables coordinates
print_dt(var.coord,rowname="Variables",title=html("<b>Variables coordinates</b>"))
# Out:
# GT(_tbl_data=   Variables     Dim.1     Dim.2
# 0      Dim.1  0.469294  0.000078
# 1      Dim.2  0.014008  0.009026
# 2      Dim.3  0.017410  0.077802
# 3      Dim.4  0.012442 -0.055534
# 4      Dim.5 -0.005798 -0.002146
# 5      Dim.6  0.023774 -0.034243
# 6      Dim.7  0.040459 -0.008075
# 7      Dim.8  0.011976  0.000994
# 8      Dim.9  0.010235  0.037636
# 9     Dim.10 -0.015691  0.001190
# 10    Dim.11 -0.016415  0.002636
# 11    Dim.12 -0.005317  0.005615
# 12    Dim.13 -0.003878  0.000883, _body=<great_tables._gt_data.Body object at 0x0000019CAC91AB30>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019C884F75B0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAC91AC50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', t ...

# %% [markdown]
# ### Variables contributions

# %%
#variables contributions
print_dt(var.contrib,rowname="Variables",title=html("<b>Variables contributions</b>"))
# Out:
# GT(_tbl_data=   Variables      Dim.1      Dim.2
# 0      Dim.1  98.349034   0.000051
# 1      Dim.2   0.087623   0.683547
# 2      Dim.3   0.135360  50.785319
# 3      Dim.4   0.069132  25.874089
# 4      Dim.5   0.015012   0.038639
# 5      Dim.6   0.252402   9.837873
# 6      Dim.7   0.730988   0.547075
# 7      Dim.8   0.064052   0.008281
# 8      Dim.9   0.046779  11.883862
# 9     Dim.10   0.109953   0.011883
# 10    Dim.11   0.120321   0.058308
# 11    Dim.12   0.012627   0.264528
# 12    Dim.13   0.006717   0.006545, _body=<great_tables._gt_data.Body object at 0x0000019CAA6CBA60>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAC919D80>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA6CA200>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading ...

# %% [markdown]
# ### Variables squared cosinus (cos2)

# %%
#variables squared cosinus (cos2)
print_dt(var.cos2,rowname="Variables",title=html("<b>Variables squared cosinus (cos2)</b>"))
# Out:
# GT(_tbl_data=   Variables     Dim.1     Dim.2
# 0      Dim.1  1.000000  0.000000
# 1      Dim.2  0.706606  0.293394
# 2      Dim.3  0.047688  0.952312
# 3      Dim.4  0.047799  0.952201
# 4      Dim.5  0.879507  0.120493
# 5      Dim.6  0.325246  0.674754
# 6      Dim.7  0.961691  0.038309
# 7      Dim.8  0.993165  0.006835
# 8      Dim.9  0.068863  0.931137
# 9     Dim.10  0.994280  0.005720
# 10    Dim.11  0.974855  0.025145
# 11    Dim.12  0.472793  0.527207
# 12    Dim.13  0.950693  0.049307, _body=<great_tables._gt_data.Body object at 0x0000019CAA6C98D0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAC9186D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables squared cosinus (cos2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA6C9330>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category=' ...

# %% [markdown]
# ### Addtionals informations

# %%
#variables additionals informations
print_dt(var.infos,rowname="Variables",title=html("<b>Variables additionals informations <br> (weight, sq. dist., inertia)</b>"))
# Out:
# GT(_tbl_data=   Variables  Weight  Sq. Dist.   Inertia  % Inertia
# 0      Dim.1     1.0   0.220237  0.220237  93.378837
# 1      Dim.2     1.0   0.000278  0.000278   0.117739
# 2      Dim.3     1.0   0.006356  0.006356   2.695023
# 3      Dim.4     1.0   0.003239  0.003239   1.373220
# 4      Dim.5     1.0   0.000038  0.000038   0.016206
# 5      Dim.6     1.0   0.001738  0.001738   0.736817
# 6      Dim.7     1.0   0.001702  0.001702   0.721694
# 7      Dim.8     1.0   0.000144  0.000144   0.061234
# 8      Dim.9     1.0   0.001521  0.001521   0.644982
# 9     Dim.10     1.0   0.000248  0.000248   0.104996
# 10    Dim.11     1.0   0.000276  0.000276   0.117187
# 11    Dim.12     1.0   0.000060  0.000060   0.025357
# 12    Dim.13     1.0   0.000016  0.000016   0.006709, _body=<great_tables._gt_data.Body object at 0x0000019CAA6C84F0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Weight', type=<ColInfoTypeEnum.default: 1>, column_label='Weight', column_align='right', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None), ColInfo(var='Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='Inertia', column_align='right', column_width=None), ColInfo(var='% Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='% Inertia', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA6C8040>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables additionals informations <br> (weight, sq. dist., inertia)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA6CA080>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInf ...

# %% [markdown]
# ## Supplementary quantitative variables

# %%
#supplementary quantitative variables
quanti_sup = res_mcaiv.quanti_sup_
quanti_sup._fields
# Out:
# ('coord', 'cos2')

# %% [markdown]
# ### Supplementary quantitative variables coordinates

# %%
#supplementary quantitative variables coordinates
print_dt(quanti_sup.coord,rowname="Variables",title=html("<b>Supplementary quantitative variables <br> coordinates</b>"))
# Out:
# GT(_tbl_data=  Variables     Dim.1     Dim.2
# 0       Age -0.012489 -0.999922
# 1      Time -0.998916  0.046558, _body=<great_tables._gt_data.Body object at 0x0000019CAC911900>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAC91AA70>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary quantitative variables <br> coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAC910AF0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(s ...

# %% [markdown]
# ### Supplementary quantitative variables squared cosinus (cos2)

# %%
#supplementary quantitative variables squared cosinus (cos2)
print_dt(quanti_sup.cos2,rowname="Variables",title=html("<b>Supplementary quantitative variables <br> squared cosinus (cos2)</b>"))
# Out:
# GT(_tbl_data=  Variables     Dim.1     Dim.2
# 0       Age  0.000156  0.999844
# 1      Time  0.997832  0.002168, _body=<great_tables._gt_data.Body object at 0x0000019CAC911D80>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA6E0C40>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary quantitative variables <br> squared cosinus (cos2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAC910A30>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=Op ...

# %% [markdown]
# ## Supplementary qualitative variables/categories

# %%
#supplementary qualitative variables informations
quali_sup = res_mcaiv.quali_sup_
quali_sup._fields
# Out:
# ('barycentre', 'coord', 'cos2', 'vtest', 'dist2', 'eta2')

# %% [markdown]
# ### Supplementary variables/categories coordinates

# %%
#supplementary variables/categories coordinates
print_dt(quali_sup.coord,rowname="Categories",title=html("<b>Supplementary variables/categories <br> coordinates</b>"))
# Out:
# GT(_tbl_data=    Categories     Dim.1     Dim.2
# 0       Sick_n  0.622418 -0.002676
# 1       Sick_y -0.278450  0.001197
# 2            F  0.013362 -0.005175
# 3            M -0.013857  0.005366
# 4     Nausea_n  0.075932 -0.005405
# 5     Nausea_y -0.272091  0.019368
# 6      Vomit_n  0.155043 -0.008507
# 7      Vomit_y -0.232564  0.012760
# 8       Abdo_n  0.581898 -0.000984
# 9       Abdo_y -0.283085  0.000479
# 10     Fever_n  0.500903  0.002622
# 11     Fever_y -0.286230 -0.001498
# 12  Diarrhea_n  0.479696  0.003841
# 13  Diarrhea_y -0.274112 -0.002195
# 14    Potato_n -0.246136  0.046710
# 15    Potato_y  0.014200 -0.002695
# 16      Fish_n  0.019755 -0.255251
# 17      Fish_y -0.000366  0.004727
# 18      Mayo_n  0.512920  0.001429
# 19      Mayo_y -0.113982 -0.000317
# 20     Courg_n -0.043541 -0.022454
# 21     Courg_y  0.004354  0.002245
# 22    Cheese_n  0.452319  0.022190
# 23    Cheese_y -0.065963 -0.003236
# 24  Icecream_n  0.355993  0.043816
# 25  Icecream_y -0.027921 -0.003437, _body=<great_tables._gt_data.Body object at 0x0000019CAC9109D0>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAC912860>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary variables/categories <br> coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA684520>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInf ...

# %% [markdown]
# ### Supplementary variables/categories squared cosinus (cos2)

# %%
#supplementary variables/categories squared cosinus (cos2)
print_dt(quali_sup.cos2,rowname="Categories",title=html("<b>Supplementary variables/categories <br> squared cosinus (cos2)</b>"))
# Out:
# GT(_tbl_data=    Categories     Dim.1     Dim.2
# 0       Sick_n  0.999982  0.000018
# 1       Sick_y  0.999982  0.000018
# 2            F  0.869585  0.130415
# 3            M  0.869585  0.130415
# 4     Nausea_n  0.994959  0.005041
# 5     Nausea_y  0.994959  0.005041
# 6      Vomit_n  0.996999  0.003001
# 7      Vomit_y  0.996999  0.003001
# 8       Abdo_n  0.999997  0.000003
# 9       Abdo_y  0.999997  0.000003
# 10     Fever_n  0.999973  0.000027
# 11     Fever_y  0.999973  0.000027
# 12  Diarrhea_n  0.999936  0.000064
# 13  Diarrhea_y  0.999936  0.000064
# 14    Potato_n  0.965238  0.034762
# 15    Potato_y  0.965238  0.034762
# 16      Fish_n  0.005954  0.994046
# 17      Fish_y  0.005954  0.994046
# 18      Mayo_n  0.999992  0.000008
# 19      Mayo_y  0.999992  0.000008
# 20     Courg_n  0.789928  0.210072
# 21     Courg_y  0.789928  0.210072
# 22    Cheese_n  0.997599  0.002401
# 23    Cheese_y  0.997599  0.002401
# 24  Icecream_n  0.985077  0.014923
# 25  Icecream_y  0.985077  0.014923, _body=<great_tables._gt_data.Body object at 0x0000019CAA685390>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA6CBC40>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary variables/categories <br> squared cosinus (cos2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA686290>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size ...

# %% [markdown]
# ### Supplementary variables/categories squared distance to origin (dist2)

# %%
#supplementary variables/categories squared distance to origin (dist2)
print_dt(quali_sup.dist2,rowname="Categories",title=html("<b>Supplementary variables/categories <br> squared distance <br> to origin (dist2)</b>"))
# Out:
# GT(_tbl_data=    Categories  Sq. Dist.
# 0       Sick_n   0.387411
# 1       Sick_y   0.077536
# 2            F   0.000205
# 3            M   0.000221
# 4     Nausea_n   0.005795
# 5     Nausea_y   0.074409
# 6      Vomit_n   0.024111
# 7      Vomit_y   0.054249
# 8       Abdo_n   0.338606
# 9       Abdo_y   0.080138
# 10     Fever_n   0.250910
# 11     Fever_y   0.081930
# 12  Diarrhea_n   0.230123
# 13  Diarrhea_y   0.075142
# 14    Potato_n   0.062765
# 15    Potato_y   0.000209
# 16      Fish_n   0.065543
# 17      Fish_y   0.000022
# 18      Mayo_n   0.263089
# 19      Mayo_y   0.012992
# 20     Courg_n   0.002400
# 21     Courg_y   0.000024
# 22    Cheese_n   0.205085
# 23    Cheese_y   0.004362
# 24  Icecream_n   0.128651
# 25  Icecream_y   0.000791, _body=<great_tables._gt_data.Body object at 0x0000019CAA6853F0>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA684CD0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary variables/categories <br> squared distance <br> to origin (dist2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA6876D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=Option ...

# %% [markdown]
# ### Supplementary variables/categories value-test (vtest)

# %%
#supplementary variables/categories value-test (vtest)
print_dt(quali_sup.vtest,rowname="Categories",title=html("<b>Supplementary variables/categories <br> value-test (vtest)</b>"))
# Out:
# GT(_tbl_data=    Categories     Dim.1     Dim.2
# 0       Sick_n  6.464749 -0.120461
# 1       Sick_y -6.464749  0.120461
# 2            F  0.211309 -0.354700
# 3            M -0.211309  0.354700
# 4     Nausea_n  2.232067 -0.688686
# 5     Nausea_y -2.232067  0.688686
# 6      Vomit_n  2.948720 -0.701264
# 7      Vomit_y -2.948720  0.701264
# 8       Abdo_n  6.302589 -0.046199
# 9       Abdo_y -6.302589  0.046199
# 10     Fever_n  5.879914  0.133393
# 11     Fever_y -5.879914 -0.133393
# 12  Diarrhea_n  5.630983  0.195445
# 13  Diarrhea_y -5.630983 -0.195445
# 14    Potato_n -0.918060  0.755165
# 15    Potato_y  0.918060 -0.755165
# 16      Fish_n  0.041747 -2.338001
# 17      Fish_y -0.041747  2.338001
# 18      Mayo_n  3.754743  0.045329
# 19      Mayo_y -3.754743 -0.045329
# 20     Courg_n -0.213812 -0.477925
# 21     Courg_y  0.213812  0.477925
# 22    Cheese_n  2.682317  0.570384
# 23    Cheese_y -2.682317 -0.570384
# 24  Icecream_n  1.548185  0.825953
# 25  Icecream_y -1.548185 -0.825953, _body=<great_tables._gt_data.Body object at 0x0000019CAA694D60>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA687220>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary variables/categories <br> value-test (vtest)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA694FD0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=Opt ...

# %% [markdown]
# ### Squared correlation ratio

# %%
#supplementary qualitative variables squared correlation ratio (eta2)
print_dt(quali_sup.eta2,rowname="Categories",title=html("<b>Supplementary qualitative variables <br> squared correlation ratio (eta2)</b>"))
# Out:
# GT(_tbl_data=    Categories     Dim.1     Dim.2
# 0         Sick  0.773944  0.000269
# 1          Sex  0.000827  0.002330
# 2       Nausea  0.092262  0.008783
# 3     Vomiting  0.161018  0.009107
# 4   Abdominals  0.735604  0.000040
# 5        Fever  0.640248  0.000330
# 6     Diarrhae  0.587185  0.000707
# 7       Potato  0.015608  0.010561
# 8         Fish  0.000032  0.101227
# 9         Mayo  0.261076  0.000038
# 10   Courgette  0.000847  0.004230
# 11      Cheese  0.133238  0.006025
# 12    Icecream  0.044387  0.012633, _body=<great_tables._gt_data.Body object at 0x0000019CAA695630>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA695720>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary qualitative variables <br> squared correlation ratio (eta2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA6968C0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitl ...

# %% [markdown]
# # Descriptive statistiques

# %%
#descriptive statistics for quantitative variables
print_dt(res_mcaiv.summary_quanti_,rowname="",title=html("<b>Descriptive statistics of quantitative variables</b>"))
# Out:
# GT(_tbl_data=     variable  count       mean        std  min  25%   50%   75%   max
# 0  0      Age     55  16.927273  23.779741  4.0  6.0   8.0  10.0  88.0
# 1  1     Time     55  10.163636   7.800199  0.0  0.0  12.0  16.5  22.0, _body=<great_tables._gt_data.Body object at 0x0000019CAA697280>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable', type=<ColInfoTypeEnum.default: 1>, column_label='variable', column_align='left', column_width=None), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='right', column_width=None), ColInfo(var='mean', type=<ColInfoTypeEnum.default: 1>, column_label='mean', column_align='right', column_width=None), ColInfo(var='std', type=<ColInfoTypeEnum.default: 1>, column_label='std', column_align='right', column_width=None), ColInfo(var='min', type=<ColInfoTypeEnum.default: 1>, column_label='min', column_align='right', column_width=None), ColInfo(var='25%', type=<ColInfoTypeEnum.default: 1>, column_label='25%', column_align='right', column_width=None), ColInfo(var='50%', type=<ColInfoTypeEnum.default: 1>, column_label='50%', column_align='right', column_width=None), ColInfo(var='75%', type=<ColInfoTypeEnum.default: 1>, column_label='75%', column_align='right', column_width=None), ColInfo(var='max', type=<ColInfoTypeEnum.default: 1>, column_label='max', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA695390>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Descriptive statistics of quantitative variables</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA6A7850>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, cate ...

# %%
#summary_quali
print_dt(res_mcaiv.summary_quali_,rowname="",title=html("<b>Descriptive statistics of <br> qualitative variables</b>"))
# Out:
# GT(_tbl_data=          variable   categorie  count  proportion
# 0    0        Sick      Sick_y     38    0.690909
# 1    1        Sick      Sick_n     17    0.309091
# 2    2         Sex           F     28    0.509091
# 3    3         Sex           M     27    0.490909
# 4    4      Nausea    Nausea_n     43    0.781818
# 5    5      Nausea    Nausea_y     12    0.218182
# 6    6    Vomiting     Vomit_n     33    0.600000
# 7    7    Vomiting     Vomit_y     22    0.400000
# 8    8  Abdominals      Abdo_y     37    0.672727
# 9    9  Abdominals      Abdo_n     18    0.327273
# 10  10       Fever     Fever_y     35    0.636364
# 11  11       Fever     Fever_n     20    0.363636
# 12  12    Diarrhae  Diarrhea_y     35    0.636364
# 13  13    Diarrhae  Diarrhea_n     20    0.363636
# 14  14      Potato    Potato_y     52    0.945455
# 15  15      Potato    Potato_n      3    0.054545
# 16  16        Fish      Fish_y     54    0.981818
# 17  17        Fish      Fish_n      1    0.018182
# 18  18        Mayo      Mayo_y     45    0.818182
# 19  19        Mayo      Mayo_n     10    0.181818
# 20  20   Courgette     Courg_y     50    0.909091
# 21  21   Courgette     Courg_n      5    0.090909
# 22  22      Cheese    Cheese_y     48    0.872727
# 23  23      Cheese    Cheese_n      7    0.127273
# 24  24    Icecream  Icecream_y     51    0.927273
# 25  25    Icecream  Icecream_n      4    0.072727, _body=<great_tables._gt_data.Body object at 0x0000019CAA6A5690>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable', type=<ColInfoTypeEnum.default: 1>, column_label='variable', column_align='left', column_width=None), ColInfo(var='categorie', type=<ColInfoTypeEnum.default: 1>, column_label='categorie', column_align='left', column_width=None), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='right', column_width=None), ColInfo(var='proportion', type=<ColInfoTypeEnum.default: 1>, column_label='proportion', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000019CAA6A4610>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Descriptive statistics of <br> qualitative variables</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000019CAA6A53F0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', typ ...

# %% [markdown]
# # Extractions

# %%
#extract functions
from scientisttools import get_eig, get_mcaiv, summaryMCAIV
eig = get_eig(res_mcaiv)
ind, var = get_mcaiv(res_mcaiv,"ind"), get_mcaiv(res_mcaiv,"var")
summaryMCAIV(res_mcaiv)
# Out:
#          Multiple Correspondence Analysis with Instrumental Variables - Results
#
# Eigenvalues
#                        Dim.1    Dim.2
# Variance               0.224    0.012
# Difference             0.212      NaN
# % of var.             94.946    5.054
# Cumulative % of var.  94.946  100.000
#
# Individuals (the 10 first)
#
#     Weight  Sq. Dist.  Inertia  % Inertia  Dim.1    ctr   cos2  Dim.2    ctr  \
# 1    0.018      0.517    0.009      3.982 -0.718  4.182  0.997  0.039  0.230
# 2    0.018      0.405    0.007      3.118  0.634  3.261  0.993  0.053  0.436
# 3    0.018      0.123    0.002      0.950 -0.347  0.979  0.978  0.052  0.407
# 4    0.018      0.398    0.007      3.069  0.630  3.223  0.997  0.035  0.186
# 5    0.018      0.053    0.001      0.410 -0.226  0.414  0.959  0.047  0.332
# 6    0.018      0.066    0.001      0.505  0.020  0.003  0.006 -0.255  9.939
# 7    0.018      0.123    0.002      0.949 -0.346  0.974  0.974  0.056  0.483
# 8    0.018      0.020    0.000      0.157  0.139  0.157  0.951  0.032  0.153
# 9    0.018      0.353    0.006      2.721 -0.591  2.840  0.991  0.057  0.495
# 10   0.018      0.012    0.000      0.094 -0.107  0.093  0.937  0.028  0.118
#
#      cos2
# 1   0.003
# 2   0.007
# 3   0.022
# 4   0.003
# 5   0.041
# 6   0.994
# 7   0.026
# 8   0.049
# 9   0.009
# 10  0.063
#
# Variables (the 10 first)
#
#         Dim.1     ctr   cos2  Dim.2     ctr   cos2
# Dim.1   0.469  98.349  1.000  0.000   0.000  0.000
# Dim.2   0.014   0.088  0.707  0.009   0.684  0.293
# Dim.3   0.017   0.135  0.048  0.078  50.785  0.952
# Dim.4   0.012   0.069  0.048 -0.056  25.874  0.952
# Dim.5  -0.006   0.015  0.880 -0.002   0.039  0.120
# Dim.6   0.024   0.252  0.325 -0.034   9.838  0.675
# Dim.7   0.040   0.731  0.962 -0.008   0.547  0.038
# Dim.8   0.012   0.064  0.993  0.001   0.008  0.007
# Dim.9   0.010   0.047  0.069  0.038  11.884  0.931
# Dim.10 -0.016   0.110  0.994  0.001   0.012  0.006
#
# Supplementary continuous variables
#
#       Dim.1   cos2  Dim.2   cos2
# Age  -0.012  0.000 -1.000  1.000
# Time -0.999  0.998  0.047  0.002
#
# Supplementary categories (the 10 first)
#
#           Sq. Dist.  Dim.1   cos2  vtest  Dim.2   cos2  vtest
# Sick_n        0.387  0.622  1.000  6.465 -0.003  0.000 -0.120
# Sick_y        0.078 -0.278  1.000 -6.465  0.001  0.000  0.120
# F             0.000  0.013  0.870  0.211 -0.005  0.130 -0.355
# M             0.000 -0.014  0.870 -0.211  0.005  0.130  0.355
# Nausea_n      0.006  0.076  0.995  2.232 -0.005  0.005 -0.689
# Nausea_y      0.074 -0.272  0.995 -2.232  0.019  0.005  0.689
# Vomit_n       0.024  0.155  0.997  2.949 -0.009  0.003 -0.701
# Vomit_y       0.054 -0.233  0.997 -2.949  0.013  0.003  0.701
# Abdo_n        0.339  0.582  1.000  6.303 -0.001  0.000 -0.046
# Abdo_y        0.080 -0.283  1.000 -6.303  0.000  0.000  0.046
#
# Supplementary categorical variable (eta2) (the 10 first)
#
#             Dim.1  Dim.2
# Sick        0.774  0.000
# Sex         0.001  0.002
# Nausea      0.092  0.009
# Vomiting    0.161  0.009
# Abdominals  0.736  0.000
# Fever       0.640  0.000
# Diarrhae    0.587  0.001
# Potato      0.016  0.011
# Fish        0.000  0.101
# Mayo        0.261  0.000
