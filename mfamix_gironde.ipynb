# %% [markdown]
# # MFAMIX

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
import pyreadr
gironde = pyreadr.read_r("./data/gironde.rda")["gironde"]
gironde.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 542 entries, ABZAC to MARCHEPRIME
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   farmers     542 non-null    float64
#  1   tradesmen   542 non-null    float64
#  2   managers    542 non-null    float64
#  3   workers     542 non-null    float64
#  4   unemployed  542 non-null    float64
#  5   middleempl  542 non-null    float64
#  6   retired     542 non-null    float64
#  7   employrate  542 non-null    float64
#  8   income      540 non-null    float64
#  9   density     542 non-null    float64
#  10  primaryres  542 non-null    float64
#  11  houses      542 non-null    category
#  12  owners      542 non-null    float64
#  13  council     542 non-null    category
#  14  butcher     542 non-null    category
#  15  baker       542 non-null    category
#  16  postoffice  542 non-null    category
#  17  dentist     542 non-null    category
# ...

# %%
gironde.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 542 entries, ABZAC to MARCHEPRIME
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   farmers     542 non-null    float64
#  1   tradesmen   542 non-null    float64
#  2   managers    542 non-null    float64
#  3   workers     542 non-null    float64
#  4   unemployed  542 non-null    float64
#  5   middleempl  542 non-null    float64
#  6   retired     542 non-null    float64
#  7   employrate  542 non-null    float64
#  8   income      540 non-null    float64
#  9   density     542 non-null    float64
#  10  primaryres  542 non-null    float64
#  11  houses      542 non-null    category
#  12  owners      542 non-null    float64
#  13  council     542 non-null    category
#  14  butcher     542 non-null    category
#  15  baker       542 non-null    category
#  16  postoffice  542 non-null    category
#  17  dentist     542 non-null    category
# ...

# %%
from scientisttools import MFAMIX
name = ["employment","housing","services","environment"] 
res_mfamix = MFAMIX(n_components=None,group=[9,5,9,4],name_group=name,num_group_sup=[2,3],parallelize=False) #
# Instanciation
res_mfamix.fit(gironde)
# Out:
#           eigenvalue  difference  proportion  cumulative
# Dim.1   1.186561e+00    0.068620   20.618878   20.618878
# Dim.2   1.117941e+00    0.404618   19.426460   40.045337
# Dim.3   7.133228e-01    0.231646   12.395411   52.440749
# Dim.4   4.816765e-01    0.048465    8.370093   60.810842
# Dim.5   4.332111e-01    0.068684    7.527910   68.338752
# Dim.6   3.645267e-01    0.084259    6.334381   74.673133
# Dim.7   2.802682e-01    0.007984    4.870220   79.543353
# Dim.8   2.722842e-01    0.026417    4.731483   84.274836
# Dim.9   2.458675e-01    0.045635    4.272440   88.547276
# Dim.10  2.002327e-01    0.022338    3.479444   92.026721
# Dim.11  1.778943e-01    0.017361    3.091269   95.117989
# Dim.12  1.605333e-01    0.040120    2.789587   97.907577
# Dim.13  1.204132e-01    0.120413    2.092421   99.999998
# Dim.14  1.399150e-07         NaN    0.000002  100.000000
# MFAMIX(group=[9, 5, 9, 4], n_components=None,
# ...

# %%
res_mfamix.separate_analyses_.keys()
# Out:
# dict_keys(['employment', 'housing', 'services', 'environment'])

# %%
res_mfamix.separate_analyses_["employment"].eig_
# Out:
#          eigenvalue  difference  proportion  cumulative
# Dim.1  2.383471e+00    0.795168   26.483008   26.483008
# Dim.2  1.588303e+00    0.258358   17.647811   44.130819
# Dim.3  1.329945e+00    0.222002   14.777172   58.907991
# Dim.4  1.107943e+00    0.170811   12.310479   71.218471
# Dim.5  9.371325e-01    0.281422   10.412584   81.631054
# Dim.6  6.557106e-01    0.145193    7.285673   88.916727
# Dim.7  5.105173e-01    0.023540    5.672414   94.589142
# Dim.8  4.869769e-01    0.486977    5.410854   99.999996
# Dim.9  3.386352e-07         NaN    0.000004  100.000000

# %%
res_mfamix.separate_analyses_["housing"].eig_
# Out:
#        eigenvalue  difference  proportion  cumulative
# Dim.1    2.526877    1.457599   50.537541   50.537541
# Dim.2    1.069278    0.438952   21.385553   71.923095
# Dim.3    0.630325    0.207304   12.606505   84.529600
# Dim.4    0.423022    0.072523    8.460432   92.990032
# Dim.5    0.350498         NaN    7.009968  100.000000

# %%
res_mfamix.quanti_var_sup_
# Out:
# {'coord':                Dim.1     Dim.2     Dim.3     Dim.4     Dim.5     Dim.6  \
#  building   -0.685202  0.162036  0.081400  0.091140 -0.029867  0.022225
#  water      -0.173872  0.005402 -0.048064 -0.009178 -0.040112 -0.056090
#  vegetation  0.057982  0.024447  0.009123 -0.283894  0.068289 -0.131126
#  agricul     0.354879 -0.163064 -0.038444  0.262644 -0.029364  0.112464
#
#                 Dim.7     Dim.8     Dim.9    Dim.10    Dim.11    Dim.12  \
#  building    0.252088  0.122278 -0.429148  0.168418  0.069755  0.177361
#  water      -0.093607 -0.013432 -0.067976  0.001520 -0.035138 -0.084535
#  vegetation -0.156786 -0.125566  0.024097 -0.099318 -0.073898  0.094772
#  agricul     0.079348  0.105000  0.118488  0.005552  0.039613 -0.142778
#
#                Dim.13    Dim.14
#  building    0.072938  0.016070
#  water      -0.099635  0.034742
#  vegetation -0.012925 -0.013892
#  agricul    -0.045525 -0.024771  ,
# ...

# %%
res_mfamix.quali_var_sup_
# Out:
# {'coord':                       Dim.1     Dim.2     Dim.3     Dim.4     Dim.5     Dim.6  \
#  butcher_0          0.352155 -0.067534 -0.037833  0.077337  0.035981  0.009991
#  butcher_1         -0.253264  0.074531 -0.123878 -0.113120  0.024480 -0.105925
#  butcher_2 or +    -1.402492  0.236510  0.339535 -0.236125 -0.206242  0.083636
#  baker_0            0.475141 -0.108416  0.009941  0.148695  0.035827  0.021973
#  baker_1           -0.041750 -0.043424 -0.248543 -0.093898  0.064469 -0.081272
#  baker_2 or +      -1.080666  0.301687  0.235127 -0.254075 -0.151852  0.032590
#  postoffice_0       0.429018 -0.102776  0.004160  0.124340  0.050348 -0.006795
#  postoffice_1 or + -0.757349  0.181431 -0.007343 -0.219498 -0.088880  0.011995
#  dentist_0          0.383191 -0.154906 -0.041952  0.087720  0.048052 -0.001748
#  dentist_1 to 2    -0.436290  0.228237 -0.099276 -0.258718 -0.008504 -0.051863
#  dentist_3 or +    -1.477037  0.532260  0.345507 -0.139571 -0.242977  0.074054
# ...
