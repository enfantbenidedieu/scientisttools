# %% [markdown]
# # Specific Multiple Correspondence Analysis (SpecificMCA) - Poison Dataset (predictMCA & supvarMCA)

# %%
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=4):
    dt = (GT(data=data.round(decimals=digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %%
#Specific Multiple Correpondence Analysis (SpecificMCA)
from scientisttools import load_poison, MCA
poison = load_poison()
res_specmca = MCA(excl=(0,2),quanti_sup=(0,1),quali_sup=(13,14))
res_specmca.fit(poison)
# Out:
# MCA(excl=(0, 2), quali_sup=(13, 14), quanti_sup=(0, 1))

# %% [markdown]
# ## `predictMCA`

# %%
from scientisttools import predictMCA
predict = predictMCA(res_specmca,res_specmca.call_.X)
predict._fields
# Out:
# ('coord', 'cos2', 'dist')

# %% [markdown]
# ### Individuals factor coordinates

# %%
#individuals factor coordinates
print_dt(predict.coord,rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=    Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0             1  0.4405  0.2849 -0.1213 -0.1164  0.1436
# 1             2 -0.7334  0.0499 -0.0237 -0.1465 -0.3559
# 2             3  0.4415 -0.2229  0.0539 -0.2257 -0.0226
# 3             4 -0.9740 -0.0321 -0.0686  0.0532  0.3354
# 4             5  0.4446 -0.1873  0.1023 -0.1915 -0.0009
# 5             6  0.3523  0.3785  2.0455  0.6553 -0.0558
# 6             7  0.4415 -0.2229  0.0539 -0.2257 -0.0226
# 7             8  0.6272  0.0006 -0.2198 -0.2148  0.1166
# 8             9  0.4436  0.3205 -0.0729 -0.0822  0.1654
# 9            10  0.1371 -0.2018  0.0631 -0.1912 -0.0790
# 10           11  0.6272  0.0006 -0.2198 -0.2148  0.1166
# 11           12 -0.1402 -0.2192 -0.0690 -0.2510 -0.2829
# 12           13  0.2548  0.0613  0.1523 -0.1273  0.0043
# 13           14 -0.9740 -0.0321 -0.0686  0.0532  0.3354
# 14           15 -0.9709  0.0034 -0.0202  0.0874  0.3572
# 15           16  0.4415 -0.2229  0.0539 -0.2257 -0.0226
# 16           17  0.4446 -0.1873  0.1023 -0.1915 -0.0009
# 17           18  0.6303  0.0362 -0.1714 -0.1806  0.1384
# 18           19  0.4415 -0.2229  0.0539 -0.2257 -0.0226
# 19           20 -0.9740 -0.0321 -0.0686  0.0532  0.3354
# 20           21  0.2579  0.0969  0.2007 -0.0931  0.0261
# 21           22  0.2548  0.0613  0.1523 -0.1273  0.0043
# 22           23  0.5216 -0.7372 -0.1707  0.5883 -0.2543
# 23           24  0.1549 -0.1404  0.0208 -0.1662 -0.1317
# 24           25  0.2548  0.0613  0.1523 -0.1273  0.0043
# 25           26 -0.7303  0.0855  0.0247 -0.1123 -0.3342
# 26           27  0.1494 -0.2662  0.0125 -0.2763 -0.1520
# 27           28  0.2841 -0.7837 -0.1672  0.8222  0.4588
# 28           29 -0.7334  0.0499 -0.0237 -0.1465 -0.3559
# 29           30  0.6272  0.0006 -0.2198 -0.2148  0.1166
# 30           31  0.0142 -0.0207  0.1074  0.0724  0.6957
# 31           32 -0.9709  0.0034 -0.0202  0.0874  0.3572
# 32           33 -0.7334  0.0499 -0.0237 -0.1465 -0.3559
# 33           34 -0.7303  0.0855  0.0247 -0.1123 -0.3342
# 34           35  0.5501  1.1331 -0.4906  0.4498 -0.0543
# 35           36  0.6303  0.0362 -0.1714 -0.1806  0.1384
# 36           37  0.2636  1.2157 -0.5237  0.5093 -0.1634
# 37           38 -0.6532 -0.4644 -0.2483  0.6675 -0.5876
# 38           39  0.3675  0.9451 -0.1686  0.4731 -0.1718
# 39           40  0.6303  0.0362 -0.1714 -0.1806  0.1384
# 40           41  0.4436  0.3205 -0.0729 -0.0822  0.1654
# 41           42 -0.7303  0.0855  0.0247 -0.1123 -0.3342
# 42           43  0.2548  0.0613  0.1523 -0.1273  0.0043
# 43           44  0.7074 -0.5137 -0.4444  0.5992 -0.1151
# 44           45  0.5247 -0.7016 -0.1223  0.6225 -0.2325
# 45           46  0.2579  0.0969  0.2007 -0.0931  0.0261
# 46           47 -0.9709  0.0034 -0.0202  0.0874  0.3572
# 47           48 -0.7303  0.0855  0.0247 -0.1123 -0.3342
# 48           49 -0.7334  0.0499 -0.0237 -0.1465 -0.3559
# 49           50  0.2548  0.0613  0.1523 -0.1273  0.0043
# 50           51 -0.9709  0.0034 -0.0202  0.0874  0.3572
# 51           52  0.2579  0.0969  0.2007 -0.0931  0.0261
# 52           53 -0.9740 -0.0321 -0.0686  0.0532  0.3354
# 53           54  0.1525 -0.2306  0.0609 -0.2421 -0.1303
# 54           55  0.4446 -0.1873  0.1023 -0.1915 -0.0009, _body=<great_tables._gt_data.Body object at 0x000001DF6D5F5360>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF48C0A170>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D5F4070>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category=' ...

# %% [markdown]
# ### Individuals square cosinus

# %%
#individuals square cosinus
print_dt(predict.cos2,rowname="Individuals",title=html("<b>Individuals Cos2</b>"))
# Out:
# GT(_tbl_data=    Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0             1  0.3091  0.1293  0.0234  0.0216  0.0328
# 1             2  0.7320  0.0034  0.0008  0.0292  0.1725
# 2             3  0.4833  0.1232  0.0072  0.1263  0.0013
# 3             4  0.8443  0.0009  0.0042  0.0025  0.1001
# 4             5  0.4860  0.0863  0.0257  0.0902  0.0000
# 5             6  0.0237  0.0273  0.7988  0.0820  0.0006
# 6             7  0.4833  0.1232  0.0072  0.1263  0.0013
# 7             8  0.5591  0.0000  0.0686  0.0656  0.0193
# 8             9  0.3118  0.1627  0.0084  0.0107  0.0433
# 9            10  0.0342  0.0741  0.0072  0.0665  0.0114
# 10           11  0.5591  0.0000  0.0686  0.0656  0.0193
# 11           12  0.0318  0.0778  0.0077  0.1020  0.1296
# 12           13  0.1982  0.0115  0.0708  0.0495  0.0001
# 13           14  0.8443  0.0009  0.0042  0.0025  0.1001
# 14           15  0.8364  0.0000  0.0004  0.0068  0.1132
# 15           16  0.4833  0.1232  0.0072  0.1263  0.0013
# 16           17  0.4860  0.0863  0.0257  0.0902  0.0000
# 17           18  0.5619  0.0019  0.0415  0.0461  0.0271
# 18           19  0.4833  0.1232  0.0072  0.1263  0.0013
# 19           20  0.8443  0.0009  0.0042  0.0025  0.1001
# 20           21  0.2010  0.0284  0.1217  0.0262  0.0021
# 21           22  0.1982  0.0115  0.0708  0.0495  0.0001
# 22           23  0.2088  0.4170  0.0224  0.2655  0.0496
# 23           24  0.0467  0.0384  0.0008  0.0538  0.0338
# 24           25  0.1982  0.0115  0.0708  0.0495  0.0001
# 25           26  0.7225  0.0099  0.0008  0.0171  0.1513
# 26           27  0.0437  0.1388  0.0003  0.1496  0.0453
# 27           28  0.0476  0.3622  0.0165  0.3987  0.1242
# 28           29  0.7320  0.0034  0.0008  0.0292  0.1725
# 29           30  0.5591  0.0000  0.0686  0.0656  0.0193
# 30           31  0.0003  0.0006  0.0161  0.0073  0.6756
# 31           32  0.8364  0.0000  0.0004  0.0068  0.1132
# 32           33  0.7320  0.0034  0.0008  0.0292  0.1725
# 33           34  0.7225  0.0099  0.0008  0.0171  0.1513
# 34           35  0.1377  0.5840  0.1095  0.0920  0.0013
# 35           36  0.5619  0.0019  0.0415  0.0461  0.0271
# 36           37  0.0301  0.6401  0.1188  0.1124  0.0116
# 37           38  0.2610  0.1319  0.0377  0.2726  0.2112
# 38           39  0.0710  0.4698  0.0149  0.1177  0.0155
# 39           40  0.5619  0.0019  0.0415  0.0461  0.0271
# 40           41  0.3118  0.1627  0.0084  0.0107  0.0433
# 41           42  0.7225  0.0099  0.0008  0.0171  0.1513
# 42           43  0.1982  0.0115  0.0708  0.0495  0.0001
# 43           44  0.3120  0.1645  0.1231  0.2239  0.0083
# 44           45  0.2107  0.3767  0.0115  0.2965  0.0414
# 45           46  0.2010  0.0284  0.1217  0.0262  0.0021
# 46           47  0.8364  0.0000  0.0004  0.0068  0.1132
# 47           48  0.7225  0.0099  0.0008  0.0171  0.1513
# 48           49  0.7320  0.0034  0.0008  0.0292  0.1725
# 49           50  0.1982  0.0115  0.0708  0.0495  0.0001
# 50           51  0.8364  0.0000  0.0004  0.0068  0.1132
# 51           52  0.2010  0.0284  0.1217  0.0262  0.0021
# 52           53  0.8443  0.0009  0.0042  0.0025  0.1001
# 53           54  0.0453  0.1035  0.0072  0.1141  0.0330
# 54           55  0.4860  0.0863  0.0257  0.0902  0.0000, _body=<great_tables._gt_data.Body object at 0x000001DF6D6AC580>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF6D4D1CC0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals Cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6AD1E0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading ...

# %% [markdown]
# ### Individuals square distance to origin

# %%
#individuals square distance to origin
print_dt(predict.dist,rowname="Individuals",title=html("<b>Individuals dist2</b>"))
# Out:
# GT(_tbl_data=    Individuals  Sq. Dist.
# 0             1     0.6279
# 1             2     0.7347
# 2             3     0.4033
# 3             4     1.1236
# 4             5     0.4066
# 5             6     5.2383
# 6             7     0.4033
# 7             8     0.7037
# 8             9     0.6313
# 9            10     0.5493
# 10           11     0.7037
# 11           12     0.6176
# 12           13     0.3275
# 13           14     1.1236
# 14           15     1.1269
# 15           16     0.4033
# 16           17     0.4066
# 17           18     0.7070
# 18           19     0.4033
# 19           20     1.1236
# 20           21     0.3309
# 21           22     0.3275
# 22           23     1.3033
# 23           24     0.5138
# 24           25     0.3275
# 25           26     0.7381
# 26           27     0.5104
# 27           28     1.6955
# 28           29     0.7347
# 29           30     0.7037
# 30           31     0.7164
# 31           32     1.1269
# 32           33     0.7347
# 33           34     0.7381
# 34           35     2.1984
# 35           36     0.7070
# 36           37     2.3089
# 37           38     1.6347
# 38           39     1.9014
# 39           40     0.7070
# 40           41     0.6313
# 41           42     0.7381
# 42           43     0.3275
# 43           44     1.6037
# 44           45     1.3066
# 45           46     0.3309
# 46           47     1.1269
# 47           48     0.7381
# 48           49     0.7347
# 49           50     0.3275
# 50           51     1.1269
# 51           52     0.3309
# 52           53     1.1236
# 53           54     0.5138
# 54           55     0.4066, _body=<great_tables._gt_data.Body object at 0x000001DF6D6AEA10>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF48BE78E0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals dist2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6AE9B0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value=' ...

# %% [markdown]
# ## `supvarMCA`

# %%
from scientisttools import supvarMCA
X_quanti_sup, X_quali_sup = poison.iloc[:,[0,1]], poison.iloc[:,13:]
sup_var = supvarMCA(res_specmca,X_quanti_sup=X_quanti_sup,X_quali_sup=X_quali_sup)
sup_var._fields
# Out:
# ('quanti', 'quali')

# %% [markdown]
# ### Supplementary qualitative variables

# %%
#supplementary qualitative variables
quali_sup = sup_var.quali
quali_sup._fields
# Out:
# ('coord', 'cos2', 'vtest', 'dist', 'eta2')

# %% [markdown]
# #### Supplementary categories factor coordinates

# %%
#supplementary categories factor coordinates
print_dt(quali_sup.coord,rowname="Categories",title=html("<b>Variables/Categories coordinates</b>"))
# Out:
# GT(_tbl_data=   Categories   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Cheese_n -0.8757 -0.2291 -0.0563  0.2159  0.0624
# 1    Cheese_y  0.1277  0.0334  0.0082 -0.0315 -0.0091
# 2  Icecream_n -0.4180 -0.3409 -0.2971  0.5378  0.5792
# 3  Icecream_y  0.0328  0.0267  0.0233 -0.0422 -0.0454, _body=<great_tables._gt_data.Body object at 0x000001DF6D6EBA30>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF6D6AFB20>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/Categories coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6EA260>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, catego ...

# %% [markdown]
# #### Supplementary categories value-test

# %%
#supplementary categories value-test
print_dt(quali_sup.vtest,rowname="Categories",title=html("<b>Variables/Categories vtest</b>"))
# Out:
# GT(_tbl_data=   Categories   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Cheese_n -2.4574 -0.6429 -0.1580  0.6058  0.1752
# 1    Cheese_y  2.4574  0.6429  0.1580 -0.6058 -0.1752
# 2  Icecream_n -0.8602 -0.7015 -0.6114  1.1068  1.1920
# 3  Icecream_y  0.8602  0.7015  0.6114 -1.1068 -1.1920, _body=<great_tables._gt_data.Body object at 0x000001DF6D6EAE60>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF6D6EA6E0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/Categories vtest</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6D8E50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='he ...

# %% [markdown]
# #### Supplementary qualitative variables square correlation ratio

# %%
#supplementary qualitative variables square correlation ratio
print_dt(quali_sup.eta2,rowname="Variables",title=html("<b>Variables eta2</b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Cheese  0.1118  0.0077  0.0005  0.0068  0.0006
# 1  Icecream  0.0137  0.0091  0.0069  0.0227  0.0263, _body=<great_tables._gt_data.Body object at 0x000001DF6D6D8FA0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF6D6D80D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables eta2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6DABF0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='va ...

# %% [markdown]
# #### Supplementary categories square distance to origin

# %%
#supplementary categories square distance to origin
print_dt(quali_sup.dist,rowname="Categories",title=html("<b>Variables/Categories dist2</b>"))
# Out:
# GT(_tbl_data=   Categories  Sq. Dist.
# 0    Cheese_n     6.8571
# 1    Cheese_y     0.1458
# 2  Icecream_n    12.7500
# 3  Icecream_y     0.0784, _body=<great_tables._gt_data.Body object at 0x000001DF6D6D8BE0>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF6D6D9ED0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/Categories dist2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6DA590>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', val ...

# %% [markdown]
# #### Supplementary categories square cosinus

# %%
#supplementary categories square cosinus
print_dt(quali_sup.cos2,rowname="Categories",title=html("<b>Variables/Categories Cos<sup>2</sup></b>"))
# Out:
# GT(_tbl_data=   Categories   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Cheese_n  0.1118  0.0077  0.0005  0.0068  0.0006
# 1    Cheese_y  0.1118  0.0077  0.0005  0.0068  0.0006
# 2  Icecream_n  0.0137  0.0091  0.0069  0.0227  0.0263
# 3  Icecream_y  0.0137  0.0091  0.0069  0.0227  0.0263, _body=<great_tables._gt_data.Body object at 0x000001DF6D6DB280>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF6D6DB5E0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/Categories Cos<sup>2</sup></b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6DBFA0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, ca ...

# %% [markdown]
# ### Supplementary quantitative variables

# %%
#supplementary quantitative variables
quanti_sup = sup_var.quanti
quanti_sup._fields
# Out:
# ('coord', 'cos2')

# %% [markdown]
# #### Supplementary quantitative variables factor coordinates

# %%
#supplementary quantitative variables factor coordinates
print_dt(quanti_sup.coord,rowname="Variables",title=html("<b>Quantitative variables coordinates</b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       Age -0.0029 -0.0375  0.3062  0.1293 -0.0279
# 1      Time  0.8407  0.0368  0.0174 -0.1047  0.0297, _body=<great_tables._gt_data.Body object at 0x000001DF6D6F8430>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF6D6F8D00>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Quantitative variables coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6F9BA0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category ...

# %% [markdown]
# #### Supplementary quantitative variables square cosinus

# %%
#supplementary quantitative variables square cosinus
print_dt(quanti_sup.cos2,rowname="Variables",title=html("<b>Quantitative variables Cos<sup>2</sup></b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       Age  0.0000  0.0014  0.0938  0.0167  0.0008
# 1      Time  0.7068  0.0014  0.0003  0.0110  0.0009, _body=<great_tables._gt_data.Body object at 0x000001DF6D6F94B0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001DF6D6F99C0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Quantitative variables Cos<sup>2</sup></b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001DF6D6FA950>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, cate ...
