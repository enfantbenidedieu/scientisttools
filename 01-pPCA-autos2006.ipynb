# %% [markdown]
# # pPCA - `autos2006` dataset

# %%
#disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=4):
    dt = (GT(data=data.round(digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %% [markdown]
# ## `autos2006` dataset

# %%
#autos2006 dataset
from scientisttools.datasets import autos2006
(
    GT(autos2006.rename_axis("Individuals").reset_index())
    .tab_header(title=html("<b>Autos2006 Dataset</b>"))
    .tab_spanner(label=html("<b>Individuals</b>"),columns="Individuals")
    .tab_spanner(label=html("<b>Active<br>variables</b>"),columns=autos2006.columns.tolist()[:6])
    .tab_spanner(label=html("<b>Supplementary<br>variables (quanti. & quali.)</b>"),columns=autos2006.columns.tolist()[6:])
)
# Out:
# GT(_tbl_data=        Individuals   CYL  PUISS  LONG  LARG  POIDS  VMAX     PRIX  RPOIDPUIS  \
# 0        Alfasud TI  1350     79   393   161    870   165  30570.0  11.012658
# 1          Audi 100  1588     85   468   177   1110   160  39990.0  13.058824
# 2        Simca 1300  1294     68   424   168   1050   152  29600.0  15.441176
# 3   Citroen GS Club  1222     59   412   161    930   151  28250.0  15.762712
# 4          Fiat 132  1585     98   439   164   1105   165  34900.0  11.275510
# 5       Lancia Beta  1297     82   429   169   1080   160  35480.0  13.170732
# 6       Peugeot 504  1796     79   449   169   1160   154  32300.0  14.683544
# 7     Renault 16 TL  1565     55   424   163   1010   140  32000.0  18.363636
# 8        Renault 30  2664    128   452   173   1320   180  47700.0  10.312500
# 9    Toyota Corolla  1166     55   399   157    815   140  26540.0  14.818182
# 10     Alfetta 1.66  1570    109   428   162   1060   175  42395.0   9.724771
# 11    Princess 1800  1798     82   445   172   1160   158  33990.0  14.146341
# 12      Datsun 200L  1998    115   469   169   1370   160  43980.0  11.913043
# 13      Taunus 2000  1993     98   438   170   1080   167  35010.0  11.020408
# 14           Rancho  1442     80   431   166   1129   144  39450.0  14.112500
# 15       Mazda 9295  1769     83   440   165   1095   165  27900.0  13.192771
# 16      Opel Rekord  1979    100   459   173   1120   173  32700.0  11.200000
# 17        Lada 1300  1294     68   404   161    955   140  22100.0  14.044118
# 18      Peugeot 604  2664    136   472   177   1410   180      NaN        NaN
# 19    Peugeot 304 S  1288     74   414   157    915   160      NaN        NaN
#
#    FINITION
# 0       2_B
# 1      3_TB
# 2       1_M
# 3       1_M
# 4       2_B
# 5      3_TB
# 6       2_B
# 7       2_B
# 8      3_TB
# 9       1_M
# 10     3_TB
# 11      2_B
# 12     3_TB
# 13      2_B
# 14     3_TB
# 15      1_M
# 16      2_B
# 17      1_M
# 18      NaN
# 19      NaN  , _body=<great_tables._gt_data.Body object at 0x0000023B733583D0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='CYL', type=<ColInfoTypeEnum.default: 1>, column_label='CYL', column_align='right', column_width=None), ColInfo(var='PUISS', type=<ColInfoTypeEnum.default: 1>, column_label='PUISS', column_align='right', column_width=None), ColInfo(var='LONG', type=<ColInfoTypeEnum.default: 1>, column_label='LONG', column_align='right', column_width=None), ColInfo(var='LARG', type=<ColInfoTypeEnum.default: 1>, column_label='LARG', column_align='right', column_width=None), ColInfo(var='POIDS', type=<ColInfoTypeEnum.default: 1>, column_label='POIDS', column_align='right', column_width=None), ColInfo(var='VMAX', type=<ColInfoTypeEnum.default: 1>, column_label='VMAX', column_align='right', column_width=None), ColInfo(var='PRIX', type=<ColInfoTypeEnum.default: 1>, column_label='PRIX', column_align='right', column_width=None), ColInfo(var='RPOIDPUIS', type=<ColInfoTypeEnum.default: 1>, column_label='RPOIDPUIS', column_align='right', column_width=None), ColInfo(var='FINITION', type=<ColInfoTypeEnum.default: 1>, column_label='FINITION', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B7326FA30>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Autos2006 Dataset</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B7335BAC0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_ ...

# %% [markdown]
# ## Instanciation & training

# %%
#instanciation
from scientisttools import pPCA
res_ppca = pPCA(partial=0,ind_sup=(18,19),sup_var=(6,7,8))

# %% [markdown]
# ### `fit` function

# %%
#fit function
res_ppca.fit(autos2006)
# Out:
# pPCA(ind_sup=(18, 19), partial=0, sup_var=(6, 7, 8))

# %% [markdown]
# ### `fit_transform` function

# %%
#fit_transform function
print_dt(res_ppca.fit_transform(autos2006).head(10),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       Alfasud TI -1.9211  2.1585  0.6605  0.4532  0.1032
# 1         Audi 100  3.1165 -0.8159  1.5813 -0.2042 -0.5144
# 2       Simca 1300  1.1324 -0.4388  0.3032  0.5368  0.3956
# 3  Citroen GS Club -0.7977 -0.0642  0.1806 -0.2948  0.4163
# 4         Fiat 132  0.8026  1.3731 -0.6796 -0.4688 -0.0414
# 5      Lancia Beta  2.1350  0.7518  0.2324  0.5767  0.2893
# 6      Peugeot 504  0.1850 -1.5190 -0.0502 -0.2498  0.2312
# 7    Renault 16 TL -1.9647 -2.4016 -0.1494 -0.3218  0.1621
# 8       Renault 30 -1.7094  0.4710 -0.1528  0.6158  0.0750
# 9   Toyota Corolla -2.5039 -0.4167 -0.1053 -0.3852 -0.4968, _body=<great_tables._gt_data.Body object at 0x0000023B7345D510>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B732826E0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734AC190>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category ...

# %% [markdown]
# ### `transform` function

# %%
#transform function
print_dt(res_ppca.transform(res_ppca.call_.X).head(10),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       Alfasud TI -1.9211  2.1585  0.6605  0.4532  0.1032
# 1         Audi 100  3.1165 -0.8159  1.5813 -0.2042 -0.5144
# 2       Simca 1300  1.1324 -0.4388  0.3032  0.5368  0.3956
# 3  Citroen GS Club -0.7977 -0.0642  0.1806 -0.2948  0.4163
# 4         Fiat 132  0.8026  1.3731 -0.6796 -0.4688 -0.0414
# 5      Lancia Beta  2.1350  0.7518  0.2324  0.5767  0.2893
# 6      Peugeot 504  0.1850 -1.5190 -0.0502 -0.2498  0.2312
# 7    Renault 16 TL -1.9647 -2.4016 -0.1494 -0.3218  0.1621
# 8       Renault 30 -1.7094  0.4710 -0.1528  0.6158  0.0750
# 9   Toyota Corolla -2.5039 -0.4167 -0.1053 -0.3852 -0.4968, _body=<great_tables._gt_data.Body object at 0x0000023B734AE650>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B72D88100>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734AF3A0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category ...

# %% [markdown]
# ## Eigen values

# %%
#eigen values
from scientisttools import get_eig
print_dt(get_eig(res_ppca),rowname="Dimensions",title=html("<b>Eigen values</b>"))
# Out:
# GT(_tbl_data=  Dimensions  Eigenvalue  Difference  Proportion  Cumulative
# 0      Dim.1      2.4011      0.7879     48.0212     48.0212
# 1      Dim.2      1.6132      0.9145     32.2634     80.2846
# 2      Dim.3      0.6987      0.5152     13.9737     94.2583
# 3      Dim.4      0.1835      0.0799      3.6699     97.9282
# 4      Dim.5      0.1036         NaN      2.0718    100.0000, _body=<great_tables._gt_data.Body object at 0x0000023B734F2E00>, _boxhead=Boxhead([ColInfo(var='Dimensions', type=<ColInfoTypeEnum.default: 1>, column_label='Dimensions', column_align='left', column_width=None), ColInfo(var='Eigenvalue', type=<ColInfoTypeEnum.default: 1>, column_label='Eigenvalue', column_align='right', column_width=None), ColInfo(var='Difference', type=<ColInfoTypeEnum.default: 1>, column_label='Difference', column_align='right', column_width=None), ColInfo(var='Proportion', type=<ColInfoTypeEnum.default: 1>, column_label='Proportion', column_align='right', column_width=None), ColInfo(var='Cumulative', type=<ColInfoTypeEnum.default: 1>, column_label='Cumulative', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B7345D690>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Eigen values</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734F0520>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='headi ...

# %% [markdown]
# ## Individuals

# %%
#individuals informations
from scientisttools import get_ppca
ind = get_ppca(res_ppca,"ind")
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
#individuals coordinates
print_dt(ind.coord.head(10),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       Alfasud TI -1.9211  2.1585  0.6605  0.4532  0.1032
# 1         Audi 100  3.1165 -0.8159  1.5813 -0.2042 -0.5144
# 2       Simca 1300  1.1324 -0.4388  0.3032  0.5368  0.3956
# 3  Citroen GS Club -0.7977 -0.0642  0.1806 -0.2948  0.4163
# 4         Fiat 132  0.8026  1.3731 -0.6796 -0.4688 -0.0414
# 5      Lancia Beta  2.1350  0.7518  0.2324  0.5767  0.2893
# 6      Peugeot 504  0.1850 -1.5190 -0.0502 -0.2498  0.2312
# 7    Renault 16 TL -1.9647 -2.4016 -0.1494 -0.3218  0.1621
# 8       Renault 30 -1.7094  0.4710 -0.1528  0.6158  0.0750
# 9   Toyota Corolla -2.5039 -0.4167 -0.1053 -0.3852 -0.4968, _body=<great_tables._gt_data.Body object at 0x0000023B734D7340>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B734F34C0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734D4280>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category ...

# %% [markdown]
# ### Individuals contributions

# %%
#individuals contributions
print_dt(ind.contrib.head(10),rowname="Individuals",title=html("<b>Individuals contributions</b>"))
# Out:
# GT(_tbl_data=       Individuals    Dim.1    Dim.2    Dim.3    Dim.4    Dim.5
# 0       Alfasud TI   8.5390  16.0454   3.4690   6.2189   0.5713
# 1         Audi 100  22.4733   2.2925  19.8832   1.2624  14.1898
# 2       Simca 1300   2.9672   0.6631   0.7312   8.7240   8.3949
# 3  Citroen GS Club   1.4725   0.0142   0.2593   2.6309   9.2958
# 4         Fiat 132   1.4904   6.4935   3.6729   6.6540   0.0919
# 5      Lancia Beta  10.5472   1.9465   0.4294  10.0678   4.4878
# 6      Peugeot 504   0.0792   7.9458   0.0200   1.8891   2.8669
# 7    Renault 16 TL   8.9313  19.8630   0.1775   3.1355   1.4096
# 8       Renault 30   6.7610   0.7639   0.1857  11.4821   0.3017
# 9   Toyota Corolla  14.5059   0.5980   0.0881   4.4935  13.2345, _body=<great_tables._gt_data.Body object at 0x0000023B734F8310>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B734F9810>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734F8070>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, c ...

# %% [markdown]
# ### Individuals cos2

# %%
#individuals cos2
print_dt(ind.cos2.head(10),rowname="Individuals",title=html("<b>Individuals cos2</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       Alfasud TI  0.4100  0.5176  0.0485  0.0228  0.0012
# 1         Audi 100  0.7366  0.0505  0.1896  0.0032  0.0201
# 2       Simca 1300  0.6375  0.0957  0.0457  0.1432  0.0778
# 3  Citroen GS Club  0.6818  0.0044  0.0349  0.0931  0.1857
# 4         Fiat 132  0.2005  0.5868  0.1438  0.0684  0.0005
# 5      Lancia Beta  0.8149  0.1010  0.0097  0.0594  0.0150
# 6      Peugeot 504  0.0139  0.9380  0.0010  0.0254  0.0217
# 7    Renault 16 TL  0.3947  0.5897  0.0023  0.0106  0.0027
# 8       Renault 30  0.8226  0.0624  0.0066  0.1068  0.0016
# 9   Toyota Corolla  0.9153  0.0254  0.0016  0.0217  0.0360, _body=<great_tables._gt_data.Body object at 0x0000023B734F9210>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B734D57B0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734FB7C0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='headi ...

# %% [markdown]
# ### Additionals informations

# %%
#individuals additionals informations (weight,squared distance to origin, inertia)
print_dt(ind.infos.head(10),rowname="Individuals",title=html("<b>Individuals additionals informations</b>"))
# Out:
# GT(_tbl_data=       Individuals  Weight  Sq. Dist.  Inertia  % Inertia
# 0       Alfasud TI  0.0556     9.0019   0.5001    10.0021
# 1         Audi 100  0.0556    13.1853   0.7325    14.6503
# 2       Simca 1300  0.0556     2.0116   0.1118     2.2351
# 3  Citroen GS Club  0.0556     0.9334   0.0519     1.0371
# 4         Fiat 132  0.0556     3.2130   0.1785     3.5700
# 5      Lancia Beta  0.0556     5.5938   0.3108     6.2154
# 6      Peugeot 504  0.0556     2.4598   0.1367     2.7331
# 7    Renault 16 TL  0.0556     9.7798   0.5433    10.8665
# 8       Renault 30  0.0556     3.5521   0.1973     3.9467
# 9   Toyota Corolla  0.0556     6.8492   0.3805     7.6103, _body=<great_tables._gt_data.Body object at 0x0000023B734B04C0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Weight', type=<ColInfoTypeEnum.default: 1>, column_label='Weight', column_align='right', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None), ColInfo(var='Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='Inertia', column_align='right', column_width=None), ColInfo(var='% Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='% Inertia', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B6005F3D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals additionals informations</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734B0DC0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category=' ...

# %% [markdown]
# ## Variables

# %%
#variables informations
var = get_ppca(res_ppca,"var")
var._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Variables coordinates

# %%
#variables coordinates
print_dt(var.coord,rowname="Variables",title=html("<b>Variables coordinates</b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0     PUISS  0.4854  0.7998 -0.2859  0.0781 -0.1918
# 1      LONG  0.9028 -0.2672  0.0684 -0.3239 -0.0626
# 2      LARG  0.7773 -0.2713  0.5141  0.2357 -0.0472
# 3     POIDS  0.8285 -0.1855 -0.4874  0.1075  0.1732
# 4      VMAX  0.2442  0.8911  0.3322 -0.0731  0.1751, _body=<great_tables._gt_data.Body object at 0x0000023B734B1330>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B734F3160>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734B1E10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', t ...

# %% [markdown]
# ### Variables contributions

# %%
#variables contributions
print_dt(var.contrib,rowname="Variables",title=html("<b>Variables contributions</b>"))
# Out:
# GT(_tbl_data=  Variables    Dim.1    Dim.2    Dim.3    Dim.4    Dim.5
# 0     PUISS   9.8133  39.6580  11.6999   3.3253  35.5035
# 1      LONG  33.9467   4.4264   0.6705  57.1748   3.7815
# 2      LARG  25.1661   4.5634  37.8324  30.2859   2.1522
# 3     POIDS  28.5895   2.1340  33.9985   6.3037  28.9743
# 4      VMAX   2.4845  49.2181  15.7986   2.9103  29.5885, _body=<great_tables._gt_data.Body object at 0x0000023B734D5780>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B734FB340>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B734B2740>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='head ...

# %% [markdown]
# ### Variables cos2

# %%
#variables cos2
print_dt(var.cos2,rowname="Variables",title=html("<b>Variables cos2</b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0     PUISS  0.2356  0.6398  0.0817  0.0061  0.0368
# 1      LONG  0.8151  0.0714  0.0047  0.1049  0.0039
# 2      LARG  0.6043  0.0736  0.2643  0.0556  0.0022
# 3     POIDS  0.6865  0.0344  0.2375  0.0116  0.0300
# 4      VMAX  0.0597  0.7940  0.1104  0.0053  0.0307, _body=<great_tables._gt_data.Body object at 0x0000023B734B3400>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B734B32B0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B735002B0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='va ...

# %% [markdown]
# ### Variables additionals informations

# %%
#variables additionals informations
print_dt(var.infos,rowname="Variables",title=html("<b>Variables additionals informations</b>"))
# Out:
# GT(_tbl_data=  Variables  Weight  Sq. Dist.  Inertia  % Inertia
# 0     PUISS     1.0        1.0      1.0       20.0
# 1      LONG     1.0        1.0      1.0       20.0
# 2      LARG     1.0        1.0      1.0       20.0
# 3     POIDS     1.0        1.0      1.0       20.0
# 4      VMAX     1.0        1.0      1.0       20.0, _body=<great_tables._gt_data.Body object at 0x0000023B735006D0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Weight', type=<ColInfoTypeEnum.default: 1>, column_label='Weight', column_align='right', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None), ColInfo(var='Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='Inertia', column_align='right', column_width=None), ColInfo(var='% Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='% Inertia', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73500BB0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables additionals informations</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B735021D0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', typ ...

# %% [markdown]
# ## Supplementary individuals

# %%
#supplementary individuals informations
ind_sup = res_ppca.ind_sup_
ind_sup._fields
# Out:
# ('coord', 'cos2', 'dist2')

# %% [markdown]
# ### Supplementary individuals coordinates

# %%
#supplementary individuals coordinates
print_dt(ind_sup.coord,rowname="Individuals",title=html("<b>Supplementary individuals coordinates</b>"))
# Out:
# GT(_tbl_data=     Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Peugeot 604  0.3496  0.2433 -0.3028  0.5751 -0.1312
# 1  Peugeot 304 S -1.1696  1.4928 -0.2894 -0.9546  0.2329, _body=<great_tables._gt_data.Body object at 0x0000023B73502380>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73500EE0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B73502650>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=Tr ...

# %% [markdown]
# ### Supplementary individuals cos2

# %%
#supplementary individuals cos2
print_dt(ind_sup.cos2,rowname="Individuals",title=html("<b>Supplementary individuals cos2/b>"))
# Out:
# GT(_tbl_data=     Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Peugeot 604  0.1968  0.0953  0.1476  0.5326  0.0277
# 1  Peugeot 304 S  0.2945  0.4797  0.0180  0.1961  0.0117, _body=<great_tables._gt_data.Body object at 0x0000023B73502CB0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73503AC0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary individuals cos2/b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B7350C100>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, cate ...

# %% [markdown]
# ### Supplementary individuals dist2

# %%
#supplementary individuals dist2
print_dt(ind_sup.dist2,rowname="Individuals",title=html("<b>Supplementary <br>individuals <br> dist2</b>"))
# Out:
# GT(_tbl_data=     Individuals  Sq. Dist.
# 0    Peugeot 604     0.6211
# 1  Peugeot 304 S     4.6454, _body=<great_tables._gt_data.Body object at 0x0000023B7350CE50>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B7350C9A0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary <br>individuals <br> dist2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B7350C580>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading' ...

# %% [markdown]
# ## Supplementary quantitative variables

# %%
#supplementary quantitative variables informations
quanti_sup = res_ppca.quanti_sup_
quanti_sup._fields
# Out:
# ('coord', 'cos2')

# %% [markdown]
# ### Supplementary quantitative variables coordinates

# %%
#supplementary quantitative variables coordinates
print_dt(quanti_sup.coord,rowname="Variables",title=html("<b>Supplementary quantitative variables coordinates</b>"))
# Out:
# GT(_tbl_data=   Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       PRIX  0.5484  0.2996 -0.2803  0.1461 -0.1355
# 1  RPOIDPUIS -0.1700 -0.9099 -0.0214 -0.0605  0.2981, _body=<great_tables._gt_data.Body object at 0x0000023B7350D2D0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B7350D180>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary quantitative variables coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B7350E290>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss ...

# %% [markdown]
# ### Supplementary quantitative variables cos2

# %%
#supplementary quantitative variables cos2
print_dt(quanti_sup.cos2,rowname="Variables",title=html("<b>Supplementary quantitative variables cos2</b>"))
# Out:
# GT(_tbl_data=   Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       PRIX  0.0060  0.0018  0.0016  0.0004  0.0004
# 1  RPOIDPUIS  0.0006  0.0166  0.0000  0.0001  0.0018, _body=<great_tables._gt_data.Body object at 0x0000023B7350E680>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B734B22F0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary quantitative variables cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B7350F820>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True,  ...

# %% [markdown]
# ## Supplementary qualitative variables

# %%
#supplementary qualitative variables informations
quali_sup = res_ppca.quali_sup_
quali_sup._fields
# Out:
# ('coord', 'cos2', 'vtest', 'eta2', 'dist2')

# %% [markdown]
# ### Supplementary levels coordinates

# %%
#supplementary leveks coordinates
print_dt(quali_sup.coord,rowname="Levels",title=html("<b>Supplementary levels coordinates</b>"))
# Out:
# GT(_tbl_data=  Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    1_M -0.8250 -0.2821 -0.0497 -0.0672  0.0809
# 1    2_B -0.4117 -0.1275  0.3373 -0.0744  0.0182
# 2   3_TB  1.1678  0.3839 -0.3521  0.1428 -0.0887, _body=<great_tables._gt_data.Body object at 0x0000023B735243A0>, _boxhead=Boxhead([ColInfo(var='Levels', type=<ColInfoTypeEnum.default: 1>, column_label='Levels', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B7350F730>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary levels coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B73524E20>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', ...

# %% [markdown]
# ### Supplementary levels vtest

# %%
#supplementary levels vtest
print_dt(quali_sup.vtest,rowname="Levels",title=html("<b>Supplementary levels vtest</b>"))
# Out:
# GT(_tbl_data=  Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    1_M -1.3615 -0.5680 -0.1521 -0.4009  0.6430
# 1    2_B -0.8738 -0.3302  1.3274 -0.5714  0.1864
# 2   3_TB  2.1972  0.8811 -1.2281  0.9718 -0.8037, _body=<great_tables._gt_data.Body object at 0x0000023B73525540>, _boxhead=Boxhead([ColInfo(var='Levels', type=<ColInfoTypeEnum.default: 1>, column_label='Levels', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73525750>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary levels vtest</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B73526590>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type= ...

# %% [markdown]
# ### Supplementary qualitative variables eta2

# %%
#supplementary qualitative variables eta2
print_dt(quali_sup.eta2,rowname="Variables",title=html("<b>Supplementary qualitative variables eta2</b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0  FINITION  0.2955  0.0481  0.1235  0.0556  0.0441, _body=<great_tables._gt_data.Body object at 0x0000023B735264A0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73526DA0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary qualitative variables eta2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B73527C10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, ca ...

# %% [markdown]
# ### Supplementary levels cos2

# %%
#supplementary levels cos2
print_dt(quali_sup.cos2,rowname="Levels",title=html("<b>Supplementary levels cos2</b>"))
# Out:
# GT(_tbl_data=  Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    1_M  0.8796  0.1029  0.0032  0.0058  0.0085
# 1    2_B  0.5549  0.0532  0.3726  0.0181  0.0011
# 2   3_TB  0.8199  0.0886  0.0745  0.0123  0.0047, _body=<great_tables._gt_data.Body object at 0x0000023B73530310>, _boxhead=Boxhead([ColInfo(var='Levels', type=<ColInfoTypeEnum.default: 1>, column_label='Levels', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73527970>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary levels cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B73530D90>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type=' ...

# %% [markdown]
# ### Supplementary levels dist2

# %%
#supplementary levels dist2
print_dt(quali_sup.dist2,rowname="Levels",title=html("<b>Supplementary <br>levels dist2</b>"))
# Out:
# GT(_tbl_data=  Levels  Sq. Dist.
# 0    1_M     0.7738
# 1    2_B     0.3054
# 2   3_TB     1.6633, _body=<great_tables._gt_data.Body object at 0x0000023B75947A90>, _boxhead=Boxhead([ColInfo(var='Levels', type=<ColInfoTypeEnum.default: 1>, column_label='Levels', column_align='left', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73573070>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary <br>levels dist2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B75946BF0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initi ...

# %% [markdown]
# # Others informations
#
# ## Correlation matrix

# %%
#correlation matrix
corr = res_ppca.corr_
corr._fields
# Out:
# ('corrcoef', 'pcorrcoef')

# %% [markdown]
# #### Pearson correlation

# %%
#pearson correlation
print_dt(corr.corrcoef,rowname="",title=html("<b>Pearson correlation matrix</b>"))
# Out:
# GT(_tbl_data=                 CYL   PUISS    LONG    LARG   POIDS    VMAX    PRIX  \
# 0        CYL  1.0000  0.7966  0.7015  0.6298  0.7890  0.6649  0.6386
# 1      PUISS  0.7966  1.0000  0.6414  0.5208  0.7653  0.8444  0.7987
# 2       LONG  0.7015  0.6414  1.0000  0.8493  0.8681  0.4759  0.6438
# 3       LARG  0.6298  0.5208  0.8493  1.0000  0.7169  0.4729  0.5466
# 4      POIDS  0.7890  0.7653  0.8681  0.7169  1.0000  0.4776  0.7533
# 5       VMAX  0.6649  0.8444  0.4759  0.4729  0.4776  1.0000  0.5818
# 6       PRIX  0.6386  0.7987  0.6438  0.5466  0.7533  0.5818  1.0000
# 7  RPOIDPUIS -0.4902 -0.8468 -0.2884 -0.2576 -0.3419 -0.8486 -0.5241
#
#    RPOIDPUIS
# 0    -0.4902
# 1    -0.8468
# 2    -0.2884
# 3    -0.2576
# 4    -0.3419
# 5    -0.8486
# 6    -0.5241
# 7     1.0000  , _body=<great_tables._gt_data.Body object at 0x0000023B735315A0>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='CYL', type=<ColInfoTypeEnum.default: 1>, column_label='CYL', column_align='right', column_width=None), ColInfo(var='PUISS', type=<ColInfoTypeEnum.default: 1>, column_label='PUISS', column_align='right', column_width=None), ColInfo(var='LONG', type=<ColInfoTypeEnum.default: 1>, column_label='LONG', column_align='right', column_width=None), ColInfo(var='LARG', type=<ColInfoTypeEnum.default: 1>, column_label='LARG', column_align='right', column_width=None), ColInfo(var='POIDS', type=<ColInfoTypeEnum.default: 1>, column_label='POIDS', column_align='right', column_width=None), ColInfo(var='VMAX', type=<ColInfoTypeEnum.default: 1>, column_label='VMAX', column_align='right', column_width=None), ColInfo(var='PRIX', type=<ColInfoTypeEnum.default: 1>, column_label='PRIX', column_align='right', column_width=None), ColInfo(var='RPOIDPUIS', type=<ColInfoTypeEnum.default: 1>, column_label='RPOIDPUIS', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B72D898D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Pearson correlation matrix</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B735338E0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=Tru ...

# %% [markdown]
# #### Partial correlation

# %%
#partial correlation
print_dt(corr.pcorrcoef,rowname="",title=html("<b>Partial correlation</b>"))
# Out:
# GT(_tbl_data=               PUISS    LONG    LARG   POIDS    VMAX    PRIX  RPOIDPUIS
# 0      PUISS  1.0000  0.1916  0.0408  0.3683  0.6970  0.6234    -0.8661
# 1       LONG  0.1916  1.0000  0.7361  0.7185  0.0179  0.3570     0.0892
# 2       LARG  0.0408  0.7361  1.0000  0.4610  0.0934  0.2417     0.0754
# 3      POIDS  0.3683  0.7185  0.4610  1.0000 -0.1024  0.5276     0.0836
# 4       VMAX  0.6970  0.0179  0.0934 -0.1024  1.0000  0.2734    -0.8028
# 5       PRIX  0.6234  0.3570  0.2417  0.5276  0.2734  1.0000    -0.3147
# 6  RPOIDPUIS -0.8661  0.0892  0.0754  0.0836 -0.8028 -0.3147     1.0000, _body=<great_tables._gt_data.Body object at 0x0000023B73540850>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='PUISS', type=<ColInfoTypeEnum.default: 1>, column_label='PUISS', column_align='right', column_width=None), ColInfo(var='LONG', type=<ColInfoTypeEnum.default: 1>, column_label='LONG', column_align='right', column_width=None), ColInfo(var='LARG', type=<ColInfoTypeEnum.default: 1>, column_label='LARG', column_align='right', column_width=None), ColInfo(var='POIDS', type=<ColInfoTypeEnum.default: 1>, column_label='POIDS', column_align='right', column_width=None), ColInfo(var='VMAX', type=<ColInfoTypeEnum.default: 1>, column_label='VMAX', column_align='right', column_width=None), ColInfo(var='PRIX', type=<ColInfoTypeEnum.default: 1>, column_label='PRIX', column_align='right', column_width=None), ColInfo(var='RPOIDPUIS', type=<ColInfoTypeEnum.default: 1>, column_label='RPOIDPUIS', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73533D00>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Partial correlation</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B73542320>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_lef ...

# %% [markdown]
# ## Separate ols model

# %%
#separate ols model
separate_model = res_ppca.separate_model_
separate_model._fields
# Out:
# ('PUISS', 'LONG', 'LARG', 'POIDS', 'VMAX', 'PRIX', 'RPOIDPUIS')

# %%
for i, lab in enumerate(list(separate_model._fields)):
    print(f"{lab}")
    print(separate_model[i].summary())
    print(" ")
# Out:
# PUISS
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  PUISS   R-squared:                       0.635
# Model:                            WLS   Adj. R-squared:                  0.612
# Method:                 Least Squares   F-statistic:                     27.79
# Date:                Thu, 02 Oct 2025   Prob (F-statistic):           7.60e-05
# Time:                        18:20:54   Log-Likelihood:                -70.224
# No. Observations:                  18   AIC:                             144.4
# Df Residuals:                      16   BIC:                             146.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         13.7804     13.766      1.001      0.332     -15.401      42.962
# CYL            0.0434      0.008      5.272      0.000       0.026       0.061
# ==============================================================================
# Omnibus:                        1.031   Durbin-Watson:                   2.296
# Prob(Omnibus):                  0.597   Jarque-Bera (JB):                0.137
# Skew:                           0.152   Prob(JB):                        0.934
# Kurtosis:                       3.301   Cond. No.                     7.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# LONG
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                   LONG   R-squared:                       0.492
# Model:                            WLS   Adj. R-squared:                  0.460
# Method:                 Least Squares   F-statistic:                     15.50
# Date:                Thu, 02 Oct 2025   Prob (F-statistic):            0.00118
# Time:                        18:20:54   Log-Likelihood:                -74.657
# No. Observations:                  18   AIC:                             153.3
# Df Residuals:                      16   BIC:                             155.1
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        365.8322     17.609     20.775      0.000     328.502     403.162
# CYL            0.0415      0.011      3.937      0.001       0.019       0.064
# ==============================================================================
# Omnibus:                        0.810   Durbin-Watson:                   2.037
# Prob(Omnibus):                  0.667   Jarque-Bera (JB):                0.131
# Skew:                           0.197   Prob(JB):                        0.936
# Kurtosis:                       3.139   Cond. No.                     7.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# LARG
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                   LARG   R-squared:                       0.397
# Model:                            WLS   Adj. R-squared:                  0.359
# Method:                 Least Squares   F-statistic:                     10.52
# Date:                Thu, 02 Oct 2025   Prob (F-statistic):            0.00510
# Time:                        18:20:54   Log-Likelihood:                -50.545
# No. Observations:                  18   AIC:                             105.1
# Df Residuals:                      16   BIC:                             106.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        152.0647      4.613     32.964      0.000     142.285     161.844
# CYL            0.0089      0.003      3.243      0.005       0.003       0.015
# ==============================================================================
# Omnibus:                        5.433   Durbin-Watson:                   1.901
# Prob(Omnibus):                  0.066   Jarque-Bera (JB):                3.265
# Skew:                           1.012   Prob(JB):                        0.195
# Kurtosis:                       3.506   Cond. No.                     7.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# POIDS
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                  POIDS   R-squared:                       0.622
# Model:                            WLS   Adj. R-squared:                  0.599
# Method:                 Least Squares   F-statistic:                     26.38
# Date:                Thu, 02 Oct 2025   Prob (F-statistic):           9.96e-05
# Time:                        18:20:54   Log-Likelihood:                -104.81
# No. Observations:                  18   AIC:                             213.6
# Df Residuals:                      16   BIC:                             215.4
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        607.3366     94.052      6.457      0.000     407.954     806.719
# CYL            0.2890      0.056      5.136      0.000       0.170       0.408
# ==============================================================================
# Omnibus:                        0.475   Durbin-Watson:                   2.082
# Prob(Omnibus):                  0.788   Jarque-Bera (JB):                0.405
# Skew:                           0.315   Prob(JB):                        0.817
# Kurtosis:                       2.621   Cond. No.                     7.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# VMAX
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                   VMAX   R-squared:                       0.442
# Model:                            WLS   Adj. R-squared:                  0.407
# Method:                 Least Squares   F-statistic:                     12.68
# Date:                Thu, 02 Oct 2025   Prob (F-statistic):            0.00261
# Time:                        18:20:54   Log-Likelihood:                -64.711
# No. Observations:                  18   AIC:                             133.4
# Df Residuals:                      16   BIC:                             135.2
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const        123.0527     10.134     12.142      0.000     101.569     144.536
# CYL            0.0216      0.006      3.561      0.003       0.009       0.034
# ==============================================================================
# Omnibus:                        0.075   Durbin-Watson:                   1.946
# Prob(Omnibus):                  0.963   Jarque-Bera (JB):                0.285
# Skew:                           0.092   Prob(JB):                        0.867
# Kurtosis:                       2.412   Cond. No.                     7.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# PRIX
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:                   PRIX   R-squared:                       0.408
# Model:                            WLS   Adj. R-squared:                  0.371
# Method:                 Least Squares   F-statistic:                     11.02
# Date:                Thu, 02 Oct 2025   Prob (F-statistic):            0.00434
# Time:                        18:20:54   Log-Likelihood:                -178.54
# No. Observations:                  18   AIC:                             361.1
# Df Residuals:                      16   BIC:                             362.9
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const       1.585e+04   5652.005      2.804      0.013    3865.263    2.78e+04
# CYL           11.2227      3.381      3.319      0.004       4.055      18.390
# ==============================================================================
# Omnibus:                        0.712   Durbin-Watson:                   2.246
# Prob(Omnibus):                  0.700   Jarque-Bera (JB):                0.681
# Skew:                           0.185   Prob(JB):                        0.711
# Kurtosis:                       2.121   Cond. No.                     7.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
#
# RPOIDPUIS
#                             WLS Regression Results
# ==============================================================================
# Dep. Variable:              RPOIDPUIS   R-squared:                       0.240
# Model:                            WLS   Adj. R-squared:                  0.193
# Method:                 Least Squares   F-statistic:                     5.060
# Date:                Thu, 02 Oct 2025   Prob (F-statistic):             0.0389
# Time:                        18:20:54   Log-Likelihood:                -37.021
# No. Observations:                  18   AIC:                             78.04
# Df Residuals:                      16   BIC:                             79.82
# Df Model:                           1
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         17.9588      2.176      8.252      0.000      13.346      22.572
# CYL           -0.0029      0.001     -2.249      0.039      -0.006      -0.000
# ==============================================================================
# Omnibus:                        3.264   Durbin-Watson:                   1.760
# Prob(Omnibus):                  0.196   Jarque-Bera (JB):                1.305
# Skew:                           0.436   Prob(JB):                        0.521
# Kurtosis:                       3.990   Cond. No.                     7.69e+03
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 7.69e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.

# %% [markdown]
# ## Others

# %%
#others informations
others = res_ppca.others_
others._fields
# Out:
# ('kaiser_msa', 'coef_n', 'statistics')

# %% [markdown]
# ### Kaiser Measure of Sampling (MSA)

# %%
#kaiser measure of sampling
print_dt(others.kaiser_msa,rowname="",title=html("<b>Kaiser Measure <br>of Sampling</b>"))
# Out:
# GT(_tbl_data=              Kaiser's MSA
# 0    overall        0.6509
# 1        CYL        0.6943
# 2      PUISS        0.5700
# 3       LONG        0.8923
# 4       LARG        0.6225
# 5      POIDS        0.6103
# 6       VMAX        0.8573
# 7       PRIX        0.6692
# 8  RPOIDPUIS        0.4609, _body=<great_tables._gt_data.Body object at 0x0000023B73560760>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var="Kaiser's MSA", type=<ColInfoTypeEnum.default: 1>, column_label="Kaiser's MSA", column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73503A00>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Kaiser Measure <br>of Sampling</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B735626E0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='init ...

# %% [markdown]
# ### Standardized coefficients

# %%
#standardized coefficients
print_dt(others.coef_n,rowname="",title=html("<b>Standardize <br> coeffcients</b>"))
# Out:
# GT(_tbl_data=              Coefficients
# 0      PUISS        0.7966
# 1       LONG        0.7015
# 2       LARG        0.6298
# 3      POIDS        0.7890
# 4       VMAX        0.6649
# 5       PRIX        0.6386
# 6  RPOIDPUIS       -0.4902, _body=<great_tables._gt_data.Body object at 0x0000023B735606D0>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='Coefficients', type=<ColInfoTypeEnum.default: 1>, column_label='Coefficients', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73562950>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Standardize <br> coeffcients</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B73570490>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initia ...

# %% [markdown]
# ### Linear regression model statistics

# %%
#statistics
print_dt(others.statistics,rowname="",title=html("<b>Linear regression model statistics</b>"))
# Out:
# GT(_tbl_data=               intercept      CYL      R2  Adj. R2       RMSE
# 0      PUISS     13.7804   0.0434  0.6346   0.6118    11.9698
# 1       LONG    365.8322   0.0415  0.4920   0.4603    15.3121
# 2       LARG    152.0647   0.0089  0.3966   0.3589     4.0113
# 3      POIDS    607.3366   0.2890  0.6224   0.5988    81.7834
# 4       VMAX    123.0527   0.0216  0.4421   0.4073     8.8122
# 5       PRIX  15846.9785  11.2227  0.4078   0.3708  4914.7025
# 6  RPOIDPUIS     17.9588  -0.0029  0.2403   0.1928     1.8923, _body=<great_tables._gt_data.Body object at 0x0000023B73571E40>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='left', column_width=None), ColInfo(var='intercept', type=<ColInfoTypeEnum.default: 1>, column_label='intercept', column_align='right', column_width=None), ColInfo(var='CYL', type=<ColInfoTypeEnum.default: 1>, column_label='CYL', column_align='right', column_width=None), ColInfo(var='R2', type=<ColInfoTypeEnum.default: 1>, column_label='R2', column_align='right', column_width=None), ColInfo(var='Adj. R2', type=<ColInfoTypeEnum.default: 1>, column_label='Adj. R2', column_align='right', column_width=None), ColInfo(var='RMSE', type=<ColInfoTypeEnum.default: 1>, column_label='RMSE', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023B73560BE0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Linear regression model statistics</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023B73572A10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='headin ...

# %%
#summary
from scientisttools import summarypPCA
summarypPCA(res_ppca)
# Out:
#                      Partial Principal Component Analysis - Results
#
# Importance of components
#                           Dim.1   Dim.2   Dim.3   Dim.4    Dim.5
# Variance                  2.401   1.613   0.699   0.183    0.104
# Difference                0.788   0.914   0.515   0.080      NaN
# % of var.                48.021  32.263  13.974   3.670    2.072
# Cumulative of % of var.  48.021  80.285  94.258  97.928  100.000
#
# Individuals (the 10 first)
#
#                  Weight  Sq. Dist.  Inertia  % Inertia  Dim.1     ctr   cos2  \
# Alfasud TI        0.056      9.002    0.500     10.002 -1.921   8.539  0.410
# Audi 100          0.056     13.185    0.733     14.650  3.117  22.473  0.737
# Simca 1300        0.056      2.012    0.112      2.235  1.132   2.967  0.638
# Citroen GS Club   0.056      0.933    0.052      1.037 -0.798   1.473  0.682
# Fiat 132          0.056      3.213    0.179      3.570  0.803   1.490  0.200
# Lancia Beta       0.056      5.594    0.311      6.215  2.135  10.547  0.815
# Peugeot 504       0.056      2.460    0.137      2.733  0.185   0.079  0.014
# Renault 16 TL     0.056      9.780    0.543     10.866 -1.965   8.931  0.395
# Renault 30        0.056      3.552    0.197      3.947 -1.709   6.761  0.823
# Toyota Corolla    0.056      6.849    0.381      7.610 -2.504  14.506  0.915
#
#                  Dim.2     ctr   cos2  Dim.3     ctr   cos2
# Alfasud TI       2.158  16.045  0.518  0.661   3.469  0.048
# Audi 100        -0.816   2.292  0.050  1.581  19.883  0.190
# Simca 1300      -0.439   0.663  0.096  0.303   0.731  0.046
# Citroen GS Club -0.064   0.014  0.004  0.181   0.259  0.035
# Fiat 132         1.373   6.493  0.587 -0.680   3.673  0.144
# Lancia Beta      0.752   1.947  0.101  0.232   0.429  0.010
# Peugeot 504     -1.519   7.946  0.938 -0.050   0.020  0.001
# Renault 16 TL   -2.402  19.863  0.590 -0.149   0.177  0.002
# Renault 30       0.471   0.764  0.062 -0.153   0.186  0.007
# Toyota Corolla  -0.417   0.598  0.025 -0.105   0.088  0.002
#
# Supplementary individuals
#
#                Sq. Dist.  Dim.1   cos2  Dim.2   cos2  Dim.3   cos2
# Peugeot 604        0.621   0.35  0.197  0.243  0.095 -0.303  0.148
# Peugeot 304 S      4.645  -1.17  0.294  1.493  0.480 -0.289  0.018
#
# Variables
#
#        Dim.1     ctr   cos2  Dim.2     ctr   cos2  Dim.3     ctr   cos2
# PUISS  0.485   9.813  0.236  0.800  39.658  0.640 -0.286  11.700  0.082
# LONG   0.903  33.947  0.815 -0.267   4.426  0.071  0.068   0.671  0.005
# LARG   0.777  25.166  0.604 -0.271   4.563  0.074  0.514  37.832  0.264
# POIDS  0.829  28.589  0.686 -0.186   2.134  0.034 -0.487  33.999  0.238
# VMAX   0.244   2.484  0.060  0.891  49.218  0.794  0.332  15.799  0.110
#
# Supplementary continuous variables
#
#            Dim.1   cos2  Dim.2   cos2  Dim.3   cos2
# PRIX       0.548  0.006   0.30  0.002 -0.280  0.002
# RPOIDPUIS -0.170  0.001  -0.91  0.017 -0.021  0.000
#
# Supplementary categories
#
#       Sq. Dist.  Dim.1   cos2  v.test  Dim.2   cos2  v.test  Dim.3   cos2  \
# 1_M       0.774 -0.825  0.880  -1.361 -0.282  0.103  -0.568 -0.050  0.003
# 2_B       0.305 -0.412  0.555  -0.874 -0.128  0.053  -0.330  0.337  0.373
# 3_TB      1.663  1.168  0.820   2.197  0.384  0.089   0.881 -0.352  0.075
#
#       v.test
# 1_M   -0.152
# 2_B    1.327
# 3_TB  -1.228
#
# Supplementary categorical variable (eta2)
#
#           Dim.1  Dim.2  Dim.3
# FINITION  0.296  0.048  0.123
