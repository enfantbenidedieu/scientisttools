# %% [markdown]
# # FAMD with plotnine

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
from scientisttools import load_tennis
D = load_tennis()
display(D)
# Out:
#             Taille Lateralite MainsRevers  Titres  Finales  TitresGC  \
# Joueur
# Agassi         180   droitier        deux      60       30         8
# Becker         191   droitier         une      49       28         6
# Borg           180   droitier        deux      64       25        11
# Connors        178    gaucher        deux     109       52         8
# Courier        185   droitier        deux      23       13         4
# Edberg         187   droitier         une      41       36         6
# Kafelnikov     190   droitier        deux      26       20         2
# Kuerten        190   droitier         une      20        9         3
# Lendl          187   droitier         une      94       50         8
# McEnroe        180    gaucher         une      77       31         7
# Nastase        180   droitier         une      58       38         2
# Rafter         185   droitier         une      11       14         2
# Safin          193   droitier        deux      15       12         2
# Sampras        185   droitier         une      64       24        14
# Vilas          180    gaucher         une      62       40         4
# Wilander       182   droitier        deux      33       27         7
# Djokovic       188   droitier        deux      79       34        17
# Federer        185   droitier         une     103       54        20
# Murray         191   droitier        deux      46       22         3
# Nadal          185    gaucher        deux      85       37        19
#
#            RolandGarros  BestClassDouble
# Joueur
# Agassi        vainqueur              123
# Becker             demi                6
# Borg          vainqueur              890
# Connors            demi              370
# Courier       vainqueur               20
# Edberg           finale                1
# Kafelnikov    vainqueur                4
# Kuerten       vainqueur               38
# Lendl         vainqueur               20
# McEnroe          finale                1
# Nastase       vainqueur               59
# Rafter             demi                6
# Safin              demi               71
# Sampras            demi               27
# Vilas         vainqueur              175
# Wilander      vainqueur                3
# Djokovic      vainqueur              114
# Federer       vainqueur               24
# Murray           finale               51
# Nadal         vainqueur               26

# %%
from scientisttools import FAMD
afdm = FAMD(ind_sup=list(range(16,20)),quanti_sup=7,quali_sup=6)
afdm.fit(D)
# Out:
# FAMD(ind_sup=[16, 17, 18, 19], quali_sup=6, quanti_sup=7)

# %% [markdown]
# ## Scree plot

# %%
# scree plot
from scientisttools import fviz_screeplot
p = fviz_screeplot(afdm,choice="proportion",add_labels=True)
print(p)

# %%
# Eigenvalue plot
p = fviz_screeplot(afdm,choice="eigenvalue",add_labels=True)
print(p)

# %% [markdown]
# ## Individuals Factor Map - FAMD
#
# ### color
#
# #### Color with css color

# %%
from scientisttools import fviz_famd_ind
p = fviz_famd_ind(afdm,repel=True,quali_sup=True)
print(p)

# %% [markdown]
# #### Color using cos2

# %%
# Color using cos2
p = fviz_famd_ind(afdm,color="cos2",repel=True)
print(p)

# %% [markdown]
# #### Color using contrib

# %%
# Color using contrib
p = fviz_famd_ind(afdm,color="contrib",repel=True)
print(p)

# %% [markdown]
# #### Color using numpy array

# %%
# Using  numpy color
import numpy as np
np.random.seed(123)
color_numpy = np.random.normal(size=16)
p = fviz_famd_ind(afdm,color=color_numpy,repel=True)
print(p)

# %% [markdown]
# #### Color using cluster

# %%
# Using KMeans
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3,random_state=np.random.seed(123), n_init="auto").fit(afdm.ind_["coord"])
p = fviz_famd_ind(afdm,color=kmeans,repel=True)
print(p)

# %% [markdown]
# ### Color using continuous variables
#
# #### Color using active continuous variables

# %%
# Using active continous variables
p = fviz_famd_ind(afdm,color="Taille",repel=True)
print(p)

# %% [markdown]
# #### Color using supplementary continuous variables

# %%
# Using supplementary continous variables
p = fviz_famd_ind(afdm,color="BestClassDouble",repel=True)
print(p)

# %% [markdown]
# ### Habillage
#
# #### Habillage using active variables/categories

# %%
# Using active categories
p = fviz_famd_ind(afdm,habillage="Lateralite",repel=True)
print(p)

# %% [markdown]
# #### Habillage using supplementary variables/categories

# %%
# Using supplementary categories
p = fviz_famd_ind(afdm,habillage="RolandGarros",repel=True)
print(p)

# %% [markdown]
# ## Continuous variables Factor Map - FAMD
#
# ### Color using css color

# %%
from scientisttools import fviz_famd_col
p = fviz_famd_col(afdm)
print(p)

# %% [markdown]
# ### Color using cos2

# %%
# Color using cos2
p = fviz_famd_col(afdm,color="cos2")
print(p)

# %% [markdown]
# ### Color using contrib

# %%
# Color using contrib
p = fviz_famd_col(afdm,color="contrib")
print(p)

# %% [markdown]
# ### Color using numpy array

# %%
# Color using numpy array
np.random.seed(123)
color_numpy = np.random.normal(size=4)
p = fviz_famd_col(afdm,color=color_numpy)
print(p)

# %% [markdown]
# ### Color using cluster

# %%
# Color using KMeans
kmeans = KMeans(n_clusters=3,random_state=np.random.seed(123), n_init="auto").fit(afdm.quanti_var_["coord"])
p = fviz_famd_col(afdm,color=kmeans)
print(p)

# %% [markdown]
# ## Variables/categories Factor Map - FAMD
#
# ### Color using css color

# %%
# using css color
from scientisttools import fviz_famd_mod
p = fviz_famd_mod(afdm,repel=True)
print(p)

# %% [markdown]
# ### Color using cos2

# %%
# Color using cos2
p = fviz_famd_mod(afdm,color="cos2",repel=True)
print(p)

# %% [markdown]
# ### Color using contrib

# %%
# Using contrib
p = fviz_famd_mod(afdm,color="contrib",repel=True)
print(p)

# %% [markdown]
# ### Color using numpy array

# %%
# Color using numpy array
np.random.seed(123)
color_numpy = np.random.normal(size=afdm.quali_var_["coord"].shape[0])
p = fviz_famd_mod(afdm,color=color_numpy,repel=True)
print(p)

# %% [markdown]
# ### Color using cluster

# %%
# Color using KMeans
kmeans = KMeans(n_clusters=3,random_state=np.random.seed(123), n_init="auto").fit(afdm.quali_var_["coord"])
p = fviz_famd_mod(afdm,color=kmeans,repel=True)
print(p)

# %% [markdown]
# ## Variables graphs - FAMD

# %%
# variables graphs
from scientisttools import fviz_famd_var
p = fviz_famd_var(afdm,repel=True)
print(p)

# %% [markdown]
# ## fviz_famd
#
# ### Individuals Factor Map

# %%
# Individuals Factor Map
from scientisttools import fviz_famd
p = fviz_famd(afdm,choice="ind",repel=True)
print(p)

# %% [markdown]
# ### Quantitatives variables

# %%
# Quantitatives variables factor map - FAMD
p = fviz_famd(afdm,choice="quanti_var")
print(p)

# %% [markdown]
# ### Categorical variables

# %%
# using categorical variables
p = fviz_famd(afdm,choice="quali_var",repel=True)
print(p)

# %% [markdown]
# ### Variables

# %%
p = fviz_famd(afdm,choice="var",repel=True)
print(p)

# %% [markdown]
# ## fviz_contrib

# %%
from scientisttools import fviz_contrib
p = fviz_contrib(afdm,choice="ind")
print(p)

# %%
p = fviz_contrib(afdm,choice="quanti_var")
print(p)

# %%
p = fviz_contrib(afdm,choice="quali_var")
print(p)

# %% [markdown]
# ## Plot cos2

# %%
from scientisttools import fviz_cos2
p = fviz_cos2(afdm)
print(p)

# %%
p = fviz_cos2(afdm,choice="quanti_var")
print(p)

# %%
p = fviz_cos2(afdm,choice="quali_var")
print(p)

# %% [markdown]
# ## Corrcircle

# %%
from scientisttools import fviz_corrcircle
p = fviz_corrcircle(afdm)
print(p)
