# %% [markdown]
# # PCAmix - wine dataset

# %%
# disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %% [markdown]
# ## wine dataset

# %%
# wine dataset
from scientisttools.datasets import wine
wine._fields
# Out:
# ('data', 'group', 'name')

# %%
# overall dataset
data = wine.data
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 21 entries, 2EL  to T2
# Data columns (total 31 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   Label                          21 non-null     category
#  1   Soil                           21 non-null     category
#  2   Odor.Intensity.before.shaking  21 non-null     float64
#  3   Aroma.quality.before.shaking   21 non-null     float64
#  4   Fruity.before.shaking          21 non-null     float64
#  5   Flower.before.shaking          21 non-null     float64
#  6   Spice.before.shaking           21 non-null     float64
#  7   Visual.intensity               21 non-null     float64
#  8   Nuance                         21 non-null     float64
#  9   Surface.feeling                21 non-null     float64
#  10  Odor.Intensity                 21 non-null     float64
#  11  Quality.of.odour               21 non-null     float64
#  12  Fruity                         21 non-null     float64
#  13  Flower                         21 non-null     float64
#  14  Spice                          21 non-null     float64
#  15  Plante                         21 non-null     float64
#  16  Phenolic                       21 non-null     float64
#  17  Aroma.intensity                21 non-null     float64
#  18  Aroma.persistency              21 non-null     float64
#  19  Aroma.quality                  21 non-null     float64
#  20  Attack.intensity               21 non-null     float64
#  21  Acidity                        21 non-null     float64
#  22  Astringency                    21 non-null     float64
#  23  Alcohol                        21 non-null     float64
#  24  Balance                        21 non-null     float64
#  25  Smooth                         21 non-null     float64
#  26  Bitterness                     21 non-null     float64
#  27  Intensity                      21 non-null     float64
#  28  Harmony                        21 non-null     float64
#  29  Overall.quality                21 non-null     float64
#  30  Typical                        21 non-null     float64
# dtypes: category(2), float64(29)
# memory usage: 5.0+ KB

# %% [markdown]
# ## Instanciation and training

# %%
# instanciation
from scientisttools import PCAmix
clf = PCAmix()

# %% [markdown]
# ### `fit` function

# %%
# fit function
clf.fit(data)
# Out:
# PCAmix()

# %% [markdown]
# ### `fit_transform` function

# %%
# fit_transform function - individuals coordinates
ind_coord = clf.fit_transform(data)
ind_coord
# Out:
#            Dim1      Dim2      Dim3      Dim4      Dim5
# 2EL    0.198477 -1.512808 -2.113443  1.808266 -1.118888
# 1CHA  -3.540549 -2.674165 -2.895503  1.916068  0.249935
# 1FON  -1.815741 -2.149922 -1.398919 -2.486194  0.119577
# 1VAU  -9.499231  1.281334  2.200877  0.760833  2.779669
# 1DAM   5.213173  0.059018  0.919782 -0.104890 -0.284949
# 2BOU   2.450057 -1.068744 -0.261388 -1.969844  1.155831
# 1BOI   3.414361 -0.793806  0.916614 -2.090484  0.915714
# 3EL    0.474080  1.524485 -3.484140  1.516153  1.107220
# DOM1   0.106161 -1.041672  0.744694 -0.139086 -0.052508
# 1TUR  -2.285563 -0.256804  1.367165  1.696984 -1.458322
# 4EL    1.690926  0.917458  1.113086  0.931600 -0.406941
# PER1   2.171458  1.386702  0.884361  0.888758 -1.267405
# 2DAM   4.192096 -1.083790 -0.384767  0.997206 -0.330048
# 1POY   4.004004 -0.686665 -0.813099 -0.306817 -0.396323
# 1ING   2.339847 -0.978930 -0.839113 -1.286382  0.111773
# 1BEN   1.054588 -2.331939  0.873186 -1.626735  0.328853
# 2BEA   2.877978 -0.980502  2.534460  1.316121  0.752364
# 1ROC  -0.674619 -1.065117  1.828929  1.673534  0.815557
# 2ING -10.491315 -2.429993 -0.138200 -1.793875 -2.103998
# T1    -1.107265  6.746014  0.804686 -0.891207 -2.417148
# T2    -0.772924  7.139846 -1.859268 -0.810009  1.500038

# %% [markdown]
# ### `transform` function

# %%
# transform function - individuals coordinates
ind_coord = clf.transform(data)
ind_coord
# Out:
#            Dim1      Dim2      Dim3      Dim4      Dim5
# 2EL    0.198477 -1.512808 -2.113443  1.808266 -1.118888
# 1CHA  -3.540549 -2.674165 -2.895503  1.916068  0.249935
# 1FON  -1.815741 -2.149922 -1.398919 -2.486194  0.119577
# 1VAU  -9.499231  1.281334  2.200877  0.760833  2.779669
# 1DAM   5.213173  0.059018  0.919782 -0.104890 -0.284949
# 2BOU   2.450057 -1.068744 -0.261388 -1.969844  1.155831
# 1BOI   3.414361 -0.793806  0.916614 -2.090484  0.915714
# 3EL    0.474080  1.524485 -3.484140  1.516153  1.107220
# DOM1   0.106161 -1.041672  0.744694 -0.139086 -0.052508
# 1TUR  -2.285563 -0.256804  1.367165  1.696984 -1.458322
# 4EL    1.690926  0.917458  1.113086  0.931600 -0.406941
# PER1   2.171458  1.386702  0.884361  0.888758 -1.267405
# 2DAM   4.192096 -1.083790 -0.384767  0.997206 -0.330048
# 1POY   4.004004 -0.686665 -0.813099 -0.306817 -0.396323
# 1ING   2.339847 -0.978930 -0.839113 -1.286382  0.111773
# 1BEN   1.054588 -2.331939  0.873186 -1.626735  0.328853
# 2BEA   2.877978 -0.980502  2.534460  1.316121  0.752364
# 1ROC  -0.674619 -1.065117  1.828929  1.673534  0.815557
# 2ING -10.491315 -2.429993 -0.138200 -1.793875 -2.103998
# T1    -1.107265  6.746014  0.804686 -0.891207 -2.417148
# T2    -0.772924  7.139846 -1.859268 -0.810009  1.500038

# %%
# attributes
from scientisttools import sprintf
sprintf(clf)
# Out:
# **Results of the Principal Component Analysis of Mixed Data (PCAmix)**
#
# *The results are available in the following objects:
#
# name                 description
# -------------------  -----------------------------------------------------
# .call_               summary called parameters
# .eig_                eigenvalues
# .ind_                results for the individuals
# .levels_             results for the levels
# .quali_var_          results for the qualitative variables
# .quanti_var_         results for the quantitative variables
# .separate_analyses_  results for the separate analyses
# .svd_                results for generalized singular values decomposition
# .var_                results for variables

# %% [markdown]
# ## Eigen values

# %%
#eigenvalues
from scientisttools import get_eig
eig =  get_eig(clf)
eig
# Out:
#        Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1    15.466717    8.978694       45.490344       45.490344
# Dim2     6.488023    3.909089       19.082421       64.572764
# Dim3     2.578934    0.511839        7.585100       72.157865
# Dim4     2.067096    0.611116        6.079693       78.237558
# Dim5     1.455980    0.213716        4.282294       82.519852
# Dim6     1.242263    0.277295        3.653716       86.173567
# Dim7     0.964969    0.107389        2.838143       89.011711
# Dim8     0.857580    0.239209        2.522294       91.534005
# Dim9     0.618371    0.062589        1.818737       93.352742
# Dim10    0.555781    0.120269        1.634651       94.987393
# Dim11    0.435512    0.040967        1.280918       96.268311
# Dim12    0.394546    0.133299        1.160428       97.428739
# Dim13    0.261246    0.095949        0.768371       98.197110
# Dim14    0.165297    0.032747        0.486168       98.683279
# Dim15    0.132550    0.026079        0.389853       99.073132
# Dim16    0.106471    0.032566        0.313150       99.386282
# Dim17    0.073905    0.023577        0.217368       99.603650
# Dim18    0.050329    0.004876        0.148025       99.751675
# Dim19    0.045453    0.006475        0.133684       99.885360
# Dim20    0.038978         NaN        0.114640      100.000000

# %%
# scree plot - eigenvalue
from scientisttools import fviz_screeplot
p = fviz_screeplot(obj=clf,choice="eigenvalue")
print(p.show())
# Out:
# None

# %%
# scree plot - proportion
p = fviz_screeplot(obj=clf,choice="proportion")
print(p.show())
# Out:
# None

# %%
# scree plot - cumulative
p = fviz_screeplot(obj=clf,choice="cumulative")
print(p.show())
# Out:
# None

# %% [markdown]
# ## Individuals informations

# %%
#individuals informations
from scientisttools import get_mix
ind = get_mix(clf)
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
# individuals coordinates
ind.coord
# Out:
#            Dim1      Dim2      Dim3      Dim4      Dim5
# 2EL    0.198477 -1.512808 -2.113443  1.808266 -1.118888
# 1CHA  -3.540549 -2.674165 -2.895503  1.916068  0.249935
# 1FON  -1.815741 -2.149922 -1.398919 -2.486194  0.119577
# 1VAU  -9.499231  1.281334  2.200877  0.760833  2.779669
# 1DAM   5.213173  0.059018  0.919782 -0.104890 -0.284949
# 2BOU   2.450057 -1.068744 -0.261388 -1.969844  1.155831
# 1BOI   3.414361 -0.793806  0.916614 -2.090484  0.915714
# 3EL    0.474080  1.524485 -3.484140  1.516153  1.107220
# DOM1   0.106161 -1.041672  0.744694 -0.139086 -0.052508
# 1TUR  -2.285563 -0.256804  1.367165  1.696984 -1.458322
# 4EL    1.690926  0.917458  1.113086  0.931600 -0.406941
# PER1   2.171458  1.386702  0.884361  0.888758 -1.267405
# 2DAM   4.192096 -1.083790 -0.384767  0.997206 -0.330048
# 1POY   4.004004 -0.686665 -0.813099 -0.306817 -0.396323
# 1ING   2.339847 -0.978930 -0.839113 -1.286382  0.111773
# 1BEN   1.054588 -2.331939  0.873186 -1.626735  0.328853
# 2BEA   2.877978 -0.980502  2.534460  1.316121  0.752364
# 1ROC  -0.674619 -1.065117  1.828929  1.673534  0.815557
# 2ING -10.491315 -2.429993 -0.138200 -1.793875 -2.103998
# T1    -1.107265  6.746014  0.804686 -0.891207 -2.417148
# T2    -0.772924  7.139846 -1.859268 -0.810009  1.500038

# %%
# graph of individuals
from scientisttools import fviz_mix
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind = "black",
    repel = True,
    ind_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals contributions

# %%
# individuals contributions
ind.contrib
# Out:
#            Dim1       Dim2       Dim3       Dim4       Dim5
# 2EL    0.012128   1.679717   8.247485   7.532596   4.094478
# 1CHA   3.859436   5.248616  15.480627   8.457499   0.204306
# 1FON   1.015057   3.392453   3.613477  14.239346   0.046765
# 1VAU  27.781744   1.205017   8.944004   1.333517  25.270364
# 1DAM   8.367329   0.002556   1.562106   0.025345   0.265558
# 2BOU   1.848141   0.838332   0.126158   8.938893   4.369323
# 1BOI   3.589231   0.462484   1.551362  10.067315   2.742493
# 3EL    0.069197   1.705748  22.414630   5.295488   4.009524
# DOM1   0.003470   0.796398   1.023991   0.044565   0.009017
# 1TUR   1.608307   0.048403   3.451295   6.634005   6.955561
# 4EL    0.880303   0.617790   2.287694   1.999305   0.541613
# PER1   1.451728   1.411350   1.444108   1.819647   5.253587
# 2DAM   5.410594   0.862103   0.273360   2.290814   0.356271
# 1POY   4.935960   0.346065   1.220751   0.216860   0.513716
# 1ING   1.685611   0.703350   1.300115   3.812062   0.040860
# 1BEN   0.342411   3.991192   1.407842   6.096122   0.353695
# 2BEA   2.550103   0.705611  11.860732   3.990359   1.851317
# 1ROC   0.140120   0.832651   6.176382   6.451923   2.175373
# 2ING  33.887725   4.333894   0.035266   7.413178  14.478252
# T1     0.377473  33.401252   1.195620   1.829689  19.108737
# T2     0.183932  37.415019   6.382993   1.511471   7.359191

# %%
# graph of individuals - color by contributions
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind="contrib",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph 
from scientisttools import fviz_corrplot
p = fviz_corrplot(
    X=ind.contrib,
    legend_title="Contrib",
    title="Contributions of individuals"
)
print(p.show())
# Out:
# None

# %%
# contributions of individuals to axis 1
from scientisttools import fviz_contrib
p = fviz_contrib(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals cos2

# %%
# individuals cos2
ind.cos2
# Out:
#           Dim1      Dim2      Dim3      Dim4      Dim5
# 2EL   0.002336  0.135699  0.264844  0.193880  0.074230
# 1CHA  0.334056  0.190570  0.223422  0.097836  0.001665
# 1FON  0.159643  0.223814  0.094760  0.299303  0.000692
# 1VAU  0.840821  0.015299  0.045136  0.005394  0.071997
# 1DAM  0.752147  0.000096  0.023414  0.000304  0.002247
# 2BOU  0.321495  0.061174  0.003659  0.207819  0.071550
# 1BOI  0.534901  0.028912  0.038550  0.200515  0.038475
# 3EL   0.009194  0.095076  0.496609  0.094039  0.050152
# DOM1  0.000794  0.076483  0.039089  0.001364  0.000194
# 1TUR  0.250846  0.003167  0.089756  0.138285  0.102124
# 4EL   0.223301  0.065738  0.096761  0.067780  0.012933
# PER1  0.289968  0.118253  0.048096  0.048575  0.098782
# 2DAM  0.740627  0.049503  0.006239  0.041909  0.004591
# 1POY  0.648266  0.019066  0.026733  0.003806  0.006351
# 1ING  0.357732  0.062616  0.046007  0.108124  0.000816
# 1BEN  0.073416  0.358969  0.050331  0.174685  0.007139
# 2BEA  0.292593  0.033961  0.226914  0.061190  0.019996
# 1ROC  0.030652  0.076408  0.225288  0.188631  0.044797
# 2ING  0.872121  0.046787  0.000151  0.025498  0.035076
# T1    0.021447  0.796098  0.011327  0.013894  0.102207
# T2    0.009781  0.834600  0.056596  0.010742  0.036839

# %%
# graph of individuals - color by cosinus
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind="cos2",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus
p = fviz_corrplot(
    X=ind.cos2,
    legend_title="Cos2",
    title="Cosinus of individuals"
)
print(p.show())
# Out:
# None

# %%
# cosinus of individuals to axis 1
from scientisttools import fviz_cos2
p = fviz_cos2(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals additionals informations

# %%
# individuals additionals informations
ind.infos
# Out:
#         Weight   Sq. Dist.   Inertia  Inertia (%)
# 2EL   0.047619   16.865194  0.803104     2.362072
# 1CHA  0.047619   37.525064  1.786908     5.255611
# 1FON  0.047619   20.651821  0.983420     2.892412
# 1VAU  0.047619  107.318168  5.110389    15.030556
# 1DAM  0.047619   36.132811  1.720610     5.060618
# 2BOU  0.047619   18.671433  0.889116     2.615047
# 1BOI  0.047619   21.794439  1.037830     3.052442
# 3EL   0.047619   24.444244  1.164012     3.423564
# DOM1  0.047619   14.187208  0.675581     1.987004
# 1TUR  0.047619   20.824747  0.991655     2.916631
# 4EL   0.047619   12.804370  0.609732     1.793329
# PER1  0.047619   16.261202  0.774343     2.277479
# 2DAM  0.047619   23.728087  1.129909     3.323261
# 1POY  0.047619   24.730679  1.177651     3.463680
# 1ING  0.047619   15.304437  0.728783     2.143479
# 1BEN  0.047619   15.148764  0.721370     2.121676
# 2BEA  0.047619   28.308095  1.348005     3.964719
# 1ROC  0.047619   14.847610  0.707029     2.079497
# 2ING  0.047619  126.206887  6.009852    17.676035
# T1    0.047619   57.164707  2.722129     8.006262
# T2    0.047619   61.080034  2.908573     8.554627

# %% [markdown]
# ## Quantitative variables informations

# %%
#quantitative variables informations
from scientisttools import get_mix
quanti_var = get_mix(clf,"quanti_var")
quanti_var._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Quantitative variables coordinates

# %%
# quantitative variables coordinates
quanti_var.coord
# Out:
#                                    Dim1      Dim2      Dim3      Dim4  \
# Odor.Intensity.before.shaking  0.472630  0.762627 -0.030667  0.046289
# Aroma.quality.before.shaking   0.813516  0.052852  0.240061 -0.134555
# Fruity.before.shaking          0.681922 -0.048210  0.483720 -0.137372
# Flower.before.shaking          0.477437 -0.303123 -0.480369  0.316597
# Spice.before.shaking          -0.055582  0.768472 -0.187539 -0.388203
# Visual.intensity               0.844312  0.336891 -0.143231 -0.019101
# Nuance                         0.825798  0.329670 -0.137063 -0.053002
# Surface.feeling                0.930044  0.184492  0.047938 -0.002523
# Odor.Intensity                 0.544804  0.685482 -0.176463  0.263008
# Quality.of.odour               0.826498 -0.273865  0.361146  0.145962
# Fruity                         0.746195 -0.217436  0.488855 -0.011038
# Flower                         0.279402 -0.558496 -0.430558  0.261479
# Spice                          0.207070  0.681688 -0.057738 -0.421442
# Plante                        -0.602431  0.620399  0.055050  0.347918
# Phenolic                       0.344164  0.404193 -0.073418  0.545531
# Aroma.intensity                0.885003  0.152565  0.044602  0.139494
# Aroma.persistency              0.918552  0.202632 -0.040049  0.067166
# Aroma.quality                  0.811761 -0.480471  0.077137 -0.070977
# Attack.intensity               0.874586  0.094582 -0.101075 -0.069975
# Acidity                       -0.223608  0.346200  0.636052 -0.036029
# Astringency                    0.738717  0.528693 -0.160123 -0.124582
# Alcohol                        0.756856  0.298914  0.210657  0.067768
# Balance                        0.856242 -0.436118 -0.056565 -0.000800
# Smooth                         0.902555 -0.339062 -0.106213  0.049268
# Bitterness                     0.308631  0.715620  0.032443  0.025786
# Intensity                      0.939783  0.117616 -0.047087 -0.137527
# Harmony                        0.949400 -0.162581 -0.154749 -0.030258
# Overall.quality                0.837404 -0.431514 -0.070233 -0.049812
# Typical                        0.839954 -0.377760  0.030843  0.099208
#
#                                    Dim5
# Odor.Intensity.before.shaking -0.135668
# Aroma.quality.before.shaking  -0.311705
# Fruity.before.shaking         -0.200200
# Flower.before.shaking          0.235027
# Spice.before.shaking           0.271543
# Visual.intensity              -0.109080
# Nuance                        -0.095895
# Surface.feeling               -0.100050
# Odor.Intensity                 0.019339
# Quality.of.odour              -0.052540
# Fruity                        -0.224619
# Flower                         0.469733
# Spice                          0.150352
# Plante                        -0.038533
# Phenolic                       0.022201
# Aroma.intensity               -0.231021
# Aroma.persistency              0.231101
# Aroma.quality                  0.039964
# Attack.intensity               0.249638
# Acidity                        0.525425
# Astringency                    0.082658
# Alcohol                        0.064871
# Balance                        0.018978
# Smooth                        -0.010799
# Bitterness                     0.223142
# Intensity                      0.195300
# Harmony                        0.022932
# Overall.quality                0.152340
# Typical                       -0.009884

# %%
# graph of variables - correlation circle
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables contributions

# %%
# quantitative variables contributions
quanti_var.contrib
# Out:
#                                    Dim1      Dim2       Dim3       Dim4  \
# Odor.Intensity.before.shaking  1.444258  8.964209   0.036467   0.103657
# Aroma.quality.before.shaking   4.278914  0.043054   2.234614   0.875875
# Fruity.before.shaking          3.006566  0.035824   9.072953   0.912928
# Flower.before.shaking          1.473785  1.416204   8.947668   4.849010
# Spice.before.shaking           0.019974  9.102144   1.363773   7.290504
# Visual.intensity               4.609012  1.749312   0.795491   0.017650
# Nuance                         4.409093  1.675119   0.728454   0.135901
# Surface.feeling                5.592537  0.524620   0.089108   0.000308
# Odor.Intensity                 1.919036  7.242345   1.207443   3.346404
# Quality.of.odour               4.416578  1.156007   5.057380   1.030670
# Fruity                         3.600035  0.728701   9.266588   0.005894
# Flower                         0.504731  4.807602   7.188244   3.307603
# Spice                          0.277227  7.162412   0.129264   8.592423
# Plante                         2.346477  5.932398   0.117509   5.855886
# Phenolic                       0.765830  2.518053   0.209010  14.397197
# Aroma.intensity                5.063974  0.358755   0.077138   0.941349
# Aroma.persistency              5.455180  0.632853   0.062193   0.218245
# Aroma.quality                  4.260473  3.558136   0.230718   0.243708
# Attack.intensity               4.945459  0.137880   0.396139   0.236878
# Acidity                        0.323279  1.847316  15.687183   0.062797
# Astringency                    3.528235  4.308194   0.994187   0.750843
# Alcohol                        3.703637  1.377149   1.720726   0.222175
# Balance                        4.740179  2.931537   0.124068   0.000031
# Smooth                         5.266823  1.771932   0.437441   0.117429
# Bitterness                     0.615857  7.893182   0.040812   0.032167
# Intensity                      5.710278  0.213216   0.085975   0.914986
# Harmony                        5.827744  0.407405   0.928570   0.044292
# Overall.quality                4.533899  2.869970   0.191269   0.120034
# Typical                        4.561559  2.199483   0.036886   0.476136
#
#                                     Dim5
# Odor.Intensity.before.shaking   1.264149
# Aroma.quality.before.shaking    6.673161
# Fruity.before.shaking           2.752777
# Flower.before.shaking           3.793836
# Spice.before.shaking            5.064339
# Visual.intensity                0.817205
# Nuance                          0.631595
# Surface.feeling                 0.687509
# Odor.Intensity                  0.025687
# Quality.of.odour                0.189597
# Fruity                          3.465262
# Flower                         15.154681
# Spice                           1.552617
# Plante                          0.101979
# Phenolic                        0.033851
# Aroma.intensity                 3.665621
# Aroma.persistency               3.668176
# Aroma.quality                   0.109694
# Attack.intensity                4.280227
# Acidity                        18.961196
# Astringency                     0.469261
# Alcohol                         0.289033
# Balance                         0.024738
# Smooth                          0.008010
# Bitterness                      3.419838
# Intensity                       2.619681
# Harmony                         0.036117
# Overall.quality                 1.593944
# Typical                         0.006710

# %%
# graph of variables - color by contrib
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    col_var = "contrib",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of contributions for variables
p = fviz_corrplot(
    X=quanti_var.contrib,
    legend_title="Contrib",
    title="Contributions of variables"
)
print(p.show())
# Out:
# None

# %%
# contributions of variables to axis 1
p = fviz_contrib(
    obj=clf,
    choice="quanti_var"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables cos2

# %%
# quantitative variables cos2
quanti_var.cos2
# Out:
#                                    Dim1      Dim2      Dim3          Dim4  \
# Odor.Intensity.before.shaking  0.223379  0.581600  0.000940  2.142690e-03
# Aroma.quality.before.shaking   0.661808  0.002793  0.057629  1.810517e-02
# Fruity.before.shaking          0.465017  0.002324  0.233985  1.887109e-02
# Flower.before.shaking          0.227946  0.091884  0.230754  1.002337e-01
# Spice.before.shaking           0.003089  0.590549  0.035171  1.507017e-01
# Visual.intensity               0.712863  0.113496  0.020515  3.648336e-04
# Nuance                         0.681942  0.108682  0.018786  2.809195e-03
# Surface.feeling                0.864982  0.034037  0.002298  6.363499e-06
# Odor.Intensity                 0.296812  0.469885  0.031139  6.917337e-02
# Quality.of.odour               0.683100  0.075002  0.130427  2.130493e-02
# Fruity                         0.556807  0.047278  0.238979  1.218342e-04
# Flower                         0.078065  0.311918  0.185380  6.837132e-02
# Spice                          0.042878  0.464699  0.003334  1.776136e-01
# Plante                         0.362923  0.384895  0.003030  1.210468e-01
# Phenolic                       0.118449  0.163372  0.005390  2.976038e-01
# Aroma.intensity                0.783231  0.023276  0.001989  1.945859e-02
# Aroma.persistency              0.843737  0.041060  0.001604  4.511332e-03
# Aroma.quality                  0.658955  0.230853  0.005950  5.037668e-03
# Attack.intensity               0.764900  0.008946  0.010216  4.896499e-03
# Acidity                        0.050001  0.119854  0.404562  1.298065e-03
# Astringency                    0.545702  0.279517  0.025639  1.552065e-02
# Alcohol                        0.572831  0.089350  0.044376  4.592560e-03
# Balance                        0.733150  0.190199  0.003200  6.405438e-07
# Smooth                         0.814605  0.114963  0.011281  2.427368e-03
# Bitterness                     0.095253  0.512111  0.001053  6.649130e-04
# Intensity                      0.883192  0.013834  0.002217  1.891363e-02
# Harmony                        0.901361  0.026433  0.023947  9.155477e-04
# Overall.quality                0.701245  0.186204  0.004933  2.481222e-03
# Typical                        0.705523  0.142703  0.000951  9.842176e-03
#
#                                    Dim5
# Odor.Intensity.before.shaking  0.018406
# Aroma.quality.before.shaking   0.097160
# Fruity.before.shaking          0.040080
# Flower.before.shaking          0.055237
# Spice.before.shaking           0.073736
# Visual.intensity               0.011898
# Nuance                         0.009196
# Surface.feeling                0.010010
# Odor.Intensity                 0.000374
# Quality.of.odour               0.002760
# Fruity                         0.050454
# Flower                         0.220649
# Spice                          0.022606
# Plante                         0.001485
# Phenolic                       0.000493
# Aroma.intensity                0.053371
# Aroma.persistency              0.053408
# Aroma.quality                  0.001597
# Attack.intensity               0.062319
# Acidity                        0.276071
# Astringency                    0.006832
# Alcohol                        0.004208
# Balance                        0.000360
# Smooth                         0.000117
# Bitterness                     0.049792
# Intensity                      0.038142
# Harmony                        0.000526
# Overall.quality                0.023208
# Typical                        0.000098

# %%
# graph of variables - color by cosinus
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    col_var = "cos2",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus for variables
p = fviz_corrplot(
    X=quanti_var.cos2,
    legend_title="Cos2",
    title="Cosinus of continuous variables"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables additionals informations

# %%
# quantitative variables additionals informations
quanti_var.infos
# Out:
#                                Weight  Sq. Dist.  Inertia  Inertia (%)
# Odor.Intensity.before.shaking     1.0        1.0      1.0     2.941176
# Aroma.quality.before.shaking      1.0        1.0      1.0     2.941176
# Fruity.before.shaking             1.0        1.0      1.0     2.941176
# Flower.before.shaking             1.0        1.0      1.0     2.941176
# Spice.before.shaking              1.0        1.0      1.0     2.941176
# Visual.intensity                  1.0        1.0      1.0     2.941176
# Nuance                            1.0        1.0      1.0     2.941176
# Surface.feeling                   1.0        1.0      1.0     2.941176
# Odor.Intensity                    1.0        1.0      1.0     2.941176
# Quality.of.odour                  1.0        1.0      1.0     2.941176
# Fruity                            1.0        1.0      1.0     2.941176
# Flower                            1.0        1.0      1.0     2.941176
# Spice                             1.0        1.0      1.0     2.941176
# Plante                            1.0        1.0      1.0     2.941176
# Phenolic                          1.0        1.0      1.0     2.941176
# Aroma.intensity                   1.0        1.0      1.0     2.941176
# Aroma.persistency                 1.0        1.0      1.0     2.941176
# Aroma.quality                     1.0        1.0      1.0     2.941176
# Attack.intensity                  1.0        1.0      1.0     2.941176
# Acidity                           1.0        1.0      1.0     2.941176
# Astringency                       1.0        1.0      1.0     2.941176
# Alcohol                           1.0        1.0      1.0     2.941176
# Balance                           1.0        1.0      1.0     2.941176
# Smooth                            1.0        1.0      1.0     2.941176
# Bitterness                        1.0        1.0      1.0     2.941176
# Intensity                         1.0        1.0      1.0     2.941176
# Harmony                           1.0        1.0      1.0     2.941176
# Overall.quality                   1.0        1.0      1.0     2.941176
# Typical                           1.0        1.0      1.0     2.941176

# %% [markdown]
# ## Levels informations

# %%
# levels informations
levels = clf.levels_
levels._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos', 'vtest')

# %% [markdown]
# ### Levels coordinates

# %%
# levels coordinates
levels.coord
# Out:
#                 Dim1      Dim2      Dim3      Dim4      Dim5
# Bourgueuil -0.129180 -0.638184 -0.087990 -1.304538  0.072895
# Chinon     -0.457038 -0.177252  1.137825  0.627965  0.889885
# Saumur      0.236657  0.412555 -0.365760  0.483215 -0.363355
# Env1       -0.462379 -0.519514 -0.900660 -0.046208 -0.199715
# Env2       -0.437199  0.177733  0.920903  0.827926  0.076669
# Env4       -0.239041  2.725753 -0.328345 -0.591629 -0.380026
# Reference   0.842962 -0.386224  0.336685 -0.376130  0.253531

# %%
# graph of variable categories
p = fviz_mix(
    obj=clf,
    choice="levels",
    repel=True,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels vtest

# %%
# levels vtest
levels.vtest
# Out:
#                 Dim1      Dim2      Dim3      Dim4      Dim5
# Bourgueuil -0.365375 -1.805056 -0.248873 -3.689789  0.206179
# Chinon     -0.991455 -0.384514  2.468289  1.362248  1.930431
# Saumur      1.110021  1.935056 -1.715567  2.266479 -1.704288
# Env1       -1.462172 -1.642849 -2.848136 -0.146124 -0.631555
# Env2       -1.092998  0.444333  2.302257  2.069814  0.191672
# Env4       -0.346837  3.954939 -0.476413 -0.858425 -0.551400
# Reference   2.665680 -1.221349  1.064691 -1.189429  0.801735

# %% [markdown]
# ### Levels contributions

# %%
# levels contributions
levels.contrib
# Out:
#                 Dim1       Dim2       Dim3       Dim4       Dim5
# Bourgueuil  0.030826   1.793539   0.085774  23.522558   0.104274
# Chinon      0.257245   0.092238   9.562059   3.633717  10.359830
# Saumur      0.189677   1.374123   2.717226   5.916891   4.749866
# Env1        0.460763   1.386633  10.484796   0.034432   0.913157
# Env2        0.294246   0.115924   7.829575   7.895379   0.096124
# Env4        0.035185  10.906150   0.398136   1.612681   0.944676
# Reference   1.531428   0.766383   1.465161   2.281366   1.471583

# %%
# graph of variable categories  - color by contributions
p = fviz_mix(
    obj=clf,
    choice="levels",
    col_var = "contrib",
    repel=True,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of contributions for variable categories
p = fviz_corrplot(
    X=levels.contrib,
    legend_title="Contrib",
    title="Contributions of variable categories"
)
print(p.show())
# Out:
# None

# %%
# contributions of levels to axis 1
p = fviz_contrib(
    obj=clf,
    choice="levels"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels cos2

# %%
# levels cos2
levels.cos2
# Out:
#                 Dim1      Dim2      Dim3      Dim4      Dim5
# Bourgueuil  0.006675  0.162911  0.003097  0.680727  0.002125
# Chinon      0.049149  0.007393  0.304623  0.092786  0.186328
# Saumur      0.061607  0.187222  0.147158  0.256846  0.145230
# Env1        0.106897  0.134948  0.405594  0.001068  0.019943
# Env2        0.059732  0.009872  0.265019  0.214207  0.001837
# Env4        0.006015  0.782077  0.011348  0.036845  0.015202
# Reference   0.355292  0.074585  0.056678  0.070737  0.032139

# %%
# graph of variable categories - color by cosinus
p = fviz_mix(
    obj=clf,
    choice="levels",
    col_var = "cos2",
    repel=True,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus for variable categories
p = fviz_corrplot(
    X=levels.cos2,
    legend_title="Cos2",
    title="Cosinus of variable categories"
)
print(p.show())
# Out:
# None

# %%
# cosinus of variable categories to axis 1
p = fviz_cos2(
    obj=clf,
    choice="levels"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels additionals informations

# %%
# levels additionals informations
levels.infos
# Out:
#                Weight  Sq. Dist.   Inertia  Inertia (%)
# Bourgueuil   3.500000   0.204082  0.714286     2.100840
# Chinon       5.250000   0.154195  0.809524     2.380952
# Saumur       1.909091   0.249433  0.476190     1.400560
# Env1         3.000000   0.222222  0.666667     1.960784
# Env2         4.200000   0.181406  0.761905     2.240896
# Env4        10.500000   0.086168  0.904762     2.661064
# Reference    3.000000   0.222222  0.666667     1.960784

# %% [markdown]
# ## Variables informations

# %%
# variables informations
var = get_mix(clf,"var")
var._fields
# Out:
# ('coord', 'contrib', 'cos2')

# %% [markdown]
# ### Variables coordinates

# %%
# variables coordinates
var.coord
# Out:
#                                    Dim1      Dim2      Dim3          Dim4  \
# Odor.Intensity.before.shaking  0.223379  0.581600  0.000940  2.142690e-03
# Aroma.quality.before.shaking   0.661808  0.002793  0.057629  1.810517e-02
# Fruity.before.shaking          0.465017  0.002324  0.233985  1.887109e-02
# Flower.before.shaking          0.227946  0.091884  0.230754  1.002337e-01
# Spice.before.shaking           0.003089  0.590549  0.035171  1.507017e-01
# Visual.intensity               0.712863  0.113496  0.020515  3.648336e-04
# Nuance                         0.681942  0.108682  0.018786  2.809195e-03
# Surface.feeling                0.864982  0.034037  0.002298  6.363499e-06
# Odor.Intensity                 0.296812  0.469885  0.031139  6.917337e-02
# Quality.of.odour               0.683100  0.075002  0.130427  2.130493e-02
# Fruity                         0.556807  0.047278  0.238979  1.218342e-04
# Flower                         0.078065  0.311918  0.185380  6.837132e-02
# Spice                          0.042878  0.464699  0.003334  1.776136e-01
# Plante                         0.362923  0.384895  0.003030  1.210468e-01
# Phenolic                       0.118449  0.163372  0.005390  2.976038e-01
# Aroma.intensity                0.783231  0.023276  0.001989  1.945859e-02
# Aroma.persistency              0.843737  0.041060  0.001604  4.511332e-03
# Aroma.quality                  0.658955  0.230853  0.005950  5.037668e-03
# Attack.intensity               0.764900  0.008946  0.010216  4.896499e-03
# Acidity                        0.050001  0.119854  0.404562  1.298065e-03
# Astringency                    0.545702  0.279517  0.025639  1.552065e-02
# Alcohol                        0.572831  0.089350  0.044376  4.592560e-03
# Balance                        0.733150  0.190199  0.003200  6.405438e-07
# Smooth                         0.814605  0.114963  0.011281  2.427368e-03
# Bitterness                     0.095253  0.512111  0.001053  6.649130e-04
# Intensity                      0.883192  0.013834  0.002217  1.891363e-02
# Harmony                        0.901361  0.026433  0.023947  9.155477e-04
# Overall.quality                0.701245  0.186204  0.004933  2.481222e-03
# Typical                        0.705523  0.142703  0.000951  9.842176e-03
# Label                          0.073892  0.211503  0.318887  6.836540e-01
# Soil                           0.359079  0.854803  0.520369  2.444104e-01
#
#                                    Dim5
# Odor.Intensity.before.shaking  0.018406
# Aroma.quality.before.shaking   0.097160
# Fruity.before.shaking          0.040080
# Flower.before.shaking          0.055237
# Spice.before.shaking           0.073736
# Visual.intensity               0.011898
# Nuance                         0.009196
# Surface.feeling                0.010010
# Odor.Intensity                 0.000374
# Quality.of.odour               0.002760
# Fruity                         0.050454
# Flower                         0.220649
# Spice                          0.022606
# Plante                         0.001485
# Phenolic                       0.000493
# Aroma.intensity                0.053371
# Aroma.persistency              0.053408
# Aroma.quality                  0.001597
# Attack.intensity               0.062319
# Acidity                        0.276071
# Astringency                    0.006832
# Alcohol                        0.004208
# Balance                        0.000360
# Smooth                         0.000117
# Bitterness                     0.049792
# Intensity                      0.038142
# Harmony                        0.000526
# Overall.quality                0.023208
# Typical                        0.000098
# Label                          0.221512
# Soil                           0.049875

# %%
# graph of variables
p = fviz_mix(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = False,
    quanti_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Variables contributions

# %%
# variables contributions
var.contrib
# Out:
#                                    Dim1       Dim2       Dim3       Dim4  \
# Odor.Intensity.before.shaking  1.444258   8.964209   0.036467   0.103657
# Aroma.quality.before.shaking   4.278914   0.043054   2.234614   0.875875
# Fruity.before.shaking          3.006566   0.035824   9.072953   0.912928
# Flower.before.shaking          1.473785   1.416204   8.947668   4.849010
# Spice.before.shaking           0.019974   9.102144   1.363773   7.290504
# Visual.intensity               4.609012   1.749312   0.795491   0.017650
# Nuance                         4.409093   1.675119   0.728454   0.135901
# Surface.feeling                5.592537   0.524620   0.089108   0.000308
# Odor.Intensity                 1.919036   7.242345   1.207443   3.346404
# Quality.of.odour               4.416578   1.156007   5.057380   1.030670
# Fruity                         3.600035   0.728701   9.266588   0.005894
# Flower                         0.504731   4.807602   7.188244   3.307603
# Spice                          0.277227   7.162412   0.129264   8.592423
# Plante                         2.346477   5.932398   0.117509   5.855886
# Phenolic                       0.765830   2.518053   0.209010  14.397197
# Aroma.intensity                5.063974   0.358755   0.077138   0.941349
# Aroma.persistency              5.455180   0.632853   0.062193   0.218245
# Aroma.quality                  4.260473   3.558136   0.230718   0.243708
# Attack.intensity               4.945459   0.137880   0.396139   0.236878
# Acidity                        0.323279   1.847316  15.687183   0.062797
# Astringency                    3.528235   4.308194   0.994187   0.750843
# Alcohol                        3.703637   1.377149   1.720726   0.222175
# Balance                        4.740179   2.931537   0.124068   0.000031
# Smooth                         5.266823   1.771932   0.437441   0.117429
# Bitterness                     0.615857   7.893182   0.040812   0.032167
# Intensity                      5.710278   0.213216   0.085975   0.914986
# Harmony                        5.827744   0.407405   0.928570   0.044292
# Overall.quality                4.533899   2.869970   0.191269   0.120034
# Typical                        4.561559   2.199483   0.036886   0.476136
# Label                          0.477748   3.259900  12.365059  33.073167
# Soil                           2.321623  13.175091  20.177668  11.823857
#
#                                     Dim5
# Odor.Intensity.before.shaking   1.264149
# Aroma.quality.before.shaking    6.673161
# Fruity.before.shaking           2.752777
# Flower.before.shaking           3.793836
# Spice.before.shaking            5.064339
# Visual.intensity                0.817205
# Nuance                          0.631595
# Surface.feeling                 0.687509
# Odor.Intensity                  0.025687
# Quality.of.odour                0.189597
# Fruity                          3.465262
# Flower                         15.154681
# Spice                           1.552617
# Plante                          0.101979
# Phenolic                        0.033851
# Aroma.intensity                 3.665621
# Aroma.persistency               3.668176
# Aroma.quality                   0.109694
# Attack.intensity                4.280227
# Acidity                        18.961196
# Astringency                     0.469261
# Alcohol                         0.289033
# Balance                         0.024738
# Smooth                          0.008010
# Bitterness                      3.419838
# Intensity                       2.619681
# Harmony                         0.036117
# Overall.quality                 1.593944
# Typical                         0.006710
# Label                          15.213970
# Soil                            3.425539

# %% [markdown]
# ### Variables cos2

# %%
# variables cos2
var.cos2
# Out:
#                                    Dim1      Dim2          Dim3          Dim4  \
# Odor.Intensity.before.shaking  0.049898  0.338258  8.844538e-07  4.591118e-06
# Aroma.quality.before.shaking   0.437989  0.000008  3.321128e-03  3.277972e-04
# Fruity.before.shaking          0.216241  0.000005  5.474921e-02  3.561180e-04
# Flower.before.shaking          0.051959  0.008443  5.324762e-02  1.004679e-02
# Spice.before.shaking           0.000010  0.348748  1.236987e-03  2.271100e-02
# Visual.intensity               0.508173  0.012881  4.208731e-04  1.331035e-07
# Nuance                         0.465045  0.011812  3.529274e-04  7.891577e-06
# Surface.feeling                0.748194  0.001159  5.280948e-06  4.049412e-11
# Odor.Intensity                 0.088097  0.220792  9.696471e-04  4.784954e-03
# Quality.of.odour               0.466625  0.005625  1.701107e-02  4.539001e-04
# Fruity                         0.310034  0.002235  5.711106e-02  1.484357e-08
# Flower                         0.006094  0.097293  3.436577e-02  4.674637e-03
# Spice                          0.001839  0.215945  1.111309e-05  3.154659e-02
# Plante                         0.131713  0.148144  9.183786e-06  1.465232e-02
# Phenolic                       0.014030  0.026690  2.905469e-05  8.856804e-02
# Aroma.intensity                0.613450  0.000542  3.957475e-06  3.786366e-04
# Aroma.persistency              0.711893  0.001686  2.572578e-06  2.035212e-05
# Aroma.quality                  0.434222  0.053293  3.540327e-05  2.537810e-05
# Attack.intensity               0.585072  0.000080  1.043698e-04  2.397570e-05
# Acidity                        0.002500  0.014365  1.636705e-01  1.684973e-06
# Astringency                    0.297791  0.078130  6.573806e-04  2.408905e-04
# Alcohol                        0.328135  0.007983  1.969264e-03  2.109161e-05
# Balance                        0.537509  0.036176  1.023769e-05  4.102963e-13
# Smooth                         0.663581  0.013217  1.272678e-04  5.892114e-06
# Bitterness                     0.009073  0.262258  1.107808e-06  4.421093e-07
# Intensity                      0.780029  0.000191  4.916111e-06  3.577253e-04
# Harmony                        0.812451  0.000699  5.734683e-04  8.382276e-07
# Overall.quality                0.491745  0.034672  2.433156e-05  6.156463e-06
# Typical                        0.497763  0.020364  9.049301e-07  9.686843e-05
# Label                          0.002730  0.022367  5.084438e-02  2.336914e-01
# Soil                           0.042979  0.243563  9.026122e-02  1.991215e-02
#
#                                        Dim5
# Odor.Intensity.before.shaking  3.387717e-04
# Aroma.quality.before.shaking   9.440043e-03
# Fruity.before.shaking          1.606397e-03
# Flower.before.shaking          3.051180e-03
# Spice.before.shaking           5.436962e-03
# Visual.intensity               1.415707e-04
# Nuance                         8.456439e-05
# Surface.feeling                1.001999e-04
# Odor.Intensity                 1.398705e-07
# Quality.of.odour               7.620305e-06
# Fruity                         2.545557e-03
# Flower                         4.868603e-02
# Spice                          5.110219e-04
# Plante                         2.204624e-06
# Phenolic                       2.429146e-07
# Aroma.intensity                2.848433e-03
# Aroma.persistency              2.852404e-03
# Aroma.quality                  2.550802e-06
# Attack.intensity               3.883688e-03
# Acidity                        7.621531e-02
# Astringency                    4.668098e-05
# Alcohol                        1.770947e-05
# Balance                        1.297277e-07
# Smooth                         1.360008e-08
# Bitterness                     2.479259e-03
# Intensity                      1.454815e-03
# Harmony                        2.765284e-07
# Overall.quality                5.385881e-04
# Typical                        9.544499e-09
# Label                          2.453386e-02
# Soil                           8.291774e-04

# %% [markdown]
# ## Others functions
#
# ### Ellipses - `fviz_ellipses`

# %%
# ellipses
from scientisttools import fviz_ellipses
p = fviz_ellipses(
    obj=clf,
    habillage=["Label","Soil"],
    repel=True,
    add_ellipses=True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Summaries - `summary`

# %%
# summary
from scientisttools import summary
summary(clf)
# Out:
#                      Principal Component Analysis of Mixed Data - Results
#
# Importance of components:
#       Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1     15.4667      8.9787         45.4903         45.4903
# Dim2      6.4880      3.9091         19.0824         64.5728
# Dim3      2.5789      0.5118          7.5851         72.1579
#
# Individuals (the 10 first):
#         Dim1    cos2      ctr    Dim2    cos2     ctr    Dim3    cos2      ctr
# 2EL   0.1985  0.0023   0.0121 -1.5128  0.1357  1.6797 -2.1134  0.2648   8.2475
# 1CHA -3.5405  0.3341   3.8594 -2.6742  0.1906  5.2486 -2.8955  0.2234  15.4806
# 1FON -1.8157  0.1596   1.0151 -2.1499  0.2238  3.3925 -1.3989  0.0948   3.6135
# 1VAU -9.4992  0.8408  27.7817  1.2813  0.0153  1.2050  2.2009  0.0451   8.9440
# 1DAM  5.2132  0.7521   8.3673  0.0590  0.0001  0.0026  0.9198  0.0234   1.5621
# 2BOU  2.4501  0.3215   1.8481 -1.0687  0.0612  0.8383 -0.2614  0.0037   0.1262
# 1BOI  3.4144  0.5349   3.5892 -0.7938  0.0289  0.4625  0.9166  0.0386   1.5514
# 3EL   0.4741  0.0092   0.0692  1.5245  0.0951  1.7057 -3.4841  0.4966  22.4146
# DOM1  0.1062  0.0008   0.0035 -1.0417  0.0765  0.7964  0.7447  0.0391   1.0240
# 1TUR -2.2856  0.2508   1.6083 -0.2568  0.0032  0.0484  1.3672  0.0898   3.4513
#
# Continuous (the 10 first):
#                                  Dim1    cos2     ctr    Dim2    cos2     ctr  \
# Odor.Intensity.before.shaking  0.4726  0.2234  1.4443  0.7626  0.5816  8.9642
# Aroma.quality.before.shaking   0.8135  0.6618  4.2789  0.0529  0.0028  0.0431
# Fruity.before.shaking          0.6819  0.4650  3.0066 -0.0482  0.0023  0.0358
# Flower.before.shaking          0.4774  0.2279  1.4738 -0.3031  0.0919  1.4162
# Spice.before.shaking          -0.0556  0.0031  0.0200  0.7685  0.5905  9.1021
# Visual.intensity               0.8443  0.7129  4.6090  0.3369  0.1135  1.7493
# Nuance                         0.8258  0.6819  4.4091  0.3297  0.1087  1.6751
# Surface.feeling                0.9300  0.8650  5.5925  0.1845  0.0340  0.5246
# Odor.Intensity                 0.5448  0.2968  1.9190  0.6855  0.4699  7.2423
# Quality.of.odour               0.8265  0.6831  4.4166 -0.2739  0.0750  1.1560
#
#                                  Dim3    cos2     ctr
# Odor.Intensity.before.shaking -0.0307  0.0009  0.0365
# Aroma.quality.before.shaking   0.2401  0.0576  2.2346
# Fruity.before.shaking          0.4837  0.2340  9.0730
# Flower.before.shaking         -0.4804  0.2308  8.9477
# Spice.before.shaking          -0.1875  0.0352  1.3638
# Visual.intensity              -0.1432  0.0205  0.7955
# Nuance                        -0.1371  0.0188  0.7285
# Surface.feeling                0.0479  0.0023  0.0891
# Odor.Intensity                -0.1765  0.0311  1.2074
# Quality.of.odour               0.3611  0.1304  5.0574
#
# Categories:
#               Dim1   vtest    cos2     ctr    Dim2   vtest    cos2      ctr  \
# Bourgueuil -0.1292 -0.3654  0.0067  0.0308 -0.6382 -1.8051  0.1629   1.7935
# Chinon     -0.4570 -0.9915  0.0491  0.2572 -0.1773 -0.3845  0.0074   0.0922
# Saumur      0.2367  1.1100  0.0616  0.1897  0.4126  1.9351  0.1872   1.3741
# Env1       -0.4624 -1.4622  0.1069  0.4608 -0.5195 -1.6428  0.1349   1.3866
# Env2       -0.4372 -1.0930  0.0597  0.2942  0.1777  0.4443  0.0099   0.1159
# Env4       -0.2390 -0.3468  0.0060  0.0352  2.7258  3.9549  0.7821  10.9061
# Reference   0.8430  2.6657  0.3553  1.5314 -0.3862 -1.2213  0.0746   0.7664
#
#               Dim3   vtest    cos2      ctr
# Bourgueuil -0.0880 -0.2489  0.0031   0.0858
# Chinon      1.1378  2.4683  0.3046   9.5621
# Saumur     -0.3658 -1.7156  0.1472   2.7172
# Env1       -0.9007 -2.8481  0.4056  10.4848
# Env2        0.9209  2.3023  0.2650   7.8296
# Env4       -0.3283 -0.4764  0.0113   0.3981
# Reference   0.3367  1.0647  0.0567   1.4652
#
# Categorical variables:
#          Dim1     ctr    Dim2      ctr    Dim3      ctr
# Label  0.0739  0.4777  0.2115   3.2599  0.3189  12.3651
# Soil   0.3591  2.3216  0.8548  13.1751  0.5204  20.1777

# %%
# formatting text to markdown
summary(clf,to_markdown=True)
# Out:
#                      Principal Component Analysis of Mixed Data - Results
#
# Importance of components:
#         Eigenvalue    Difference    Proportion (%)    Cumulative (%)
# ----  ------------  ------------  ----------------  ----------------
# Dim1       15.4667        8.9787           45.4903           45.4903
# Dim2        6.488         3.9091           19.0824           64.5728
# Dim3        2.5789        0.5118            7.5851           72.1579
#
# Individuals (the 10 first):
#          Dim1    cos2      ctr     Dim2    cos2     ctr     Dim3    cos2      ctr
# ----  -------  ------  -------  -------  ------  ------  -------  ------  -------
# 2EL    0.1985  0.0023   0.0121  -1.5128  0.1357  1.6797  -2.1134  0.2648   8.2475
# 1CHA  -3.5405  0.3341   3.8594  -2.6742  0.1906  5.2486  -2.8955  0.2234  15.4806
# 1FON  -1.8157  0.1596   1.0151  -2.1499  0.2238  3.3925  -1.3989  0.0948   3.6135
# 1VAU  -9.4992  0.8408  27.7817   1.2813  0.0153  1.205    2.2009  0.0451   8.944
# 1DAM   5.2132  0.7521   8.3673   0.059   0.0001  0.0026   0.9198  0.0234   1.5621
# 2BOU   2.4501  0.3215   1.8481  -1.0687  0.0612  0.8383  -0.2614  0.0037   0.1262
# 1BOI   3.4144  0.5349   3.5892  -0.7938  0.0289  0.4625   0.9166  0.0386   1.5514
# 3EL    0.4741  0.0092   0.0692   1.5245  0.0951  1.7057  -3.4841  0.4966  22.4146
# DOM1   0.1062  0.0008   0.0035  -1.0417  0.0765  0.7964   0.7447  0.0391   1.024
# 1TUR  -2.2856  0.2508   1.6083  -0.2568  0.0032  0.0484   1.3672  0.0898   3.4513
#
# Continuous (the 10 first):
#                                   Dim1    cos2     ctr     Dim2    cos2     ctr     Dim3    cos2     ctr
# -----------------------------  -------  ------  ------  -------  ------  ------  -------  ------  ------
# Odor.Intensity.before.shaking   0.4726  0.2234  1.4443   0.7626  0.5816  8.9642  -0.0307  0.0009  0.0365
# Aroma.quality.before.shaking    0.8135  0.6618  4.2789   0.0529  0.0028  0.0431   0.2401  0.0576  2.2346
# Fruity.before.shaking           0.6819  0.465   3.0066  -0.0482  0.0023  0.0358   0.4837  0.234   9.073
# Flower.before.shaking           0.4774  0.2279  1.4738  -0.3031  0.0919  1.4162  -0.4804  0.2308  8.9477
# Spice.before.shaking           -0.0556  0.0031  0.02     0.7685  0.5905  9.1021  -0.1875  0.0352  1.3638
# Visual.intensity                0.8443  0.7129  4.609    0.3369  0.1135  1.7493  -0.1432  0.0205  0.7955
# Nuance                          0.8258  0.6819  4.4091   0.3297  0.1087  1.6751  -0.1371  0.0188  0.7285
# Surface.feeling                 0.93    0.865   5.5925   0.1845  0.034   0.5246   0.0479  0.0023  0.0891
# Odor.Intensity                  0.5448  0.2968  1.919    0.6855  0.4699  7.2423  -0.1765  0.0311  1.2074
# Quality.of.odour                0.8265  0.6831  4.4166  -0.2739  0.075   1.156    0.3611  0.1304  5.0574
#
# Categories:
#                Dim1    vtest    cos2     ctr     Dim2    vtest    cos2      ctr     Dim3    vtest    cos2      ctr
# ----------  -------  -------  ------  ------  -------  -------  ------  -------  -------  -------  ------  -------
# Bourgueuil  -0.1292  -0.3654  0.0067  0.0308  -0.6382  -1.8051  0.1629   1.7935  -0.088   -0.2489  0.0031   0.0858
# Chinon      -0.457   -0.9915  0.0491  0.2572  -0.1773  -0.3845  0.0074   0.0922   1.1378   2.4683  0.3046   9.5621
# Saumur       0.2367   1.11    0.0616  0.1897   0.4126   1.9351  0.1872   1.3741  -0.3658  -1.7156  0.1472   2.7172
# Env1        -0.4624  -1.4622  0.1069  0.4608  -0.5195  -1.6428  0.1349   1.3866  -0.9007  -2.8481  0.4056  10.4848
# Env2        -0.4372  -1.093   0.0597  0.2942   0.1777   0.4443  0.0099   0.1159   0.9209   2.3023  0.265    7.8296
# Env4        -0.239   -0.3468  0.006   0.0352   2.7258   3.9549  0.7821  10.9061  -0.3283  -0.4764  0.0113   0.3981
# Reference    0.843    2.6657  0.3553  1.5314  -0.3862  -1.2213  0.0746   0.7664   0.3367   1.0647  0.0567   1.4652
#
# Categorical variables:
#          Dim1     ctr    Dim2      ctr    Dim3      ctr
# -----  ------  ------  ------  -------  ------  -------
# Label  0.0739  0.4777  0.2115   3.2599  0.3189  12.3651
# Soil   0.3591  2.3216  0.8548  13.1751  0.5204  20.1777

# %% [markdown]
# ### Dimension description - `dimdesc`

# %%
# dimension description
from scientisttools import dimdesc
dim_desc = dimdesc(clf,axis=[0,1])
dim_desc.keys()
# Out:
# dict_keys(['Dim1', 'Dim2'])

# %% [markdown]
# ### `Dim1` dimension

# %%
# Dim1 dimension
dim_desc["Dim1"]._fields
# Out:
# ('call', 'quanti', 'category')

# %% [markdown]
# #### Description of Dim1 by quantitative variables

# %%
# description of Dim1 by quantitative variables
dim_desc["Dim1"].quanti
# Out:
#                                correlation        pvalue
# Harmony                           0.949400  5.255839e-11
# Intensity                         0.939783  2.643016e-10
# Surface.feeling                   0.930044  1.056564e-09
# Aroma.persistency                 0.918552  4.281721e-09
# Smooth                            0.902555  2.206577e-08
# Aroma.intensity                   0.885003  9.915754e-08
# Attack.intensity                  0.874586  2.166644e-07
# Balance                           0.856242  7.354269e-07
# Visual.intensity                  0.844312  1.493481e-06
# Typical                           0.839954  1.906789e-06
# Overall.quality                   0.837404  2.192635e-06
# Quality.of.odour                  0.826498  3.883447e-06
# Nuance                            0.825798  4.023321e-06
# Aroma.quality.before.shaking      0.813516  7.302980e-06
# Aroma.quality                     0.811761  7.924409e-06
# Alcohol                           0.756856  7.148093e-05
# Fruity                            0.746195  1.026566e-04
# Astringency                       0.738717  1.309840e-04
# Fruity.before.shaking             0.681922  6.621663e-04
# Odor.Intensity                    0.544804  1.065514e-02
# Flower.before.shaking             0.477437  2.861723e-02
# Odor.Intensity.before.shaking     0.472630  3.049407e-02
# Plante                           -0.602431  3.851628e-03

# %% [markdown]
# #### Description of Dim1 by levels

# %%
# description of Dim1 by levels
dim_desc["Dim1"].category
# Out:
#                 Estimate   pvalue
# Soil=Reference   4.97277  0.00435
