# %% [markdown]
# # FAMD - autos2005 dataset

# %%
# disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %% [markdown]
# ## autos2005 dataset

# %%
# autos2005 dataset
from scientisttools.datasets import autos2005
autos2005._fields
# Out:
# ('actif', 'ind_sup', 'sup_var', 'data')

# %%
# overall dataset
data = autos2005.data
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 45 entries, ALFA 156 to MERCEDES
# Data columns (total 16 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   puissance     45 non-null     int64
#  1   cylindree     45 non-null     int64
#  2   vitesse       45 non-null     int64
#  3   longueur      45 non-null     int64
#  4   largeur       45 non-null     int64
#  5   hauteur       45 non-null     int64
#  6   poids         45 non-null     int64
#  7   CO2           45 non-null     int64
#  8   prix          45 non-null     int64
#  9   origine       45 non-null     str
#  10  carburant     45 non-null     str
#  11  type4X4       45 non-null     str
#  12  coffre        38 non-null     float64
#  13  reservoir     38 non-null     float64
#  14  consommation  38 non-null     float64
#  15  surtaxe       38 non-null     str
# dtypes: float64(3), int64(9), str(4)
# memory usage: 6.0+ KB

# %% [markdown]
# ## Instanciation and training

# %%
# instanciation
from scientisttools import FAMD
clf = FAMD(ind_sup=range(38,45),sup_var=range(12,16))

# %% [markdown]
# ### `fit` function

# %%
# fit function
clf.fit(data)
# Out:
# FAMD(ind_sup=range(38, 45), sup_var=range(12, 16))

# %% [markdown]
# ### `fit_transform` function

# %%
# fit_transform function - individuals coordinates
ind_coord = clf.fit_transform(data)
ind_coord
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# ALFA 156   1.926355 -2.210697 -0.136748 -1.413584  0.086288
# AUDIA3    -1.530127 -0.774674  0.395755 -1.069045  0.500480
# AUDIA8     5.044196 -2.233793  0.886695 -0.551746  0.934364
# AVENSIS   -0.378548  0.775136  0.289204  0.037953 -1.751094
# BMW X5     2.908971  0.792592  1.942173  0.240357  1.130565
# BMW530     2.361730 -1.900818  0.541355 -0.831661  0.321859
# CHRYS300   5.375234 -1.392862 -1.124205 -0.790000 -0.439996
# CITRONC2  -3.793471 -0.154881 -1.192111  0.445525  0.642891
# CITRONC4  -0.956496 -0.309168  0.492382  1.695511 -0.653233
# CITRONC5   1.263753 -1.519353 -1.002797  0.970737  0.258052
# CLIO      -3.185350 -0.127988  0.152794  1.207490 -0.899235
# CORSA     -3.341345  0.397463  1.387862 -0.663732 -0.500888
# FIESTA    -3.077963  0.443507  1.553040 -0.504841 -0.425597
# GOLF      -1.905283  0.575964  1.705882 -0.325653 -0.006768
# LAGUNA    -0.176220 -1.504658 -0.915818  0.913525  0.017214
# LANDCRUI   5.308792  4.191512 -0.094795  0.490429  1.160521
# MAZDARX8   1.069839 -1.473971 -1.745799 -1.202617 -1.665572
# MEGANECC  -0.180189 -1.599410 -0.899688  0.910936  0.002863
# MERC_A    -1.114909  0.573248  1.671760 -0.336100  0.238243
# MERC_E     2.092044 -0.931949  2.021415  0.088476 -0.588459
# MODUS     -2.173742 -0.072765 -1.106887  0.638633  1.019780
# MONDEO     0.498111 -1.363592  0.751897 -0.625464  0.364132
# MURANO     3.855049  2.214318 -1.802917 -0.729993  0.683214
# MUSA      -1.793730  1.343465  1.552099 -0.385352  0.627229
# OUTLAND    1.759862  2.633746 -0.730905 -0.180524 -1.236774
# P1007     -2.863038  0.447999 -1.077086  0.669455  1.316542
# P307CC     0.062422 -1.524148 -1.032707  0.853722  0.092434
# P407      -0.098574 -1.242825 -0.754673  1.102267  0.240740
# P607       1.860826 -0.945364  0.484537  1.893822 -0.701544
# PANDA     -4.237168  0.404188 -0.055952 -1.601231  1.000707
# PASSAT    -0.038284 -1.229433  0.393206 -0.915604  0.174213
# PTCRUISER  0.735570  0.099887 -1.554969 -1.066986 -0.414205
# SANTA_FE   1.060730  3.820407 -0.295682  0.176013 -0.286512
# TWINGO    -4.304411 -0.240405 -1.363127  0.232432  0.553621
# VECTRA    -0.131025 -0.451318  1.825127 -0.078393 -0.727265
# VELSATIS   1.005977  0.242958  0.740140  2.121928  0.120804
# X-TRAIL    0.637168  3.376214 -0.468442 -0.100025 -0.744247
# YARIS     -3.546755  0.871466 -1.432016 -1.316660 -0.445368

# %% [markdown]
# ### `transform` function

# %%
# transform function - individuals coordinates
ind_coord = clf.transform(data)
ind_coord
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# ALFA 156   1.926355 -2.210697 -0.136748 -1.413584  0.086288
# AUDIA3    -1.530127 -0.774674  0.395755 -1.069045  0.500480
# AUDIA8     5.044196 -2.233793  0.886695 -0.551746  0.934364
# AVENSIS   -0.378548  0.775136  0.289204  0.037953 -1.751094
# BMW X5     2.908971  0.792592  1.942173  0.240357  1.130565
# BMW530     2.361730 -1.900818  0.541355 -0.831661  0.321859
# CHRYS300   5.375234 -1.392862 -1.124205 -0.790000 -0.439996
# CITRONC2  -3.793471 -0.154881 -1.192111  0.445525  0.642891
# CITRONC4  -0.956496 -0.309168  0.492382  1.695511 -0.653233
# CITRONC5   1.263753 -1.519353 -1.002797  0.970737  0.258052
# CLIO      -3.185350 -0.127988  0.152794  1.207490 -0.899235
# CORSA     -3.341345  0.397463  1.387862 -0.663732 -0.500888
# FIESTA    -3.077963  0.443507  1.553040 -0.504841 -0.425597
# GOLF      -1.905283  0.575964  1.705882 -0.325653 -0.006768
# LAGUNA    -0.176220 -1.504658 -0.915818  0.913525  0.017214
# LANDCRUI   5.308792  4.191512 -0.094795  0.490429  1.160521
# MAZDARX8   1.069839 -1.473971 -1.745799 -1.202617 -1.665572
# MEGANECC  -0.180189 -1.599410 -0.899688  0.910936  0.002863
# MERC_A    -1.114909  0.573248  1.671760 -0.336100  0.238243
# MERC_E     2.092044 -0.931949  2.021415  0.088476 -0.588459
# MODUS     -2.173742 -0.072765 -1.106887  0.638633  1.019780
# MONDEO     0.498111 -1.363592  0.751897 -0.625464  0.364132
# MURANO     3.855049  2.214318 -1.802917 -0.729993  0.683214
# MUSA      -1.793730  1.343465  1.552099 -0.385352  0.627229
# OUTLAND    1.759862  2.633746 -0.730905 -0.180524 -1.236774
# P1007     -2.863038  0.447999 -1.077086  0.669455  1.316542
# P307CC     0.062422 -1.524148 -1.032707  0.853722  0.092434
# P407      -0.098574 -1.242825 -0.754673  1.102267  0.240740
# P607       1.860826 -0.945364  0.484537  1.893822 -0.701544
# PANDA     -4.237168  0.404188 -0.055952 -1.601231  1.000707
# PASSAT    -0.038284 -1.229433  0.393206 -0.915604  0.174213
# PTCRUISER  0.735570  0.099887 -1.554969 -1.066986 -0.414205
# SANTA_FE   1.060730  3.820407 -0.295682  0.176013 -0.286512
# TWINGO    -4.304411 -0.240405 -1.363127  0.232432  0.553621
# VECTRA    -0.131025 -0.451318  1.825127 -0.078393 -0.727265
# VELSATIS   1.005977  0.242958  0.740140  2.121928  0.120804
# X-TRAIL    0.637168  3.376214 -0.468442 -0.100025 -0.744247
# YARIS     -3.546755  0.871466 -1.432016 -1.316660 -0.445368
# CORVETTE   5.480293 -3.330639 -1.529499 -1.393798 -1.736875
# TAHOE      7.343133  3.635931 -1.157151  0.023072  2.976690
# OPEL       3.677638  0.868515  0.887719  1.973019  1.970842
# RENAULT    0.623822  0.319645 -1.718418  0.293492  1.001164
# CITROEN    0.017173 -1.684019  0.574988 -1.386361  0.855988
# TOYOTA    -0.083790  0.473470  0.817062  0.145953 -1.211020
# MERCEDES   2.402846  0.519229 -0.281626 -1.978356  0.142709

# %%
# attributes
from scientisttools import sprintf
sprintf(clf)
# Out:
# **Results of the Factor Analysis of Mixed Data (FAMD)**
#
# *The results are available in the following objects:
#
# name                 description
# -------------------  -----------------------------------------------------
# .call_               summary called parameters
# .eig_                eigenvalues
# .ind_                results for the individuals
# .ind_sup_            results for the supplementary individuals
# .levels_             results for the levels
# .levels_sup_         results for the supplementary levels
# .quali_var_          results for the qualitative variables
# .quali_var_sup_      results for the supplementary qualitative variables
# .quanti_var_         results for the quantitative variables
# .quanti_var_sup_     results for the supplementary quantitative variables
# .separate_analyses_  results for the separate analyses
# .svd_                results for generalized singular values decomposition
# .var_                results for variables

# %% [markdown]
# ## Eigen values

# %%
#eigenvalues
from scientisttools import get_eig
eig =  get_eig(clf)
eig
# Out:
#        Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1     6.602293    4.092257       50.786869       50.786869
# Dim2     2.510036    1.205140       19.307967       70.094835
# Dim3     1.304896    0.438129       10.037661       80.132497
# Dim4     0.866767    0.309234        6.667435       86.799932
# Dim5     0.557532    0.167951        4.288710       91.088642
# Dim6     0.389581    0.121886        2.996776       94.085418
# Dim7     0.267694    0.095605        2.059188       96.144606
# Dim8     0.172089    0.032077        1.323764       97.468370
# Dim9     0.140012    0.043340        1.077018       98.545388
# Dim10    0.096673    0.045782        0.743635       99.289023
# Dim11    0.050890    0.019811        0.391465       99.680488
# Dim12    0.031080    0.020623        0.239075       99.919563
# Dim13    0.010457         NaN        0.080437      100.000000

# %%
# scree plot - eigenvalue
from scientisttools import fviz_screeplot
p = fviz_screeplot(obj=clf,choice="eigenvalue")
print(p.show())
# Out:
# None

# %%
# scree plot - proportion
p = fviz_screeplot(obj=clf,choice="proportion")
print(p.show())
# Out:
# None

# %%
# scree plot - cumulative
p = fviz_screeplot(obj=clf,choice="cumulative")
print(p.show())
# Out:
# None

# %% [markdown]
# ## Individuals informations

# %%
#individuals informations
from scientisttools import get_mix
ind = get_mix(clf)
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
# individuals coordinates
ind.coord
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# ALFA 156   1.926355 -2.210697 -0.136748 -1.413584  0.086288
# AUDIA3    -1.530127 -0.774674  0.395755 -1.069045  0.500480
# AUDIA8     5.044196 -2.233793  0.886695 -0.551746  0.934364
# AVENSIS   -0.378548  0.775136  0.289204  0.037953 -1.751094
# BMW X5     2.908971  0.792592  1.942173  0.240357  1.130565
# BMW530     2.361730 -1.900818  0.541355 -0.831661  0.321859
# CHRYS300   5.375234 -1.392862 -1.124205 -0.790000 -0.439996
# CITRONC2  -3.793471 -0.154881 -1.192111  0.445525  0.642891
# CITRONC4  -0.956496 -0.309168  0.492382  1.695511 -0.653233
# CITRONC5   1.263753 -1.519353 -1.002797  0.970737  0.258052
# CLIO      -3.185350 -0.127988  0.152794  1.207490 -0.899235
# CORSA     -3.341345  0.397463  1.387862 -0.663732 -0.500888
# FIESTA    -3.077963  0.443507  1.553040 -0.504841 -0.425597
# GOLF      -1.905283  0.575964  1.705882 -0.325653 -0.006768
# LAGUNA    -0.176220 -1.504658 -0.915818  0.913525  0.017214
# LANDCRUI   5.308792  4.191512 -0.094795  0.490429  1.160521
# MAZDARX8   1.069839 -1.473971 -1.745799 -1.202617 -1.665572
# MEGANECC  -0.180189 -1.599410 -0.899688  0.910936  0.002863
# MERC_A    -1.114909  0.573248  1.671760 -0.336100  0.238243
# MERC_E     2.092044 -0.931949  2.021415  0.088476 -0.588459
# MODUS     -2.173742 -0.072765 -1.106887  0.638633  1.019780
# MONDEO     0.498111 -1.363592  0.751897 -0.625464  0.364132
# MURANO     3.855049  2.214318 -1.802917 -0.729993  0.683214
# MUSA      -1.793730  1.343465  1.552099 -0.385352  0.627229
# OUTLAND    1.759862  2.633746 -0.730905 -0.180524 -1.236774
# P1007     -2.863038  0.447999 -1.077086  0.669455  1.316542
# P307CC     0.062422 -1.524148 -1.032707  0.853722  0.092434
# P407      -0.098574 -1.242825 -0.754673  1.102267  0.240740
# P607       1.860826 -0.945364  0.484537  1.893822 -0.701544
# PANDA     -4.237168  0.404188 -0.055952 -1.601231  1.000707
# PASSAT    -0.038284 -1.229433  0.393206 -0.915604  0.174213
# PTCRUISER  0.735570  0.099887 -1.554969 -1.066986 -0.414205
# SANTA_FE   1.060730  3.820407 -0.295682  0.176013 -0.286512
# TWINGO    -4.304411 -0.240405 -1.363127  0.232432  0.553621
# VECTRA    -0.131025 -0.451318  1.825127 -0.078393 -0.727265
# VELSATIS   1.005977  0.242958  0.740140  2.121928  0.120804
# X-TRAIL    0.637168  3.376214 -0.468442 -0.100025 -0.744247
# YARIS     -3.546755  0.871466 -1.432016 -1.316660 -0.445368

# %%
# graph of individuals
from scientisttools import fviz_mix
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind = "black",
    repel = True,
    ind_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals contributions

# %%
# individuals contributions
ind.contrib
# Out:
#                 Dim1       Dim2      Dim3       Dim4       Dim5
# ALFA 156    1.479090   5.123831  0.037712   6.066772   0.035144
# AUDIA3      0.933204   0.629180  0.315860   3.469816   1.182277
# AUDIA8     10.141576   5.231456  1.585585   0.924257   4.120773
# AVENSIS     0.057117   0.629930  0.168674   0.004373  14.473228
# BMW X5      3.372875   0.658622  7.607049   0.175399   6.033056
# BMW530      2.223218   3.788066  0.591024   2.099940   0.488966
# CHRYS300   11.516390   2.034007  2.548774   1.894824   0.913783
# CITRONC2    5.735815   0.025150  2.865985   0.602642   1.950835
# CITRONC4    0.364660   0.100213  0.488929   8.728011   2.014107
# CITRONC5    0.636570   2.420215  2.027993   2.861000   0.314312
# CLIO        4.044230   0.017174  0.047082   4.426716   3.816742
# CORSA       4.450043   0.165627  3.884481   1.337517   1.184206
# FIESTA      3.776143   0.206223  4.864138   0.773789   0.854957
# GOLF        1.446908   0.347798  5.868653   0.321976   0.000216
# LAGUNA      0.012378   2.373626  1.691450   2.533702   0.001399
# LANDCRUI   11.233448  18.419505  0.018122   0.730240   6.357004
# MAZDARX8    0.456203   2.277793  6.146513   4.391057  13.094023
# MEGANECC    0.012941   2.681982  1.632392   2.519356   0.000039
# MERC_A      0.495451   0.344526  5.636227   0.342965   0.267909
# MERC_E      1.744469   0.910585  8.240458   0.023766   1.634480
# MODUS       1.883379   0.005551  2.470852   1.238274   4.908618
# MONDEO      0.098895   1.949421  1.140136   1.187734   0.625841
# MURANO      5.923542   5.140630  6.555295   1.617902   2.203232
# MUSA        1.282436   1.892297  4.858246   0.450848   1.856941
# OUTLAND     1.234465   7.272508  1.077363   0.098942   7.219827
# P1007       3.267202   0.210422  2.339598   1.360682   8.181175
# P307CC      0.001553   2.435513  2.150774   2.212828   0.040329
# P407        0.003873   1.619409  1.148570   3.688820   0.273554
# P607        1.380172   0.936989  0.473473  10.889116   2.323038
# PANDA       7.156044   0.171279  0.006314   7.784350   4.726723
# PASSAT      0.000584   1.584697  0.311804   2.545245   0.143255
# PTCRUISER   0.215660   0.010460  4.876230   3.456458   0.809800
# SANTA_FE    0.448468  15.302269  0.176315   0.094060   0.387464
# TWINGO      7.384976   0.060593  3.747257   0.164024   1.446678
# VECTRA      0.006843   0.213551  6.717792   0.018658   2.496502
# VELSATIS    0.403365   0.061887  1.104760  13.670220   0.068882
# X-TRAIL     0.161819  11.950789  0.442540   0.030376   2.614453
# YARIS       5.013997   0.796227  4.135581   5.263341   0.936232

# %%
# graph of individuals - color by contributions
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind="contrib",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph 
from scientisttools import fviz_corrplot
p = fviz_corrplot(
    X=ind.contrib,
    legend_title="Contrib",
    title="Contributions of individuals"
)
print(p.show())
# Out:
# None

# %%
# contributions of individuals to axis 1
from scientisttools import fviz_contrib
p = fviz_contrib(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals cos2

# %%
# individuals cos2
ind.cos2
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# ALFA 156   0.289994  0.381921  0.001461  0.156156  0.000582
# AUDIA3     0.434755  0.111437  0.029083  0.212218  0.046512
# AUDIA8     0.731004  0.143358  0.022588  0.008746  0.025082
# AVENSIS    0.025377  0.106404  0.014812  0.000255  0.543025
# BMW X5     0.535081  0.039723  0.238515  0.003653  0.080822
# BMW530     0.517402  0.335157  0.027185  0.064159  0.009609
# CHRYS300   0.753802  0.050615  0.032973  0.016282  0.005051
# CITRONC2   0.864782  0.001442  0.085402  0.011928  0.024837
# CITRONC4   0.188499  0.019694  0.049951  0.592302  0.087918
# CITRONC5   0.249533  0.360679  0.157119  0.147234  0.010404
# CLIO       0.741793  0.001198  0.001707  0.106595  0.059117
# CORSA      0.776076  0.010981  0.133892  0.030623  0.017440
# FIESTA     0.733157  0.015222  0.186653  0.019723  0.014017
# GOLF       0.465790  0.042566  0.373396  0.013608  0.000006
# LAGUNA     0.007260  0.529272  0.196075  0.195094  0.000069
# LANDCRUI   0.580093  0.361616  0.000185  0.004951  0.027721
# MAZDARX8   0.090520  0.171825  0.241044  0.114383  0.219399
# MEGANECC   0.007203  0.567478  0.179562  0.184079  0.000002
# MERC_A     0.206951  0.054711  0.465304  0.018807  0.009450
# MERC_E     0.427599  0.084855  0.399214  0.000765  0.033832
# MODUS      0.591156  0.000662  0.153282  0.051026  0.130106
# MONDEO     0.033610  0.251873  0.076582  0.052993  0.017961
# MURANO     0.604153  0.199327  0.132141  0.021663  0.018976
# MUSA       0.344576  0.193296  0.257994  0.015903  0.042133
# OUTLAND    0.214508  0.480435  0.037001  0.002257  0.105942
# P1007      0.684970  0.016771  0.096943  0.037451  0.144839
# P307CC     0.000873  0.520219  0.238829  0.163217  0.001913
# P407       0.002223  0.353343  0.130285  0.277939  0.013258
# P607       0.387045  0.099896  0.026242  0.400893  0.055012
# PANDA      0.817208  0.007436  0.000143  0.116705  0.045582
# PASSAT     0.000363  0.374752  0.038333  0.207850  0.007525
# PTCRUISER  0.086391  0.001593  0.386068  0.181776  0.027394
# SANTA_FE   0.066466  0.862203  0.005165  0.001830  0.004849
# TWINGO     0.859793  0.002682  0.086226  0.002507  0.014223
# VECTRA     0.003951  0.046875  0.766593  0.001414  0.121721
# VELSATIS   0.149315  0.008709  0.080827  0.664336  0.002153
# X-TRAIL    0.030425  0.854236  0.016445  0.000750  0.041510
# YARIS      0.669100  0.040395  0.109075  0.092209  0.010550

# %%
# graph of individuals - color by cosinus
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind="cos2",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus
p = fviz_corrplot(
    X=ind.cos2,
    legend_title="Cos2",
    title="Cosinus of individuals"
)
print(p.show())
# Out:
# None

# %%
# cosinus of individuals to axis 1
from scientisttools import fviz_cos2
p = fviz_cos2(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals additionals informations

# %%
# individuals additionals informations
ind.infos
# Out:
#              Weight  Sq. Dist.   Inertia  Inertia (%)
# ALFA 156   0.026316  12.796298  0.336745     2.590344
# AUDIA3     0.026316   5.385302  0.141718     1.090142
# AUDIA8     0.026316  34.806783  0.915968     7.045908
# AVENSIS    0.026316   5.646759  0.148599     1.143069
# BMW X5     0.026316  15.814642  0.416175     3.201345
# BMW530     0.026316  10.780341  0.283693     2.182255
# CHRYS300   0.026316  38.329862  1.008681     7.759081
# CITRONC2   0.026316  16.640523  0.437909     3.368527
# CITRONC4   0.026316   4.853528  0.127724     0.982496
# CITRONC5   0.026316   6.400248  0.168428     1.295597
# CLIO       0.026316  13.678284  0.359955     2.768883
# CORSA      0.026316  14.385941  0.378577     2.912134
# FIESTA     0.026316  12.922001  0.340053     2.615790
# GOLF       0.026316   7.793432  0.205090     1.577618
# LAGUNA     0.026316   4.277570  0.112568     0.865905
# LANDCRUI   0.026316  48.584101  1.278529     9.834838
# MAZDARX8   0.026316  12.644219  0.332743     2.559558
# MEGANECC   0.026316   4.507856  0.118628     0.912521
# MERC_A     0.026316   6.006355  0.158062     1.215861
# MERC_E     0.026316  10.235407  0.269353     2.071945
# MODUS      0.026316   7.993075  0.210344     1.618031
# MONDEO     0.026316   7.382227  0.194269     1.494378
# MURANO     0.026316  24.598733  0.647335     4.979501
# MUSA       0.026316   9.337471  0.245723     1.890176
# OUTLAND    0.026316  14.438204  0.379953     2.922713
# P1007      0.026316  11.966929  0.314919     2.422455
# P307CC     0.026316   4.465472  0.117512     0.903942
# P407       0.026316   4.371430  0.115038     0.884905
# P607       0.026316   8.946432  0.235432     1.811019
# PANDA      0.026316  21.969437  0.578143     4.447254
# PASSAT     0.026316   4.033353  0.106141     0.816468
# PTCRUISER  0.026316   6.262957  0.164815     1.267805
# SANTA_FE   0.026316  16.928159  0.445478     3.426753
# TWINGO     0.026316  21.549325  0.567087     4.362211
# VECTRA     0.026316   4.345314  0.114350     0.879618
# VELSATIS   0.026316   6.777561  0.178357     1.371976
# X-TRAIL    0.026316  13.343875  0.351155     2.701189
# YARIS      0.026316  18.800594  0.494752     3.805788

# %% [markdown]
# ## Quantitative variables informations

# %%
#quantitative variables informations
from scientisttools import get_mix
quanti_var = get_mix(clf,"quanti_var")
quanti_var._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Quantitative variables coordinates

# %%
# quantitative variables coordinates
quanti_var.coord
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# puissance  0.915854 -0.271477 -0.126173 -0.078209 -0.087112
# cylindree  0.888270 -0.039245  0.045671 -0.032799  0.112091
# vitesse    0.703443 -0.598329  0.038675  0.039319 -0.216977
# longueur   0.898565 -0.142099  0.129831  0.146551 -0.141009
# largeur    0.875931 -0.038653  0.187474  0.126832  0.116522
# hauteur    0.288396  0.846071  0.027647  0.046766  0.354161
# poids      0.915436  0.248944  0.099364  0.185024  0.078065
# CO2        0.891451 -0.090057 -0.327149 -0.156212  0.060012
# prix       0.940477 -0.062264  0.126079  0.016837  0.106727

# %%
# graph of variables - correlation circle
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables contributions

# %%
# quantitative variables contributions
quanti_var.contrib
# Out:
#                 Dim1       Dim2      Dim3      Dim4       Dim5
# puissance  12.704499   2.936194  1.219985  0.705684   1.361081
# cylindree  11.950761   0.061361  0.159850  0.124112   2.253572
# vitesse     7.494842  14.262651  0.114627  0.178358   8.444140
# longueur   12.229363   0.804451  1.291754  2.477867   3.566367
# largeur    11.621027   0.059522  2.693438  1.855917   2.435263
# hauteur     1.259747  28.518943  0.058574  0.252322  22.497385
# poids      12.692914   2.469008  0.756629  3.949611   1.093058
# CO2        12.036509   0.323113  8.201898  2.815326   0.645963
# prix       13.396814   0.154454  1.218178  0.032705   2.043035

# %%
# graph of variables - color by contrib
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    col_var = "contrib",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of contributions for variables
p = fviz_corrplot(
    X=quanti_var.contrib,
    legend_title="Contrib",
    title="Contributions of variables"
)
print(p.show())
# Out:
# None

# %%
# contributions of variables to axis 1
p = fviz_contrib(
    obj=clf,
    choice="quanti_var"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables cos2

# %%
# quantitative variables cos2
quanti_var.cos2
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# puissance  0.838788  0.073700  0.015920  0.006117  0.007588
# cylindree  0.789024  0.001540  0.002086  0.001076  0.012564
# vitesse    0.494831  0.357998  0.001496  0.001546  0.047079
# longueur   0.807418  0.020192  0.016856  0.021477  0.019884
# largeur    0.767254  0.001494  0.035147  0.016086  0.013577
# hauteur    0.083172  0.715836  0.000764  0.002187  0.125430
# poids      0.838023  0.061973  0.009873  0.034234  0.006094
# CO2        0.794686  0.008110  0.107026  0.024402  0.003601
# prix       0.884497  0.003877  0.015896  0.000283  0.011391

# %%
# graph of variables - color by cosinus
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    col_var = "cos2",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus for variables
p = fviz_corrplot(
    X=quanti_var.cos2,
    legend_title="Cos2",
    title="Cosinus of continuous variables"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables additionals informations

# %%
# quantitative variables additionals informations
quanti_var.infos
# Out:
#            Weight  Sq. Dist.  Inertia  Inertia (%)
# puissance     1.0        1.0      1.0     7.692308
# cylindree     1.0        1.0      1.0     7.692308
# vitesse       1.0        1.0      1.0     7.692308
# longueur      1.0        1.0      1.0     7.692308
# largeur       1.0        1.0      1.0     7.692308
# hauteur       1.0        1.0      1.0     7.692308
# poids         1.0        1.0      1.0     7.692308
# CO2           1.0        1.0      1.0     7.692308
# prix          1.0        1.0      1.0     7.692308

# %% [markdown]
# ## Levels informations

# %%
# levels informations
levels = clf.levels_
levels._fields
# Out:
# ('coord', 'cos2', 'dist2', 'contrib', 'vtest')

# %% [markdown]
# ### Levels coordinates

# %%
# levels coordinates
levels.coord
# Out:
#                  Dim1      Dim2      Dim3      Dim4      Dim5
# Autres       1.587694  1.511585 -0.896053 -0.468241 -0.514003
# Europe      -0.155895 -0.437723  1.095704 -0.598238  0.208607
# France      -1.041424 -0.657693 -0.575003  1.050460  0.154687
# Diesel       0.044101  0.964731  0.836976  0.316315 -0.308486
# Essence     -0.035701 -0.780973 -0.677552 -0.256065  0.249726
# type4X4_non -0.382473 -0.492006  0.102810  0.010427  0.012842
# type4X4_oui  2.524320  3.247239 -0.678548 -0.068820 -0.084759

# %%
# graph of variable categories
p = fviz_mix(
    obj=clf,
    choice="levels",
    repel=True,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels vtest

# %%
# levels vtest
levels.vtest
# Out:
#                  Dim1      Dim2      Dim3      Dim4      Dim5
# Autres       2.246163  3.468283 -2.851461 -1.828270 -2.502376
# Europe      -0.298035 -1.357194  4.711813 -3.156499  1.372386
# France      -1.777799 -1.820898 -2.207927  4.949156  0.908701
# Diesel       0.093933  3.332590  4.009966  1.859451 -2.261078
# Essence     -0.093933 -3.332590 -4.009966 -1.859451  2.261078
# type4X4_non -2.326087 -4.852921  1.406441  0.175022  0.268771
# type4X4_oui  2.326087  4.852921 -1.406441 -0.175022 -0.268771

# %% [markdown]
# ### Levels contributions

# %%
# levels contributions
levels.contrib
# Out:
#                  Dim1       Dim2       Dim3       Dim4       Dim5
# Autres       1.521810   9.543813  12.408852   7.679820  22.367012
# Europe       0.022008   1.200457  27.831890  18.804063   5.526179
# France       0.851188   2.348801   6.642757  50.247532   2.633457
# Diesel       0.001996   6.608729  18.405158   5.958013  13.696038
# Essence      0.001616   5.349924  14.899413   4.823153  11.087269
# type4X4_non  0.291435   3.336655   0.539078   0.012568   0.046076
# type4X4_oui  1.923471  22.021923   3.557918   0.082949   0.304104

# %%
# graph of variable categories  - color by contributions
p = fviz_mix(
    obj=clf,
    choice="levels",
    col_var = "contrib",
    repel=True,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of contributions for variable categories
p = fviz_corrplot(
    X=levels.contrib,
    legend_title="Contrib",
    title="Contributions of variable categories"
)
print(p.show())
# Out:
# None

# %%
# contributions of levels to axis 1
p = fviz_contrib(
    obj=clf,
    choice="levels"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels cos2

# %%
# levels cos2
levels.cos2
# Out:
#                  Dim1      Dim2      Dim3      Dim4      Dim5
# Autres       0.410995  0.372536  0.130909  0.035747  0.043076
# Europe       0.013281  0.104703  0.656068  0.195574  0.023780
# France       0.364033  0.145188  0.110975  0.370378  0.008031
# Diesel       0.001056  0.505554  0.380523  0.054349  0.051692
# Essence      0.001056  0.505554  0.380523  0.054349  0.051692
# type4X4_non  0.360277  0.596179  0.026032  0.000268  0.000406
# type4X4_oui  0.360277  0.596179  0.026032  0.000268  0.000406

# %%
# graph of variable categories - color by cosinus
p = fviz_mix(
    obj=clf,
    choice="levels",
    col_var = "cos2",
    repel=True,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus for variable categories
p = fviz_corrplot(
    X=levels.cos2,
    legend_title="Cos2",
    title="Cosinus of variable categories"
)
print(p.show())
# Out:
# None

# %%
# cosinus of variable categories to axis 1
p = fviz_cos2(
    obj=clf,
    choice="levels"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels dist2

# %%
# levels dist2
levels.dist2.to_frame()
# Out:
#              Sq. Dist.
# Autres        6.133345
# Europe        1.829946
# France        2.979299
# Diesel        1.840963
# Essence       1.206436
# type4X4_non   0.406036
# type4X4_oui  17.686908

# %% [markdown]
# ## Variables informations

# %%
# variables informations
var = get_mix(clf,"var")
var._fields
# Out:
# ('coord', 'contrib', 'cos2')

# %% [markdown]
# ### Variables coordinates

# %%
# variables coordinates
var.coord
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# puissance  0.838788  0.073700  0.015920  0.006117  0.007588
# cylindree  0.789024  0.001540  0.002086  0.001076  0.012564
# vitesse    0.494831  0.357998  0.001496  0.001546  0.047079
# longueur   0.807418  0.020192  0.016856  0.021477  0.019884
# largeur    0.767254  0.001494  0.035147  0.016086  0.013577
# hauteur    0.083172  0.715836  0.000764  0.002187  0.125430
# poids      0.838023  0.061973  0.009873  0.034234  0.006094
# CO2        0.794686  0.008110  0.107026  0.024402  0.003601
# prix       0.884497  0.003877  0.015896  0.000283  0.011391
# origine    0.158125  0.328641  0.611781  0.665082  0.170196
# carburant  0.000238  0.300166  0.434590  0.093448  0.138175
# type4X4    0.146235  0.636509  0.053462  0.000828  0.001952

# %%
# graph of variables
p = fviz_mix(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = False,
    quanti_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Variables contributions

# %%
# variables contributions
var.contrib
# Out:
#                 Dim1       Dim2       Dim3       Dim4       Dim5
# puissance  12.704499   2.936194   1.219985   0.705684   1.361081
# cylindree  11.950761   0.061361   0.159850   0.124112   2.253572
# vitesse     7.494842  14.262651   0.114627   0.178358   8.444140
# longueur   12.229363   0.804451   1.291754   2.477867   3.566367
# largeur    11.621027   0.059522   2.693438   1.855917   2.435263
# hauteur     1.259747  28.518943   0.058574   0.252322  22.497385
# poids      12.692914   2.469008   0.756629   3.949611   1.093058
# CO2        12.036509   0.323113   8.201898   2.815326   0.645963
# prix       13.396814   0.154454   1.218178   0.032705   2.043035
# origine     2.395006  13.093071  46.883499  76.731415  30.526647
# carburant   0.003612  11.958653  33.304571  10.781166  24.783308
# type4X4     2.214907  25.358578   4.096996   0.095517   0.350181

# %% [markdown]
# ### Variables cos2

# %%
# variables cos2
var.cos2
# Out:
#                    Dim1      Dim2          Dim3          Dim4      Dim5
# puissance  7.035657e-01  0.005432  2.534315e-04  3.741324e-05  0.000058
# cylindree  6.225592e-01  0.000002  4.350883e-06  1.157261e-06  0.000158
# vitesse    2.448581e-01  0.128162  2.237300e-06  2.389957e-06  0.002216
# longueur   6.519244e-01  0.000408  2.841264e-04  4.612753e-04  0.000395
# largeur    5.886791e-01  0.000002  1.235281e-03  2.587745e-04  0.000184
# hauteur    6.917618e-03  0.512421  5.842078e-07  4.783140e-06  0.015733
# poids      7.022832e-01  0.003841  9.748060e-05  1.171961e-03  0.000037
# CO2        6.315252e-01  0.000066  1.145462e-02  5.954726e-04  0.000013
# prix       7.823347e-01  0.000015  2.526813e-04  8.035780e-08  0.000130
# origine    1.250181e-02  0.054002  1.871379e-01  2.211672e-01  0.014483
# carburant  5.686851e-08  0.090100  1.888685e-01  8.732443e-03  0.019092
# type4X4    2.138456e-02  0.405144  2.858136e-03  6.854401e-07  0.000004

# %% [markdown]
# ## Supplementary individuals informations

# %%
# supplementary individuals informations
ind_sup = clf.ind_sup_
ind_sup._fields
# Out:
# ('coord', 'cos2', 'dist2')

# %% [markdown]
# ### Supplementary individuals coordinates

# %%
# supplementary individuals coordinates
ind_sup.coord
# Out:
#               Dim1      Dim2      Dim3      Dim4      Dim5
# CORVETTE  5.480293 -3.330639 -1.529499 -1.393798 -1.736875
# TAHOE     7.343133  3.635931 -1.157151  0.023072  2.976690
# OPEL      3.677638  0.868515  0.887719  1.973019  1.970842
# RENAULT   0.623822  0.319645 -1.718418  0.293492  1.001164
# CITROEN   0.017173 -1.684019  0.574988 -1.386361  0.855988
# TOYOTA   -0.083790  0.473470  0.817062  0.145953 -1.211020
# MERCEDES  2.402846  0.519229 -0.281626 -1.978356  0.142709

# %%
# graph of individuals
from scientisttools import fviz_mix
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind = "black",
    repel = True,
    ind_sup = True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Supplementary individuals cos2

# %%
# individuals cos2
ind_sup.cos2
# Out:
#               Dim1      Dim2      Dim3      Dim4      Dim5
# CORVETTE  0.501674  0.185297  0.039076  0.032450  0.050391
# TAHOE     0.626870  0.153690  0.015567  0.000006  0.103011
# OPEL      0.307777  0.017165  0.017933  0.088585  0.088390
# RENAULT   0.017866  0.004691  0.135571  0.003955  0.046017
# CITROEN   0.000018  0.170382  0.019863  0.115473  0.044021
# TOYOTA    0.000432  0.013798  0.041091  0.001311  0.090268
# MERCEDES  0.114971  0.005369  0.001579  0.077937  0.000406

# %% [markdown]
# ### Supplementary individuals dist2

# %%
# supplementary individuals dist2
ind_sup.dist2.to_frame()
# Out:
#           Sq. Dist.
# CORVETTE  59.866782
# TAHOE     86.017157
# OPEL      43.944185
# RENAULT   21.781633
# CITROEN   16.644525
# TOYOTA    16.246736
# MERCEDES  50.218569

# %% [markdown]
# ## Supplementary quantitative variables informations

# %%
# supplementary quantitative variables
quanti_var_sup = clf.quanti_var_sup_
quanti_var_sup._fields
# Out:
# ('coord', 'cos2', 'dist2')

# %% [markdown]
# ### Supplementary quantitative variables coordinates

# %%
# supplementary quantitative variables coordinates
quanti_var_sup.coord
# Out:
#                   Dim1      Dim2      Dim3      Dim4      Dim5
# coffre        0.596306  0.126690  0.354184  0.044716 -0.136088
# reservoir     0.890398  0.039033  0.171115  0.230733  0.099478
# consommation  0.837315 -0.162208 -0.414523 -0.197950  0.095953

# %%
# graph of variables - correlation circle
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    repel=True,
    quanti_sup=True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Supplementary quantitative variables cos2

# %%
# supplementary quantitative variables cos2
quanti_var_sup.cos2
# Out:
#                   Dim1      Dim2      Dim3      Dim4      Dim5
# coffre        0.355581  0.016050  0.125446  0.002000  0.018520
# reservoir     0.792809  0.001524  0.029280  0.053238  0.009896
# consommation  0.701097  0.026311  0.171829  0.039184  0.009207

# %% [markdown]
# ## Supplementary levels informations

# %%
# supplementary levels informations
levels_sup = clf.levels_sup_
levels_sup._fields
# Out:
# ('coord', 'cos2', 'dist2', 'vtest')

# %% [markdown]
# ### Supplementary levels coordinates

# %%
# supplementary levels coordinates
levels_sup.coord
# Out:
#                  Dim1      Dim2      Dim3      Dim4      Dim5
# surtaxe_non -0.331639 -0.758933 -0.221723 -0.038539  0.166018
# surtaxe_oui  0.216286  0.494956  0.144602  0.025134 -0.108272

# %%
# graph of individuals
from scientisttools import fviz_mix
p = fviz_mix(
    obj=clf,
    choice="levels",
    repel = True,
    quali_sup = True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Supplementary levels vtest

# %%
# supplementary levels vtest
levels_sup.vtest
# Out:
#                  Dim1     Dim2      Dim3      Dim4    Dim5
# surtaxe_non -0.634017 -2.35313 -0.953465 -0.203342  1.0922
# surtaxe_oui  0.634017  2.35313  0.953465  0.203342 -1.0922

# %% [markdown]
# ### Supplementary levels cos2

# %%
# supplementary levels cos2
levels_sup.cos2
# Out:
#                  Dim1      Dim2      Dim3      Dim4      Dim5
# surtaxe_non  0.136029  0.712373  0.060802  0.001837  0.034089
# surtaxe_oui  0.136029  0.712373  0.060802  0.001837  0.034089

# %% [markdown]
# ### Supplementary levels dist2

# %%
# supplementary levels dist2
levels_sup.dist2.to_frame()
# Out:
#              Sq. Dist.
# surtaxe_non   0.808536
# surtaxe_oui   0.343895

# %% [markdown]
# ## Supplementary qualitative variables informations

# %%
# supplementary qualitative variables informations
quali_var_sup = clf.quali_var_sup_
quali_var_sup._fields
# Out:
# ('coord',)

# %% [markdown]
# ### Supplementary qualitative variables coordinates

# %%
# supplementary qualitative variables coordinates
quali_var_sup.coord
# Out:
#              Dim1      Dim2     Dim3      Dim4      Dim5
# surtaxe  0.010864  0.149655  0.02457  0.001118  0.032241

# %% [markdown]
# ## Others functions
#
# ### Ellipses - `fviz_ellipses`

# %%
# ellipses
from scientisttools import fviz_ellipses
p = fviz_ellipses(
    obj=clf,
    habillage=["origine","carburant"],
    repel=True,
    add_ellipses=True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Summaries - `summary`

# %%
# summary
from scientisttools import summary
summary(clf)
# Out:
#                      Factor Analysis of Mixed Data - Results
#
# Importance of components:
#       Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1      6.6023      4.0923         50.7869         50.7869
# Dim2      2.5100      1.2051         19.3080         70.0948
# Dim3      1.3049      0.4381         10.0377         80.1325
#
# Individuals (the 10 first):
#             Dim1    cos2      ctr    Dim2    cos2     ctr    Dim3    cos2  \
# ALFA 156  1.9264  0.2900   1.4791 -2.2107  0.3819  5.1238 -0.1367  0.0015
# AUDIA3   -1.5301  0.4348   0.9332 -0.7747  0.1114  0.6292  0.3958  0.0291
# AUDIA8    5.0442  0.7310  10.1416 -2.2338  0.1434  5.2315  0.8867  0.0226
# AVENSIS  -0.3785  0.0254   0.0571  0.7751  0.1064  0.6299  0.2892  0.0148
# BMW X5    2.9090  0.5351   3.3729  0.7926  0.0397  0.6586  1.9422  0.2385
# BMW530    2.3617  0.5174   2.2232 -1.9008  0.3352  3.7881  0.5414  0.0272
# CHRYS300  5.3752  0.7538  11.5164 -1.3929  0.0506  2.0340 -1.1242  0.0330
# CITRONC2 -3.7935  0.8648   5.7358 -0.1549  0.0014  0.0251 -1.1921  0.0854
# CITRONC4 -0.9565  0.1885   0.3647 -0.3092  0.0197  0.1002  0.4924  0.0500
# CITRONC5  1.2638  0.2495   0.6366 -1.5194  0.3607  2.4202 -1.0028  0.1571
#
#              ctr
# ALFA 156  0.0377
# AUDIA3    0.3159
# AUDIA8    1.5856
# AVENSIS   0.1687
# BMW X5    7.6070
# BMW530    0.5910
# CHRYS300  2.5488
# CITRONC2  2.8660
# CITRONC4  0.4889
# CITRONC5  2.0280
#
# Supplementary individuals:
#             Dim1    cos2    Dim2    cos2    Dim3    cos2
# CORVETTE  5.4803  0.5017 -3.3306  0.1853 -1.5295  0.0391
# TAHOE     7.3431  0.6269  3.6359  0.1537 -1.1572  0.0156
# OPEL      3.6776  0.3078  0.8685  0.0172  0.8877  0.0179
# RENAULT   0.6238  0.0179  0.3196  0.0047 -1.7184  0.1356
# CITROEN   0.0172  0.0000 -1.6840  0.1704  0.5750  0.0199
# TOYOTA   -0.0838  0.0004  0.4735  0.0138  0.8171  0.0411
# MERCEDES  2.4028  0.1150  0.5192  0.0054 -0.2816  0.0016
#
# Continuous:
#              Dim1    cos2      ctr    Dim2    cos2      ctr    Dim3    cos2  \
# puissance  0.9159  0.8388  12.7045 -0.2715  0.0737   2.9362 -0.1262  0.0159
# cylindree  0.8883  0.7890  11.9508 -0.0392  0.0015   0.0614  0.0457  0.0021
# vitesse    0.7034  0.4948   7.4948 -0.5983  0.3580  14.2627  0.0387  0.0015
# longueur   0.8986  0.8074  12.2294 -0.1421  0.0202   0.8045  0.1298  0.0169
# largeur    0.8759  0.7673  11.6210 -0.0387  0.0015   0.0595  0.1875  0.0351
# hauteur    0.2884  0.0832   1.2597  0.8461  0.7158  28.5189  0.0276  0.0008
# poids      0.9154  0.8380  12.6929  0.2489  0.0620   2.4690  0.0994  0.0099
# CO2        0.8915  0.7947  12.0365 -0.0901  0.0081   0.3231 -0.3271  0.1070
# prix       0.9405  0.8845  13.3968 -0.0623  0.0039   0.1545  0.1261  0.0159
#
#               ctr
# puissance  1.2200
# cylindree  0.1599
# vitesse    0.1146
# longueur   1.2918
# largeur    2.6934
# hauteur    0.0586
# poids      0.7566
# CO2        8.2019
# prix       1.2182
#
# Categories:
#                Dim1   vtest    cos2     ctr    Dim2   vtest    cos2      ctr  \
# Autres       1.5877  2.2462  0.4110  1.5218  1.5116  3.4683  0.3725   9.5438
# Europe      -0.1559 -0.2980  0.0133  0.0220 -0.4377 -1.3572  0.1047   1.2005
# France      -1.0414 -1.7778  0.3640  0.8512 -0.6577 -1.8209  0.1452   2.3488
# Diesel       0.0441  0.0939  0.0011  0.0020  0.9647  3.3326  0.5056   6.6087
# Essence     -0.0357 -0.0939  0.0011  0.0016 -0.7810 -3.3326  0.5056   5.3499
# type4X4_non -0.3825 -2.3261  0.3603  0.2914 -0.4920 -4.8529  0.5962   3.3367
# type4X4_oui  2.5243  2.3261  0.3603  1.9235  3.2472  4.8529  0.5962  22.0219
#
#                Dim3   vtest    cos2      ctr
# Autres      -0.8961 -2.8515  0.1309  12.4089
# Europe       1.0957  4.7118  0.6561  27.8319
# France      -0.5750 -2.2079  0.1110   6.6428
# Diesel       0.8370  4.0100  0.3805  18.4052
# Essence     -0.6776 -4.0100  0.3805  14.8994
# type4X4_non  0.1028  1.4064  0.0260   0.5391
# type4X4_oui -0.6785 -1.4064  0.0260   3.5579
#
# Categorical variables:
#              Dim1     ctr    Dim2      ctr    Dim3      ctr
# origine    0.1581  2.3950  0.3286  13.0931  0.6118  46.8835
# carburant  0.0002  0.0036  0.3002  11.9587  0.4346  33.3046
# type4X4    0.1462  2.2149  0.6365  25.3586  0.0535   4.0970
#
# Supplementary continuous variables:
#                 Dim1    cos2    Dim2    cos2    Dim3    cos2
# coffre        0.5963  0.3556  0.1267  0.0161  0.3542  0.1254
# reservoir     0.8904  0.7928  0.0390  0.0015  0.1711  0.0293
# consommation  0.8373  0.7011 -0.1622  0.0263 -0.4145  0.1718
#
# Supplementary categories:
#                Dim1  vtest   cos2    Dim2   vtest    cos2    Dim3   vtest  \
# surtaxe_non -0.3316 -0.634  0.136 -0.7589 -2.3531  0.7124 -0.2217 -0.9535
# surtaxe_oui  0.2163  0.634  0.136  0.4950  2.3531  0.7124  0.1446  0.9535
#
#                cos2
# surtaxe_non  0.0608
# surtaxe_oui  0.0608
#
# Supplementary categorical variables:
#            Dim1    Dim2    Dim3
# surtaxe  0.0109  0.1497  0.0246

# %%
# formatting text to markdown
summary(clf,to_markdown=True)
# Out:
#                      Factor Analysis of Mixed Data - Results
#
# Importance of components:
#         Eigenvalue    Difference    Proportion (%)    Cumulative (%)
# ----  ------------  ------------  ----------------  ----------------
# Dim1        6.6023        4.0923           50.7869           50.7869
# Dim2        2.51          1.2051           19.308            70.0948
# Dim3        1.3049        0.4381           10.0377           80.1325
#
# Individuals (the 10 first):
#              Dim1    cos2      ctr     Dim2    cos2     ctr     Dim3    cos2     ctr
# --------  -------  ------  -------  -------  ------  ------  -------  ------  ------
# ALFA 156   1.9264  0.29     1.4791  -2.2107  0.3819  5.1238  -0.1367  0.0015  0.0377
# AUDIA3    -1.5301  0.4348   0.9332  -0.7747  0.1114  0.6292   0.3958  0.0291  0.3159
# AUDIA8     5.0442  0.731   10.1416  -2.2338  0.1434  5.2315   0.8867  0.0226  1.5856
# AVENSIS   -0.3785  0.0254   0.0571   0.7751  0.1064  0.6299   0.2892  0.0148  0.1687
# BMW X5     2.909   0.5351   3.3729   0.7926  0.0397  0.6586   1.9422  0.2385  7.607
# BMW530     2.3617  0.5174   2.2232  -1.9008  0.3352  3.7881   0.5414  0.0272  0.591
# CHRYS300   5.3752  0.7538  11.5164  -1.3929  0.0506  2.034   -1.1242  0.033   2.5488
# CITRONC2  -3.7935  0.8648   5.7358  -0.1549  0.0014  0.0251  -1.1921  0.0854  2.866
# CITRONC4  -0.9565  0.1885   0.3647  -0.3092  0.0197  0.1002   0.4924  0.05    0.4889
# CITRONC5   1.2638  0.2495   0.6366  -1.5194  0.3607  2.4202  -1.0028  0.1571  2.028
#
# Supplementary individuals:
#              Dim1    cos2     Dim2    cos2     Dim3    cos2
# --------  -------  ------  -------  ------  -------  ------
# CORVETTE   5.4803  0.5017  -3.3306  0.1853  -1.5295  0.0391
# TAHOE      7.3431  0.6269   3.6359  0.1537  -1.1572  0.0156
# OPEL       3.6776  0.3078   0.8685  0.0172   0.8877  0.0179
# RENAULT    0.6238  0.0179   0.3196  0.0047  -1.7184  0.1356
# CITROEN    0.0172  0       -1.684   0.1704   0.575   0.0199
# TOYOTA    -0.0838  0.0004   0.4735  0.0138   0.8171  0.0411
# MERCEDES   2.4028  0.115    0.5192  0.0054  -0.2816  0.0016
#
# Continuous:
#              Dim1    cos2      ctr     Dim2    cos2      ctr     Dim3    cos2     ctr
# ---------  ------  ------  -------  -------  ------  -------  -------  ------  ------
# puissance  0.9159  0.8388  12.7045  -0.2715  0.0737   2.9362  -0.1262  0.0159  1.22
# cylindree  0.8883  0.789   11.9508  -0.0392  0.0015   0.0614   0.0457  0.0021  0.1599
# vitesse    0.7034  0.4948   7.4948  -0.5983  0.358   14.2627   0.0387  0.0015  0.1146
# longueur   0.8986  0.8074  12.2294  -0.1421  0.0202   0.8045   0.1298  0.0169  1.2918
# largeur    0.8759  0.7673  11.621   -0.0387  0.0015   0.0595   0.1875  0.0351  2.6934
# hauteur    0.2884  0.0832   1.2597   0.8461  0.7158  28.5189   0.0276  0.0008  0.0586
# poids      0.9154  0.838   12.6929   0.2489  0.062    2.469    0.0994  0.0099  0.7566
# CO2        0.8915  0.7947  12.0365  -0.0901  0.0081   0.3231  -0.3271  0.107   8.2019
# prix       0.9405  0.8845  13.3968  -0.0623  0.0039   0.1545   0.1261  0.0159  1.2182
#
# Categories:
#                 Dim1    vtest    cos2     ctr     Dim2    vtest    cos2      ctr     Dim3    vtest    cos2      ctr
# -----------  -------  -------  ------  ------  -------  -------  ------  -------  -------  -------  ------  -------
# Autres        1.5877   2.2462  0.411   1.5218   1.5116   3.4683  0.3725   9.5438  -0.8961  -2.8515  0.1309  12.4089
# Europe       -0.1559  -0.298   0.0133  0.022   -0.4377  -1.3572  0.1047   1.2005   1.0957   4.7118  0.6561  27.8319
# France       -1.0414  -1.7778  0.364   0.8512  -0.6577  -1.8209  0.1452   2.3488  -0.575   -2.2079  0.111    6.6428
# Diesel        0.0441   0.0939  0.0011  0.002    0.9647   3.3326  0.5056   6.6087   0.837    4.01    0.3805  18.4052
# Essence      -0.0357  -0.0939  0.0011  0.0016  -0.781   -3.3326  0.5056   5.3499  -0.6776  -4.01    0.3805  14.8994
# type4X4_non  -0.3825  -2.3261  0.3603  0.2914  -0.492   -4.8529  0.5962   3.3367   0.1028   1.4064  0.026    0.5391
# type4X4_oui   2.5243   2.3261  0.3603  1.9235   3.2472   4.8529  0.5962  22.0219  -0.6785  -1.4064  0.026    3.5579
#
# Categorical variables:
#              Dim1     ctr    Dim2      ctr    Dim3      ctr
# ---------  ------  ------  ------  -------  ------  -------
# origine    0.1581  2.395   0.3286  13.0931  0.6118  46.8835
# carburant  0.0002  0.0036  0.3002  11.9587  0.4346  33.3046
# type4X4    0.1462  2.2149  0.6365  25.3586  0.0535   4.097
#
# Supplementary continuous variables:
#                 Dim1    cos2     Dim2    cos2     Dim3    cos2
# ------------  ------  ------  -------  ------  -------  ------
# coffre        0.5963  0.3556   0.1267  0.0161   0.3542  0.1254
# reservoir     0.8904  0.7928   0.039   0.0015   0.1711  0.0293
# consommation  0.8373  0.7011  -0.1622  0.0263  -0.4145  0.1718
#
# Supplementary categories:
#                 Dim1    vtest    cos2     Dim2    vtest    cos2     Dim3    vtest    cos2
# -----------  -------  -------  ------  -------  -------  ------  -------  -------  ------
# surtaxe_non  -0.3316   -0.634   0.136  -0.7589  -2.3531  0.7124  -0.2217  -0.9535  0.0608
# surtaxe_oui   0.2163    0.634   0.136   0.495    2.3531  0.7124   0.1446   0.9535  0.0608
#
# Supplementary categorical variables:
#            Dim1    Dim2    Dim3
# -------  ------  ------  ------
# surtaxe  0.0109  0.1497  0.0246

# %% [markdown]
# ### Dimension description - `dimdesc`

# %%
# dimension description
from scientisttools import dimdesc
dim_desc = dimdesc(clf,axis=[0,1])
dim_desc.keys()
# Out:
# dict_keys(['Dim1', 'Dim2'])

# %% [markdown]
# ### `Dim1` dimension

# %%
# Dim1 dimension
dim_desc["Dim1"]._fields
# Out:
# ('call', 'quanti', 'quali', 'category')

# %% [markdown]
# #### Description of Dim1 by quantitative variables

# %%
# description of Dim1 by quantitative variables
dim_desc["Dim1"].quanti
# Out:
#               correlation        pvalue
# prix             0.940477  1.873405e-18
# puissance        0.915854  7.761001e-16
# poids            0.915436  8.454828e-16
# longueur         0.898565  1.939119e-14
# CO2              0.891451  6.184701e-14
# reservoir        0.890398  7.293517e-14
# cylindree        0.888270  1.012530e-13
# largeur          0.875931  6.008567e-13
# consommation     0.837315  5.658351e-11
# vitesse          0.703443  8.402188e-07
# coffre           0.596306  7.790381e-05

# %% [markdown]
# #### Description of Dim1 by levels

# %%
# description of Dim1 by levels
dim_desc["Dim1"].category
# Out:
#                      Estimate    pvalue
# origine=Autres       2.154728  0.022514
# type4X4=type4X4_non -2.906793  0.017816
# type4X4=type4X4_oui  2.906793  0.017816

# %% [markdown]
# #### Description of Dim1 by qualitative variables

# %%
# description of Dim1 by qualitative variables
dim_desc["Dim1"].quali
# Out:
#                R2    pvalue
# origine  0.158125  0.049185
# type4X4  0.146235  0.017816
