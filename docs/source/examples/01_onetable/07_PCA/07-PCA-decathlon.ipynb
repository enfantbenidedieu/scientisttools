# %% [markdown]
# # PCA - decathlon dataset

# %%
# disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %% [markdown]
# ## decathlon dataset

# %%
# decathlon dataset
from scientisttools.datasets import decathlon
data = decathlon.data
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 46 entries, SEBRLE to Christian Plaziat
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   X100m         46 non-null     float64
#  1   Long.Jump     46 non-null     float64
#  2   Shot.Put      46 non-null     float64
#  3   High.Jump     46 non-null     float64
#  4   X400m         46 non-null     float64
#  5   X110m.Hurdle  46 non-null     float64
#  6   Discus        46 non-null     float64
#  7   Pole.Vault    46 non-null     float64
#  8   Javeline      46 non-null     float64
#  9   X1500m        46 non-null     float64
#  10  Rank          46 non-null     int64
#  11  Points        46 non-null     int64
#  12  Competition   46 non-null     str
# dtypes: float64(10), int64(2), str(1)
# memory usage: 5.0+ KB

# %% [markdown]
# ## Instanciation & training

# %%
#instanciation
from scientisttools import PCA
clf = PCA(ind_sup=range(41,46),sup_var=(10,11,12))

# %% [markdown]
# ### `fit` function

# %%
# fit function
clf.fit(data)
# Out:
# PCA(ind_sup=range(41, 46), sup_var=(10, 11, 12))

# %% [markdown]
# ### `fit_transform` function

# %%
# fit_transform function - individuals coordinates
ind_coord = clf.fit_transform(data)
ind_coord
# Out:
#                  Dim1      Dim2      Dim3      Dim4      Dim5
# SEBRLE       0.791628  0.771611  0.826841  1.174627  0.707159
# CLAY         1.234991  0.574578  2.141247 -0.354845 -1.974571
# KARPOV       1.358215  0.484021  1.956258 -1.856524  0.795215
# BERNARD     -0.609515 -0.874629  0.889941  2.220612  0.361636
# YURKOV      -0.585968  2.130954 -1.225157  0.873579  1.251369
# WARNERS      0.356890 -1.684957  0.766553 -0.589305  1.001662
# ZSIVOCZKY    0.271775 -1.093776 -1.282767 -1.621565  0.044073
# McMULLEN     0.587516  0.230730 -0.417633 -1.524233  0.251520
# MARTINEAU   -1.995359  0.560996 -0.729947 -0.542191  1.578213
# HERNU       -1.546076  0.488383  0.840786  0.331195 -0.234980
# BARRAS      -1.341653 -0.310912 -0.000368 -0.645253  0.316287
# NOOL        -2.344974 -1.966375 -1.336482  0.195303  0.830228
# BOURGUIGNON -3.979042  0.199860  1.326485  0.524351  0.290012
# Sebrle       4.038449  1.365826 -0.289957  1.941134  0.376955
# Clay         3.919365  0.836961  0.231175  1.493972 -1.037609
# Karpov       4.619987  0.039995 -0.041586 -1.313526  0.187730
# Macey        2.233461  1.041766 -1.864362 -0.743214  0.977270
# Warners      2.168396 -1.803200  0.851017 -0.284600 -0.151395
# Zsivoczky    0.925132  1.168652 -1.477480  0.807595  0.872973
# Hernu        0.889038 -0.618425 -0.898295 -0.134785  0.634985
# Nool         0.295306 -1.545617  1.355260  2.199722 -0.035389
# Bernard      1.906334 -0.085804 -0.757186 -1.450979  0.341646
# Schwarzl     0.081079 -1.353457  0.822487  0.399091  0.288370
# Pogorelov    0.539677  0.770751  1.347620 -0.552157  0.972295
# Barras       0.002145  0.360338 -1.569693  0.612383 -0.675065
# Smith        0.870311  1.059326 -1.643429 -1.121327 -2.019908
# Averyanov    0.349155 -1.558650  0.282535 -0.027263 -0.360988
# Ojaniemi     0.380114 -0.772447 -0.370943  0.687279 -0.499257
# Smirnov     -0.484514 -1.060661 -1.228338  0.566032 -0.407184
# Qi          -0.434467 -0.326147 -1.069798 -0.204974 -0.535597
# Drews       -0.248684 -3.081677  1.054843 -0.645775 -0.178414
# Parkhomenko -1.069429  2.093182 -0.999984  1.534553  0.281807
# Terek       -0.681953  0.535614  2.209126  0.108623  1.043156
# Gomez       -0.289889 -1.196716 -1.306103  0.077851 -1.261438
# Turi        -1.541813  0.427168  0.514086 -0.142847 -0.038720
# Lorenzo     -2.408510 -1.582930 -1.502346  0.301031 -0.681959
# Karlivans   -1.994369 -0.294182 -0.342784 -1.272070  0.373221
# Korkizoglou -0.957830  2.066386  2.586553 -1.191468 -0.800891
# Uldal       -2.562260  0.245469 -0.419141 -0.021188 -1.259541
# Casarsa     -2.857088  3.797845  0.030561 -0.737694 -0.770450

# %%
# attributes
from scientisttools import sprintf
sprintf(clf)
# Out:
# **Results of the Principal Component Analysis (PCA)**
#
# *The results are available in the following objects:
#
# name              description
# ----------------  -----------------------------------------------------
# .call_            summary called parameters
# .eig_             eigenvalues
# .ind_             results for the individuals
# .ind_sup_         results for the supplementary individuals
# .levels_sup_      results for the supplementary levels
# .quali_var_sup_   results for the supplementary qualitative variables
# .quanti_var_      results for the quantitative variables
# .quanti_var_sup_  results for the supplementary quantitative variables
# .svd_             results for generalized singular values decomposition

# %% [markdown]
# ## Eigen values

# %%
# eigen values
from scientisttools import get_eig
eig = get_eig(clf)
eig
# Out:
#        Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1     3.271906    1.534775       32.719055       32.719055
# Dim2     1.737131    0.332214       17.371310       50.090366
# Dim3     1.404917    0.348066       14.049167       64.139532
# Dim4     1.056850    0.372077       10.568504       74.708036
# Dim5     0.684774    0.085505        6.847735       81.555771
# Dim6     0.599269    0.148033        5.992687       87.548458
# Dim7     0.451235    0.054359        4.512353       92.060811
# Dim8     0.396877    0.182062        3.968766       96.029577
# Dim9     0.214815    0.032587        2.148149       98.177725
# Dim10    0.182227         NaN        1.822275      100.000000

# %%
# scree plot
from scientisttools import fviz_screeplot
p = fviz_screeplot(clf,choice="eigenvalue")
print(p.show())
# Out:
# None

# %%
# proportion
p = fviz_screeplot(clf,choice="proportion")
print(p.show())
# Out:
# None

# %%
# cumulative proportion
p = fviz_screeplot(clf,choice="cumulative")
print(p.show())
# Out:
# None

# %% [markdown]
# ## Individuals informations

# %%
#individuals
from scientisttools import get_pca
ind = get_pca(clf)
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
# individuals coordinates
ind.coord
# Out:
#                  Dim1      Dim2      Dim3      Dim4      Dim5
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals contributions

# %%
# individuals contributions
ind.contrib
# Out:
#                   Dim1       Dim2          Dim3       Dim4       Dim5
# SEBRLE        0.467151   0.835951  1.186888e+00   3.184219   1.781162
# CLAY          1.136953   0.463534  7.959744e+00   0.290589  13.887205
# KARPOV        1.375157   0.328936  6.643820e+00   7.954334   2.252361
# BERNARD       0.276939   1.074066  1.374952e+00  11.380155   0.465814
# YURKOV        0.255955   6.375758  2.605847e+00   1.761194   5.577507
# WARNERS       0.094947   3.986218  1.020117e+00   0.801461   3.573643
# ZSIVOCZKY     0.055060   1.679732  2.856679e+00   6.068357   0.006919
# McMULLEN      0.257309   0.074747  3.027995e-01   5.361733   0.225327
# MARTINEAU     2.967957   0.441879  9.250128e-01   0.678434   8.871574
# HERNU         1.781875   0.334892  1.227259e+00   0.253145   0.196667
# BARRAS        1.341824   0.135724  2.355361e-07   0.960867   0.356314
# NOOL          4.099127   5.428955  3.100927e+00   0.088028   2.455068
# BOURGUIGNON  11.802456   0.056084  3.054712e+00   0.634521   0.299573
# Sebrle       12.157506   2.619234  1.459591e-01   8.695884   0.506113
# Clay         11.451090   0.983545  9.277875e-02   5.150954   3.834743
# Karpov       15.910981   0.002246  3.002311e-03   3.981803   0.125526
# Macey         3.718536   1.523786  6.034288e+00   1.274764   3.401719
# Warners       3.505038   4.565323  1.257310e+00   0.186927   0.081638
# Zsivoczky     0.638003   1.917581  3.789736e+00   1.505184   2.714378
# Hernu         0.589191   0.536980  1.400889e+00   0.041926   1.436137
# Nool          0.065007   3.354186  3.188680e+00  11.167049   0.004461
# Bernard       2.709028   0.010337  9.953382e-01   4.858755   0.415739
# Schwarzl      0.004900   2.572009  1.174420e+00   0.367576   0.296189
# Pogorelov     0.217112   0.834088  3.152828e+00   0.703603   3.367172
# Schoenbeck    0.009761   0.002230  9.517066e-01   1.991093   2.600266
# Barras        0.000003   0.182307  4.277552e+00   0.865464   1.623158
# Smith         0.564630   1.575587  4.688863e+00   2.901796  14.532232
# Averyanov     0.090877   3.410993  1.385834e-01   0.001715   0.464146
# Ojaniemi      0.107707   0.837763  2.388803e-01   1.090107   0.887804
# Smirnov       0.174996   1.579563  2.619396e+00   0.739409   0.590541
# Qi            0.140711   0.149352  1.986868e+00   0.096962   1.021751
# Drews         0.046101  13.333917  1.931706e+00   0.962421   0.113378
# Parkhomenko   0.852549   6.151735  1.736007e+00   5.434584   0.282861
# Terek         0.346676   0.402799  8.472402e+00   0.027230   3.875860
# Gomez         0.062644   2.010786  2.961557e+00   0.013987   5.667621
# Turi          1.772062   0.256201  4.588144e-01   0.047092   0.005340
# Lorenzo       4.324265   3.518089  3.918371e+00   0.209134   1.656480
# Karlivans     2.965011   0.121511  2.039886e-01   3.734433   0.496136
# Korkizoglou   0.683899   5.995236  1.161470e+01   3.276175   2.284631
# Uldal         4.893974   0.084601  3.049897e-01   0.001036   5.650592
# Casarsa       6.085030  20.251540  1.621460e-03   1.255899   2.114257

# %%
# graph of individuals - color by contributions
p = fviz_pca(
    obj=clf,
    choice="ind",
    col_ind="contrib",
    repel=True,
    ind_sup=False,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph 
from scientisttools import fviz_corrplot
p = fviz_corrplot(
    X=ind.contrib,
    legend_title="Contrib",
    title="Contributions of individuals"
)
print(p.show())
# Out:
# None

# %%
# contributions of individuals to axis 1
from scientisttools import fviz_contrib
p = fviz_contrib(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ###
# Terek        4.316993e-02  0.026630  4.530158e-01  0.001095  0.101012
# Gomez        1.231257e-02  0.209830  2.499419e-01  0.000888  0.233140
# Turi         2.524637e-01  0.019379  2.806770e-02  0.002167  0.000159
# Lorenzo      4.708005e-01  0.203359  1.831808e-01  0.007355  0.037745
# Karlivans    5.439001e-01  0.011834  1.606751e-02  0.221274  0.019048
# Korkizoglou  5.806095e-02  0.270228  4.233992e-01  0.089840  0.040593
# Uldal        7.566016e-01  0.006944  2.024606e-02  0.000052  0.182829
# Casarsa      3.371043e-01  0.595650  3.857070e-05  0.022473  0.024514

# %%
# graph of individuals - color by cosinus
p = fviz_pca(
    obj=clf,
    choice="ind",
    col_ind="cos2",
    repel=True,
    ind_sup=False,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus
p = fviz_corrplot(
    X=ind.cos2,
    legend_title="Cos2",
    title="Cosinus of individuals"
)
print(p.show())
# Out:
# None

# %%
# cosinus of individuals to axis 1
from scientisttools import fviz_cos2
p = fviz_cos2(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals additionals informations

# %%
# individuals additionals informations
ind.infos
# Out:
#               Weight  Sq. Dist.   Inertia  Inertia (%)
# SEBRLE       0.02439   5.611396  0.136863     1.368633
# CLAY         0.02439  12.299080  0.299978     2.999776
# KARPOV       0.02439  11.535524  0.281354     2.813542
# BERNARD      0.02439   7.631997  0.186146     1.861463
# YURKOV       0.02439   9.107759  0.222140     2.221405
# WARNERS      0.02439   5.894568  0.143770     1.437700
# ZSIVOCZKY    0.02439   6.569623  0.160235     1.602347
# McMULLEN     0.02439   6.560337  0.160008     1.600082
# MARTINEAU    0.02439  14.004392  0.341571     3.415705
# HERNU        0.02439   7.808954  0.190462     1.904623
# BARRAS       0.02439   3.809844  0.092923     0.929230
# NOOL         0.02439  13.944345  0.340106     3.401060
# BOURGUIGNON  0.02439  18.478065  0.450685     4.506845
# Sebrle       0.02439  23.452440  0.572011     5.720107
# Clay         0.02439  21.599144  0.526808     5.268084
# Karpov       0.02439  25.059172  0.611199     6.111993
# Macey        0.02439  11.791425  0.287596     2.875957
# Warners      0.02439   8.872533  0.216403     2.164032
# Zsivoczky    0.02439   6.583716  0.160578     1.605784
# Hernu        0.02439   3.327765  0.081165     0.811650
# Nool         0.02439   9.598156  0.234101     2.341014
# Bernard      0.02439   7.993441  0.194962     1.949620
# Schwarzl     0.02439   3.884297  0.094739     0.947390
# Pogorelov    0.02439   5.678151  0.138491     1.384915
# Schoenbeck   0.02439   3.229193  0.078761     0.787608
# Barras       0.02439   4.945994  0.120634     1.206340
# Smith        0.02439  12.505645  0.305016     3.050157
# Averyanov    0.02439   6.354119  0.154979     1.549785
# Ojaniemi     0.02439   5.464223  0.133274     1.332737
# Smirnov      0.02439   4.085295  0.099641     0.996413
# Qi           0.02439   3.113441  0.075938     0.759376
# Drews        0.02439  11.714338  0.285716     2.857156
# Parkhomenko  0.02439  12.149960  0.296340     2.963405
# Terek        0.02439  10.772776  0.262751     2.627506
# Gomez        0.02439   6.825202  0.166468     1.664683
# Turi         0.02439   9.415959  0.229658     2.296575
# Lorenzo      0.02439  12.321398  0.300522     3.005219
# Karlivans    0.02439   7.312935  0.178364     1.783643
# Korkizoglou  0.02439  15.801291  0.385397     3.853973
# Uldal        0.02439   8.677188  0.211639     2.116387
# Casarsa      0.02439  24.214920  0.590608     5.906078

# %% [markdown]
# ## Variables informations

# %%
# variables
var = get_pca(clf,element="var")
var._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Variables coordinates

# %%
# variables coordinates
var.coord
# Out:
#                   Dim1      Dim2      Dim3      Dim4      Dim5
# X100m        -0.774720  0.187142 -0.184407 -0.037818  0.302196
# Long.Jump     0.741900 -0.345421  0.182211  0.101786  0.036678
# Shot.Put      0.622503  0.598303 -0.023378  0.190592  0.111151
# High.Jump     0.571945  0.350294 -0.259512 -0.135594  0.555440
# X400m        -0.679610  0.569438  0.131470  0.029302 -0.087692
# X110m.Hurdle -0.746245  0.228793 -0.092637  0.290831  0.164321
# Discus        0.552467  0.606313  0.042952 -0.259671 -0.104827
# Pole.Vault    0.050342 -0.180357  0.691757  0.551534  0.329959
# Javeline      0.277111  0.316989 -0.389655  0.712277 -0.305129
# X1500m       -0.058077  0.474224  0.782143 -0.161089 -0.153562

# %%
# graph of variables - correlation circle
p = fviz_pca(
    obj=clf,
    choice="var",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Variables contributions

# %%
# variables contributions
var.contrib
# Out:
#                    Dim1       Dim2       Dim3       Dim4       Dim5
# X100m         18.343770   2.016090   2.420499   0.135329  13.336184
# Long.Jump     16.822467   6.868559   2.363191   0.980301   0.196456
# Shot.Put      11.843540  20.606785   0.038903   3.437115   1.804174
# High.Jump      9.997887   7.063694   4.793625   1.739678  45.053306
# X400m         14.116229  18.666374   1.230271   0.081242   1.122971
# X110m.Hurdle  17.020115   3.013382   0.610832   8.003279   3.943110
# Discus         9.328486  21.162245   0.131317   6.380208   1.604724
# Pole.Vault     0.077455   1.872547  34.060900  28.782667  15.899147
# Javeline       2.346963   5.784369  10.807142  48.004802  13.596270
# X1500m         0.103088  12.945954  43.543320   2.455379   3.443657

# %%
# graph of variables - color by contrib
p = fviz_pca(
    obj=clf,
    choice="var",
    col_var = "contrib",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of contributions for variables
p = fviz_corrplot(
    X=var.contrib,
    legend_title="Contrib",
    title="Contributions of variables"
)
print(p.show())
# Out:
# None

# %%
# contributions of variables to axis 1
p = fviz_contrib(
    obj=clf,
    choice="quanti_var"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Variables cos2

# %%
# variables cos2
var.cos2
# Out:
#                   Dim1      Dim2      Dim3      Dim4      Dim5
# X100m         0.600191  0.035022  0.034006  0.001430  0.091323
# Long.Jump     0.550415  0.119316  0.033201  0.010360  0.001345
# Shot.Put      0.387509  0.357967  0.000547  0.036325  0.012355
# High.Jump     0.327121  0.122706  0.067346  0.018386  0.308513
# X400m         0.461870  0.324259  0.017284  0.000859  0.007690
# X110m.Hurdle  0.556882  0.052346  0.008582  0.084583  0.027001
# Discus        0.305219  0.367616  0.001845  0.067429  0.010989
# Pole.Vault    0.002534  0.032529  0.478527  0.304190  0.108873
# Javeline      0.076790  0.100482  0.151831  0.507339  0.093104
# X1500m        0.003373  0.224888  0.611747  0.025950  0.023581

# %%
# graph of variables - color by cosinus
p = fviz_pca(
    obj=clf,
    choice="var",
    col_var = "cos2",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus for variables
p = fviz_corrplot(
    X=var.cos2,
    legend_title="Cos2",
    title="Cosinus of variables"
)
print(p.show())
# Out:
# None

# %%
# cosinus of variables to axis 1
p = fviz_cos2(
    obj=clf,
    choice="quanti_var"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Variables addtionals informations

# %%
# variables additionals informations
var.infos
# Out:
#               Weight  Sq. Dist.  Inertia  Inertia (%)
# X100m            1.0        1.0      1.0         10.0
# Long.Jump        1.0        1.0      1.0         10.0
# Shot.Put         1.0        1.0      1.0         10.0
# High.Jump        1.0        1.0      1.0         10.0
# X400m            1.0        1.0      1.0         10.0
# X110m.Hurdle     1.0        1.0      1.0         10.0
# Discus           1.0        1.0      1.0         10.0
# Pole.Vault       1.0        1.0      1.0         10.0
# Javeline         1.0        1.0      1.0         10.0
# X1500m           1.0        1.0      1.0         10.0

# %% [markdown]
# ## Biplot

# %%
# biplot of individuals and variables
p = fviz_pca(
    obj=clf,
    choice ="biplot",
    repel_ind = True,
    repel_var = True,
    ind_sup=False,
    quanti_sup = False,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ## Statistics with PCA

# %%
# statistics with PCA
from scientisttools import statsPCA
stats = statsPCA(clf)
stats._fields
# Out:
# ('corr', 'others')

# %% [markdown]
# ### Correlation

# %%
# correlation
corr = stats.corr
corr._fields
# Out:
# ('corrcoef', 'pcorrcoef', 'reconst', 'resid')

# %% [markdown]
# #### Pearson correlation

# %%
# pearson correlation
corr.corrcoef
# Out:
#                  X100m  Long.Jump  Shot.Put  High.Jump     X400m  \
# X100m         1.000000  -0.598678 -0.356482  -0.246253  0.520298
# Long.Jump    -0.598678   1.000000  0.183304   0.294644 -0.602063
# Shot.Put     -0.356482   0.183304  1.000000   0.489212 -0.138433
# High.Jump    -0.246253   0.294644  0.489212   1.000000 -0.187957
# X400m         0.520298  -0.602063 -0.138433  -0.187957  1.000000
# X110m.Hurdle  0.579889  -0.505410 -0.251616  -0.283289  0.547988
# Discus       -0.221708   0.194310  0.615768   0.369218 -0.117879
# Pole.Vault   -0.082537   0.204014  0.061182  -0.156181 -0.079292
# Javeline     -0.157746   0.119759  0.374956   0.171880  0.004232
# X1500m       -0.060546  -0.033686  0.115803  -0.044903  0.408106
#
#               X110m.Hurdle    Discus  Pole.Vault  Javeline    X1500m
# X100m             0.579889 -0.221708   -0.082537 -0.157746 -0.060546
# Long.Jump        -0.505410  0.194310    0.204014  0.119759 -0.033686
# X100m             0.676689 -0.344319   -0.121463 -0.202652 -0.050806
# Long.Jump        -0.613919  0.177992    0.293934  0.086402 -0.086408
# Shot.Put         -0.251792  0.644524    0.049050  0.473106  0.181521
# High.Jump        -0.270791  0.494207   -0.105417  0.104590 -0.133526
# X400m             0.619373 -0.022974   -0.058743 -0.011421  0.421085
# X110m.Hurdle      0.729394 -0.370280    0.071708  0.058842  0.007300
# Discus           -0.370280  0.753098   -0.229635  0.175580  0.346965
# Pole.Vault        0.071708 -0.229635    0.926653 -0.020603  0.313084
# Javeline          0.058842  0.175580   -0.020603  0.929546 -0.238420
# X1500m            0.007300  0.346965    0.313084 -0.238420  0.889539

# %% [markdown]
# #### Residuals correlations

# %%
# residuals correlation
corr.resid
# Out:
#                  X100m  Long.Jump  Shot.Put  High.Jump     X400m  \
# X100m              NaN   0.067096 -0.016878  -0.089546 -0.060923
# Long.Jump     0.067096        NaN -0.091080   0.032032  0.075114
# Shot.Put     -0.016878  -0.091080       NaN  -0.118369 -0.048835
# High.Jump    -0.089546   0.032032 -0.118369        NaN  0.088071
# X400m        -0.060923   0.075114 -0.048835   0.088071       NaN
# X110m.Hurdle -0.096800   0.108509  0.000176  -0.012498 -0.071385
# Discus        0.122611   0.016318 -0.028756  -0.124988 -0.094906
# Pole.Vault    0.038926  -0.089920  0.012131  -0.050764 -0.020549
# Javeline      0.044906   0.033357 -0.098151   0.067290  0.015653
# X1500m       -0.009741   0.052722 -0.065717   0.088624 -0.012978
#
#               X110m.Hurdle    Discus  Pole.Vault  Javeline    X1500m
# X100m            -0.096800  0.122611    0.038926  0.044906 -0.009741
# Long.Jump         0.108509  0.016318   -0.089920  0.033357  0.052722
# Shot.Put          0.000176 -0.028756    0.012131 -0.098151 -0.065717
# High.Jump        -0.012498 -0.124988   -0.050764  0.067290  0.088624
# X400m            -0.071385 -0.094906   -0.020549  0.015653 -0.012978
# X110m.Hurdle           NaN  0.044079   -0.074412 -0.050099  0.030240
# Discus            0.044079       NaN    0.079562 -0.017691 -0.088790
# Pole.Vault       -0.074412  0.079562         NaN -0.009398 -0.065636
# Javeline         -0.050099 -0.017691   -0.009398       NaN  0.058027
# X1500m            0.030240 -0.088790   -0.065636  0.058027       NaN

# %% [markdown]
# ### Others statistics

# %%
# others statistics
others = stats.others
others._fields
# Out:
# ('threshold', 'bartlett', 'broken', 'msa')

# %% [markdown]
# #### Kaiser threshold

# %%
# kaiser threshold
others.threshold
# Out:
#                  Kaiser-Guttman  Karlis-Saporta-Spinaki
# Critical values             1.0                1.948683

# %% [markdown]
# #### Bartlett test

# %%
# bartlett test
others.bartlett
# Out:
#                  |CORR.MATRIX|       CHISQ  dof       p-value
# Bartlett's test       0.024277  133.235798   45  1.156850e-10

# %% [markdown]
# #### Broken-stick critical values

# %%
# broken-stick critical values
others.broken
# Out:
#        Eigenvalue  Broken-stick critical values
# Dim1     3.271906                      2.928968
# Dim2     1.737131                      1.928968
# Dim3     1.404917                      1.428968
# Dim4     1.056850                      1.095635
# Dim5     0.684774                      0.845635
# Dim6     0.599269                      0.645635
# Dim7     0.451235                      0.478968
# Dim8     0.396877                      0.336111
# Dim9     0.214815                      0.211111
# Dim10    0.182227                      0.100000

# %% [markdown]
# ### Kaiser Measure of sampling adequancy - MSA

# %%
# measure of sampling adequancy
others.msa.to_frame()
# Out:
#               Kaiser's MSA
# overall           0.595960
# X100m             0.687058
# Long.Jump         0.717802
# Shot.Put          0.567854
# High.Jump         0.697939
# X400m             0.614161
# X110m.Hurdle      0.830240
# Discus            0.542680
# Pole.Vault        0.243974
# Javeline          0.442235
# X1500m            0.294044

# %% [markdown]
# ## Supplementary individuals informations

# %%
# supplementary individuals
ind_sup = clf.ind_sup_
ind_sup._fields
# Out:
# ('coord', 'cos2', 'dist2')

# %% [markdown]
# ### Supplementary individuals coordinates

# %%
# supplementary individuals coordinates
ind_sup.coord
# Out:
#                        Dim1      Dim2      Dim3      Dim4      Dim5
# Christian Schenk   1.630669  1.916026 -1.842366  0.182996  2.724505
# Torsten Voss       1.566727 -0.929610  0.150823  1.303518  0.310455
# Dave Steen         0.266513 -1.162435 -0.545881  2.038753  0.857200
# Daley Thompson     1.508294  0.463269  0.317601  1.172629 -0.277091
# Christian Plaziat  1.529499 -1.894488  0.357216 -0.999982  1.514249

# %%
# graph of individuals with supplementary individuals
p = fviz_pca(
    obj=clf,
    choice="ind",
    repel=True,
    ind_sup=True,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Supplementary individuals cos2

# %%
# supplementary individuals cos2
ind_sup.cos2
# Out:
#                        Dim1      Dim2      Dim3      Dim4      Dim5
# Christian Schenk   0.140207  0.193571  0.178974  0.001766  0.391394
# Torsten Voss       0.396738  0.139675  0.003677  0.274632  0.015578
# Dave Steen         0.008400  0.159792  0.035238  0.491527  0.086892
# Daley Thompson     0.424028  0.040003  0.018801  0.256297  0.014311
# Christian Plaziat  0.217002  0.332927  0.011837  0.092757  0.212696

# %% [markdown]
# ### Supplementary individuals dist2

# %%
# supplementary individuals squared distance to origin (dist2)
ind_sup.dist2.to_frame()
# Out:
#                    Sq. Dist.
# Christian Schenk   18.965380
# Torsten Voss        6.187036
# Dave Steen          8.456332
# Daley Thompson      5.365095
# Christian Plaziat  10.780411

# %% [markdown]
# ## Supplementary quantitative variables informations

# %%
# supplementary quantitative variables informations
quanti_var_sup = clf.quanti_var_sup_
quanti_var_sup._fields
# Out:
# ('coord', 'cos2', 'dist2')

# %% [markdown]
# ### Supplementary quantitative variables coordinates

# %%
# supplementary quantitative variables coordinates
quanti_var_sup.coord
# Out:
#             Dim1      Dim2      Dim3      Dim4      Dim5
# Rank   -0.670510  0.051398 -0.058343 -0.161408 -0.350026
# Points  0.956154 -0.016516 -0.066352  0.236008  0.113626

# %%
# graph of variables with supplementary quantitative variables
p = fviz_pca(
    obj=clf,
    choice="var",
    repel=True,
    quanti_sup = True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Supplementary quantitative variables cos2

# %%
# supplementary quantitative variables cos2
quanti_var_sup.cos2
# Out:
#             Dim1      Dim2      Dim3      Dim4      Dim5
# Rank    0.449584  0.002642  0.003404  0.026052  0.122518
# Points  0.914231  0.000273  0.004403  0.055700  0.012911

# %% [markdown]
# ## Supplementary levels informations

# %%
# supplementary levels informations
levels_sup = clf.levels_sup_
levels_sup._fields
# Out:
# ('coord', 'cos2', 'dist2', 'vtest')

# %% [markdown]
# ### Supplementary levels coordinates

# %%
# supplementary levels coordinates
levels_sup.coord
# Out:
#               Dim1      Dim2      Dim3      Dim4      Dim5
# Decastar -0.600121 -0.037655  0.288904 -0.139558  0.401371
# OlympicG  0.278628  0.017483 -0.134134  0.064795 -0.186351

# %%
# graph of individuals with supplementary levels
p = fviz_pca(
    obj=clf,
    choice="ind",
    repel=True,
    ind_sup=False,
    quali_sup=True
)
print(p.show())
# Out:
# None

# %%
# graph of individuals - confidence ellipse
p = fviz_pca(
    obj=clf,
    choice="ind",
    repel=True,
    habillage = "Competition",
    add_ellipses = True,
    ind_sup=True,
    quali_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Supplementary levels vtest

# %%
# supplementary levels vtest
levels_sup.vtest
# Out:
#               Dim1     Dim2      Dim3      Dim4      Dim5
# Decastar -1.429753 -0.12312  1.050392 -0.585018  2.090235
# OlympicG  1.429753  0.12312 -1.050392  0.585018 -2.090235

# %% [markdown]
# ### Supplementary levels cos2

# %%
# supplementary levels squared cosinus (cos2)
levels_sup.cos2
# Out:
#               Dim1      Dim2      Dim3      Dim4      Dim5
# Decastar  0.402769  0.001586  0.093344  0.021781  0.180165
# OlympicG  0.402769  0.001586  0.093344  0.021781  0.180165

# %% [markdown]
# ### Supplementary levels dist2

# %%
# supplementary levels dist2
levels_sup.dist2.to_frame()
# Out:
#           Sq. Dist.
# Decastar   0.894174
# OlympicG   0.192749

# %% [markdown]
# ## Supplementary qualitative variables informations

# %%
# supplmentary qualitative variables informations
quali_var_sup = clf.quali_var_sup_
quali_var_sup._fields
# Out:
# ('coord',)

# %% [markdown]
# ### Supplementary qualitative variables coordinates (=correlation ratio)

# %%
# supplementary qualitative variables coordinates (=correlation ratio)
quali_var_sup.coord
# Out:
#                  Dim1      Dim2      Dim3      Dim4      Dim5
# Competition  0.051105  0.000379  0.027583  0.008556  0.109227

# %%
# graph of variables (cos2 if quantitative and eta2 if qualitative)
from plotnine import ggplot
from scientisttools import add_scatter, set_axis
# draw variables cos2
p = add_scatter(
    p=ggplot(),
    data=var.cos2,
    color="black",
    repel=True
)
# add correlation ratio
p = add_scatter(
    p=p,
    data=quali_var_sup.coord,
    color="blue",
    repel=True
)
# set axis
p = set_axis(
    p = p,
    obj=clf,
    title = "Graph of variables"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ## Others functions
#
# ### Data reconstitution - `reconst`

# %%
#data reconstruction
from scientisttools import reconst
# ncp = 1
rec1 = reconst(clf,ncp=1)
rec1
# Out:
#                  X100m  Long.Jump   Shot.Put  High.Jump      X400m  \
# SEBRLE       10.909965   7.361471  14.698920   1.998821  49.277484
# CLAY         10.860632   7.418302  14.823168   2.011138  49.087701
# Barras          14.710024  44.460302    4.513666  64.401117  268.914180
# Smith           14.249345  48.438356    4.079573  62.589570  276.941356
# Averyanov       14.365356  42.498859    4.825411  56.886117  275.400746
# Ojaniemi        14.528207  43.114345    4.781507  61.437808  272.683867
# Smirnov         14.694880  41.750516    4.640547  61.257250  265.306977
# Qi              14.625376  43.652067    4.511096  59.566465  271.209592
# Drews           14.264315  40.089526    4.930709  51.128599  275.906521
# Parkhomenko     15.245576  44.915265    4.772281  66.076507  277.120771
# Terek           14.810678  44.187421    5.221340  53.495252  295.878941
# Gomez           14.505884  42.503080    4.469237  61.254437  266.788628
# Turi            14.895685  43.609000    4.791707  56.470750  285.620059
# Lorenzo         14.972139  39.294665    4.532433  59.290271  262.834526
# Karlivans       14.844795  42.714631    4.556787  52.201780  277.434448
# Korkizoglou     14.631766  48.176417    4.828772  53.404693  311.497629
# Uldal           15.014226  42.590886    4.525438  59.527767  280.536032
# Casarsa         15.292692  48.194209    4.409769  59.454304  299.051934

# %% [markdown]
# ### Description of axis - `dimdesc`

# %%
# description of axis
from scientisttools import dimdesc
desc_ncp = dimdesc(obj=clf,axis=range(clf.call_.ncp))
desc_ncp.keys()
# Out:
# dict_keys(['Dim1', 'Dim2', 'Dim3', 'Dim4', 'Dim5'])

# %% [markdown]
# #### `Dim1` dimension

# %%
# Dim1 dimension
desc_ncp["Dim1"]._fields
# Out:
# ('call', 'quanti')

# %%
# description of Dim1 by continuous variables
desc_ncp["Dim1"].quanti
# Out:
#               correlation        pvalue
# Points           0.956154  2.099191e-22
# Long.Jump        0.741900  2.849886e-08
# Shot.Put         0.622503  1.388321e-05
# High.Jump        0.571945  9.362285e-05
# Discus           0.552467  1.802220e-04
# Rank            -0.670510  1.616348e-06
# X400m           -0.679610  1.028175e-06
# X110m.Hurdle    -0.746245  2.136962e-08
# X100m           -0.774720  2.778467e-09

# %% [markdown]
# #### `Dim2` dimension

# %%
# Dim2 dimension
desc_ncp["Dim2"]._fields
# Out:
# ('call', 'quanti')

# %%
# description of Dim2 by continuous variables
desc_ncp["Dim2"].quanti
# Out:
#            correlation    pvalue
# Discus        0.606313  0.000027
# Shot.Put      0.598303  0.000036
# X400m         0.569438  0.000102
# X1500m        0.474224  0.001734
# High.Jump     0.350294  0.024750
# Javeline      0.316989  0.043450
# Long.Jump    -0.345421  0.026970

# %% [markdown]
# #### `Dim3` dimension

# %%
# Dim3 dimension
desc_ncp["Dim3"]._fields
# Out:
# ('call', 'quanti')

# %%
# description of Dim3 by continuous variables
desc_ncp["Dim3"].quanti
# Out:
#             correlation        pvalue
# X1500m         0.782143  1.554450e-09
# Pole.Vault     0.691757  5.480172e-07
# Javeline      -0.389655  1.179331e-02

# %% [markdown]
# #### `Dim4` dimension

# %%
# Dim4 dimension
desc_ncp["Dim4"]._fields
# Out:
# ('call', 'quanti')

# %%
# description of Dim4 by continuous variables
desc_ncp["Dim4"].quanti
# Out:
#             correlation        pvalue
# Javeline       0.712277  1.761578e-07
# Pole.Vault     0.551534  1.857748e-04

# %% [markdown]
# #### `Dim5` dimension

# %%
# Dim5 dimension
desc_ncp["Dim5"]._fields
# Out:
# ('call', 'quanti', 'quali', 'category')

# %%
# description of Dim5 by continuous variables
desc_ncp["Dim5"].quanti
# Out:
#             correlation    pvalue
# High.Jump      0.555440  0.000164
# Pole.Vault     0.329959  0.035132
# Rank          -0.350026  0.024868

# %%
# description of Dim5 by categorical variables
desc_ncp["Dim5"].quali
# Out:
#                    R2    pvalue
# Competition  0.109227  0.034818

# %%
# description of Dim5 by levels
desc_ncp["Dim5"].category
# Out:
#                       Estimate    pvalue
# Competition=Decastar  0.587722  0.034818
# Competition=OlympicG -0.587722  0.034818

# %% [markdown]
# ## Summary

# %%
# summary
from scientisttools import summary
summary(clf)
# Out:
#                      Principal Component Analysis - Results
#
# Importance of components:
#       Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1      3.2719      1.5348         32.7191         32.7191
# Dim2      1.7371      0.3322         17.3713         50.0904
# Dim3      1.4049      0.3481         14.0492         64.1395
#
# Individuals (the 10 first):
#              Dim1    cos2     ctr    Dim2    cos2     ctr    Dim3    cos2  \
# SEBRLE     0.7916  0.1117  0.4672  0.7716  0.1061  0.8360  0.8268  0.1218
# CLAY       1.2350  0.1240  1.1370  0.5746  0.0268  0.4635  2.1412  0.3728
# KARPOV     1.3582  0.1599  1.3752  0.4840  0.0203  0.3289  1.9563  0.3318
# BERNARD   -0.6095  0.0487  0.2769 -0.8746  0.1002  1.0741  0.8899  0.1038
# YURKOV    -0.5860  0.0377  0.2560  2.1310  0.4986  6.3758 -1.2252  0.1648
# WARNERS    0.3569  0.0216  0.0949 -1.6850  0.4816  3.9862  0.7666  0.0997
# ZSIVOCZKY  0.2718  0.0112  0.0551 -1.0938  0.1821  1.6797 -1.2828  0.2505
# McMULLEN   0.5875  0.0526  0.2573  0.2307  0.0081  0.0747 -0.4176  0.0266
# MARTINEAU -1.9954  0.2843  2.9680  0.5610  0.0225  0.4419 -0.7299  0.0380
# HERNU     -1.5461  0.3061  1.7819  0.4884  0.0305  0.3349  0.8408  0.0905
#
#               ctr
# SEBRLE     1.1869
# CLAY       7.9597
# KARPOV     6.6438
# BERNARD    1.3750
# YURKOV     2.6058
# WARNERS    1.0201
# ZSIVOCZKY  2.8567
# McMULLEN   0.3028
# MARTINEAU  0.9250
# HERNU      1.2273
#
# Supplementary individuals:
#                      Dim1    cos2    Dim2    cos2    Dim3    cos2
# Christian Schenk   1.6307  0.1402  1.9160  0.1936 -1.8424  0.1790
# Torsten Voss       1.5667  0.3967 -0.9296  0.1397  0.1508  0.0037
# Dave Steen         0.2665  0.0084 -1.1624  0.1598 -0.5459  0.0352
# Daley Thompson     1.5083  0.4240  0.4633  0.0400  0.3176  0.0188
# Christian Plaziat  1.5295  0.2170 -1.8945  0.3329  0.3572  0.0118
#
# Continuous (the 10 first):
#                 Dim1    cos2      ctr    Dim2    cos2      ctr    Dim3  \
# X100m        -0.7747  0.6002  18.3438  0.1871  0.0350   2.0161 -0.1844
# Long.Jump     0.7419  0.5504  16.8225 -0.3454  0.1193   6.8686  0.1822
# Shot.Put      0.6225  0.3875  11.8435  0.5983  0.3580  20.6068 -0.0234
# High.Jump     0.5719  0.3271   9.9979  0.3503  0.1227   7.0637 -0.2595
# X400m        -0.6796  0.4619  14.1162  0.5694  0.3243  18.6664  0.1315
# X110m.Hurdle -0.7462  0.5569  17.0201  0.2288  0.0523   3.0134 -0.0926
# Discus        0.5525  0.3052   9.3285  0.6063  0.3676  21.1622  0.0430
# Pole.Vault    0.0503  0.0025   0.0775 -0.1804  0.0325   1.8725  0.6918
# Javeline      0.2771  0.0768   2.3470  0.3170  0.1005   5.7844 -0.3897
# X1500m       -0.0581  0.0034   0.1031  0.4742  0.2249  12.9460  0.7821
#
#                 cos2      ctr
# X100m         0.0340   2.4205
# Long.Jump     0.0332   2.3632
# Shot.Put      0.0005   0.0389
# High.Jump     0.0673   4.7936
# X400m         0.0173   1.2303
# X110m.Hurdle  0.0086   0.6108
# Discus        0.0018   0.1313
# Pole.Vault    0.4785  34.0609
# Javeline      0.1518  10.8071
# X1500m        0.6117  43.5433
#
# Supplementary continuous variables:
#           Dim1    cos2    Dim2    cos2    Dim3    cos2
# Rank   -0.6705  0.4496  0.0514  0.0026 -0.0583  0.0034
# Points  0.9562  0.9142 -0.0165  0.0003 -0.0664  0.0044
#
# Supplementary categories:
#             Dim1   vtest    cos2    Dim2   vtest    cos2    Dim3   vtest  \
# Decastar -0.6001 -1.4298  0.4028 -0.0377 -0.1231  0.0016  0.2889  1.0504
# OlympicG  0.2786  1.4298  0.4028  0.0175  0.1231  0.0016 -0.1341 -1.0504
#
#             cos2
# Decastar  0.0933
# OlympicG  0.0933
#
# Supplementary categorical variables:
#                Dim1    Dim2    Dim3
# Competition  0.0511  0.0004  0.0276

# %%
# formatting text to markdown
summary(clf,to_markdown=True)
# Out:
#                      Principal Component Analysis - Results
#
# Importance of components:
#         Eigenvalue    Difference    Proportion (%)    Cumulative (%)
# ----  ------------  ------------  ----------------  ----------------
# Dim1        3.2719        1.5348           32.7191           32.7191
# Dim2        1.7371        0.3322           17.3713           50.0904
# Dim3        1.4049        0.3481           14.0492           64.1395
#
# Individuals (the 10 first):
#               Dim1    cos2     ctr     Dim2    cos2     ctr     Dim3    cos2     ctr
# ---------  -------  ------  ------  -------  ------  ------  -------  ------  ------
# SEBRLE      0.7916  0.1117  0.4672   0.7716  0.1061  0.836    0.8268  0.1218  1.1869
# CLAY        1.235   0.124   1.137    0.5746  0.0268  0.4635   2.1412  0.3728  7.9597
# KARPOV      1.3582  0.1599  1.3752   0.484   0.0203  0.3289   1.9563  0.3318  6.6438
# BERNARD    -0.6095  0.0487  0.2769  -0.8746  0.1002  1.0741   0.8899  0.1038  1.375
# YURKOV     -0.586   0.0377  0.256    2.131   0.4986  6.3758  -1.2252  0.1648  2.6058
# WARNERS     0.3569  0.0216  0.0949  -1.685   0.4816  3.9862   0.7666  0.0997  1.0201
# ZSIVOCZKY   0.2718  0.0112  0.0551  -1.0938  0.1821  1.6797  -1.2828  0.2505  2.8567
# McMULLEN    0.5875  0.0526  0.2573   0.2307  0.0081  0.0747  -0.4176  0.0266  0.3028
# MARTINEAU  -1.9954  0.2843  2.968    0.561   0.0225  0.4419  -0.7299  0.038   0.925
# HERNU      -1.5461  0.3061  1.7819   0.4884  0.0305  0.3349   0.8408  0.0905  1.2273
#
# Supplementary individuals:
#                      Dim1    cos2     Dim2    cos2     Dim3    cos2
# -----------------  ------  ------  -------  ------  -------  ------
# Christian Schenk   1.6307  0.1402   1.916   0.1936  -1.8424  0.179
# Torsten Voss       1.5667  0.3967  -0.9296  0.1397   0.1508  0.0037
# Dave Steen         0.2665  0.0084  -1.1624  0.1598  -0.5459  0.0352
# Daley Thompson     1.5083  0.424    0.4633  0.04     0.3176  0.0188
# Christian Plaziat  1.5295  0.217   -1.8945  0.3329   0.3572  0.0118
#
# Continuous (the 10 first):
#                  Dim1    cos2      ctr     Dim2    cos2      ctr     Dim3    cos2      ctr
# ------------  -------  ------  -------  -------  ------  -------  -------  ------  -------
# X100m         -0.7747  0.6002  18.3438   0.1871  0.035    2.0161  -0.1844  0.034    2.4205
# Long.Jump      0.7419  0.5504  16.8225  -0.3454  0.1193   6.8686   0.1822  0.0332   2.3632
# Shot.Put       0.6225  0.3875  11.8435   0.5983  0.358   20.6068  -0.0234  0.0005   0.0389
# High.Jump      0.5719  0.3271   9.9979   0.3503  0.1227   7.0637  -0.2595  0.0673   4.7936
# X400m         -0.6796  0.4619  14.1162   0.5694  0.3243  18.6664   0.1315  0.0173   1.2303
# X110m.Hurdle  -0.7462  0.5569  17.0201   0.2288  0.0523   3.0134  -0.0926  0.0086   0.6108
# Discus         0.5525  0.3052   9.3285   0.6063  0.3676  21.1622   0.043   0.0018   0.1313
# Pole.Vault     0.0503  0.0025   0.0775  -0.1804  0.0325   1.8725   0.6918  0.4785  34.0609
# Javeline       0.2771  0.0768   2.347    0.317   0.1005   5.7844  -0.3897  0.1518  10.8071
# X1500m        -0.0581  0.0034   0.1031   0.4742  0.2249  12.946    0.7821  0.6117  43.5433
#
# Supplementary continuous variables:
#            Dim1    cos2     Dim2    cos2     Dim3    cos2
# ------  -------  ------  -------  ------  -------  ------
# Rank    -0.6705  0.4496   0.0514  0.0026  -0.0583  0.0034
# Points   0.9562  0.9142  -0.0165  0.0003  -0.0664  0.0044
#
# Supplementary categories:
#              Dim1    vtest    cos2     Dim2    vtest    cos2     Dim3    vtest    cos2
# --------  -------  -------  ------  -------  -------  ------  -------  -------  ------
# Decastar  -0.6001  -1.4298  0.4028  -0.0377  -0.1231  0.0016   0.2889   1.0504  0.0933
# OlympicG   0.2786   1.4298  0.4028   0.0175   0.1231  0.0016  -0.1341  -1.0504  0.0933
#
# Supplementary categorical variables:
#                Dim1    Dim2    Dim3
# -----------  ------  ------  ------
# Competition  0.0511  0.0004  0.0276
