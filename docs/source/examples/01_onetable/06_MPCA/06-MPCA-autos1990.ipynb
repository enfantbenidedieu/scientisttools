# %% [markdown]
# # MPCA - autos1990 dataset

# %%
# disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %% [markdown]
# ## autos1990 dataset

# %%
# wine dataset
from scientisttools.datasets import autos1990
data = autos1990
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 27 entries, AS2 to VW3
# Data columns (total 9 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   CONS    27 non-null     float64
#  1   CYLI    27 non-null     int64
#  2   VITE    27 non-null     int64
#  3   VOLU    27 non-null     int64
#  4   RP/P    27 non-null     float64
#  5   LONG    27 non-null     float64
#  6   FISC    27 non-null     str
#  7   MARQ    27 non-null     str
#  8   PRIX    27 non-null     str
# dtypes: float64(3), int64(3), str(3)
# memory usage: 2.1+ KB

# %% [markdown]
# ## Instanciation and training

# %%
# instanciation
from scientisttools import MPCA
clf = MPCA()

# %% [markdown]
# ### `fit` function

# %%
# fit function
clf.fit(data)
# Out:
# MPCA()

# %% [markdown]
# ### `fit_transform` function

# %%
# fit_transform function - individuals coordinates
ind_coord = clf.fit_transform(data)
ind_coord
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# AS2 -2.626868 -1.700462  1.403855  0.374420 -1.431409
# CI4 -2.397295  0.966126  1.758490  0.827966 -1.324621
# PE6 -1.631235  2.247254  0.329646 -0.568445  1.283136
# FI3 -2.086566 -1.102789  0.837737  0.359289  0.400727
# FI5 -1.769700 -0.132189 -0.580175 -1.282820  1.868576
# FI8  3.766185 -0.661957  1.355248 -1.455975 -0.049329
# FID  2.161129 -1.272850 -0.715298  1.044895  0.709465
# FO1 -1.795874 -1.233806  0.752408  0.108646  0.327720
# RE7  4.002668  1.815679  1.850259 -0.808617 -0.566181
# NI1 -1.912613 -1.764613  0.130560 -1.156757 -0.415251
# OP1 -1.888796 -1.381416  0.838695 -0.054705  0.169040
# PE1 -2.165121  1.501280  1.388492  1.019595  0.526395
# PE3 -0.222393  2.356597 -2.199960  2.058609 -0.646423
# DA2  3.098776 -1.113514 -0.348331  1.346747  1.484363
# PE9  4.150984  2.107470  1.816939 -0.583353 -0.074522
# RE1 -3.337327  1.561796  1.051333  1.109674  0.378394
# RE3 -1.773843  3.395349 -2.098894  0.012404  0.425613
# RE4 -1.172103  2.963985 -1.914665 -0.519590 -0.620547
# FO9  2.484617 -1.478592 -0.587998  0.903153  0.213665
# RE8  3.805576  1.557855  1.921905 -1.174844 -1.154160
# SE4  3.084617 -1.219290 -0.222294  1.394515  0.881066
# SE9 -2.506774 -1.524648  1.571622  0.681453 -0.616449
# SZ2 -2.000447 -1.858788  0.350305 -1.048469 -0.806124
# SZ3  0.883669 -1.118285 -3.014050 -0.128212 -1.980307
# TO1 -1.644697 -0.628712 -1.553439 -2.891343  1.465478
# TO3  1.132242 -1.016719 -3.494236 -0.623758 -1.247660
# VW3  2.361192 -1.264758 -0.628156  1.055521  0.799346

# %% [markdown]
# ### `transform` function

# %%
# transform function - individuals coordinates
ind_coord = clf.transform(data)
ind_coord
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# AS2 -2.626868 -1.700462  1.403855  0.374420 -1.431409
# CI4 -2.397295  0.966126  1.758490  0.827966 -1.324621
# PE6 -1.631235  2.247254  0.329646 -0.568445  1.283136
# FI3 -2.086566 -1.102789  0.837737  0.359289  0.400727
# FI5 -1.769700 -0.132189 -0.580175 -1.282820  1.868576
# FI8  3.766185 -0.661957  1.355248 -1.455975 -0.049329
# FID  2.161129 -1.272850 -0.715298  1.044895  0.709465
# FO1 -1.795874 -1.233806  0.752408  0.108646  0.327720
# RE7  4.002668  1.815679  1.850259 -0.808617 -0.566181
# NI1 -1.912613 -1.764613  0.130560 -1.156757 -0.415251
# OP1 -1.888796 -1.381416  0.838695 -0.054705  0.169040
# PE1 -2.165121  1.501280  1.388492  1.019595  0.526395
# PE3 -0.222393  2.356597 -2.199960  2.058609 -0.646423
# DA2  3.098776 -1.113514 -0.348331  1.346747  1.484363
# PE9  4.150984  2.107470  1.816939 -0.583353 -0.074522
# RE1 -3.337327  1.561796  1.051333  1.109674  0.378394
# RE3 -1.773843  3.395349 -2.098894  0.012404  0.425613
# RE4 -1.172103  2.963985 -1.914665 -0.519590 -0.620547
# FO9  2.484617 -1.478592 -0.587998  0.903153  0.213665
# RE8  3.805576  1.557855  1.921905 -1.174844 -1.154160
# SE4  3.084617 -1.219290 -0.222294  1.394515  0.881066
# SE9 -2.506774 -1.524648  1.571622  0.681453 -0.616449
# SZ2 -2.000447 -1.858788  0.350305 -1.048469 -0.806124
# SZ3  0.883669 -1.118285 -3.014050 -0.128212 -1.980307
# TO1 -1.644697 -0.628712 -1.553439 -2.891343  1.465478
# TO3  1.132242 -1.016719 -3.494236 -0.623758 -1.247660
# VW3  2.361192 -1.264758 -0.628156  1.055521  0.799346

# %%
# attributes
from scientisttools import sprintf
sprintf(clf)
# Out:
# **Results of the Mixed Principal Component Analysis (MPCA)**
#
# *The results are available in the following objects:
#
# name                 description
# -------------------  -----------------------------------------------------
# .call_               summary called parameters
# .eig_                eigenvalues
# .ind_                results for the individuals
# .levels_             results for the levels
# .quali_var_          results for the qualitative variables
# .quanti_var_         results for the quantitative variables
# .separate_analyses_  results for the separate analyses
# .svd_                results for generalized singular values decomposition
# .var_                results for variables

# %% [markdown]
# ## Eigen values

# %%
#eigenvalues
from scientisttools import get_eig
eig =  get_eig(clf)
eig
# Out:
#        Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1     6.153650    3.397784       41.024332       41.024332
# Dim2     2.755866    0.407014       18.372438       59.396770
# Dim3     2.348852    1.139269       15.659013       75.055783
# Dim4     1.209583    0.272588        8.063886       83.119668
# Dim5     0.936995    0.128760        6.246630       89.366299
# Dim6     0.808235    0.500608        5.388230       94.754529
# Dim7     0.307627    0.097812        2.050846       96.805375
# Dim8     0.209815    0.111817        1.398765       98.204140
# Dim9     0.097998    0.021374        0.653320       98.857460
# Dim10    0.076624    0.004898        0.510826       99.368286
# Dim11    0.071726    0.048695        0.478174       99.846461
# Dim12    0.023031         NaN        0.153539      100.000000

# %%
# scree plot - eigenvalue
from scientisttools import fviz_screeplot
p = fviz_screeplot(obj=clf,choice="eigenvalue")
print(p.show())
# Out:
# None

# %%
# scree plot - proportion
p = fviz_screeplot(obj=clf,choice="proportion")
print(p.show())
# Out:
# None

# %%
# scree plot - cumulative
p = fviz_screeplot(obj=clf,choice="cumulative")
print(p.show())
# Out:
# None

# %% [markdown]
# ## Individuals informations

# %%
#individuals informations
from scientisttools import get_mix
ind = get_mix(clf)
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
# individuals coordinates
ind.coord
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# AS2 -2.626868 -1.700462  1.403855  0.374420 -1.431409
# CI4 -2.397295  0.966126  1.758490  0.827966 -1.324621
# PE6 -1.631235  2.247254  0.329646 -0.568445  1.283136
# FI3 -2.086566 -1.102789  0.837737  0.359289  0.400727
# FI5 -1.769700 -0.132189 -0.580175 -1.282820  1.868576
# FI8  3.766185 -0.661957  1.355248 -1.455975 -0.049329
# FID  2.161129 -1.272850 -0.715298  1.044895  0.709465
# FO1 -1.795874 -1.233806  0.752408  0.108646  0.327720
# RE7  4.002668  1.815679  1.850259 -0.808617 -0.566181
# NI1 -1.912613 -1.764613  0.130560 -1.156757 -0.415251
# OP1 -1.888796 -1.381416  0.838695 -0.054705  0.169040
# PE1 -2.165121  1.501280  1.388492  1.019595  0.526395
# PE3 -0.222393  2.356597 -2.199960  2.058609 -0.646423
# DA2  3.098776 -1.113514 -0.348331  1.346747  1.484363
# PE9  4.150984  2.107470  1.816939 -0.583353 -0.074522
# RE1 -3.337327  1.561796  1.051333  1.109674  0.378394
# RE3 -1.773843  3.395349 -2.098894  0.012404  0.425613
# RE4 -1.172103  2.963985 -1.914665 -0.519590 -0.620547
# FO9  2.484617 -1.478592 -0.587998  0.903153  0.213665
# RE8  3.805576  1.557855  1.921905 -1.174844 -1.154160
# SE4  3.084617 -1.219290 -0.222294  1.394515  0.881066
# SE9 -2.506774 -1.524648  1.571622  0.681453 -0.616449
# SZ2 -2.000447 -1.858788  0.350305 -1.048469 -0.806124
# SZ3  0.883669 -1.118285 -3.014050 -0.128212 -1.980307
# TO1 -1.644697 -0.628712 -1.553439 -2.891343  1.465478
# TO3  1.132242 -1.016719 -3.494236 -0.623758 -1.247660
# VW3  2.361192 -1.264758 -0.628156  1.055521  0.799346

# %%
# graph of individuals
from scientisttools import fviz_mix
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind = "black",
    repel = True,
    ind_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals contributions

# %%
# individuals contributions
ind.contrib
# Out:
#           Dim1       Dim2       Dim3       Dim4       Dim5
# AS2   4.153171   3.886081   3.107601   0.429257   8.098913
# CI4   3.458966   1.254427   4.875965   2.099066   6.935579
# PE6   1.601535   6.787070   0.171347   0.989413   6.507955
# FI3   2.620402   1.634419   1.106615   0.395266   0.634740
# FI5   1.884963   0.023484   0.530761   5.038854  13.801318
# FI8   8.537029   0.588894   2.896130   6.490956   0.009618
# FID   2.811027   2.177371   0.806779   3.343075   1.989581
# FO1   1.941133   2.045842   0.892663   0.036144   0.424527
# RE7   9.642786   4.430534   5.398157   2.002101   1.267097
# NI1   2.201698   4.184826   0.026878   4.097178   0.681586
# OP1   2.147205   2.564643   1.109145   0.009163   0.112948
# PE1   2.821422   3.029014   3.039955   3.183142   1.095272
# PE3   0.029768   7.463606   7.631504  12.976224   1.651704
# DA2   5.779413   1.666362   0.191322   5.553579   8.709217
# PE9  10.370638   5.968990   5.205488   1.041989   0.021952
# RE1   6.703492   3.278134   1.742856   3.770433   0.565962
# RE3   1.893800  15.493407   6.946426   0.000471   0.716026
# RE4   0.826866  11.806747   5.780508   0.826651   1.522117
# FO9   3.715543   2.938156   0.545170   2.497602   0.180454
# RE8   8.716544   3.261611   5.824311   4.226306   5.265402
# SE4   5.726721   1.997986   0.077918   5.954520   3.068430
# SE9   3.782107   3.124047   3.894726   1.421912   1.502080
# SZ2   2.408560   4.643419   0.193497   3.365981   2.568635
# SZ3   0.469984   1.680674  14.324568   0.050334  15.501167
# TO1   1.628079   0.531228   3.805124  25.597637   8.489020
# TO3   0.771581   1.389249  19.252405   1.191332   6.153072
# VW3   3.355567   2.149776   0.622180   3.411414   2.525626

# %%
# graph of individuals - color by contributions
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind="contrib",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph 
from scientisttools import fviz_corrplot
p = fviz_corrplot(
    X=ind.contrib,
    legend_title="Contrib",
    title="Contributions of individuals"
)
print(p.show())
# Out:
# None

# %%
# contributions of individuals to axis 1
from scientisttools import fviz_contrib
p = fviz_contrib(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals cos2

# %%
# individuals cos2
ind.cos2
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# AS2  0.393628  0.164946  0.112423  0.007997  0.116879
# CI4  0.394645  0.064096  0.212346  0.047075  0.120489
# PE6  0.209410  0.397437  0.008552  0.025430  0.129572
# FI3  0.549312  0.153441  0.088546  0.016287  0.020261
# FI5  0.298589  0.001666  0.032092  0.156894  0.332887
# FI8  0.685984  0.021192  0.088828  0.102522  0.000118
# FID  0.520224  0.180461  0.056991  0.121612  0.056065
# FO1  0.473792  0.223630  0.083165  0.001734  0.015778
# RE7  0.647916  0.133321  0.138447  0.026443  0.012964
# NI1  0.354869  0.302074  0.001654  0.129807  0.016728
# OP1  0.509688  0.272636  0.100495  0.000428  0.004082
# PE1  0.367387  0.176637  0.151094  0.081473  0.021716
# PE3  0.002954  0.331696  0.289068  0.253115  0.024958
# DA2  0.623909  0.080562  0.007884  0.117846  0.143160
# PE9  0.656091  0.169116  0.125702  0.012958  0.000211
# RE1  0.554413  0.121418  0.055020  0.061295  0.007127
# RE3  0.145875  0.534465  0.204236  0.000007  0.008398
# RE4  0.081199  0.519241  0.216672  0.015957  0.022760
# FO9  0.572090  0.202601  0.032040  0.075591  0.004231
# RE8  0.609584  0.102152  0.155474  0.058097  0.056069
# SE4  0.660406  0.103186  0.003430  0.134975  0.053880
# SE9  0.432616  0.160034  0.170047  0.031970  0.026162
# SZ2  0.402336  0.347372  0.012338  0.110521  0.065334
# SZ3  0.051027  0.081720  0.593644  0.001074  0.256265
# TO1  0.162380  0.023728  0.144860  0.501835  0.128920
# TO3  0.069909  0.056371  0.665827  0.021217  0.084889
# VW3  0.567349  0.162781  0.040153  0.113376  0.065022

# %%
# graph of individuals - color by cosinus
p = fviz_mix(
    obj=clf,
    choice="ind",
    col_ind="cos2",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus
p = fviz_corrplot(
    X=ind.cos2,
    legend_title="Cos2",
    title="Cosinus of individuals"
)
print(p.show())
# Out:
# None

# %%
# cosinus of individuals to axis 1
from scientisttools import fviz_cos2
p = fviz_cos2(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals additionals informations

# %%
# individuals additionals informations
ind.infos
# Out:
#        Weight  Sq. Dist.   Inertia  Inertia (%)
# AS2  0.037037  17.530355  0.649272     4.328483
# CI4  0.037037  14.562517  0.539352     3.595683
# PE6  0.037037  12.706787  0.470622     3.137478
# FI3  0.037037   7.925836  0.293549     1.956997
# FI5  0.037037  10.488785  0.388474     2.589823
# FI8  0.037037  20.677079  0.765818     5.105452
# FID  0.037037   8.977820  0.332512     2.216746
# FO1  0.037037   6.807131  0.252116     1.680773
# RE7  0.037037  24.727490  0.915833     6.105553
# NI1  0.037037  10.308274  0.381788     2.545253
# OP1  0.037037   6.999476  0.259240     1.728266
# PE1  0.037037  12.759704  0.472582     3.150544
# PE3  0.037037  16.742876  0.620107     4.134044
# DA2  0.037037  15.390726  0.570027     3.800179
# PE9  0.037037  26.262624  0.972690     6.484599
# RE1  0.037037  20.089256  0.744047     4.960310
# RE3  0.037037  21.569948  0.798887     5.325913
# RE4  0.037037  16.919317  0.626641     4.177609
# FO9  0.037037  10.790815  0.399660     2.664399
# RE8  0.037037  23.757852  0.879920     5.866136
# SE4  0.037037  14.407606  0.533615     3.557433
# SE9  0.037037  14.525380  0.537977     3.586514
# SZ2  0.037037   9.946391  0.368385     2.455899
# SZ3  0.037037  15.302950  0.566776     3.778506
# TO1  0.037037  16.658598  0.616985     4.113234
# TO3  0.037037  18.337612  0.679171     4.527805
# VW3  0.037037   9.826796  0.363955     2.426369

# %% [markdown]
# ## Quantitative variables informations

# %%
#quantitative variables informations
from scientisttools import get_mix
quanti_var = get_mix(clf,"quanti_var")
quanti_var._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Quantitative variables coordinates

# %%
# quantitative variables coordinates
quanti_var.coord
# Out:
#           Dim1      Dim2      Dim3      Dim4      Dim5
# CONS  0.859012 -0.117609  0.345895  0.036224  0.167043
# CYLI  0.950441  0.067598 -0.059370  0.029615 -0.073148
# VITE  0.928352 -0.101186  0.103113 -0.225809 -0.101447
# VOLU  0.151948  0.375336  0.476545  0.618212  0.279747
# RP/P -0.864684  0.223102 -0.009520  0.234878  0.166710
# LONG  0.292079  0.269671 -0.334891 -0.069933  0.506087
# 4CV  -0.829601 -0.225533  0.400444 -0.169944  0.139799
# 5CV  -0.044295  0.377974 -0.791452  0.069307 -0.400827
# 6CV   0.915821 -0.072409  0.227730  0.123018  0.182113
# ETRA  0.022882 -0.945880 -0.195347 -0.095776  0.140474
# FRAN -0.022882  0.945880  0.195347  0.095776 -0.140474
# CP1  -0.702382 -0.302027  0.504614  0.154892 -0.221186
# CP2  -0.307164  0.450615 -0.361921 -0.455122  0.435591
# CP3   0.489931 -0.299382 -0.593292  0.520044  0.017891
# CP4   0.660909  0.302648  0.472400 -0.381343 -0.198629

# %%
# graph of variables - correlation circle
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables contributions

# %%
# quantitative variables contributions
quanti_var.contrib
# Out:
#            Dim1       Dim2       Dim3       Dim4       Dim5
# CONS  11.991275   0.501903   5.093707   0.108482   2.977964
# CYLI  14.679706   0.165810   0.150063   0.072508   0.571044
# VITE  14.005294   0.371521   0.452659   4.215477   1.098357
# VOLU   0.375193   5.111899   9.668361  31.596531   8.352085
# RP/P  12.150162   1.806123   0.003859   4.560882   2.966116
# LONG   1.386335   2.638820   4.774767   0.404328  27.334663
# 4CV   11.184220   1.845703   6.826981   2.387666   2.085792
# 5CV    0.031884   5.184003  26.668183   0.397119  17.146591
# 6CV   13.629758   0.190251   2.207925   1.251127   3.539530
# ETRA   0.008509  32.464927   1.624646   0.758357   2.105977
# FRAN   0.008509  32.464927   1.624646   0.758357   2.105977
# CP1    8.017031   3.310051  10.840822   1.983449   5.221275
# CP2    1.533229   7.368060   5.576641  17.124606  20.249805
# CP3    3.900656   3.252329  14.985851  22.358594   0.034162
# CP4    7.098241   3.323673   9.500889  12.022516   4.210662

# %%
# graph of variables - color by contrib
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    col_var = "contrib",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of contributions for variables
p = fviz_corrplot(
    X=quanti_var.contrib,
    legend_title="Contrib",
    title="Contributions of variables"
)
print(p.show())
# Out:
# None

# %%
# contributions of variables to axis 1
p = fviz_contrib(
    obj=clf,
    choice="quanti_var"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables cos2

# %%
# quantitative variables cos2
quanti_var.cos2
# Out:
#           Dim1      Dim2      Dim3      Dim4      Dim5
# CONS  0.737901  0.013832  0.119644  0.001312  0.027903
# CYLI  0.903338  0.004569  0.003525  0.000877  0.005351
# VITE  0.861837  0.010239  0.010632  0.050990  0.010292
# VOLU  0.023088  0.140877  0.227095  0.382186  0.078259
# RP/P  0.747678  0.049774  0.000091  0.055168  0.027792
# LONG  0.085310  0.072722  0.112152  0.004891  0.256124
# 4CV   0.688238  0.050865  0.160356  0.028881  0.019544
# 5CV   0.001962  0.142864  0.626396  0.004803  0.160663
# 6CV   0.838728  0.005243  0.051861  0.015133  0.033165
# ETRA  0.000524  0.894690  0.038161  0.009173  0.019733
# FRAN  0.000524  0.894690  0.038161  0.009173  0.019733
# CP1   0.493340  0.091221  0.254635  0.023991  0.048923
# CP2   0.094350  0.203054  0.130987  0.207136  0.189740
# CP3   0.240033  0.089630  0.351995  0.270446  0.000320
# CP4   0.436801  0.091596  0.223162  0.145422  0.039454

# %%
# graph of variables - color by cosinus
p = fviz_mix(
    obj=clf,
    choice="quanti_var",
    col_var = "cos2",
    repel=True,
    quanti_sup=False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus for variables
p = fviz_corrplot(
    X=quanti_var.cos2,
    legend_title="Cos2",
    title="Cosinus of continuous variables"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Quantitative variables additionals informations

# %%
# quantitative variables additionals informations
quanti_var.infos
# Out:
#       Weight  Sq. Dist.  Inertia  Inertia (%)
# CONS     1.0        1.0      1.0     6.666667
# CYLI     1.0        1.0      1.0     6.666667
# VITE     1.0        1.0      1.0     6.666667
# VOLU     1.0        1.0      1.0     6.666667
# RP/P     1.0        1.0      1.0     6.666667
# LONG     1.0        1.0      1.0     6.666667
# 4CV      1.0        1.0      1.0     6.666667
# 5CV      1.0        1.0      1.0     6.666667
# 6CV      1.0        1.0      1.0     6.666667
# ETRA     1.0        1.0      1.0     6.666667
# FRAN     1.0        1.0      1.0     6.666667
# CP1      1.0        1.0      1.0     6.666667
# CP2      1.0        1.0      1.0     6.666667
# CP3      1.0        1.0      1.0     6.666667
# CP4      1.0        1.0      1.0     6.666667

# %% [markdown]
# ## Levels informations

# %%
# levels informations
levels = clf.levels_
levels._fields
# Out:
# ('coord', 'contrib', 'vtest')

# %% [markdown]
# ### Levels coordinates

# %%
# levels coordinates
levels.coord
# Out:
#           Dim1      Dim2      Dim3      Dim4      Dim5
# 4CV  -2.135640 -0.388536  0.636887 -0.193961  0.140432
# 5CV  -0.230486  1.316185 -2.544361  0.159890 -0.813865
# 6CV   3.212860 -0.169995  0.493586  0.191338  0.249301
# ETRA  0.043535 -1.204317 -0.229620 -0.080788  0.104289
# FRAN -0.074009  2.047339  0.390355  0.137340 -0.177292
# CP1  -2.271768 -0.653732  1.008350  0.222111 -0.279158
# CP2  -1.598316  1.569137 -1.163505 -1.049959  0.884451
# CP3   1.872981 -0.765926 -1.401290  0.881434  0.026689
# CP4   3.931353  1.204762  1.736088 -1.005697 -0.461048

# %%
# graph of individuals with variable categories
from scientisttools import add_scatter
p = fviz_mix(
    obj=clf,
    choice="ind",
    repel=True
)
# add variable categories
p = add_scatter(
    p = p,
    data = levels.coord,
    color = "red",
    repel = True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels vtest

# %%
# levels vtest
levels.vtest
# Out:
#           Dim1      Dim2      Dim3      Dim4      Dim5
# 4CV  -4.230151 -1.149997  2.041874 -0.866545  0.712838
# 5CV  -0.225859  1.927296 -4.035629  0.353399 -2.043827
# 6CV   4.669788 -0.369215  1.161199  0.627271  0.928599
# ETRA  0.116676 -4.823063 -0.996079 -0.488361  0.716279
# FRAN -0.116676  4.823063  0.996079  0.488361 -0.716279
# CP1  -3.581458 -1.540044  2.573034  0.789796 -1.127830
# CP2  -1.566234  2.297694 -1.845444 -2.320677  2.221087
# CP3   2.498169 -1.526557 -3.025208  2.651714  0.091227
# CP4   3.369988  1.543209  2.408777 -1.944474 -1.012816

# %% [markdown]
# ### Levels contributions

# %%
# levels contributions
levels.contrib
# Out:
#            Dim1       Dim2       Dim3       Dim4       Dim5
# 4CV   11.184220   1.845703   6.826981   2.387666   2.085792
# 5CV    0.031884   5.184003  26.668183   0.397119  17.146591
# 6CV   13.629758   0.190251   2.207925   1.251127   3.539530
# ETRA   0.008509  32.464927   1.624646   0.758357   2.105977
# FRAN   0.008509  32.464927   1.624646   0.758357   2.105977
# CP1    8.017031   3.310051  10.840822   1.983449   5.221275
# CP2    1.533229   7.368060   5.576641  17.124606  20.249805
# CP3    3.900656   3.252329  14.985851  22.358594   0.034162
# CP4    7.098241   3.323673   9.500889  12.022516   4.210662

# %%
# graph of contributions for variable categories
p = fviz_corrplot(
    X=levels.contrib,
    legend_title="Contrib",
    title="Contributions of variable categories"
)
print(p.show())
# Out:
# None

# %%
# contributions of levels to axis 1
p = fviz_contrib(
    obj=clf,
    choice="levels"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ## Variables informations

# %%
# variables informations
var = get_mix(clf,"var")
var._fields
# Out:
# ('coord', 'contrib')

# %% [markdown]
# ### Variables coordinates

# %%
# variables coordinates
var.coord
# Out:
#           Dim1      Dim2      Dim3      Dim4      Dim5
# CONS  0.737901  0.013832  0.119644  0.001312  0.027903
# CYLI  0.903338  0.004569  0.003525  0.000877  0.005351
# VITE  0.861837  0.010239  0.010632  0.050990  0.010292
# VOLU  0.023088  0.140877  0.227095  0.382186  0.078259
# RP/P  0.747678  0.049774  0.000091  0.055168  0.027792
# LONG  0.085310  0.072722  0.112152  0.004891  0.256124
# FISC  0.917614  0.146278  0.628118  0.028978  0.163154
# MARQ  0.000524  0.894690  0.038161  0.009173  0.019733
# PRIX  0.928500  0.363985  0.704857  0.498075  0.219240

# %%
# graph of variables
p = fviz_mix(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = False,
    quanti_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Variables contributions

# %%
# variables contributions
var.contrib
# Out:
#            Dim1       Dim2       Dim3       Dim4       Dim5
# CONS  11.991275   0.501903   5.093707   0.108482   2.977964
# CYLI  14.679706   0.165810   0.150063   0.072508   0.571044
# VITE  14.005294   0.371521   0.452659   4.215477   1.098357
# VOLU   0.375193   5.111899   9.668361  31.596531   8.352085
# RP/P  12.150162   1.806123   0.003859   4.560882   2.966116
# LONG   1.386335   2.638820   4.774767   0.404328  27.334663
# FISC  24.845862   7.219957  35.703090   4.035913  22.771912
# MARQ   0.017017  64.929855   3.249291   1.516713   4.211954
# PRIX  20.549156  17.254112  40.904204  53.489166  29.715904

# %% [markdown]
# ## Others functions
#
# ### Ellipses - `fviz_ellipses`

# %%
# ellipses
from scientisttools import fviz_ellipses
p = fviz_ellipses(
    obj=clf,
    habillage=["FISC","MARQ"],
    repel=True,
    add_ellipses=True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Summaries - `summary`

# %%
# summary
from scientisttools import summary
summary(clf)
# Out:
#                      Mixed Principal Component Analysis - Results
#
# Importance of components:
#       Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1      6.1536      3.3978         41.0243         41.0243
# Dim2      2.7559      0.4070         18.3724         59.3968
# Dim3      2.3489      1.1393         15.6590         75.0558
#
# Individuals (the 10 first):
#        Dim1    cos2     ctr    Dim2    cos2     ctr    Dim3    cos2     ctr
# AS2 -2.6269  0.3936  4.1532 -1.7005  0.1649  3.8861  1.4039  0.1124  3.1076
# CI4 -2.3973  0.3946  3.4590  0.9661  0.0641  1.2544  1.7585  0.2123  4.8760
# PE6 -1.6312  0.2094  1.6015  2.2473  0.3974  6.7871  0.3296  0.0086  0.1713
# FI3 -2.0866  0.5493  2.6204 -1.1028  0.1534  1.6344  0.8377  0.0885  1.1066
# FI5 -1.7697  0.2986  1.8850 -0.1322  0.0017  0.0235 -0.5802  0.0321  0.5308
# FI8  3.7662  0.6860  8.5370 -0.6620  0.0212  0.5889  1.3552  0.0888  2.8961
# FID  2.1611  0.5202  2.8110 -1.2728  0.1805  2.1774 -0.7153  0.0570  0.8068
# FO1 -1.7959  0.4738  1.9411 -1.2338  0.2236  2.0458  0.7524  0.0832  0.8927
# RE7  4.0027  0.6479  9.6428  1.8157  0.1333  4.4305  1.8503  0.1384  5.3982
# NI1 -1.9126  0.3549  2.2017 -1.7646  0.3021  4.1848  0.1306  0.0017  0.0269
#
# Continuous (the 10 first):
#         Dim1    cos2      ctr    Dim2    cos2      ctr    Dim3    cos2  \
# CONS  0.8590  0.7379  11.9913 -0.1176  0.0138   0.5019  0.3459  0.1196
# CYLI  0.9504  0.9033  14.6797  0.0676  0.0046   0.1658 -0.0594  0.0035
# VITE  0.9284  0.8618  14.0053 -0.1012  0.0102   0.3715  0.1031  0.0106
# VOLU  0.1519  0.0231   0.3752  0.3753  0.1409   5.1119  0.4765  0.2271
# RP/P -0.8647  0.7477  12.1502  0.2231  0.0498   1.8061 -0.0095  0.0001
# LONG  0.2921  0.0853   1.3863  0.2697  0.0727   2.6388 -0.3349  0.1122
# 4CV  -0.8296  0.6882  11.1842 -0.2255  0.0509   1.8457  0.4004  0.1604
# 5CV  -0.0443  0.0020   0.0319  0.3780  0.1429   5.1840 -0.7915  0.6264
# 6CV   0.9158  0.8387  13.6298 -0.0724  0.0052   0.1903  0.2277  0.0519
# ETRA  0.0229  0.0005   0.0085 -0.9459  0.8947  32.4649 -0.1953  0.0382
#
#           ctr
# CONS   5.0937
# CYLI   0.1501
# VITE   0.4527
# VOLU   9.6684
# RP/P   0.0039
# LONG   4.7748
# 4CV    6.8270
# 5CV   26.6682
# 6CV    2.2079
# ETRA   1.6246
#
# Categories:
#         Dim1   vtest      ctr    Dim2   vtest      ctr    Dim3   vtest  \
# 4CV  -2.1356 -4.2302  11.1842 -0.3885 -1.1500   1.8457  0.6369  2.0419
# 5CV  -0.2305 -0.2259   0.0319  1.3162  1.9273   5.1840 -2.5444 -4.0356
# 6CV   3.2129  4.6698  13.6298 -0.1700 -0.3692   0.1903  0.4936  1.1612
# ETRA  0.0435  0.1167   0.0085 -1.2043 -4.8231  32.4649 -0.2296 -0.9961
# FRAN -0.0740 -0.1167   0.0085  2.0473  4.8231  32.4649  0.3904  0.9961
# CP1  -2.2718 -3.5815   8.0170 -0.6537 -1.5400   3.3101  1.0083  2.5730
# CP2  -1.5983 -1.5662   1.5332  1.5691  2.2977   7.3681 -1.1635 -1.8454
# CP3   1.8730  2.4982   3.9007 -0.7659 -1.5266   3.2523 -1.4013 -3.0252
# CP4   3.9314  3.3700   7.0982  1.2048  1.5432   3.3237  1.7361  2.4088
#
#           ctr
# 4CV    6.8270
# 5CV   26.6682
# 6CV    2.2079
# ETRA   1.6246
# FRAN   1.6246
# CP1   10.8408
# CP2    5.5766
# CP3   14.9859
# CP4    9.5009
#
# Categorical variables:
#         Dim1      ctr    Dim2      ctr    Dim3      ctr
# FISC  0.9176  24.8459  0.1463   7.2200  0.6281  35.7031
# MARQ  0.0005   0.0170  0.8947  64.9299  0.0382   3.2493
# PRIX  0.9285  20.5492  0.3640  17.2541  0.7049  40.9042

# %%
# formatting text to markdown
summary(clf,to_markdown=True)
# Out:
#                      Mixed Principal Component Analysis - Results
#
# Importance of components:
#         Eigenvalue    Difference    Proportion (%)    Cumulative (%)
# ----  ------------  ------------  ----------------  ----------------
# Dim1        6.1536        3.3978           41.0243           41.0243
# Dim2        2.7559        0.407            18.3724           59.3968
# Dim3        2.3489        1.1393           15.659            75.0558
#
# Individuals (the 10 first):
#         Dim1    cos2     ctr     Dim2    cos2     ctr     Dim3    cos2     ctr
# ---  -------  ------  ------  -------  ------  ------  -------  ------  ------
# AS2  -2.6269  0.3936  4.1532  -1.7005  0.1649  3.8861   1.4039  0.1124  3.1076
# CI4  -2.3973  0.3946  3.459    0.9661  0.0641  1.2544   1.7585  0.2123  4.876
# PE6  -1.6312  0.2094  1.6015   2.2473  0.3974  6.7871   0.3296  0.0086  0.1713
# FI3  -2.0866  0.5493  2.6204  -1.1028  0.1534  1.6344   0.8377  0.0885  1.1066
# FI5  -1.7697  0.2986  1.885   -0.1322  0.0017  0.0235  -0.5802  0.0321  0.5308
# FI8   3.7662  0.686   8.537   -0.662   0.0212  0.5889   1.3552  0.0888  2.8961
# FID   2.1611  0.5202  2.811   -1.2728  0.1805  2.1774  -0.7153  0.057   0.8068
# FO1  -1.7959  0.4738  1.9411  -1.2338  0.2236  2.0458   0.7524  0.0832  0.8927
# RE7   4.0027  0.6479  9.6428   1.8157  0.1333  4.4305   1.8503  0.1384  5.3982
# NI1  -1.9126  0.3549  2.2017  -1.7646  0.3021  4.1848   0.1306  0.0017  0.0269
#
# Continuous (the 10 first):
#          Dim1    cos2      ctr     Dim2    cos2      ctr     Dim3    cos2      ctr
# ----  -------  ------  -------  -------  ------  -------  -------  ------  -------
# CONS   0.859   0.7379  11.9913  -0.1176  0.0138   0.5019   0.3459  0.1196   5.0937
# CYLI   0.9504  0.9033  14.6797   0.0676  0.0046   0.1658  -0.0594  0.0035   0.1501
# VITE   0.9284  0.8618  14.0053  -0.1012  0.0102   0.3715   0.1031  0.0106   0.4527
# VOLU   0.1519  0.0231   0.3752   0.3753  0.1409   5.1119   0.4765  0.2271   9.6684
# RP/P  -0.8647  0.7477  12.1502   0.2231  0.0498   1.8061  -0.0095  0.0001   0.0039
# LONG   0.2921  0.0853   1.3863   0.2697  0.0727   2.6388  -0.3349  0.1122   4.7748
# 4CV   -0.8296  0.6882  11.1842  -0.2255  0.0509   1.8457   0.4004  0.1604   6.827
# 5CV   -0.0443  0.002    0.0319   0.378   0.1429   5.184   -0.7915  0.6264  26.6682
# 6CV    0.9158  0.8387  13.6298  -0.0724  0.0052   0.1903   0.2277  0.0519   2.2079
# ETRA   0.0229  0.0005   0.0085  -0.9459  0.8947  32.4649  -0.1953  0.0382   1.6246
#
# Categories:
#          Dim1    vtest      ctr     Dim2    vtest      ctr     Dim3    vtest      ctr
# ----  -------  -------  -------  -------  -------  -------  -------  -------  -------
# 4CV   -2.1356  -4.2302  11.1842  -0.3885  -1.15     1.8457   0.6369   2.0419   6.827
# 5CV   -0.2305  -0.2259   0.0319   1.3162   1.9273   5.184   -2.5444  -4.0356  26.6682
# 6CV    3.2129   4.6698  13.6298  -0.17    -0.3692   0.1903   0.4936   1.1612   2.2079
# ETRA   0.0435   0.1167   0.0085  -1.2043  -4.8231  32.4649  -0.2296  -0.9961   1.6246
# FRAN  -0.074   -0.1167   0.0085   2.0473   4.8231  32.4649   0.3904   0.9961   1.6246
# CP1   -2.2718  -3.5815   8.017   -0.6537  -1.54     3.3101   1.0083   2.573   10.8408
# CP2   -1.5983  -1.5662   1.5332   1.5691   2.2977   7.3681  -1.1635  -1.8454   5.5766
# CP3    1.873    2.4982   3.9007  -0.7659  -1.5266   3.2523  -1.4013  -3.0252  14.9859
# CP4    3.9314   3.37     7.0982   1.2048   1.5432   3.3237   1.7361   2.4088   9.5009
#
# Categorical variables:
#         Dim1      ctr    Dim2      ctr    Dim3      ctr
# ----  ------  -------  ------  -------  ------  -------
# FISC  0.9176  24.8459  0.1463   7.22    0.6281  35.7031
# MARQ  0.0005   0.017   0.8947  64.9299  0.0382   3.2493
# PRIX  0.9285  20.5492  0.364   17.2541  0.7049  40.9042

# %% [markdown]
# ### Dimension description - `dimdesc`

# %%
# dimension description
from scientisttools import dimdesc
dim_desc = dimdesc(clf,axis=[0,1])
dim_desc.keys()
# Out:
# dict_keys(['Dim1', 'Dim2'])

# %% [markdown]
# ### `Dim1` dimension

# %%
# Dim1 dimension
dim_desc["Dim1"]._fields
# Out:
# ('call', 'quanti', 'quali', 'category')

# %% [markdown]
# #### Description of Dim1 by quantitative variables

# %%
# description of Dim1 by quantitative variables
dim_desc["Dim1"].quanti
# Out:
#       correlation        pvalue
# CYLI     0.950441  3.425403e-14
# VITE     0.928352  3.042841e-12
# CONS     0.859012  9.770004e-09
# RP/P    -0.864684  6.038377e-09

# %% [markdown]
# #### Description of Dim1 by levels

# %%
# description of Dim1 by levels
dim_desc["Dim1"].category
# Out:
#           Estimate        pvalue
# FISC=4CV -4.118733  8.821245e-08
# FISC=6CV  4.819291  2.129487e-11
# PRIX=CP1 -3.608102  4.423265e-05
# PRIX=CP3  2.661605  9.484244e-03
# PRIX=CP4  4.615067  1.749563e-04

# %% [markdown]
# ### Description of Dim1 by quantitative variables

# %%
# description of Dim1 by quantitative variables
dim_desc["Dim1"].quanti
# Out:
#       correlation        pvalue
# CYLI     0.950441  3.425403e-14
# VITE     0.928352  3.042841e-12
# CONS     0.859012  9.770004e-09
# RP/P    -0.864684  6.038377e-09
