# %% [markdown]
# # speMCA - music Dataset

# %%
# disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %% [markdown]
# ## music dataset

# %%
# music dataset
from scientisttools.datasets import music
data = music
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 9 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   FrenchPop  500 non-null    category
#  1   Rap        500 non-null    category
#  2   Rock       500 non-null    category
#  3   Jazz       500 non-null    category
#  4   Classical  500 non-null    category
#  5   Gender     500 non-null    category
#  6   Age        500 non-null    category
#  7   OnlyMus    500 non-null    category
#  8   Daily      500 non-null    category
# dtypes: category(9)
# memory usage: 4.8 KB

# %% [markdown]
# ## Instanciation and training

# %%
# instanciation
from scientisttools import MCA
clf = MCA(excl=(0,3,6,9,12),sup_var=(5,6,7,8))

# %% [markdown]
# ### `fit` function

# %%
# fit function
clf.fit(data)
# Out:
# MCA(excl=(0, 3, 6, 9, 12), sup_var=(5, 6, 7, 8))

# %% [markdown]
# ### `fit_transform` function

# %%
# fit_transform function - individuals coordinates
ind_coord = clf.fit_transform(data)
ind_coord
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# 0   -0.030826  0.380844 -0.254910 -0.678010  0.192877
# 1   -0.564463  0.643735  0.715254  0.566608 -0.099870
# 2   -0.082440  0.397394  0.272570 -0.845866  0.257154
# 3   -0.082440  0.397394  0.272570 -0.845866  0.257154
# 4    0.277382 -0.549096 -0.268276  0.379534  0.446372
# ..        ...       ...       ...       ...       ...
# 495 -0.339888 -0.285192 -0.385108  0.001292 -0.171422
# 496 -0.339888 -0.285192 -0.385108  0.001292 -0.171422
# 497 -0.627873  0.576777 -0.198138  0.815301 -0.049247
# 498  0.618228  0.103034 -0.478359 -0.191263  0.773633
# 499 -0.287027  1.228907 -0.408221  0.244503  0.278014
#
# [500 rows x 5 columns]

# %% [markdown]
# ### `transform` function

# %%
# transform function - individuals coordinates
ind_coord = clf.transform(data)
ind_coord
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# 0   -0.030826  0.380844 -0.254910 -0.678010  0.192877
# 1   -0.564463  0.643735  0.715254  0.566608 -0.099870
# 2   -0.082440  0.397394  0.272570 -0.845866  0.257154
# 3   -0.082440  0.397394  0.272570 -0.845866  0.257154
# 4    0.277382 -0.549096 -0.268276  0.379534  0.446372
# ..        ...       ...       ...       ...       ...
# 495 -0.339888 -0.285192 -0.385108  0.001292 -0.171422
# 496 -0.339888 -0.285192 -0.385108  0.001292 -0.171422
# 497 -0.627873  0.576777 -0.198138  0.815301 -0.049247
# 498  0.618228  0.103034 -0.478359 -0.191263  0.773633
# 499 -0.287027  1.228907 -0.408221  0.244503  0.278014
#
# [500 rows x 5 columns]

# %% [markdown]
# ## Eigen values

# %%
# eigenvalues
from scientisttools import get_eig
eig = get_eig(clf)
eig
# Out:
#        Eigenvalue  Difference  Proportion (%)  Cumulative (%)  modified rates  \
# Dim1     0.278521    0.060524       27.489204       27.489204        94.86338
# Dim2     0.217997    0.014839       21.515651       49.004854         4.98323
# Dim3     0.203157    0.031705       20.051068       69.055922         0.15339
# Dim4     0.171452    0.042499       16.921878       85.977800         0.00000
# Dim5     0.128953    0.124990       12.727322       98.705121         0.00000
# Dim6     0.003964    0.001174        0.391203       99.096324         0.00000
# Dim7     0.002790    0.000175        0.275336       99.371660         0.00000
# Dim8     0.002615    0.000626        0.258110       99.629770         0.00000
# Dim9     0.001990    0.000228        0.196364       99.826134         0.00000
# Dim10    0.001762         NaN        0.173866      100.000000         0.00000
#
#        cumulative modified rates
# Dim1                    94.86338
# Dim2                    99.84661
# Dim3                   100.00000
# Dim4                   100.00000
# Dim5                   100.00000
# Dim6                   100.00000
# Dim7                   100.00000
# Dim8                   100.00000
# Dim9                   100.00000
# Dim10                  100.00000

# %%
# scree plot - eigenvalue
from scientisttools import fviz_screeplot
p = fviz_screeplot(obj=clf,choice="eigenvalue")
print(p.show())
# Out:
# None

# %%
# scree plot - proportion
p = fviz_screeplot(obj=clf,choice="proportion")
print(p.show())
# Out:
# None

# %%
# scree plot - cumulative
p = fviz_screeplot(obj=clf,choice="cumulative")
print(p.show())
# Out:
# None

# %% [markdown]
# ## Individuals informations

# %%
# individuals informations
from scientisttools import get_mca
ind = get_mca(clf)
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals factor coordinates

# %%
# individuals factor coordinates
ind.coord
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# 0   -0.030826  0.380844 -0.254910 -0.678010  0.192877
# 1   -0.564463  0.643735  0.715254  0.566608 -0.099870
# 2   -0.082440  0.397394  0.272570 -0.845866  0.257154
# 3   -0.082440  0.397394  0.272570 -0.845866  0.257154
# 4    0.277382 -0.549096 -0.268276  0.379534  0.446372
# ..        ...       ...       ...       ...       ...
# 495 -0.339888 -0.285192 -0.385108  0.001292 -0.171422
# 496 -0.339888 -0.285192 -0.385108  0.001292 -0.171422
# 497 -0.627873  0.576777 -0.198138  0.815301 -0.049247
# 498  0.618228  0.103034 -0.478359 -0.191263  0.773633
# 499 -0.287027  1.228907 -0.408221  0.244503  0.278014
#
# [500 rows x 5 columns]

# %%
# graph of individuals
from scientisttools import fviz_mca
p = fviz_mca(
    obj=clf,
    choice="ind",
    repel = True,
    ind_sup = False
)
print(p.show())
# Out:
# 404 [-0.86550621 -0.75253448]
# 406 [ 0.39196341 -0.99575048]
# 414 [0.60614676 0.24296227]
# 462 [0.55931994 0.13711987]
# 50 [-0.79525294  0.88929668]
# 60 [-0.65332754  0.83464658]
# 97 [0.07440974 0.521393  ]
# 135 [-0.57117739  0.48754627]
# 138 [-0.40496033  0.6678035 ]
# 151 [ 0.5483634  -0.09085506]
# 156 [-0.99219494 -0.82309051]
# 165 [-0.7372779   0.61238086]
# 212 [0.35793733 0.28911472]
# 214 [-0.84399114 -0.30589315]
# 244 [-0.21897278  0.04933289]
# 279 [-0.28519922 -0.44385191]
# 294 [-0.17265692 -0.80330024]
# 331 [ 0.09904011 -0.39352573]
# 369 [-0.61008071 -0.42981494]
# 392 [0.10240176 0.78586956]
# 24 [-0.17114924  0.86705296]
# 47 [0.43863958 0.29679318]
# 83 [-0.03390896 -0.14341449]
# 155 [-0.43463444 -0.17707814]
# 158 [-0.69922417 -0.16653081]
# 168 [0.9632537  0.67446348]
# 169 [0.10946433 0.11787975]
# 187 [ 0.82126221 -0.22728452]
# 226 [0.00871983 0.13037083]
# 239 [-0.44645687  0.19009924]
# 265 [-0.87498977  0.82888828]
# 267 [0.24881166 0.34191976]
# 281 [-0.71531842 -0.61481918]
# 317 [-0.01815592  0.0899478 ]
# 372 [-0.46916502 -0.46578689]
# 377 [0.76045547 0.31861144]
# 400 [ 0.95312597 -0.89453125]
# 436 [-0.96842537 -0.21944737]
# 437 [-0.40350456 -0.30389662]
# 451 [ 0.49702478 -0.22563843]
# 454 [ 0.39366099 -0.00250932]
# 497 [0.79589033 0.2052615 ]
# 179 [ 0.52321277 -0.05559343]
# 189 [0.59254229 0.17859365]
# 193 [ 0.73602683 -0.94843956]
# 198 [-0.23131501 -0.39781722]
# 205 [0.93853006 0.33253224]
# 218 [0.71414234 0.28626688]
# 220 [-0.43210515  0.66092219]
# 222 [-0.40119459  0.8552644 ]
# 236 [-0.69297396  0.08387627]
# 247 [0.02036605 0.42144862]
# 251 [0.44007471 0.53560445]
# 260 [-0.82314543 -0.52782762]
# 268 [ 0.39057596 -0.51840552]
# 273 [-0.24524747 -0.45955279]
# 277 [-0.91768739  0.36089145]
# 280 [-0.98028127 -0.42505443]
# 291 [0.56070879 0.71893069]
# 297 [-0.66549971  0.91008538]
# 301 [-0.60195139  0.50905901]
# 305 [-0.79930486  0.19811143]
# 307 [ 0.25701302 -0.62076255]
# 308 [-0.41899736 -0.01568593]
# 332 [-0.65663535  0.11887589]
# 350 [-0.09768973 -0.10515825]
# 354 [-0.57132556  0.49103888]
# 356 [ 0.07266829 -0.30217638]
# 359 [-0.33004329  0.91715054]
# 360 [-0.9588463   0.01352697]
# 371 [-0.43498521  0.71946876]
# 378 [-0.77379345  0.92589364]
# 385 [ 0.04617588 -0.60757085]
# 386 [ 0.31550966 -0.11491033]
# 394 [ 0.3594187  -0.47146326]
# 415 [0.54246972 0.35348639]
# 423 [ 0.17860159 -0.37141663]
# 429 [ 0.68329216 -0.08701471]
# 430 [0.02809906 0.33782949]
# 432 [ 0.26014161 -0.93525355]
# 435 [-0.68640126 -0.42972918]
# 440 [-0.22166666  0.65932335]
# 445 [ 0.41228178 -0.72325556]
# 446 [ 0.66049548 -0.52866166]
# 448 [-0.19699346 -0.66415006]
# 453 [ 0.23601329 -0.70599933]
# 459 [-0.73976469 -0.6030863 ]
# 469 [-0.90484301 -0.68846582]
# 477 [0.67060743 0.29425873]
# 485 [-0.28592659  0.53356093]
# 487 [ 0.67863236 -0.21144002]
# 490 [-0.92072274  0.84034672]
# 491 [-0.4630369   0.91835202]
# 494 [ 0.52243698 -0.93474675]
# 42 [ 0.54211618 -0.78347826]
# 45 [0.20515274 0.4931394 ]
# 53 [-0.52869363 -0.48985415]
# 78 [-0.3407961   0.88136165]
# 79 [-0.53547994 -0.58214841]
# 82 [-0.11474982 -0.48019835]
# 89 [-0.88499297  0.78084201]
# 90 [0.85580078 0.82242596]
# 92 [-0.45167275  0.92645807]
# 98 [ 0.76004502 -0.74687334]
# 101 [-0.45542834 -0.38562921]
# 105 [0.95602825 0.42315407]
# 108 [-0.74589879 -0.06890708]
# 115 [0.31744424 0.09972768]
# 116 [-0.62541608 -0.49928129]
# 123 [-0.37739658  0.5979215 ]
# 127 [0.77628479 0.09743253]
# 134 [0.67179613 0.75597765]
# 136 [-0.47601638  0.83825169]
# 144 [-0.93488846  0.65484591]
# 173 [-0.02325405 -0.94962051]
# 58 [0.45967677 0.14525184]
# 230 [-0.88144411 -0.67011131]
# 91 [0.00913301 0.94030217]
# 201 [0.62986501 0.11297949]
# 17 [ 0.69729237 -0.80321842]
# 26 [-0.24297208  0.48271372]
# 27 [ 0.62237158 -0.34232016]
# 29 [-0.21701697 -0.74317662]
# 30 [ 0.29847725 -0.62158547]
# 39 [0.56221277 0.80508306]
# 40 [0.36400051 0.31058963]
# 41 [0.04239256 0.07887816]
# 43 [-0.6203661   0.07289605]
# 46 [0.74541425 0.84332749]
# 52 [ 0.33870113 -0.46875319]
# 54 [ 0.1859032  -0.57823836]
# 57 [-0.83519897  0.87988648]
# 59 [0.04020722 0.76597703]
# 67 [ 0.05839463 -0.60403241]
# 75 [ 0.52800635 -0.96660375]
# 80 [-0.00901882 -0.05376888]
# 84 [-0.42429429  0.85444989]
# 85 [ 0.11511211 -0.41111529]
# 86 [0.26232246 0.2137458 ]
# 93 [ 0.24308308 -0.5087343 ]
# 95 [-0.00931077  0.27648003]
# 103 [0.76230411 0.17703655]
# 107 [-0.46593119 -0.60701295]
# 111 [-0.92833164 -0.19657493]
# 121 [ 0.58518091 -0.20524992]
# 126 [-0.49761542 -0.05131788]
# 130 [-0.97297381  0.479077  ]
# 133 [-0.32057962 -0.04081042]
# 141 [-0.98454718  0.83676401]
# 143 [ 0.55136646 -0.16668536]
# 145 [0.74082075 0.89876209]
# 153 [-0.12843121 -0.97390126]
# 160 [0.72486144 0.87145935]
# 162 [-0.36014306  0.87833444]
# 166 [-0.54300325  0.60639361]
# 171 [0.07610332 0.4738736 ]
# 172 [-0.28369263  0.06234979]
# 174 [-0.72070852 -0.19300117]
# 190 [-0.92045099 -0.41163831]
# 195 [-0.76568326  0.55535244]
# 196 [-0.34499462  0.45599976]
# 197 [-0.01264671 -0.43759538]
# 199 [-0.81850646  0.5639041 ]
# 200 [-0.80254279  0.66932726]
# 204 [0.85155661 0.80155436]
# 207 [ 0.05725335 -0.18360038]
# 209 [-0.13911503  0.58745732]
# 210 [-0.2281213   0.95824481]
# 227 [-0.92650286  0.23882301]
# 241 [-0.45153896 -0.73295748]
# 246 [0.21699605 0.58725119]
# 252 [-0.23866449 -0.99824544]
# 256 [-0.9627795  -0.19683638]
# 257 [0.3115761  0.86292048]
# 259 [-0.51543004  0.82397914]
# 261 [ 0.01782078 -0.11473355]
# 263 [ 0.34763533 -0.39920261]
# 271 [ 0.60639236 -0.34236718]
# 272 [-0.89216934  0.04332209]
# 276 [-0.87776255 -0.15579702]
# 288 [-0.22785542 -0.18117224]
# 293 [-0.38478449  0.59287843]
# 300 [ 0.93660729 -0.1652901 ]
# 303 [-0.3690031  -0.84910918]
# 310 [ 0.57875633 -0.38529479]
# 318 [0.19522362 0.27452936]
# 325 [-0.80605876  0.73926326]
# 334 [-0.83026185  0.28435463]
# 339 [-0.5109245   0.16893956]
# 341 [-0.8183621   0.40738395]
# 342 [0.65715771 0.36001111]
# 344 [-0.78169791 -0.60706474]
# 346 [-0.29114725  0.3346791 ]
# 347 [ 0.90084076 -0.32467692]
# 349 [-0.50637777  0.77509129]
# 352 [ 0.77781228 -0.63832348]
# 362 [-0.63665565  0.1578411 ]
# 364 [ 0.48634405 -0.89604484]
# 365 [-0.30656296 -0.64677689]
# 373 [-0.18481675  0.45257704]
# 374 [0.45415041 0.37558956]
# 376 [ 0.34360006 -0.23263667]
# 387 [-0.51879265  0.76579832]
# 389 [-0.05854259  0.17072549]
# 403 [0.85724564 0.3633391 ]
# 411 [ 0.275601   -0.59897721]
# 412 [ 0.68134798 -0.90688561]
# 413 [0.0950632  0.52466875]
# 416 [-0.73795144 -0.18427079]
# 417 [0.51915312 0.50332643]
# 424 [ 0.01360325 -0.22408058]
# 434 [-0.95136691 -0.8323762 ]
# 441 [0.48549994 0.81240246]
# 443 [0.14123261 0.37243132]
# 444 [-0.91472482 -0.07766628]
# 460 [-0.72563301  0.11561765]
# 464 [-0.44834748 -0.46424231]
# 472 [ 0.40316546 -0.47218761]
# 474 [-0.49829574 -0.66369776]
# 476 [ 0.36697698 -0.13250845]
# 480 [0.80889853 0.53061619]
# 482 [0.61072005 0.26021292]
# 484 [-0.22746981  0.1622026 ]
# 489 [0.45221723 0.5672829 ]
# 493 [-0.98096668 -0.16832996]
# 495 [0.26217195 0.04550272]
# 496 [ 0.34110827 -0.04858958]
# 21 [-0.48555383 -0.63450808]
# 88 [-0.849436   -0.61780548]
# 124 [0.91825156 0.21527943]
# 157 [ 0.49699461 -0.03182908]
# 167 [0.48263761 0.72121435]
# 282 [ 0.4688807  -0.78489875]
# 292 [ 0.91633824 -0.69652281]
# 382 [-0.14191849 -0.85086087]
# 408 [-0.00993695  0.83824366]
# 499 [0.21805735 0.46222842]
# 120 [-0.46519673 -0.65967199]
# 419 [-0.90346678  0.41158553]
# 48 [-0.64749471 -0.94765168]
# 224 [0.85279096 0.53015157]
# 99 [0.88635519 0.01771488]
# 299 [0.79230256 0.02946618]
# 181 [-0.3846104  -0.38002314]
# 327 [-0.24228702  0.96280314]
# 340 [0.65071117 0.82471337]
# 343 [-0.1277818   0.58181454]
# 355 [-0.78913094  0.75020654]
# 368 [-0.69814409  0.03863869]
# 425 [0.53735487 0.08375225]
# 478 [-0.46267266  0.2499628 ]
# 486 [-0.1115516  -0.19990276]
# 182 [-0.72792606  0.38902529]
# 191 [0.83253932 0.00375525]
# 202 [0.55452882 0.31544296]
# 238 [ 0.12547832 -0.56551314]
# 240 [-0.51648586 -0.3096022 ]
# 269 [ 0.22365054 -0.50451175]
# 320 [ 0.59851801 -0.94471423]
# 324 [0.43664236 0.82754504]
# 68 [0.21882851 0.60002258]
# 69 [0.42371898 0.12142459]
# 71 [0.5074909  0.36647316]
# 114 [-0.65988376  0.86481909]
# 159 [-0.12997418  0.20638703]
# 20 [-0.78907084  0.87571282]
# 23 [-0.32266902 -0.11592494]
# 33 [0.95200976 0.84484807]
# 35 [-0.6690962  -0.72353739]
# 36 [-0.09633443 -0.1037645 ]
# 51 [0.3805375 0.8859844]
# 65 [-0.88171156 -0.39817587]
# 70 [0.95119287 0.02442508]
# 72 [-0.4287524  -0.22989311]
# 100 [ 0.6361617  -0.70950611]
# 112 [ 0.31339778 -0.88244023]
# 119 [-0.21099493  0.99911146]
# 122 [ 0.6162767  -0.63195239]
# 128 [0.90670496 0.23521407]
# 152 [-0.76893573 -0.1533857 ]
# 184 [-0.59687494  0.59117525]
# 208 [-0.31019854  0.4323182 ]
# 250 [-0.81347448  0.83337128]
# 264 [0.40953372 0.22799455]
# 285 [-0.88471009 -0.28138194]
# 287 [-0.5489649   0.96372911]
# 314 [-0.20912869 -0.20384309]
# 316 [-0.71112159  0.83185664]
# 329 [-0.44265412  0.41860286]
# 335 [ 0.6560963  -0.27863313]
# 363 [0.72254863 0.18487893]
# 367 [0.46018303 0.27431551]
# 383 [-0.2456639   0.64864649]
# 393 [ 0.80560459 -0.79260333]
# 401 [-0.47074374  0.01899815]
# 426 [-0.12084852 -0.61610297]
# 439 [ 0.94046389 -0.09525881]
# 452 [-0.01581329  0.79125708]
# 283 [0.0899251  0.25659032]
# 345 [-0.49560097 -0.96358247]
# 31 [-0.59210438 -0.49530996]
# 55 [ 0.18293863 -0.1039992 ]
# 62 [0.86453798 0.51302957]
# 76 [0.07211588 0.74490799]
# 149 [-0.22541011  0.44810678]
# 170 [-0.97200162  0.2907228 ]
# 194 [0.33643507 0.2626073 ]
# 216 [ 0.28774638 -0.84681871]
# 304 [-0.51332557  0.49887742]
# 313 [-0.22057194  0.95372647]
# 322 [-0.23719268 -0.98076606]
# 357 [-0.95072015 -0.56213346]
# 410 [ 0.96937444 -0.15515034]
# 455 [ 0.32837952 -0.18704294]
# 488 [ 0.94067593 -0.27753956]
# 14 [-0.04185663  0.52464488]
# 15 [ 0.33118094 -0.64362101]
# 16 [-0.95867693  0.2408294 ]
# 19 [ 0.27399134 -0.59384395]
# 25 [0.58863625 0.31125522]
# 32 [ 0.14156901 -0.12133567]
# 56 [ 0.60961903 -0.56792025]
# 81 [-0.90869482  0.18824445]
# 109 [0.84247896 0.39378192]
# 117 [0.6701449 0.2344959]
# 118 [0.73144563 0.11025893]
# 129 [ 0.45809899 -0.13247143]
# 139 [ 0.57630732 -0.54330228]
# 164 [-0.2497309 -0.8974492]
# 175 [-0.2130482  -0.02345502]
# 192 [-0.84008675 -0.8992874 ]
# 203 [0.23747174 0.53457892]
# 215 [-0.17430788  0.8302872 ]
# 225 [-0.57870807  0.7535275 ]
# 231 [ 0.07238239 -0.27786171]
# 234 [0.35849912 0.54368629]
# 245 [0.18631135 0.61592684]
# 249 [-0.20112881  0.55415294]
# 254 [ 0.07407848 -0.86268933]
# 278 [-0.28043559 -0.15429279]
# 286 [0.46320668 0.27034795]
# 295 [-0.73465735  0.85989746]
# 358 [-0.84976848 -0.04219902]
# 361 [-0.8471943   0.84404255]
# 379 [0.96947733 0.32591541]
# 395 [-0.08059034 -0.57757765]
# 396 [-0.0951564   0.49728209]
# 399 [0.6249887  0.70844745]
# 402 [-0.16281355 -0.89010469]
# 407 [0.55571904 0.01625565]
# 431 [ 0.28687994 -0.86290632]
# 447 [-0.53542784  0.05536881]
# 449 [-0.59799624  0.17157706]
# 450 [ 0.50189602 -0.90008408]
# 457 [-0.43268833  0.04084367]
# 463 [-0.46864188 -0.74591456]
# 479 [-0.69529617  0.30110593]
# 243 [-0.2476681   0.27072666]
# 418 [0.06010305 0.45598895]
# 137 [0.56665588 0.1346139 ]
# 223 [0.07126286 0.51018558]
# 242 [-0.69468243  0.0397789 ]
# 253 [0.57247945 0.57784559]
# 284 [-0.69869005 -0.28416634]
# 442 [-0.2980948  -0.23770997]
# 456 [-0.2956457   0.80290211]
# 102 [-0.48553895 -0.76221021]
# 228 [-0.05170518 -0.19747935]
# 18 [0.7504503  0.75011082]
# 270 [-0.17245663  0.10385841]
# 64 [0.64469097 0.15376227]
# 106 [-0.84247212 -0.36917521]
# 147 [ 0.40798232 -0.90755235]
# 186 [0.4574053  0.59822548]
# 233 [-0.49365933  0.07759027]
# 309 [-0.06399768  0.89565698]
# 328 [-0.55833513 -0.36614827]
# 370 [0.71914491 0.3457367 ]
# 420 [ 0.48599875 -0.81690469]
# 421 [0.25663295 0.62652341]
# 466 [-0.62130593  0.6583718 ]
# 132 [-0.96499474 -0.36784067]
# 161 [-0.80472413 -0.98807247]
# 333 [ 0.9849126  -0.07271272]
# 163 [0.82561886 0.83850229]
# 217 [0.89277024 0.47531574]
# 229 [-0.92709608 -0.85023477]
# 289 [ 0.89948752 -0.74288881]
# 290 [-0.37527046  0.91216963]
# 336 [ 0.83675955 -0.92823165]
# 63 [0.00827086 0.66721827]
# 96 [-0.43931985 -0.8216148 ]
# 110 [-0.52782651 -0.31649757]
# 142 [ 0.74779071 -0.95266946]
# 266 [-0.67138387 -0.33530766]
# 275 [0.99985756 0.58989261]
# 366 [-0.87398326 -0.41718918]
# 438 [-0.71176384 -0.12812694]
# 492 [-0.14256531  0.6953038 ]
# 498 [-0.84503682  0.85581126]
# 34 [-0.0535127   0.03474902]
# 154 [ 0.58878867 -0.01922998]
# 302 [-0.27358705  0.07854075]
# 384 [-0.15118476 -0.76605838]
# 73 [-0.57942026  0.10673737]
# 104 [-0.84905268  0.59632639]
# 146 [ 0.5219307  -0.27912369]
# 213 [0.03335845 0.96943604]
# 221 [ 0.22818266 -0.80769651]
# 258 [0.77819724 0.95096967]
# 274 [-0.07821318 -0.33420641]
# 330 [ 0.80304971 -0.24356388]
# 409 [0.22157462 0.53229202]
# 427 [-0.03763392  0.10592581]
# 471 [-0.92130619  0.53774521]
# 140 [0.09733039 0.81279951]
# 150 [0.15361934 0.11830496]
# 176 [0.8026002  0.40910748]
# 188 [ 0.5135672  -0.14563326]
# 219 [0.76244558 0.74903195]
# 321 [-0.8256583 -0.4692104]
# 338 [-0.46722344  0.10903679]
# 375 [-0.02168522  0.52579463]
# 388 [-0.87211068  0.51186208]
# 422 [0.2930625  0.88608115]
# 470 [ 0.39525746 -0.54187728]
# 473 [-0.84709982  0.9383517 ]
# 483 [0.83642482 0.21406994]
# 44 [ 0.25283377 -0.36143627]
# 49 [ 0.45251382 -0.99815009]
# 125 [-0.12203848 -0.12825047]
# 467 [-0.31065144  0.29906224]
# 28 [ 0.7640136 -0.4193076]
# 37 [-0.3921603   0.15961464]
# 77 [-0.73824503 -0.00110762]
# 185 [0.39926067 0.75369076]
# 211 [-0.3252666  -0.30843943]
# 232 [-0.81265816  0.99113078]
# 248 [0.49611741 0.88033874]
# 262 [-0.60827223 -0.08400846]
# 296 [0.24278538 0.96841438]
# 298 [0.5170171 0.5041229]
# 306 [0.99170202 0.80840234]
# 390 [-0.53122083 -0.20160156]
# 405 [0.94305304 0.16888972]
# 461 [-0.05647602  0.92701755]
# 475 [-0.81647636 -0.79248115]
# 66 [0.26200919 0.96531494]
# 177 [ 0.02945969 -0.58615048]
# 180 [-0.91969073  0.71924271]
# 148 [-0.10598479 -0.64561639]
# 323 [0.18620517 0.9662359 ]
# 348 [ 0.48511977 -0.64834973]
# 353 [ 0.20322616 -0.90524336]
# 381 [-0.37830425 -0.95647505]
# 458 [-0.22174474 -0.25368311]
# 22 [-0.17360903  0.50435121]
# 74 [-0.20473504  0.90821049]
# 87 [-0.10585288 -0.15448957]
# 237 [-0.98218176  0.37790102]
# 311 [0.24018671 0.50412715]
# 312 [0.03555839 0.56487478]
# 351 [-0.05422574 -0.14142244]
# 380 [ 0.95902118 -0.29278536]
# 428 [-0.48763609 -0.07583985]
# 481 [0.73307217 0.77547492]
# None

# %% [markdown]
# #### individuals cos2

# %%
# individuals cos2
ind.cos2
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# 0    0.001049  0.160194  0.071767  0.507721  0.041088
# 1    0.180659  0.234965  0.290075  0.182035  0.005655
# 2    0.006657  0.154692  0.072775  0.700857  0.064776
# 3    0.006657  0.154692  0.072775  0.700857  0.064776
# 4    0.096903  0.379731  0.090645  0.181418  0.250941
# ..        ...       ...       ...       ...       ...
# 495  0.308330  0.217080  0.395830  0.000004  0.078429
# 496  0.308330  0.217080  0.395830  0.000004  0.078429
# 497  0.274995  0.232058  0.027385  0.463678  0.001692
# 498  0.304071  0.008446  0.182048  0.029103  0.476153
# 499  0.043439  0.796302  0.087868  0.031522  0.040754
#
# [500 rows x 5 columns]

# %%
# graph of individuals - color by cosinus
p = fviz_mca(
    obj=clf,
    choice="ind",
    col_ind="cos2",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# 404 [ 0.00162979 -0.35381598]
# 406 [0.1111301  0.58556967]
# 414 [ 0.9619691  -0.64031508]
# 462 [-0.38238598 -0.09839985]
# 50 [-0.10923412  0.94035538]
# 60 [ 0.49491963 -0.33130532]
# 97 [0.72767846 0.66448295]
# 135 [-0.17179734 -0.43285239]
# 138 [-0.10421074 -0.52308913]
# 151 [-0.45901512  0.23984485]
# 156 [-0.83496146  0.90427857]
# 165 [-0.4921008   0.90979546]
# 212 [0.81213889 0.03321266]
# 214 [ 0.62307319 -0.77340598]
# 244 [-0.82937501  0.62688399]
# 279 [ 0.5964011  -0.16819634]
# 294 [ 0.24696091 -0.86705112]
# 331 [-0.58913372 -0.87628983]
# 369 [0.01655251 0.13760412]
# 392 [ 0.2559889 -0.6429316]
# 24 [ 0.69452552 -0.81393844]
# 47 [-0.08205374  0.469734  ]
# 83 [-0.46797514 -0.79418335]
# 155 [-0.11106092 -0.04835071]
# 158 [ 0.49685813 -0.8963902 ]
# 168 [ 0.34077959 -0.29466461]
# 169 [-0.79248261  0.54466298]
# 187 [ 0.50755067 -0.06792735]
# 226 [-0.85195758 -0.75658506]
# 239 [-0.86902565 -0.64388591]
# 265 [-0.75994883  0.2261817 ]
# 267 [ 0.31312088 -0.78765616]
# 281 [-0.60618027  0.10208731]
# 317 [-0.71208238 -0.28988058]
# 372 [-0.98237769  0.84834539]
# 377 [-0.80051206  0.43917813]
# 400 [0.34026705 0.17307275]
# 436 [0.14957149 0.95585575]
# 437 [-0.20907596 -0.60293657]
# 451 [0.57337555 0.50345957]
# 454 [-0.07373759 -0.54674135]
# 497 [0.91557516 0.73184737]
# 179 [0.56757463 0.39825363]
# 189 [-0.23655871 -0.46151088]
# 193 [-0.85651788 -0.89715563]
# 198 [ 0.43453627 -0.18910919]
# 205 [-0.4067823  -0.87277831]
# 218 [-0.86879223  0.40368818]
# 220 [0.48012733 0.24831677]
# 222 [-0.80150444  0.1955616 ]
# 236 [ 0.43581284 -0.22632538]
# 247 [ 0.15799978 -0.16866021]
# 251 [0.01456713 0.93964672]
# 260 [-0.09177859 -0.47577153]
# 268 [-0.43268299 -0.3040385 ]
# 273 [0.03619884 0.53838157]
# 277 [0.48931181 0.87550498]
# 280 [ 0.10412506 -0.5441757 ]
# 291 [0.70213141 0.87281645]
# 297 [0.39571171 0.37365081]
# 301 [-0.99741988 -0.43600384]
# 305 [-0.1686963 -0.686781 ]
# 307 [ 0.18649007 -0.76637916]
# 308 [-0.34208913 -0.0816107 ]
# 332 [ 0.73700634 -0.38384258]
# 350 [-0.13995591 -0.82186887]
# 354 [-0.23224113 -0.73744984]
# 356 [-0.88318431 -0.14689508]
# 359 [-0.15803013  0.04729357]
# 360 [ 0.48819966 -0.69037604]
# 371 [-0.68980303  0.95487666]
# 378 [ 0.16433378 -0.83731438]
# 385 [-0.8915373  -0.35748418]
# 386 [ 0.88326908 -0.02928098]
# 394 [-0.72994322 -0.14762025]
# 415 [-0.67869466  0.44627942]
# 423 [0.75497553 0.04895421]
# 429 [-0.43946854  0.38464917]
# 430 [0.41417121 0.81960487]
# 432 [-0.30625626 -0.86432121]
# 435 [-0.64650676  0.36503933]
# 440 [ 0.36645183 -0.12498678]
# 445 [-0.18034619  0.91663132]
# 446 [ 0.81071084 -0.75192492]
# 448 [ 0.80707024 -0.10320426]
# 453 [-0.06705018 -0.75988805]
# 459 [-0.5847211   0.96204522]
# 469 [-0.54642776 -0.22406972]
# 477 [-0.01405991 -0.36198026]
# 485 [-0.59955064  0.95145846]
# 487 [ 0.07405596 -0.92182906]
# 490 [-0.79416099  0.65611424]
# 491 [-0.86725961  0.49619036]
# 494 [ 0.32736163 -0.46177991]
# 42 [0.5545289 0.567957 ]
# 45 [-0.58152413  0.53263426]
# 53 [0.5171756  0.28421175]
# 78 [-0.70803908  0.12694181]
# 79 [ 0.28705306 -0.26402707]
# 82 [-0.75943331 -0.38604896]
# 89 [-0.54429827  0.36334697]
# 90 [-0.60626561  0.11176162]
# 92 [ 0.98657713 -0.01619926]
# 98 [ 0.10625177 -0.37157527]
# 101 [-0.77736534  0.24627373]
# 105 [0.5812916  0.48377798]
# 108 [0.73336707 0.38449522]
# 115 [-0.51531849  0.08069327]
# 116 [-0.30235363  0.26140813]
# 123 [-0.94615235  0.59431679]
# 127 [-0.0309527   0.04295488]
# 134 [-0.22525461 -0.41596706]
# 136 [0.50177978 0.40701353]
# 144 [-0.6743466  -0.42218599]
# 173 [0.00340597 0.63366039]
# 58 [-0.22088641  0.47934101]
# 230 [ 0.60793263 -0.53590602]
# 91 [-0.64267546 -0.51514809]
# 201 [0.34143316 0.25116384]
# 17 [0.5818898 0.7052686]
# 26 [-0.42767807  0.60127998]
# 27 [0.24782401 0.23540752]
# 29 [0.35319419 0.33727579]
# 30 [ 0.71200228 -0.32289752]
# 39 [-0.7752982  -0.82003908]
# 40 [ 0.9161793  -0.96740082]
# 41 [-0.5926568  -0.12310227]
# 43 [ 0.28906902 -0.75557683]
# 46 [-0.63888668  0.09305459]
# 52 [-0.75393951 -0.41330743]
# 54 [0.08169261 0.13910076]
# 57 [-0.88057923  0.97251679]
# 59 [-0.48986288 -0.90912794]
# 67 [-0.50170466  0.53473334]
# 75 [0.44513846 0.86669336]
# 80 [ 0.44475742 -0.02796487]
# 84 [-0.50012422 -0.49712077]
# 85 [0.50709994 0.87574909]
# 86 [-0.36638991  0.94351038]
# 93 [-0.7451908   0.63258871]
# 95 [-0.39532206  0.97919409]
# 103 [-0.09713634 -0.31797745]
# 107 [0.09843338 0.47390362]
# 111 [-0.93234719  0.42126239]
# 121 [-0.2026352  -0.14083351]
# 126 [-0.75154087 -0.05749431]
# 130 [ 0.60310367 -0.53307008]
# 133 [0.5149949  0.84091494]
# 141 [ 0.20603714 -0.74911283]
# 143 [0.85214779 0.45209888]
# 145 [0.18848026 0.80994855]
# 153 [ 0.77526513 -0.0228461 ]
# 160 [-0.83578788 -0.44714337]
# 162 [-0.47975528 -0.96909791]
# 166 [ 0.720644   -0.19198081]
# 171 [0.50805862 0.68672723]
# 172 [-0.58513414 -0.32855837]
# 174 [-0.93783095  0.03428633]
# 190 [ 0.63003516 -0.70391553]
# 195 [-0.39341183 -0.26402109]
# 196 [-0.76605439  0.4447813 ]
# 197 [-0.75029489  0.44664004]
# 199 [0.04394998 0.37684292]
# 200 [-0.90483831 -0.18732925]
# 204 [0.65792988 0.32527308]
# 207 [0.29017584 0.31666496]
# 209 [-0.19584906  0.98790119]
# 210 [ 0.31157139 -0.14180274]
# 227 [-0.5915587   0.91291688]
# 241 [ 0.4292727  -0.41184525]
# 246 [ 0.79002097 -0.57394851]
# 252 [0.71569533 0.90037716]
# 256 [ 0.45067428 -0.01666844]
# 257 [ 0.69161588 -0.76768522]
# 259 [ 0.95851619 -0.04408067]
# 261 [-0.85396339  0.63730532]
# 263 [0.67441307 0.06933634]
# 271 [ 0.6526538  -0.91692307]
# 272 [-0.72197507 -0.32054114]
# 276 [0.44834176 0.04105134]
# 288 [-0.29264863 -0.04096941]
# 293 [-0.50889085  0.54194081]
# 300 [0.5797689  0.28110707]
# 303 [ 0.58351744 -0.4603942 ]
# 310 [-0.46957795 -0.98194169]
# 318 [0.06628797 0.43382   ]
# 325 [-0.95002478  0.26951849]
# 334 [-0.83749912 -0.82172268]
# 339 [-0.99152136  0.01131292]
# 341 [-0.18850126  0.43511715]
# 342 [-0.803531   -0.63113627]
# 344 [ 0.07889084 -0.16867455]
# 346 [ 0.18274402 -0.34962607]
# 347 [0.95221135 0.98351594]
# 349 [0.26003532 0.27043484]
# 352 [ 0.86696459 -0.68273254]
# 362 [-0.85963078  0.68330567]
# 364 [-0.08496371 -0.03485721]
# 365 [-0.11395483 -0.61777006]
# 373 [0.92891819 0.58965393]
# 374 [ 0.0854142  -0.44870407]
# 376 [-0.26378363  0.35187639]
# 387 [-0.30039952  0.15014944]
# 389 [0.11288255 0.91797522]
# 403 [-0.79620741 -0.97850381]
# 411 [0.29393025 0.8724464 ]
# 412 [0.24253919 0.74076299]
# 413 [-0.87378204  0.96099861]
# 416 [0.40757535 0.04704717]
# 417 [ 0.90956176 -0.81865736]
# 424 [-0.49224646  0.24347213]
# 434 [ 0.71948163 -0.50561038]
# 441 [-0.32694527  0.06921957]
# 443 [0.05551777 0.80150589]
# 444 [-0.20855277 -0.82759801]
# 460 [ 0.49328357 -0.84089312]
# 464 [0.66691718 0.07993441]
# 472 [-0.51517384 -0.41185029]
# 474 [-0.28683933  0.76088158]
# 476 [-0.56284621  0.83680876]
# 480 [ 0.33926903 -0.03660881]
# 482 [-0.33819127  0.42893279]
# 484 [-0.59387254 -0.72034192]
# 489 [0.44371958 0.23144089]
# 493 [ 0.56374958 -0.00768037]
# 495 [-0.69459002  0.95169174]
# 496 [ 0.48549332 -0.30227532]
# 21 [0.80674206 0.98521829]
# 88 [-0.24632132  0.86578997]
# 124 [-0.32530582 -0.95450825]
# 157 [-0.63222509  0.42732176]
# 167 [ 0.36572326 -0.09914397]
# 282 [ 0.03445557 -0.76260418]
# 292 [-0.47317465  0.39539323]
# 382 [-0.22758731  0.27404881]
# 408 [ 0.21018091 -0.02352027]
# 499 [-0.39058141  0.36962701]
# 120 [ 0.28906963 -0.31933492]
# 419 [0.40561865 0.42783958]
# 48 [ 0.23003124 -0.42539115]
# 224 [-0.65284686 -0.32253679]
# 99 [-0.4522724  -0.50795288]
# 299 [-0.13853698 -0.87227251]
# 181 [0.45347264 0.56386377]
# 327 [-0.72261659 -0.47697869]
# 340 [-0.39445325  0.82447948]
# 343 [0.47962917 0.99150384]
# 355 [-0.24579003  0.66038695]
# 368 [ 0.82753413 -0.92429088]
# 425 [-0.84781633  0.76557557]
# 478 [ 0.88538508 -0.45371924]
# 486 [-0.45023369  0.95412386]
# 182 [-0.0805451  -0.40971876]
# 191 [-0.38319922 -0.11075406]
# 202 [ 0.46730513 -0.27267733]
# 238 [0.31216892 0.53872529]
# 240 [-0.28955662  0.23896613]
# 269 [0.03120504 0.52620197]
# 320 [-0.04998955 -0.75812136]
# 324 [ 0.33217997 -0.56929469]
# 68 [ 0.32464151 -0.30390229]
# 69 [0.18308839 0.31347075]
# 71 [-0.93257998  0.63060358]
# 114 [0.28392239 0.175635  ]
# 159 [-0.83206453  0.15085047]
# 20 [0.50030887 0.39553768]
# 23 [-0.1749202   0.72563461]
# 33 [-0.902901    0.49347213]
# 35 [-0.29805979  0.63296359]
# 36 [-0.47337522  0.81081102]
# 51 [0.65767363 0.27351039]
# 65 [ 0.99805654 -0.85139909]
# 70 [ 0.78397733 -0.67324727]
# 72 [-0.70877335  0.2529119 ]
# 100 [0.35469866 0.06782125]
# 112 [0.36943004 0.0425992 ]
# 119 [-0.86219568 -0.01441433]
# 122 [ 0.47069727 -0.80095005]
# 128 [-0.8432097 -0.1919793]
# 152 [ 0.48271938 -0.80935074]
# 184 [-0.75090781 -0.75174376]
# 208 [-0.88159632 -0.68921198]
# 250 [-0.74449785 -0.11053686]
# 264 [ 0.91445247 -0.14200898]
# 285 [-0.02229543 -0.57328552]
# 287 [ 0.98491122 -0.2840295 ]
# 314 [-0.80038922 -0.40192974]
# 316 [-0.09938132  0.32736145]
# 329 [ 0.75068926 -0.83271168]
# 335 [-0.79149726  0.36688591]
# 363 [ 0.1433569  -0.68955911]
# 367 [0.70185333 0.2988065 ]
# 383 [ 0.94925073 -0.12993426]
# 393 [-0.15803486  0.18046674]
# 401 [0.93179983 0.96476472]
# 426 [0.61355617 0.70250111]
# 439 [ 0.69618603 -0.5608757 ]
# 452 [-0.93071357 -0.63180283]
# 283 [-0.89320325 -0.16604958]
# 345 [ 0.12928082 -0.81697922]
# 31 [-0.48246987 -0.69833658]
# 55 [-0.41162496  0.50595558]
# 62 [-0.47408315 -0.06723809]
# 76 [ 0.90741524 -0.45656172]
# 149 [-0.33119848 -0.75038043]
# 170 [-0.44016891  0.21072976]
# 194 [-0.22469647  0.56546802]
# 216 [-0.69934598 -0.30166886]
# 304 [0.89577971 0.42945718]
# 313 [-0.27766559  0.58721888]
# 322 [ 0.48990369 -0.02020461]
# 357 [ 0.30500372 -0.34268531]
# 410 [-0.785493   -0.84725913]
# 455 [-0.29423416  0.90756146]
# 488 [ 0.92892322 -0.73033456]
# 14 [0.50714872 0.4996508 ]
# 15 [ 0.75700011 -0.11650962]
# 16 [0.62203383 0.30218221]
# 19 [-0.45993775 -0.81608371]
# 25 [ 0.2701213  -0.67321887]
# 32 [-0.70841348 -0.05590458]
# 56 [-0.10581527 -0.91351346]
# 81 [-0.78206323 -0.79213402]
# 109 [0.24981846 0.40535455]
# 117 [0.2917789  0.67312943]
# 118 [ 0.06782132 -0.97629039]
# 129 [0.63888028 0.11242155]
# 139 [-0.68919637 -0.42775271]
# 164 [0.31751165 0.16641814]
# 175 [ 0.71007049 -0.10774507]
# 192 [0.85020006 0.72125151]
# 203 [0.6269941  0.88062865]
# 215 [-0.47435607 -0.45681968]
# 225 [ 0.62787246 -0.65886393]
# 231 [-0.61580113 -0.37831546]
# 234 [ 0.9286945  -0.42228259]
# 245 [ 0.22919461 -0.29689517]
# 249 [ 0.16504804 -0.22184071]
# 254 [-0.72111591 -0.58010864]
# 278 [ 0.16984147 -0.33912301]
# 286 [0.1137134  0.37010013]
# 295 [0.12953631 0.82720455]
# 358 [ 0.58764049 -0.49011445]
# 361 [-0.20912494 -0.52322776]
# 379 [-0.80839986 -0.40388824]
# 395 [-0.99885294  0.17611767]
# 396 [-0.73985794 -0.51296242]
# 399 [ 0.73683284 -0.3152287 ]
# 402 [0.59101374 0.21792375]
# 407 [0.63269648 0.17525263]
# 431 [-0.11804565 -0.43701007]
# 447 [ 0.7582853 -0.3452069]
# 449 [-0.28699904 -0.0664554 ]
# 450 [0.39434641 0.53372705]
# 457 [-0.98600019 -0.38502064]
# 463 [ 0.30122513 -0.07359706]
# 479 [0.39993838 0.35425796]
# 243 [ 0.46151631 -0.26695478]
# 418 [-0.9344891  -0.44827254]
# 137 [-0.03233496  0.99170692]
# 223 [0.09608098 0.48489552]
# 242 [ 0.08761887 -0.99588029]
# 253 [0.04750219 0.00639746]
# 284 [-0.48135079  0.35095419]
# 442 [-0.13449601  0.19292903]
# 456 [-0.25837796 -0.97988791]
# 102 [-0.95946413  0.90255719]
# 228 [-0.01522843 -0.76854915]
# 18 [ 0.06391884 -0.87153902]
# 270 [ 0.27948415 -0.52432883]
# 64 [-0.50453812 -0.02167267]
# 106 [0.2591364  0.99094127]
# 147 [ 0.43831168 -0.20102831]
# 186 [-0.46599864  0.28476427]
# 233 [-0.3621018  -0.62076493]
# 309 [0.98182538 0.77102164]
# 328 [0.07932426 0.6920301 ]
# 370 [ 0.9245433  -0.95268173]
# 420 [-0.31776504  0.7844841 ]
# 421 [ 0.01854157 -0.55231443]
# 466 [-0.71813179  0.17407461]
# 132 [-0.87383105 -0.26638   ]
# 161 [-0.45909103  0.29199776]
# 333 [-0.78148749  0.8800859 ]
# 163 [-0.69993722 -0.3248955 ]
# 217 [-0.64035328 -0.92507181]
# 229 [-0.18432723  0.68747507]
# 289 [-0.59529194 -0.22925697]
# 290 [0.00580943 0.55538042]
# 336 [0.03359093 0.54195557]
# 63 [ 0.37201457 -0.44132798]
# 96 [-0.80798851 -0.32400891]
# 110 [-0.63430413 -0.34345298]
# 142 [-0.57710425 -0.91828639]
# 266 [-0.13994494 -0.76798041]
# 275 [ 0.72623372 -0.40765861]
# 366 [-0.79223873  0.81275631]
# 438 [-0.78523888  0.57398786]
# 492 [0.78922248 0.12673602]
# 498 [-0.45080288 -0.83192285]
# 34 [0.74949158 0.48156438]
# 154 [-0.87824678 -0.51658316]
# 302 [ 0.99304852 -0.48225377]
# 384 [-0.84428959  0.92832096]
# 73 [-0.96468181 -0.96702553]
# 104 [ 0.62246957 -0.72976336]
# 146 [ 0.81932921 -0.84068674]
# 213 [-0.60089197  0.59834639]
# 221 [ 0.9709983  -0.66644185]
# 258 [-0.24848675 -0.37014163]
# 274 [0.88790904 0.20287806]
# 330 [-0.15713798  0.09374826]
# 409 [-0.44928305 -0.47665336]
# 427 [0.74664593 0.53638683]
# 471 [ 0.69426728 -0.53570134]
# 140 [ 0.59568449 -0.14927167]
# 150 [ 0.88677847 -0.51856432]
# 176 [ 0.29271292 -0.61625288]
# 188 [-0.34400033 -0.95544898]
# 219 [0.21378045 0.03391329]
# 321 [-0.4559685  -0.36140396]
# 338 [-0.25948062 -0.40996619]
# 375 [ 0.26221045 -0.89511746]
# 388 [ 0.59583656 -0.83378271]
# 422 [ 0.6671249  -0.66792551]
# 470 [-0.20097962  0.85323145]
# 473 [ 0.69227855 -0.15484931]
# 483 [-0.26631131 -0.10698927]
# 44 [-0.32538065  0.57031413]
# 49 [0.58899476 0.44645347]
# 125 [-0.57374049  0.86319035]
# 467 [ 0.35120971 -0.6313034 ]
# 28 [-0.96742314 -0.04476108]
# 37 [-0.18296546 -0.53906423]
# 77 [0.1201436  0.48365405]
# 185 [0.19810794 0.45411385]
# 211 [0.41543583 0.13175234]
# 232 [-0.75001377  0.68670357]
# 248 [-0.22313059 -0.2215139 ]
# 262 [-0.36413697  0.38142918]
# 296 [-0.86750902 -0.91916649]
# 298 [-0.22142662 -0.43524337]
# 306 [0.66341978 0.91167614]
# 390 [ 0.06722409 -0.37623851]
# 405 [-0.89756879 -0.51042211]
# 461 [-0.46129328 -0.92925888]
# 475 [ 0.26932267 -0.62615935]
# 66 [0.76094416 0.91009967]
# 177 [0.22224901 0.73388091]
# 180 [-0.50065455  0.27972375]
# 148 [-0.48288036 -0.82369722]
# 323 [0.08704207 0.89523604]
# 348 [-0.98977934  0.30486541]
# 353 [-0.52890391  0.96497741]
# 381 [-0.56641427  0.51531433]
# 458 [-0.09541135 -0.24839079]
# 22 [-0.19085248  0.65128078]
# 74 [-0.5372056  -0.42382099]
# 87 [-0.90528346  0.6846292 ]
# 237 [0.82430407 0.90068809]
# 311 [-0.33915001  0.40913694]
# 312 [ 0.55249714 -0.98844397]
# 351 [-0.44806506  0.93834729]
# 380 [-0.41001076  0.00309455]
# 428 [ 0.20691421 -0.26098365]
# 481 [-0.42440096 -0.50958753]
# None

# %%
# graph of cosinus
from scientisttools import fviz_corrplot
p = fviz_corrplot(
    X=ind.cos2,
    legend_title="Cos2",
    title="Cosinus of individuals"
)
print(p.show())
# Out:
# None

# %%
# cosinus of individuals to axis 1
from scientisttools import fviz_cos2
p = fviz_cos2(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals contributions

# %%
# individuals contributions
ind.contrib
# Out:
#          Dim1      Dim2      Dim3      Dim4      Dim5
# 0    0.000682  0.133068  0.063969  0.536239  0.057698
# 1    0.228793  0.380185  0.503637  0.374500  0.015469
# 2    0.004880  0.144885  0.073140  0.834621  0.102562
# 3    0.004880  0.144885  0.073140  0.834621  0.102562
# 4    0.055250  0.276616  0.070853  0.168030  0.309023
# ..        ...       ...       ...       ...       ...
# 495  0.082955  0.074620  0.146003  0.000002  0.045575
# 496  0.082955  0.074620  0.146003  0.000002  0.045575
# 497  0.283084  0.305208  0.038649  0.775393  0.003761
# 498  0.274455  0.009740  0.225271  0.042672  0.928256
# 499  0.059159  1.385538  0.164055  0.069736  0.119876
#
# [500 rows x 5 columns]

# %%
# graph of individuals - color by contributions
p = fviz_mca(
    obj=clf,
    choice="ind",
    col_ind="contrib",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# 404 [-0.96756276  0.3379942 ]
# 406 [-0.2792072 -0.8421592]
# 414 [ 0.6022095  -0.27069893]
# 462 [-0.72884296  0.46885793]
# 50 [0.01158233 0.981294  ]
# 60 [-0.10333851 -0.83247977]
# 97 [ 0.27757264 -0.75131263]
# 135 [-0.74938612 -0.27811167]
# 138 [0.84482682 0.19217848]
# 151 [ 0.91856157 -0.70256364]
# 156 [-0.90657323 -0.62776683]
# 165 [0.14946177 0.22226381]
# 212 [0.27408046 0.30591416]
# 214 [ 0.90464604 -0.97921815]
# 244 [0.18783362 0.88673545]
# 279 [ 0.76710978 -0.69919262]
# 294 [-0.57480576 -0.70305108]
# 331 [-0.32998813 -0.34816049]
# 369 [0.68050448 0.81903442]
# 392 [ 0.44625594 -0.53687821]
# 24 [-0.28024912  0.77295166]
# 47 [0.58403486 0.28755426]
# 83 [ 0.2865723  -0.52532955]
# 155 [0.28673059 0.02958852]
# 158 [-0.7500079  -0.50027359]
# 168 [-0.730466    0.43451871]
# 169 [-0.21994815 -0.46548372]
# 187 [-0.18868085 -0.81745999]
# 226 [0.51928874 0.97425348]
# 239 [ 0.65233002 -0.5590907 ]
# 265 [-0.41612365  0.84252988]
# 267 [0.68351498 0.22243223]
# 281 [-0.46389094  0.67745112]
# 317 [ 0.07779644 -0.70934691]
# 372 [ 0.58807664 -0.79445784]
# 377 [-0.04166914  0.47386162]
# 400 [ 0.84566635 -0.17778732]
# 436 [-0.25809177 -0.22645213]
# 437 [-0.99302646  0.97980293]
# 451 [ 0.56654315 -0.23625501]
# 454 [0.62323503 0.4561063 ]
# 497 [-0.10551117  0.79017917]
# 179 [-0.95794109 -0.63462448]
# 189 [0.88669829 0.3061564 ]
# 193 [-0.55496364  0.00389155]
# 198 [0.33745951 0.05579681]
# 205 [-0.38647791 -0.87605897]
# 218 [-0.78696948 -0.4323716 ]
# 220 [0.46101208 0.74118355]
# 222 [ 0.99287112 -0.02969448]
# 236 [-0.47920951 -0.88178493]
# 247 [-0.6439794  -0.65928114]
# 251 [0.83732412 0.67729038]
# 260 [0.05567795 0.64605133]
# 268 [0.22223283 0.43671955]
# 273 [-0.10832994  0.55328035]
# 277 [0.11130927 0.73483616]
# 280 [ 0.94018157 -0.40376271]
# 291 [-0.80610462  0.94533124]
# 297 [ 0.28193226 -0.12386584]
# 301 [0.88729496 0.22169118]
# 305 [ 0.45599084 -0.59251851]
# 307 [-0.18151903 -0.2285726 ]
# 308 [0.11367133 0.02965586]
# 332 [0.85778531 0.29823868]
# 350 [ 0.97053196 -0.08675776]
# 354 [0.64369168 0.92131004]
# 356 [-0.72921068  0.83594855]
# 359 [ 0.30798693 -0.96356288]
# 360 [ 0.39233331 -0.52114501]
# 371 [0.62270975 0.27934813]
# 378 [0.77496791 0.44257221]
# 385 [-0.69937947  0.97482764]
# 386 [-0.47170407 -0.141523  ]
# 394 [ 0.23328444 -0.17175151]
# 415 [0.65068004 0.98791614]
# 423 [-0.51597848 -0.85698474]
# 429 [-0.48604463 -0.88298929]
# 430 [0.57219437 0.14777168]
# 432 [0.62846599 0.29571551]
# 435 [-0.19489708 -0.12809641]
# 440 [0.68039792 0.94648045]
# 445 [0.40059077 0.71880485]
# 446 [ 0.28783245 -0.33432098]
# 448 [-0.12188157  0.91028613]
# 453 [ 0.79018471 -0.76608044]
# 459 [-0.39366941  0.1576817 ]
# 469 [ 0.05505203 -0.93837188]
# 477 [0.27761594 0.21614585]
# 485 [-0.37759276 -0.82063238]
# 487 [-0.45540665 -0.16719611]
# 490 [-0.00954094 -0.63638563]
# 491 [ 0.29023579 -0.75129162]
# 494 [-0.06021958 -0.78815677]
# 42 [-0.62203514 -0.47352992]
# 45 [0.96957356 0.83642554]
# 53 [-0.01424993  0.81287616]
# 78 [ 0.61864696 -0.00308777]
# 79 [ 0.7169155  -0.52507763]
# 82 [ 0.70098088 -0.09001769]
# 89 [-0.45957883  0.48595431]
# 90 [-0.54375592  0.330459  ]
# 92 [0.44480931 0.94025029]
# 98 [ 0.2230494 -0.8434967]
# 101 [0.89426446 0.51237522]
# 105 [-0.48106748  0.94649186]
# 108 [-0.95664526  0.63431683]
# 115 [-0.51518353  0.97883702]
# 116 [-0.98259646 -0.80085077]
# 123 [0.51836001 0.76278765]
# 127 [0.43689949 0.6019968 ]
# 134 [-0.06981732 -0.69354105]
# 136 [ 0.90625927 -0.32646822]
# 144 [ 0.17192049 -0.97928944]
# 173 [ 0.01032474 -0.54098821]
# 58 [0.04206034 0.55398561]
# 230 [ 0.89839405 -0.10894397]
# 91 [0.73278396 0.73104189]
# 201 [ 0.25251369 -0.39814875]
# 17 [ 0.96762556 -0.74059004]
# 26 [-0.07998732 -0.30287902]
# 27 [ 0.84292837 -0.6542581 ]
# 29 [ 0.65490471 -0.62380254]
# 30 [-0.88044896 -0.39168375]
# 39 [ 0.36480703 -0.94937073]
# 40 [0.91019353 0.31361705]
# 41 [-0.66046292  0.47339888]
# 43 [-0.89156934  0.42902149]
# 46 [-0.45542037  0.36226097]
# 52 [-0.47606134  0.27297753]
# 54 [ 0.40996411 -0.98840815]
# 57 [0.11485724 0.51905465]
# 59 [-0.79526993 -0.61047918]
# 67 [-0.6328138  -0.63980914]
# 75 [-0.62234471  0.62863552]
# 80 [-0.93148916 -0.45787127]
# 84 [-0.72065289 -0.81364575]
# 85 [-0.76733555  0.62413233]
# 86 [0.15602636 0.9951344 ]
# 93 [-0.62977434 -0.81792529]
# 95 [-0.07564324  0.52703827]
# 103 [ 0.18455934 -0.4983355 ]
# 107 [ 0.57719661 -0.97791636]
# 111 [ 0.57015267 -0.56080408]
# 121 [-0.8827968  -0.97313315]
# 126 [0.87936389 0.3857142 ]
# 130 [-0.49975754  0.10416462]
# 133 [0.30255    0.52207543]
# 141 [-0.69699757 -0.03915276]
# 143 [-0.98953083  0.69785649]
# 145 [-0.16350654 -0.87996154]
# 153 [-0.30882243 -0.01740684]
# 160 [-0.25743066 -0.58939702]
# 162 [-0.62832525 -0.8955495 ]
# 166 [ 0.32083543 -0.50943599]
# 171 [0.80407713 0.04368744]
# 172 [ 0.89194445 -0.43490907]
# 174 [-0.18866855 -0.47849223]
# 190 [-0.39219807  0.23895159]
# 195 [0.62757693 0.41453513]
# 196 [-0.04962077  0.11335573]
# 197 [-0.44423821 -0.61305118]
# 199 [-0.04448931 -0.6378415 ]
# 200 [0.40015312 0.23718308]
# 204 [-0.91989725 -0.97882049]
# 207 [-0.4482638 -0.7862269]
# 209 [0.60419871 0.69644421]
# 210 [ 0.39443691 -0.62094669]
# 227 [-0.86880907  0.72458842]
# 241 [-0.12004161 -0.36237285]
# 246 [0.46139716 0.33552792]
# 252 [ 0.52765081 -0.74195137]
# 256 [-0.5132122   0.36094172]
# 257 [-0.51414741 -0.81003356]
# 259 [ 0.17532942 -0.05690948]
# 261 [-0.90681228  0.34540656]
# 263 [ 0.21204169 -0.37571772]
# 271 [ 0.71789766 -0.8705516 ]
# 272 [-0.83857209 -0.28660521]
# 276 [ 0.40971256 -0.77314457]
# 288 [0.9104374  0.97591482]
# 293 [-0.7526382   0.06157119]
# 300 [0.5383559  0.89529932]
# 303 [ 0.45883331 -0.64240075]
# 310 [-0.49617284  0.47575173]
# 318 [0.20118179 0.29953935]
# 325 [-0.93557467  0.91593628]
# 334 [0.35339515 0.43662957]
# 339 [0.80039494 0.17052346]
# 341 [ 0.26128137 -0.0537346 ]
# 342 [-0.74097418  0.16352378]
# 344 [-0.44104965  0.13746383]
# 346 [-0.74750228  0.47991646]
# 347 [ 0.13345997 -0.75036433]
# 349 [0.24475984 0.09183853]
# 352 [-0.99831864 -0.8226209 ]
# 362 [ 0.6215517  -0.05384664]
# 364 [-0.24720861 -0.11012701]
# 365 [0.48147585 0.35940487]
# 373 [0.24182768 0.92225484]
# 374 [0.83482525 0.91101934]
# 376 [-0.54465036 -0.73641844]
# 387 [-0.23488282  0.63982668]
# 389 [-0.22562793 -0.384557  ]
# 403 [0.03126297 0.45776916]
# 411 [ 0.2360156  -0.18832954]
# 412 [-0.87336216  0.086948  ]
# 413 [0.32693318 0.12472962]
# 416 [-0.08950977  0.50233189]
# 417 [0.27058271 0.8160937 ]
# 424 [-0.89633653 -0.36437445]
# 434 [-0.46045334  0.41567849]
# 441 [ 0.74019204 -0.94769543]
# 443 [-0.09391708  0.1959964 ]
# 444 [ 0.69593822 -0.83376566]
# 460 [-0.34256938  0.15473461]
# 464 [ 0.01350157 -0.34850134]
# 472 [0.41362697 0.70302416]
# 474 [0.30028201 0.3229091 ]
# 476 [-0.65449924 -0.1718889 ]
# 480 [ 0.30804943 -0.75233825]
# 482 [ 0.90627282 -0.35774175]
# 484 [0.68364217 0.47836549]
# 489 [-0.10420048 -0.07225268]
# 493 [-0.5010613   0.97897221]
# 495 [-0.72440597 -0.67966498]
# 496 [-0.75193643 -0.38616167]
# 21 [-0.63405077  0.69046567]
# 88 [-0.93938606 -0.64663353]
# 124 [ 0.69863776 -0.72708486]
# 157 [-0.1426089  -0.88313171]
# 167 [ 0.72751813 -0.31894646]
# 282 [-0.8576996   0.68627657]
# 292 [-0.96064818  0.13783405]
# 382 [ 0.91821654 -0.18027472]
# 408 [-0.70826842 -0.07192952]
# 499 [0.86281556 0.25255231]
# 120 [ 0.01475073 -0.12326626]
# 419 [-0.1222871  -0.34869063]
# 48 [ 0.09571633 -0.31122685]
# 224 [-0.76768393  0.12253214]
# 99 [-0.74288303 -0.59130335]
# 299 [0.85942104 0.90892367]
# 181 [-0.65985556  0.04798689]
# 327 [0.03396705 0.99191987]
# 340 [-0.54978461  0.01856819]
# 343 [ 0.01798525 -0.32478819]
# 355 [-0.47852192 -0.01685965]
# 368 [-0.11747865  0.51320784]
# 425 [-0.6415122  -0.30664872]
# 478 [-0.09888901  0.34615366]
# 486 [ 0.64162788 -0.78834634]
# 182 [0.77881109 0.83664187]
# 191 [ 0.46967956 -0.75519651]
# 202 [0.25118013 0.059824  ]
# 238 [-0.62208333  0.10316599]
# 240 [ 0.01917748 -0.2198472 ]
# 269 [0.850306   0.61466255]
# 320 [ 0.80074093 -0.68169096]
# 324 [-0.32625655  0.30087669]
# 68 [ 0.6490555  -0.98569145]
# 69 [ 0.00217842 -0.35261825]
# 71 [ 0.90326994 -0.99669779]
# 114 [ 0.69186026 -0.69528109]
# 159 [0.82209015 0.27772267]
# 20 [-0.35203385  0.15132175]
# 23 [0.99496252 0.13284848]
# 33 [-0.44027772 -0.01459212]
# 35 [ 0.90873231 -0.02287734]
# 36 [-0.5928261   0.08752359]
# 51 [-0.39910281  0.04718801]
# 65 [0.28692735 0.32245313]
# 70 [-0.9494331   0.60170357]
# 72 [0.49715419 0.96491567]
# 100 [ 0.03599982 -0.61419197]
# 112 [ 0.13472727 -0.34935591]
# 119 [-0.25947597  0.03425513]
# 122 [-0.48949734  0.39230796]
# 128 [ 0.6171698  -0.60444777]
# 152 [-0.80141439  0.1477532 ]
# 184 [ 0.5381952  -0.57176987]
# 208 [-0.30428051 -0.17672532]
# 250 [-0.16041094 -0.78925934]
# 264 [-0.53599862  0.57401473]
# 285 [-0.02027391  0.82323936]
# 287 [-0.04154003 -0.93214109]
# 314 [ 0.17600845 -0.59695446]
# 316 [ 0.9116095  -0.96305998]
# 329 [-0.37980649 -0.76750265]
# 335 [-0.58558068  0.0379859 ]
# 363 [ 0.70110614 -0.41885623]
# 367 [0.27203236 0.28214498]
# 383 [-0.50360533 -0.66729873]
# 393 [-0.58295886 -0.25826415]
# 401 [ 0.02040823 -0.66424033]
# 426 [-0.47482817 -0.146865  ]
# 439 [-0.34279278 -0.17419738]
# 452 [-0.33167104  0.90214367]
# 283 [ 0.76798362 -0.04621783]
# 345 [-0.15737189  0.87976968]
# 31 [-0.85782669 -0.18320145]
# 55 [-0.83441216 -0.53234156]
# 62 [0.85275675 0.30575701]
# 76 [0.62635303 0.52740572]
# 149 [-0.97528763  0.53284943]
# 170 [-0.93699089 -0.78988666]
# 194 [-0.86673181  0.85579371]
# 216 [-0.83280193 -0.08578292]
# 304 [0.48921744 0.49266069]
# 313 [ 0.10274911 -0.36639579]
# 322 [0.50196488 0.6134061 ]
# 357 [-0.59379594 -0.68624523]
# 410 [0.85304199 0.79414504]
# 455 [ 0.17915206 -0.54021048]
# 488 [ 0.209463   -0.59822143]
# 14 [0.7058902  0.29896913]
# 15 [-0.74250795  0.55907002]
# 16 [-0.32523194 -0.78564648]
# 19 [-0.94800126  0.89222164]
# 25 [0.55107464 0.38131057]
# 32 [ 0.02903326 -0.9961594 ]
# 56 [-0.90592172  0.65469617]
# 81 [-0.9444171  -0.21161981]
# 109 [ 0.17296065 -0.60446901]
# 117 [-0.0166661   0.77689206]
# 118 [ 0.36177407 -0.70981371]
# 129 [-0.74997397 -0.25629721]
# 139 [-0.69185964  0.8145521 ]
# 164 [-0.50774483  0.61988037]
# 175 [ 0.54718938 -0.4204438 ]
# 192 [-0.74362797 -0.31542526]
# 203 [0.40301027 0.86292451]
# 215 [-0.22407667  0.29712208]
# 225 [ 0.54287196 -0.94970485]
# 231 [0.29953007 0.19436228]
# 234 [ 0.74437984 -0.53941021]
# 245 [0.06012205 0.92935669]
# 249 [-0.71128421 -0.6669126 ]
# 254 [-0.42932064  0.26645129]
# 278 [ 0.15196513 -0.4178819 ]
# 286 [-0.95742738 -0.99296473]
# 295 [0.50692187 0.32378548]
# 358 [-0.89334838  0.90800167]
# 361 [ 0.55566793 -0.67718675]
# 379 [-0.48023432  0.48103604]
# 395 [0.54167561 0.26342799]
# 396 [0.5212316  0.13857857]
# 399 [0.0812483  0.97114967]
# 402 [-0.42896663  0.62347262]
# 407 [-0.14028501 -0.05674123]
# 431 [-0.11199868 -0.01606045]
# 447 [0.7627706  0.80432478]
# 449 [-0.00018667  0.29689853]
# 450 [0.16810512 0.94580461]
# 457 [-0.34359264  0.81482029]
# 463 [0.4733204  0.67617634]
# 479 [-0.19482298 -0.19823662]
# 243 [0.26896609 0.92074252]
# 418 [0.14582549 0.03409453]
# 137 [0.20962214 0.77537725]
# 223 [0.46937391 0.36118289]
# 242 [-0.31294442 -0.60087874]
# 253 [-0.85590215  0.11890557]
# 284 [ 0.66386965 -0.27779024]
# 442 [-0.63154853  0.66551266]
# 456 [0.83164626 0.5077    ]
# 102 [-0.15326881  0.7955524 ]
# 228 [ 0.78229263 -0.00997126]
# 18 [-0.32216237 -0.31065548]
# 270 [0.27657153 0.87849486]
# 64 [ 0.95111874 -0.47015704]
# 106 [0.86087124 0.28234221]
# 147 [-0.67315338  0.58375442]
# 186 [-0.99948665  0.72816418]
# 233 [-0.45274826 -0.45558453]
# 309 [-0.93858136  0.97808614]
# 328 [-0.07833004  0.37487792]
# 370 [-0.77886609  0.68501849]
# 420 [-0.26450293  0.3191883 ]
# 421 [ 0.60440228 -0.71327677]
# 466 [ 0.14792705 -0.91882852]
# 132 [0.46178064 0.24909706]
# 161 [ 0.15203349 -0.94231896]
# 333 [ 0.94930674 -0.03951826]
# 163 [ 0.30460651 -0.53978747]
# 217 [-0.71258055  0.10257906]
# 229 [-0.19522363  0.89914401]
# 289 [ 0.77469767 -0.89884128]
# 290 [ 0.55609383 -0.53115557]
# 336 [ 0.46069718 -0.796499  ]
# 63 [-0.55574544  0.30357124]
# 96 [ 0.15238792 -0.81662027]
# 110 [-0.51836785 -0.97967211]
# 142 [0.27418023 0.66573266]
# 266 [ 0.51166981 -0.1081196 ]
# 275 [-0.75377782  0.66093673]
# 366 [-0.92772647  0.73823975]
# 438 [ 0.47511483 -0.63665389]
# 492 [-0.876986    0.17173223]
# 498 [-0.32337155 -0.43992046]
# 34 [0.58528008 0.63399841]
# 154 [-0.7414     -0.79750773]
# 302 [-0.34452282  0.22505262]
# 384 [0.42286204 0.21223644]
# 73 [-0.41303246 -0.05703215]
# 104 [ 0.49914362 -0.36321719]
# 146 [-0.64000243 -0.50659473]
# 213 [-0.7584448   0.07795369]
# 221 [-0.95821395 -0.91203496]
# 258 [0.66489717 0.18225131]
# 274 [0.82625624 0.43912019]
# 330 [0.72227382 0.51679221]
# 409 [-0.99247336 -0.4353265 ]
# 427 [-0.06332729  0.94511182]
# 471 [-0.10921947  0.24451952]
# 140 [-0.30585522 -0.85930619]
# 150 [ 0.55782837 -0.88683493]
# 176 [-0.22857295 -0.6595108 ]
# 188 [-0.44923896  0.361789  ]
# 219 [-0.06923623  0.22523731]
# 321 [0.69663314 0.70374732]
# 338 [-0.59123835 -0.95720459]
# 375 [ 0.64334253 -0.39753466]
# 388 [ 0.23017364 -0.86169981]
# 422 [0.29355654 0.85546974]
# 470 [-0.31649333  0.72035175]
# 473 [-0.10180385 -0.06433637]
# 483 [0.84366169 0.20167625]
# 44 [-0.0321596  0.5342859]
# 49 [0.03944106 0.97052767]
# 125 [0.29600541 0.51982762]
# 467 [ 0.38301193 -0.79662036]
# 28 [0.41177674 0.83526721]
# 37 [0.315614   0.53100377]
# 77 [ 0.02189556 -0.57260027]
# 185 [-0.44617754  0.93898218]
# 211 [ 0.77075554 -0.95028063]
# 232 [ 0.81657424 -0.1675932 ]
# 248 [0.07499333 0.25387931]
# 262 [0.2700928  0.93571489]
# 296 [0.54956713 0.98090612]
# 298 [-0.10711183  0.52252604]
# 306 [0.24978831 0.7944012 ]
# 390 [ 0.75169415 -0.22368081]
# 405 [-0.21302731  0.24315281]
# 461 [-0.14827547 -0.79432215]
# 475 [ 0.08296514 -0.48048172]
# 66 [ 0.96321664 -0.46869288]
# 177 [-0.34911589 -0.18032752]
# 180 [0.09455942 0.77002338]
# 148 [0.39106802 0.65258777]
# 323 [0.36466105 0.79816886]
# 348 [-0.37338967  0.33806502]
# 353 [0.95432646 0.99234914]
# 381 [0.68085656 0.64983356]
# 458 [-0.58985628  0.00462501]
# 22 [ 0.05917158 -0.07041475]
# 74 [ 0.4649308  -0.25333935]
# 87 [-0.70559085  0.0588386 ]
# 237 [ 0.27593241 -0.59840446]
# 311 [-0.91841068  0.483813  ]
# 312 [-0.89898607  0.96197292]
# 351 [0.97500339 0.49351403]
# 380 [ 0.9333782  -0.73975447]
# 428 [0.08511744 0.77614501]
# 481 [-0.37561719  0.24945092]
# None

# %%
# graph 
p = fviz_corrplot(
    X=ind.contrib,
    legend_title="Contrib",
    title="Contributions of individuals"
)
print(p.show())
# Out:
# None

# %%
# contributions of individuals to axis 1
from scientisttools import fviz_contrib
p = fviz_contrib(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals additionals informations

# %%
# individuals additionals informations
ind.infos
# Out:
#      Weight  Sq. Dist.   Inertia  Inertia (%)
# 0     0.002   0.905414  0.001811     0.178724
# 1     0.002   1.763643  0.003527     0.348133
# 2     0.002   1.020878  0.002042     0.201516
# 3     0.002   1.020878  0.002042     0.201516
# 4     0.002   0.794002  0.001588     0.156731
# ..      ...        ...       ...          ...
# 495   0.002   0.374677  0.000749     0.073959
# 496   0.002   0.374677  0.000749     0.073959
# 497   0.002   1.433570  0.002867     0.282979
# 498   0.002   1.256965  0.002514     0.248118
# 499   0.002   1.896533  0.003793     0.374365
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Levels informations

# %%
# levels informations
levels = clf.levels_
levels._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos', 'coord_n', 'vtest')

# %% [markdown]
# ### Levels coordinates - Quasi barycenters

# %%
# levels coordinates - quasi barycenters
levels.coord
# Out:
#                    Dim1      Dim2      Dim3      Dim4      Dim5
# FrenchPop_No  -0.136197  0.038636  1.188756 -0.347519  0.115410
# FrenchPop_Yes  0.083869 -0.032464 -0.766875  0.224642 -0.066501
# Rap_No         0.117808 -0.314256 -0.065482 -0.261996 -0.036594
# Rap_Yes       -0.642112  1.698016  0.355883  1.423280  0.182771
# Rock_No       -0.247889 -0.411519  0.133232  0.323051 -0.160989
# Rock_Yes       0.651519  1.110882 -0.340222 -0.858693  0.426610
# Jazz_No       -0.387389 -0.085214 -0.102834 -0.057282  0.272805
# Jazz_Yes       1.609523  0.361099  0.355162  0.229163 -1.159085
# Classical_No  -0.462864  0.177721 -0.077240 -0.230536 -0.324821
# Classical_Yes  1.165961 -0.438364  0.186059  0.552555  0.784429

# %%
# graph of variable categories
p = fviz_mca(
    obj=clf,
    choice="levels",
    repel = True,
    quali_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels of coordinates - barycenters

# %%
# levels coordinates - quasi barycenters
levels.coord_n
# Out:
#                    Dim1      Dim2      Dim3      Dim4      Dim5
# FrenchPop_No  -0.071878  0.018039  0.535808 -0.143897  0.041444
# FrenchPop_Yes  0.044262 -0.015158 -0.345653  0.093017 -0.023881
# Rap_No         0.062173 -0.146727 -0.029515 -0.108484 -0.013141
# Rap_Yes       -0.338875  0.792805  0.160407  0.589335  0.065633
# Rock_No       -0.130824 -0.192139  0.060051  0.133765 -0.057811
# Rock_Yes       0.343840  0.518672 -0.153348 -0.355558  0.153196
# Jazz_No       -0.204445 -0.039786 -0.046351 -0.023719  0.097965
# Jazz_Yes       0.849426  0.168597  0.160082  0.094889 -0.416228
# Classical_No  -0.244277  0.082978 -0.034814 -0.095458 -0.116643
# Classical_Yes  0.615336 -0.204673  0.083862  0.228795  0.281689

# %% [markdown]
# ### Levels vtest

# %%
# levels vtest
levels.vtest
# Out:
#                     Dim1       Dim2       Dim3       Dim4       Dim5
# FrenchPop_No   -2.422462   0.687195  21.143797  -6.181149   2.052737
# FrenchPop_Yes   2.304133  -0.891896 -21.068399   6.171591  -1.826991
# Rap_No          5.898651 -15.734875  -3.278682 -13.118170  -1.832281
# Rap_Yes        -6.119787  16.183305   3.391823  13.564875   1.741940
# Rock_No        -8.879634 -14.741021   4.772486  11.572021  -5.766784
# Rock_Yes        8.851112  15.091712  -4.622041 -11.665645   5.795640
# Jazz_No       -16.784243  -3.692020  -4.455460  -2.481844  11.819719
# Jazz_Yes       17.413324   3.906706   3.842476   2.479295 -12.540063
# Classical_No  -15.869525   6.093256  -2.648196  -7.904036 -11.136646
# Classical_Yes  16.403511  -6.167198   2.617606   7.773709  11.035875

# %% [markdown]
# ### Levels cos2

# %%
# levels cos2
levels.cos2
# Out:
#                    Dim1      Dim2      Dim3      Dim4      Dim5
# FrenchPop_No   0.011760  0.000946  0.895912  0.076566  0.008444
# FrenchPop_Yes  0.010639  0.001594  0.889534  0.076330  0.006689
# Rap_No         0.069728  0.496165  0.021543  0.344863  0.006728
# Rap_Yes        0.075054  0.524848  0.023055  0.368749  0.006081
# Rock_No        0.158012  0.435466  0.045645  0.268360  0.066645
# Rock_Yes       0.156998  0.456432  0.042812  0.272720  0.067314
# Jazz_No        0.564551  0.027317  0.039782  0.012344  0.279971
# Jazz_Yes       0.607663  0.030586  0.029588  0.012318  0.315137
# Classical_No   0.504693  0.074404  0.014054  0.125198  0.248547
# Classical_Yes  0.539229  0.076221  0.013731  0.121103  0.244069

# %%
# graph of variable categories - color by cos2
p = fviz_mca(
    obj=clf,
    choice="levels",
    col_var = "cos2",
    repel = True,
    quali_sup = False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus for variable categories
p = fviz_corrplot(
    X=levels.cos2,
    legend_title="Co2",
    title="Cosinus of variable categories"
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus - levels
p = fviz_cos2(
    obj=clf,
    choice="levels"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels contributions

# %%
# levels contributions
levels.contrib
# Out:
#                     Dim1       Dim2       Dim3       Dim4       Dim5
# FrenchPop_No    0.516818   0.053136  53.977671   5.466075   0.801522
# FrenchPop_Yes   0.304068   0.058209  34.853219   3.543750   0.412908
# Rap_No          0.831162   7.556392   0.352049   6.677906   0.173217
# Rap_Yes         4.559478  40.736581   1.920143  36.390471   0.797873
# Rock_No         3.177022  11.186467   1.258184   8.765206   2.894161
# Rock_Yes        8.229826  30.568889   3.076714  23.223416   7.621192
# Jazz_No         8.513241   0.526292   0.822434   0.302381   9.118656
# Jazz_Yes       35.344389   2.272931   2.359414   1.163931  39.589655
# Classical_No   10.799813   2.034206   0.412300   4.352110  11.487415
# Classical_Yes  27.724183   5.006896   0.967873  10.114755  27.103402

# %%
# graph of variable categories - color by contributions
p = fviz_mca(
    obj=clf,
    choice="levels",
    col_var = "contrib",
    repel = True,
    quali_sup = False
)
print(p.show())
# Out:
# None

# %%
# graph of contributions for variable categories
p = fviz_corrplot(
    X=levels.contrib,
    legend_title="Contrib",
    title="Contributions of variable categories"
)
print(p.show())
# Out:
# None

# %%
# contributions of variable categories to axis 1
p = fviz_contrib(
    obj=clf,
    choice="levels"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels additionals informations

# %%
# levels additionals informations
levels.infos
# Out:
#                Proportion  Weight  Sq. Dist.  Inertia  Inertia (%)
# FrenchPop_No        0.388  0.0776   1.577320   0.1224    12.080537
# FrenchPop_Yes       0.602  0.1204   0.661130   0.0796     7.856297
# Rap_No              0.834  0.1668   0.199041   0.0332     3.276747
# Rap_Yes             0.154  0.0308   5.493506   0.1692    16.699566
# Rock_No             0.720  0.1440   0.388889   0.0560     5.527043
# Rock_Yes            0.270  0.0540   2.703704   0.1460    14.409791
# Jazz_No             0.790  0.1580   0.265823   0.0420     4.145282
# Jazz_Yes            0.190  0.0380   4.263158   0.1620    15.988946
# Classical_No        0.702  0.1404   0.424501   0.0596     5.882353
# Classical_Yes       0.284  0.0568   2.521127   0.1432    14.133439

# %% [markdown]
# ## Qualitative variables informations

# %%
# qualitative variables informations
quali_var = clf.quali_var_
quali_var._fields
# Out:
# ('coord', 'contrib', 'infos')

# %% [markdown]
# ### Qualitative variables coordinates

# %%
# qualitative variables coordinates
quali_var.coord
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# FrenchPop  0.011432  0.001214  0.902333  0.077238  0.007830
# Rap        0.075070  0.526385  0.023081  0.369209  0.006261
# Rock       0.158852  0.455126  0.044033  0.274226  0.067799
# Jazz       0.610763  0.030511  0.032321  0.012570  0.314055
# Classical  0.536486  0.076747  0.014020  0.124019  0.248821

# %%
# graph of variables
p = fviz_mca(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = False,
    quanti_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Qualitative variables contributions

# %%
# qualitative variables contributions
quali_var.contrib
# Out:
#                 Dim1       Dim2       Dim3       Dim4       Dim5
# FrenchPop   0.820886   0.111345  88.830890   9.009825   1.214430
# Rap         5.390640  48.292973   2.272192  43.068377   0.971090
# Rock       11.406848  41.755357   4.334898  31.988622  10.515353
# Jazz       43.857630   2.799224   3.181848   1.466312  48.708311
# Classical  38.523996   7.041102   1.380173  14.466864  38.590817

# %% [markdown]
# ### Qualitative variables additionals informations

# %%
# qualitative variables additionals informations
quali_var.infos
# Out:
#            Weight  Inertia  Inertia (%)
# FrenchPop     0.2   0.2020    19.936834
# Rap           0.2   0.2024    19.976313
# Rock          0.2   0.2020    19.936834
# Jazz          0.2   0.2040    20.134228
# Classical     0.2   0.2028    20.015792

# %% [markdown]
# ## Supplementary quantitative variables informations

# %%
# supplementary quantitative variables informations
quanti_var_sup = clf.quanti_var_sup_
quanti_var_sup._fields
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[45], line 2
#       1 # supplementary quantitative variables informations
# ----> 2 quanti_var_sup = clf.quanti_var_sup_
#       3 quanti_var_sup._fields
#
# AttributeError: 'MCA' object has no attribute 'quanti_var_sup_'

# %% [markdown]
# ### Supplementary quantitative variables coordinates

# %%
# supplementary quantitatives variables coordinates
quanti_var_sup.coord

# %%
# correlation circle
from scientisttools import fviz_corcircle
p = fviz_corcircle(clf)
print(p.show())

# %% [markdown]
# ### Supplementary quantitative variables cos2

# %%
# supplementary quantitative variables cos2
quanti_var_sup.cos2

# %%
# graph of variables with supplementary quantitative variables
p = fviz_mca(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = False,
    quanti_sup = True
)
print(p.show())

# %% [markdown]
# ## Supplementary levels informations

# %%
# supplementary levels informations
levels_sup = clf.levels_sup_
levels_sup._fields

# %% [markdown]
# ### Supplementary levels coordinates - Quasi barycenters

# %%
# supplementary levels coordinates - quasi barycenters
levels_sup.coord

# %%
# graph of variable categories with supplementary levels
p = fviz_mca(
    obj=clf,
    choice="levels",
    repel = True,
    quali_sup = True
)
print(p.show())

# %% [markdown]
# ### Supplementary levels coordiates - Barycenters

# %%
# supplementary levels coordinates - barycenters
levels_sup.coord_n

# %% [markdown]
# ### Supplementary vtest

# %%
# supplementary levels vtest
levels_sup.vtest

# %% [markdown]
# ### Supplementary levels cos2

# %%
# supplementary levels cos2
levels_sup.cos2

# %% [markdown]
# ### Supplementary levels dist2

# %%
# supplementary levels dist2
levels_sup.dist2.to_frame()

# %% [markdown]
# ## Supplementary qualitative variables informations

# %%
# supplementary qualitative variables informations
quali_var_sup = clf.quali_var_sup_
quali_var_sup._fields

# %% [markdown]
# ### Supplementary qualitative variables coordinates

# %%
# supplementary qualitative variables coordinates
quali_var_sup.coord

# %%
# graph of variables with supplementary qualitative variables
p = fviz_mca(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = True,
    quanti_sup = False
)
print(p.show())

# %% [markdown]
# ## Others functions
#
# ### Ellipses - `fviz_ellipses`

# %%
# ellipses
from scientisttools import fviz_ellipses
p = fviz_ellipses(
    obj=clf,
    habillage=["Nausea","Diarrhae"],
    repel=True,
    add_ellipses=True
)
print(p.show())

# %% [markdown]
# ### Summary

# %%
# summary
from scientisttools import summary
summary(clf)

# %%
# formatting text to markdown
summary(clf,to_markdown=True)
