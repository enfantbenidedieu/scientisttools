# %% [markdown]
# # MCA - canines dataset

# %%
# disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %% [markdown]
# ## canines dataset

# %%
# canines dataset
from scientisttools.datasets import canines
canines._fields
# Out:
# ('actif', 'ind_sup', 'sup_var', 'data')

# %%
# overall dataset
data = canines.data
data.info()
# Out:
# <class 'pandas.DataFrame'>
# Index: 33 entries, Beauceron to Wisky
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Taille        33 non-null     str
#  1   Poids         33 non-null     str
#  2   Velocite      33 non-null     str
#  3   Intelligence  33 non-null     str
#  4   Affection     33 non-null     str
#  5   Agressivite   33 non-null     str
#  6   Fonction      27 non-null     str
#  7   Cote          27 non-null     float64
# dtypes: float64(1), str(7)
# memory usage: 2.3+ KB

# %% [markdown]
# ## Instanciation and training

# %%
# instanciation & training
from scientisttools import MCA
clf = MCA(ind_sup=range(27,33),sup_var=(6,7))

# %% [markdown]
# ### `fit` function

# %%
#fit function
clf.fit(data)
# Out:
# MCA(ind_sup=range(27, 33), sup_var=(6, 7))

# %% [markdown]
# ### `fit_transform` function

# %%
#fit_transform - individuals coordinates
ind_coord = clf.fit_transform(data)
ind_coord
# Out:
#                     Dim1      Dim2      Dim3      Dim4      Dim5
# Beauceron      -0.317200 -0.417701 -0.101468 -0.211436 -0.118510
# Basset          0.254110  1.101227 -0.190701  0.292637 -0.524009
# Berger All     -0.486396 -0.464450 -0.498134  0.577425  0.275902
# Boxer           0.447365 -0.881778  0.692016  0.260002 -0.455590
# Bull-Dog        1.013352  0.549879 -0.163423 -0.349919  0.330786
# Bull-Mastif    -0.752574  0.546912  0.497573  0.655153  0.721946
# Caniche         0.912301 -0.016188 -0.576570  0.628133  0.434017
# Chihuahua       0.840799  0.843852 -0.469947 -0.086343 -0.177346
# Cocker          0.733295  0.079073  0.662230  0.189743 -0.104627
# Colley         -0.117325 -0.526108 -0.334894 -0.657755  0.192130
# Dalmatien       0.647240 -0.990184  0.458590 -0.186316 -0.144950
# Doberman       -0.873210 -0.315481 -0.452314  0.510087  0.239880
# Dogue All      -1.047017  0.506958  0.165035  0.062888 -0.316522
# Epag. Breton    0.478044 -1.036933  0.061924  0.602545  0.249461
# Epag. Français -0.144910 -0.515783  0.117127 -0.468922  0.000850
# Fox-Hound      -0.876568  0.025240 -0.362171 -0.015198 -0.662665
# Fox-Terrier     0.881622  0.138967  0.053522  0.285590 -0.271035
# Gd Bleu Gasc   -0.517338 -0.113404  0.044029  0.240972 -0.817923
# Labrador        0.647240 -0.990184  0.458590 -0.186316 -0.144950
# Levrier        -0.676693 -0.083167 -0.595598 -0.461516 -0.352025
# Mastiff        -0.755932  0.887633  0.587715  0.129868 -0.180598
# Pekinois        0.840799  0.843852 -0.469947 -0.086343 -0.177346
# Pointer        -0.673335 -0.423887 -0.685740  0.063769  0.550519
# St-Bernard     -0.583379  0.593660  0.894239 -0.133709  0.327535
# Setter         -0.504140 -0.377139 -0.289074 -0.725093  0.156108
# Teckel          1.013352  0.549879 -0.163423 -0.349919  0.330786
# Terre-Neuve    -0.383504  0.485254  0.660813 -0.580027  0.638174

# %% [markdown]
# ### `transform` function

# %%
# transform - individuals coordinates
ind_coord = clf.transform(canines.actif)
ind_coord
# Out:
#                     Dim1      Dim2      Dim3      Dim4      Dim5
# Beauceron      -0.317200 -0.417701 -0.101468 -0.211436 -0.118510
# Basset          0.254110  1.101227 -0.190701  0.292637 -0.524009
# Berger All     -0.486396 -0.464450 -0.498134  0.577425  0.275902
# Boxer           0.447365 -0.881778  0.692016  0.260002 -0.455590
# Bull-Dog        1.013352  0.549879 -0.163423 -0.349919  0.330786
# Bull-Mastif    -0.752574  0.546912  0.497573  0.655153  0.721946
# Caniche         0.912301 -0.016188 -0.576570  0.628133  0.434017
# Chihuahua       0.840799  0.843852 -0.469947 -0.086343 -0.177346
# Cocker          0.733295  0.079073  0.662230  0.189743 -0.104627
# Colley         -0.117325 -0.526108 -0.334894 -0.657755  0.192130
# Dalmatien       0.647240 -0.990184  0.458590 -0.186316 -0.144950
# Doberman       -0.873210 -0.315481 -0.452314  0.510087  0.239880
# Dogue All      -1.047017  0.506958  0.165035  0.062888 -0.316522
# Epag. Breton    0.478044 -1.036933  0.061924  0.602545  0.249461
# Epag. Français -0.144910 -0.515783  0.117127 -0.468922  0.000850
# Fox-Hound      -0.876568  0.025240 -0.362171 -0.015198 -0.662665
# Fox-Terrier     0.881622  0.138967  0.053522  0.285590 -0.271035
# Gd Bleu Gasc   -0.517338 -0.113404  0.044029  0.240972 -0.817923
# Labrador        0.647240 -0.990184  0.458590 -0.186316 -0.144950
# Levrier        -0.676693 -0.083167 -0.595598 -0.461516 -0.352025
# Mastiff        -0.755932  0.887633  0.587715  0.129868 -0.180598
# Pekinois        0.840799  0.843852 -0.469947 -0.086343 -0.177346
# Pointer        -0.673335 -0.423887 -0.685740  0.063769  0.550519
# St-Bernard     -0.583379  0.593660  0.894239 -0.133709  0.327535
# Setter         -0.504140 -0.377139 -0.289074 -0.725093  0.156108
# Teckel          1.013352  0.549879 -0.163423 -0.349919  0.330786
# Terre-Neuve    -0.383504  0.485254  0.660813 -0.580027  0.638174

# %%
# attributes
from scientisttools import sprintf
sprintf(clf)

# %% [markdown]
# ## Eigen values

# %%
#eigenvalues
from scientisttools import get_eig
eig = get_eig(clf)
eig
# Out:
#        Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1     0.481606    0.096869       28.896370       28.896370
# Dim2     0.384737    0.173783       23.084237       51.980607
# Dim3     0.210954    0.053400       12.657243       64.637850
# Dim4     0.157554    0.007421        9.453242       74.091092
# Dim5     0.150133    0.026837        9.007960       83.099052
# Dim6     0.123295    0.041833        7.397718       90.496770
# Dim7     0.081462    0.035793        4.887748       95.384518
# Dim8     0.045670    0.022128        2.740185       98.124703
# Dim9     0.023542    0.015829        1.412515       99.537218
# Dim10    0.007713         NaN        0.462782      100.000000

# %%
# scree plot - eigenvalue
from scientisttools import fviz_screeplot
p = fviz_screeplot(obj=clf,choice="eigenvalue")
print(p.show())
# Out:
# None

# %%
# scree plot - proportion
p = fviz_screeplot(obj=clf,choice="proportion")
print(p.show())
# Out:
# None

# %%
# scree plot - cumulative
p = fviz_screeplot(obj=clf,choice="cumulative")
print(p.show())
# Out:
# None

# %% [markdown]
# ## Individuals informations

# %%
# individuals informations
from scientisttools import get_mca
ind = get_mca(clf,"ind")
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
# individuals coordinates
ind.coord
# Out:
#                     Dim1      Dim2      Dim3      Dim4      Dim5
# Beauceron      -0.317200 -0.417701 -0.101468 -0.211436 -0.118510
# Basset          0.254110  1.101227 -0.190701  0.292637 -0.524009
# Berger All     -0.486396 -0.464450 -0.498134  0.577425  0.275902
# Boxer           0.447365 -0.881778  0.692016  0.260002 -0.455590
# Bull-Dog        1.013352  0.549879 -0.163423 -0.349919  0.330786
# Bull-Mastif    -0.752574  0.546912  0.497573  0.655153  0.721946
# Caniche         0.912301 -0.016188 -0.576570  0.628133  0.434017
# Chihuahua       0.840799  0.843852 -0.469947 -0.086343 -0.177346
# Cocker          0.733295  0.079073  0.662230  0.189743 -0.104627
# Colley         -0.117325 -0.526108 -0.334894 -0.657755  0.192130
# Dalmatien       0.647240 -0.990184  0.458590 -0.186316 -0.144950
# Doberman       -0.873210 -0.315481 -0.452314  0.510087  0.239880
# Dogue All      -1.047017  0.506958  0.165035  0.062888 -0.316522
# Epag. Breton    0.478044 -1.036933  0.061924  0.602545  0.249461
# Epag. Français -0.144910 -0.515783  0.117127 -0.468922  0.000850
# Fox-Hound      -0.876568  0.025240 -0.362171 -0.015198 -0.662665
# Fox-Terrier     0.881622  0.138967  0.053522  0.285590 -0.271035
# Gd Bleu Gasc   -0.517338 -0.113404  0.044029  0.240972 -0.817923
# Labrador        0.647240 -0.990184  0.458590 -0.186316 -0.144950
# Levrier        -0.676693 -0.083167 -0.595598 -0.461516 -0.352025
# Mastiff        -0.755932  0.887633  0.587715  0.129868 -0.180598
# Pekinois        0.840799  0.843852 -0.469947 -0.086343 -0.177346
# Pointer        -0.673335 -0.423887 -0.685740  0.063769  0.550519
# St-Bernard     -0.583379  0.593660  0.894239 -0.133709  0.327535
# Setter         -0.504140 -0.377139 -0.289074 -0.725093  0.156108
# Teckel          1.013352  0.549879 -0.163423 -0.349919  0.330786
# Terre-Neuve    -0.383504  0.485254  0.660813 -0.580027  0.638174

# %%
# graph of individuals
from scientisttools import fviz_mca
p = fviz_mca(
    obj=clf,
    choice="ind",
    repel = True,
    ind_sup = False
)
print(p.show())
# Out:
# 10 [-0.62559099 -0.60359681]
# 18 [-0.77045186  0.79266862]
# 7 [ 0.33231687 -0.50092233]
# 21 [-0.59531972 -0.36952944]
# None

# %% [markdown]
# ### Individuals cos2

# %%
# individuals cos2
ind.cos2
# Out:
#                     Dim1      Dim2      Dim3      Dim4          Dim5
# Beauceron       0.088635  0.153700  0.009070  0.039382  1.237222e-02
# Basset          0.033804  0.634867  0.019039  0.044832  1.437493e-01
# Berger All      0.153722  0.140164  0.161232  0.216646  4.946160e-02
# Boxer           0.111331  0.432524  0.266393  0.037605  1.154621e-01
# Bull-Dog        0.624485  0.183881  0.016242  0.074462  6.654209e-02
# Bull-Mastif     0.270691  0.142958  0.118328  0.205144  2.491061e-01
# Caniche         0.385194  0.000121  0.153853  0.182602  8.717967e-02
# Chihuahua       0.379931  0.382695  0.118691  0.004007  1.690306e-02
# Cocker          0.279157  0.003246  0.227672  0.018691  5.683030e-03
# Colley          0.012396  0.249261  0.100999  0.389612  3.324270e-02
# Dalmatien       0.236285  0.553017  0.118619  0.019580  1.185067e-02
# Doberman        0.487612  0.063648  0.130833  0.166389  3.679795e-02
# Dogue All       0.560794  0.131474  0.013933  0.002023  5.125103e-02
# Epag. Breton    0.104983  0.493953  0.001762  0.166787  2.858850e-02
# Epag. Français  0.017533  0.222126  0.011454  0.183597  6.028475e-07
# Fox-Hound       0.558313  0.000463  0.095309  0.000168  3.190765e-01
# Fox-Terrier     0.436271  0.010840  0.001608  0.045780  4.123268e-02
# Gd Bleu Gasc    0.186023  0.008939  0.001347  0.040360  4.649900e-01
# Labrador        0.236285  0.553017  0.118619  0.019580  1.185067e-02
# Levrier         0.338816  0.005118  0.262474  0.157599  9.169119e-02
# Mastiff         0.299995  0.413633  0.181336  0.008854  1.712283e-02
# Pekinois        0.379931  0.382695  0.118691  0.004007  1.690306e-02
# Pointer         0.294592  0.116751  0.305546  0.002642  1.969263e-01
# St-Bernard      0.201563  0.208730  0.473605  0.010588  6.353655e-02
# Setter          0.223894  0.125298  0.073614  0.463157  2.146795e-02
# Teckel          0.624485  0.183881  0.016242  0.074462  6.654209e-02
# Terre-Neuve     0.088401  0.141532  0.262466  0.202214  2.447904e-01

# %%
# graph of individuals - color by cosinus
p = fviz_mca(
    obj=clf,
    choice="ind",
    col_ind="cos2",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# 10 [-0.23526171  0.39067042]
# 18 [0.25768237 0.82454729]
# 7 [ 0.45882566 -0.71094851]
# 21 [-0.33129299  0.14384037]
# None

# %%
# graph of cosinus
from scientisttools import fviz_corrplot
p = fviz_corrplot(
    X=ind.cos2,
    legend_title="Cos2",
    title="Cosinus of individuals"
)
print(p.show())
# Out:
# None

# %%
# cosinus of individuals to axis 1
from scientisttools import fviz_cos2
p = fviz_cos2(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals contrib

# %%
# individuals contributions
ind.contrib
# Out:
#                     Dim1       Dim2       Dim3       Dim4       Dim5
# Beauceron       0.773768   1.679591   0.180761   1.050911   0.346472
# Basset          0.496578  11.674160   0.638490   2.013103   6.773884
# Berger All      1.819380   2.076582   4.356528   7.837874   1.877893
# Boxer           1.539104   7.484976   8.407762   1.589130   5.120461
# Bull-Dog        7.897052   2.910764   0.468895   2.878342   2.699333
# Bull-Mastif     4.355552   2.879430   4.346724  10.090014  12.857925
# Caniche         6.400604   0.002523   5.836494   9.274927   4.647010
# Chihuahua       5.436620   6.854956   3.877452   0.175251   0.775901
# Cocker          4.135252   0.060191   7.699573   0.846329   0.270054
# Colley          0.105859   2.664534   1.969076  10.170316   0.910652
# Dalmatien       3.221622   9.438523   3.692301   0.816035   0.518320
# Doberman        5.863836   0.958117   3.591930   6.116394   1.419542
# Dogue All       8.430465   2.474089   0.478189   0.092970   2.471540
# Epag. Breton    1.757440  10.350778   0.067323   8.534653   1.535211
# Epag. Français  0.161488   2.560978   0.240857   5.169021   0.000018
# Fox-Hound       5.909013   0.006133   2.302910   0.005430  10.833002
# Fox-Terrier     5.977356   0.185907   0.050295   1.917313   1.812221
# Gd Bleu Gasc    2.058223   0.123802   0.034035   1.365028  16.503872
# Labrador        3.221622   9.438523   3.692301   0.816035   0.518320
# Levrier         3.521496   0.066584   6.228079   5.007036   3.057090
# Mastiff         4.394500   7.584704   6.064324   0.396468   0.804614
# Pekinois        5.436620   6.854956   3.877452   0.175251   0.775901
# Pointer         3.486640   1.729709   8.255949   0.095593   7.476639
# St-Bernard      2.617254   3.392717  14.039635   0.420269   2.646524
# Setter          1.954548   1.369226   1.467118  12.359296   0.601188
# Teckel          7.897052   2.910764   0.468895   2.878342   2.699333
# Terre-Neuve     1.131057   2.266782   7.666653   7.908668  10.047081

# %%
# graph of individuals - color by contributions
p = fviz_mca(
    obj=clf,
    choice="ind",
    col_ind="contrib",
    repel=True,
    ind_sup=False
)
print(p.show())
# Out:
# 10 [0.55102622 0.62225391]
# 18 [-0.51548525 -0.65409353]
# 7 [-0.05160407  0.55623525]
# 21 [ 0.21378486 -0.34134299]
# None

# %%
# graph 
p = fviz_corrplot(
    X=ind.contrib,
    legend_title="Contrib",
    title="Contributions of individuals"
)
print(p.show())
# Out:
# None

# %%
# contributions of individuals to axis 1
from scientisttools import fviz_contrib
p = fviz_contrib(
    obj=clf,
    choice="ind"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Individuals additional informations

# %%
# individuals addutionals informations
ind.infos
# Out:
#                   Weight  Sq. Dist.   Inertia  Inertia (%)
# Beauceron       0.037037   1.135165  0.042043     2.522589
# Basset          0.037037   1.910165  0.070747     4.244811
# Berger All      0.037037   1.539011  0.057000     3.420024
# Boxer           0.037037   1.797665  0.066580     3.994811
# Bull-Dog        0.037037   1.644368  0.060903     3.654151
# Bull-Mastif     0.037037   2.092308  0.077493     4.649573
# Caniche         0.037037   2.160714  0.080026     4.801587
# Chihuahua       0.037037   1.860714  0.068915     4.134921
# Cocker          0.037037   1.926236  0.071342     4.280525
# Colley          0.037037   1.110440  0.041127     2.467643
# Dalmatien       0.037037   1.772940  0.065664     3.939866
# Doberman        0.037037   1.563736  0.057916     3.474969
# Dogue All       0.037037   1.954808  0.072400     4.344017
# Epag. Breton    0.037037   2.176786  0.080622     4.837302
# Epag. Français  0.037037   1.197665  0.044358     2.661477
# Fox-Hound       0.037037   1.376236  0.050972     3.058303
# Fox-Terrier     0.037037   1.781593  0.065985     3.959096
# Gd Bleu Gasc    0.037037   1.438736  0.053287     3.197192
# Labrador        0.037037   1.772940  0.065664     3.939866
# Levrier         0.037037   1.351511  0.050056     3.003358
# Mastiff         0.037037   1.904808  0.070548     4.232906
# Pekinois        0.037037   1.860714  0.068915     4.134921
# Pointer         0.037037   1.539011  0.057000     3.420024
# St-Bernard      0.037037   1.688462  0.062536     3.752137
# Setter          0.037037   1.135165  0.042043     2.522589
# Teckel          0.037037   1.644368  0.060903     3.654151
# Terre-Neuve     0.037037   1.663736  0.061620     3.697192

# %% [markdown]
# ## Levels informations

# %%
# levels informations
levels = clf.levels_
levels._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos', 'coord_n', 'vtest')

# %% [markdown]
# ### Levels coordinates - Quasi barycenters

# %%
# levels coordinates
levels.coord
# Out:
#               Dim1      Dim2      Dim3      Dim4      Dim5
# Taille+   0.851088 -1.231720  1.016052  0.342456 -0.310040
# Taille++ -0.836675 -0.020578 -0.051217 -0.170222  0.112663
# Taille-   1.184956  0.923897 -0.616000  0.120149 -0.019963
# Poids+   -0.305405 -0.818876 -0.231272 -0.118364 -0.190201
# Poids++  -1.015134  0.973901  1.221595  0.067605  0.614518
# Poids-    1.168918  0.824345 -0.358770  0.164884 -0.051221
# Veloc+    0.603687 -0.887814  0.356312  0.370243 -0.371036
# Veloc++  -0.892100 -0.371832 -0.763088 -0.239848 -0.010089
# Veloc-    0.319941  1.044900  0.401729 -0.080331  0.305908
# Intell+   0.369443 -0.285503  0.493203 -0.603492  0.146256
# Intell++ -0.335066 -0.459483 -0.599924  1.275249  1.063191
# Intell-  -0.349045  0.808555 -0.351511  0.024238 -1.035060
# Affec+    0.775496 -0.266936 -0.060797  0.077216  0.040322
# Affec-   -0.835150  0.287470  0.065474 -0.083156 -0.043424
# Agress+  -0.431539  0.209196  0.333548  0.551156 -0.374464
# Agress-   0.400714 -0.194253 -0.309723 -0.511788  0.347717

# %%
# graph of variable categories
p = fviz_mca(
    obj=clf,
    choice="levels",
    repel =True,
    quali_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels coordinates - Barycenters

# %%
# levels normalized coordinates - barycenters
levels.coord_n
# Out:
#               Dim1      Dim2      Dim3      Dim4      Dim5
# Taille+   0.590637 -0.764001  0.466670  0.135931 -0.120131
# Taille++ -0.580635 -0.012764 -0.023524 -0.067566  0.043653
# Taille-   0.822334  0.573067 -0.282927  0.047691 -0.007735
# Poids+   -0.211945 -0.507926 -0.106223 -0.046982 -0.073697
# Poids++  -0.704481  0.604083  0.561075  0.026834  0.238107
# Poids-    0.811204  0.511318 -0.164782  0.065447 -0.019847
# Veloc+    0.418946 -0.550686  0.163653  0.146961 -0.143765
# Veloc++  -0.619098 -0.230637 -0.350484 -0.095203 -0.003909
# Veloc-    0.222032  0.648122  0.184513 -0.031886  0.118530
# Intell+   0.256385 -0.177090  0.226527 -0.239544  0.056670
# Intell++ -0.232528 -0.285004 -0.275543  0.506185  0.411954
# Intell-  -0.242230  0.501524 -0.161448  0.009621 -0.401054
# Affec+    0.538178 -0.165573 -0.027924  0.030649  0.015623
# Affec-   -0.579576  0.178309  0.030072 -0.033007 -0.016825
# Agress+  -0.299479  0.129758  0.153198  0.218771 -0.145093
# Agress-   0.278087 -0.120490 -0.142255 -0.203144  0.134730

# %% [markdown]
# ### Levels vtest

# %%
# levels vtest
levels.vtest
# Out:
#               Dim1      Dim2      Dim3      Dim4      Dim5
# Taille+   2.068878 -2.994141  2.469882  0.832464 -0.753665
# Taille++ -4.769783 -0.117315 -0.291984 -0.970413  0.642278
# Taille-   3.574562  2.787045 -1.858237  0.362445 -0.060222
# Poids+   -1.616053 -4.333083 -1.223777 -0.626323 -1.006452
# Poids++  -2.467651  2.367418  2.969528  0.164338  1.493809
# Poids-    3.867577  2.727493 -1.187057  0.545548 -0.169475
# Veloc+    1.997406 -2.937492  1.178924  1.225017 -1.227638
# Veloc++  -3.216512 -1.340661 -2.751351 -0.864785 -0.036375
# Veloc-    1.251214  4.086363  1.571069 -0.314157  1.196337
# Intell+   1.815270 -1.402831  2.423369 -2.965280  0.718636
# Intell++ -0.913235 -1.252340 -1.635117  3.475742  2.897771
# Intell-  -1.154879  2.675250 -1.163039  0.080195 -3.424683
# Affec+    4.103541 -1.412493 -0.321707  0.408588  0.213363
# Affec-   -4.103541  1.412493  0.321707 -0.408588 -0.213363
# Agress+  -2.120382  1.027890  1.638902  2.708128 -1.839943
# Agress-   2.120382 -1.027890 -1.638902 -2.708128  1.839943

# %% [markdown]
# ### Levels contributions

# %%
# levels contributions
levels.contrib
# Out:
#                Dim1       Dim2       Dim3       Dim4       Dim5
# Taille+    4.642073  12.170670  15.104237   2.297396   1.976132
# Taille++  13.458546   0.010191   0.115139   1.702852   0.782824
# Taille-   12.597815   9.586617   7.772416   0.395909   0.011470
# Poids+     1.673686  15.062072   2.191147   0.768462   2.082406
# Poids++    6.604042   7.608867  21.833395   0.089533   7.763356
# Poids-    14.010416   8.722246   3.013148   0.852122   0.086298
# Veloc+     3.736854  10.117058   2.972003   4.296552   4.528256
# Veloc++    9.180417   1.996447  15.335161   2.028481   0.003766
# Veloc-     1.311993  17.517423   4.722403   0.252828   3.847622
# Intell+    2.274208   1.700144   9.253181  18.549900   1.143359
# Intell++   0.863384   2.032408   6.318886  38.229311  27.885847
# Intell-    1.249240   8.391308   2.892448   0.018413  35.239587
# Affec+    10.791470   1.600529   0.151422   0.327037   0.093588
# Affec-    11.621583   1.723646   0.163069   0.352194   0.100787
# Agress+    3.102956   0.912786   4.232119  15.472079   7.495031
# Agress-    2.881317   0.847587   3.929825  14.366931   6.959671

# %%
# graph of variable categories - color by contributions
p = fviz_mca(
    obj=clf,
    choice="levels",
    col_var = "contrib",
    repel = True,
    quali_sup = False
)
print(p.show())
# Out:
# None

# %%
# graph of contributions for variable categories
p = fviz_corrplot(
    X=levels.contrib,
    legend_title="Contrib",
    title="Contributions of variable categories"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels cos2

# %%
# levels cos2
levels.cos2
# Out:
#               Dim1      Dim2      Dim3      Dim4      Dim5
# Taille+   0.164625  0.344803  0.234628  0.026654  0.021847
# Taille++  0.875032  0.000529  0.003279  0.036219  0.015866
# Taille-   0.491442  0.298755  0.132809  0.005053  0.000139
# Poids+    0.100447  0.722139  0.057601  0.015088  0.038959
# Poids++   0.234204  0.215564  0.339158  0.001039  0.085826
# Poids-    0.575313  0.286124  0.054196  0.011447  0.001105
# Veloc+    0.153447  0.331879  0.053456  0.057718  0.057965
# Veloc++   0.397921  0.069130  0.291151  0.028764  0.000051
# Veloc-    0.060213  0.642245  0.094933  0.003796  0.055047
# Intell+   0.126739  0.075690  0.225874  0.338188  0.019863
# Intell++  0.032077  0.060321  0.102831  0.464645  0.322964
# Intell-   0.051298  0.275268  0.052025  0.000247  0.451094
# Affec+    0.647656  0.076736  0.003981  0.006421  0.001751
# Affec-    0.647656  0.076736  0.003981  0.006421  0.001751
# Agress+   0.172924  0.040637  0.103308  0.282075  0.130207
# Agress-   0.172924  0.040637  0.103308  0.282075  0.130207

# %%
# graph of variable categories - color by cos2
p = fviz_mca(
    obj=clf,
    choice="levels",
    col_var = "cos2",
    repel = True,
    quali_sup = False
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus for variable categories
p = fviz_corrplot(
    X=levels.cos2,
    legend_title="Co2",
    title="Cosinus of variable categories"
)
print(p.show())
# Out:
# None

# %%
# graph of cosinus - levels
p = fviz_cos2(
    obj=clf,
    choice="levels"
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Levels additionals informations

# %%
# levels additionals informations
levels.infos
# Out:
#           Proportion    Weight  Sq. Dist.   Inertia  Inertia (%)
# Taille+     0.185185  0.030864   4.400000  0.135802     8.148148
# Taille++    0.555556  0.092593   0.800000  0.074074     4.444444
# Taille-     0.259259  0.043210   2.857143  0.123457     7.407407
# Poids+      0.518519  0.086420   0.928571  0.080247     4.814815
# Poids++     0.185185  0.030864   4.400000  0.135802     8.148148
# Poids-      0.296296  0.049383   2.375000  0.117284     7.037037
# Veloc+      0.296296  0.049383   2.375000  0.117284     7.037037
# Veloc++     0.333333  0.055556   2.000000  0.111111     6.666667
# Veloc-      0.370370  0.061728   1.700000  0.104938     6.296296
# Intell+     0.481481  0.080247   1.076923  0.086420     5.185185
# Intell++    0.222222  0.037037   3.500000  0.129630     7.777778
# Intell-     0.296296  0.049383   2.375000  0.117284     7.037037
# Affec+      0.518519  0.086420   0.928571  0.080247     4.814815
# Affec-      0.481481  0.080247   1.076923  0.086420     5.185185
# Agress+     0.481481  0.080247   1.076923  0.086420     5.185185
# Agress-     0.518519  0.086420   0.928571  0.080247     4.814815

# %% [markdown]
# ## Qualitative variables informations

# %%
# qualitative variables informations
quali_var = get_mca(clf,"quali_var")
quali_var._fields
# Out:
# ('coord', 'contrib', 'infos')

# %% [markdown]
# ### Qualitative variables coordinates (eta2)

# %%
# qualitative variables coordinates
quali_var.coord
# Out:
#                   Dim1      Dim2      Dim3      Dim4      Dim5
# Taille        0.887073  0.502486  0.291013  0.041558  0.024956
# Poids         0.644046  0.724688  0.342223  0.016166  0.089468
# Velocite      0.411174  0.684007  0.291491  0.062182  0.075484
# Intelligence  0.126764  0.279870  0.233710  0.536922  0.578931
# Affection     0.647656  0.076736  0.003981  0.006421  0.001751
# Agressivite   0.172924  0.040637  0.103308  0.282075  0.130207

# %%
# graph of variables
p = fviz_mca(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = False,
    quanti_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Qualitative variables contributions

# %%
# qualitative variables contributions
quali_var.contrib
# Out:
#                    Dim1       Dim2       Dim3       Dim4       Dim5
# Taille        30.698434  21.767479  22.991793   4.396158   2.770426
# Poids         22.288144  31.393185  27.037690   1.710116   9.932061
# Velocite      14.229264  29.630928  23.029566   6.577861   8.379644
# Intelligence   4.386832  12.123861  18.464515  56.797624  64.268793
# Affection     22.413052   3.324175   0.314491   0.679230   0.194374
# Agressivite    5.984273   1.760373   8.161945  29.839010  14.454702

# %% [markdown]
# ### Qualitative variables additionals informations

# %%
# qualitative variables additionals
quali_var.infos
# Out:
#                 Weight   Inertia  Inertia (%)
# Taille        0.166667  0.333333         20.0
# Poids         0.166667  0.333333         20.0
# Velocite      0.166667  0.333333         20.0
# Intelligence  0.166667  0.333333         20.0
# Affection     0.166667  0.166667         10.0
# Agressivite   0.166667  0.166667         10.0

# %% [markdown]
# ## Statistics with MCA

# %%
# statistics with MCA
from scientisttools import statsMCA
stats = statsMCA(clf)
stats._fields
# Out:
# ('correction', 'others')

# %% [markdown]
# ### Eigen values correction

# %%
# eigen values corrections
eig_correction = stats.correction
eig_correction._fields
# Out:
# ('benzecri', 'greenacre')

# %% [markdown]
# #### Benzecri eigen values correction

# %%
# benzecri eigen values correction
eig_correction.benzecri
# Out:
#       Eigenvalue  Proportion  Cumulative
# Dim1    0.142829   66.701311   66.701311
# Dim2    0.068479   31.979703   98.681014
# Dim3    0.002824    1.318986  100.000000

# %% [markdown]
# #### Greenacre eigen values correction

# %%
# greenacre eigen values correction
eig_correction.greenacre
# Out:
#       Eigenvalue  Proportion  Cumulative
# Dim1    0.142829   54.450544   54.450544
# Dim2    0.068479   26.106117   80.556662
# Dim3    0.002824    1.076733   81.633395

# %% [markdown]
# ### Others statistics

# %%
# others statistcs
others = stats.others
others._fields
# Out:
# ('inertia', 'kaiser')

# %% [markdown]
# #### Inertia

# %%
# inertia
others.inertia
# Out:
# 1.6666666666666665

# %% [markdown]
# #### Kaiser critical values

# %%
# kaiser critical values
others.kaiser
# Out:
#                         threshold  proportion
# Kaiser critical values   0.166667        60.0

# %% [markdown]
# ## Supplementary individuals informations

# %%
# supplementary individuals informations
ind_sup = clf.ind_sup_
ind_sup._fields
# Out:
# ('coord', 'cos2', 'dist2')

# %% [markdown]
# ### Supplementary individuals coordinates

# %%
# supplementary individuals coordinates
ind_sup.coord
# Out:
#             Dim1      Dim2      Dim3      Dim4      Dim5
# Medor   0.177285  0.181293  0.311384  0.911267  0.253762
# Djeck   0.071455 -0.183034  0.598513 -0.323498  0.383015
# Taico  -0.000878 -0.210670 -0.703078  0.699349  0.218854
# Rocky   0.474687 -0.696212  0.152066  0.077260 -0.653083
# Boudog  0.135578  0.426579 -0.306858 -0.037918 -0.151799
# Wisky   0.036218  0.413231  0.929178  0.412473 -0.326398

# %%
# graph of individuals with supplementary individuals
p = fviz_mca(
    obj=clf,
    choice="ind",
    repel = True,
    ind_sup = True
)
print(p.show())
# Out:
# 10 [ 0.64699906 -0.67412581]
# 18 [ 0.72445926 -0.31808466]
# 7 [-0.26107536  0.80983698]
# 21 [ 0.22177602 -0.28164193]
# None

# %% [markdown]
# ### Supplementary individuals cos2

# %%
# supplementary individuals cos2
ind_sup.cos2
# Out:
#                 Dim1      Dim2      Dim3      Dim4      Dim5
# Medor   1.334717e-02  0.013958  0.041175  0.352643  0.027346
# Djeck   2.915118e-03  0.019127  0.204519  0.059749  0.083757
# Taico   4.099356e-07  0.023584  0.262675  0.259895  0.025452
# Rocky   1.132707e-01  0.243661  0.011624  0.003001  0.214407
# Boudog  1.054083e-02  0.104351  0.053997  0.000825  0.013214
# Wisky   5.289124e-04  0.068853  0.348123  0.068600  0.042956

# %% [markdown]
# ### Supplementary individuals dist2

# %%
# supplementary individuals dist2
ind_sup.dist2.to_frame()
# Out:
#         Sq. Dist.
# Medor    2.354808
# Djeck    1.751511
# Taico    1.881868
# Rocky    1.989286
# Boudog   1.743819
# Wisky    2.480082

# %% [markdown]
# ## Supplementary quantitative variables informations

# %%
# supplementary quantitative variables
quanti_var_sup = clf.quanti_var_sup_
quanti_var_sup._fields
# Out:
# ('coord', 'cos2', 'dist2')

# %% [markdown]
# ### Supplementary quantitatives variables coordinates

# %%
# supplementary quantitatives factor coordinates
quanti_var_sup.coord
# Out:
#           Dim1      Dim2      Dim3      Dim4      Dim5
# Cote -0.042141  0.601291  0.258801  0.342585 -0.030073

# %%
# correlation circle
from scientisttools import fviz_corcircle
p = fviz_corcircle(clf)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Supplementary quantitative variables cos2

# %%
# supplementary quantitative variables cos2
quanti_var_sup.cos2
# Out:
#           Dim1      Dim2      Dim3      Dim4      Dim5
# Cote  0.001776  0.361551  0.066978  0.117364  0.000904

# %%
# graph of variables with supplementary quantitative variables
p = fviz_mca(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = False,
    quanti_sup = True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ## Supplementary levels informations

# %%
# supplementary levels informations
levels_sup = clf.levels_sup_
levels_sup._fields
# Out:
# ('coord', 'cos2', 'dist2', 'coord_n', 'vtest')

# %% [markdown]
# ### Supplementary levels coordinates - Quasi-barycenters

# %%
# supplementary levels coordinates - quasi barycenters
levels_sup.coord
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# chasse    -0.322391 -0.432432 -0.348749 -0.183945 -0.442940
# compagnie  1.039341  0.095320 -0.067896 -0.088964 -0.011143
# utilite   -0.936487  0.367336  0.477213  0.318144  0.512236

# %%
# graph of variable categories with supplementary levels
p = fviz_mca(
    obj=clf,
    choice="levels",
    repel = True,
    quali_sup = True
)
print(p.show())
# Out:
# None

# %% [markdown]
# ### Supplementary levels coordinates - Barycenters

# %%
# supplementary levels coordinates - barycenters
levels_sup.coord_n
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# chasse    -0.223732 -0.268226 -0.160179 -0.073014 -0.171626
# compagnie  0.721280  0.059125 -0.031185 -0.035313 -0.004318
# utilite   -0.649902  0.227848  0.219183  0.126281  0.198476

# %% [markdown]
# ### Supplementary levels vtest

# %%
# supplementary levels vtest
levels_sup.vtest
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# chasse    -1.162396 -1.559156 -1.257432 -0.663224 -1.597044
# compagnie  4.064622  0.372776 -0.265527 -0.347919 -0.043577
# utilite   -3.098535  1.215397  1.578945  1.052636  1.694827

# %% [markdown]
# ### Supplementary levels cos2

# %%
# supplementary levels cos2
levels_sup.cos2
# Out:
#                Dim1      Dim2      Dim3      Dim4      Dim5
# chasse     0.051968  0.093499  0.060813  0.016918  0.098098
# compagnie  0.635429  0.005345  0.002712  0.004656  0.000073
# utilite    0.369266  0.056815  0.095887  0.042617  0.110478

# %% [markdown]
# ### Supplementary levels dist2

# %%
# supplementary levels dist2
levels_sup.dist2.to_frame()
# Out:
#            Sq. Dist.
# chasse         2.000
# compagnie      1.700
# utilite        2.375

# %% [markdown]
# ## Supplementary qualitative variables informations

# %%
# supplementary qualitative variables informations
quali_var_sup = clf.quali_var_sup_
quali_var_sup._fields
# Out:
# ('coord',)

# %% [markdown]
# ### Supplementary qualitative variables coordinates

# %%
# supplementary qualitative variables coordinates
quali_var_sup.coord
# Out:
#               Dim1      Dim2      Dim3    Dim4      Dim5
# Fonction  0.694584  0.105679  0.109725  0.0442  0.143189

# %%
# graph of variables with supplementary qualitative variables
p = fviz_mca(
    obj=clf,
    choice="var",
    repel=True,
    quali_sup = True,
    quanti_sup = False
)
print(p.show())
# Out:
# None

# %% [markdown]
# ## Others functions

# %% [markdown]
# ### Ellipses - `fviz_ellipses`

# %%
# ellipses
from scientisttools import fviz_ellipses
p = fviz_ellipses(
    obj=clf,
    habillage=["Taille","Poids"],
    repel=True,
    add_ellipses=True
)
print(p.show())
# Out:
# 3 [0.45184196 0.37068552]
# 6 [-0.48601953  0.54759143]
# 1 [-0.37285763  0.12743245]
# 7 [-0.06261488 -0.88375531]
# 3 [0.87261051 0.4296409 ]
# 5 [-0.93126971  0.63874018]
# None

# %% [markdown]
# ### Summary - `summary`

# %%
# summary
from scientisttools import summary
summary(clf)
# Out:
#                      Multiple Correspondence Analysis - Results
#
# Importance of components:
#       Eigenvalue  Difference  Proportion (%)  Cumulative (%)
# Dim1      0.4816      0.0969         28.8964         28.8964
# Dim2      0.3847      0.1738         23.0842         51.9806
# Dim3      0.2110      0.0534         12.6572         64.6379
#
# Individuals (the 10 first):
#                Dim1    cos2     ctr    Dim2    cos2      ctr    Dim3    cos2  \
# Beauceron   -0.3172  0.0886  0.7738 -0.4177  0.1537   1.6796 -0.1015  0.0091
# Basset       0.2541  0.0338  0.4966  1.1012  0.6349  11.6742 -0.1907  0.0190
# Berger All  -0.4864  0.1537  1.8194 -0.4644  0.1402   2.0766 -0.4981  0.1612
# Boxer        0.4474  0.1113  1.5391 -0.8818  0.4325   7.4850  0.6920  0.2664
# Bull-Dog     1.0134  0.6245  7.8971  0.5499  0.1839   2.9108 -0.1634  0.0162
# Bull-Mastif -0.7526  0.2707  4.3556  0.5469  0.1430   2.8794  0.4976  0.1183
# Caniche      0.9123  0.3852  6.4006 -0.0162  0.0001   0.0025 -0.5766  0.1539
# Chihuahua    0.8408  0.3799  5.4366  0.8439  0.3827   6.8550 -0.4699  0.1187
# Cocker       0.7333  0.2792  4.1353  0.0791  0.0032   0.0602  0.6622  0.2277
# Colley      -0.1173  0.0124  0.1059 -0.5261  0.2493   2.6645 -0.3349  0.1010
#
#                 ctr
# Beauceron    0.1808
# Basset       0.6385
# Berger All   4.3565
# Boxer        8.4078
# Bull-Dog     0.4689
# Bull-Mastif  4.3467
# Caniche      5.8365
# Chihuahua    3.8775
# Cocker       7.6996
# Colley       1.9691
#
# Supplementary individuals:
#           Dim1    cos2    Dim2    cos2    Dim3    cos2
# Medor   0.1773  0.0133  0.1813  0.0140  0.3114  0.0412
# Djeck   0.0715  0.0029 -0.1830  0.0191  0.5985  0.2045
# Taico  -0.0009  0.0000 -0.2107  0.0236 -0.7031  0.2627
# Rocky   0.4747  0.1133 -0.6962  0.2437  0.1521  0.0116
# Boudog  0.1356  0.0105  0.4266  0.1044 -0.3069  0.0540
# Wisky   0.0362  0.0005  0.4132  0.0689  0.9292  0.3481
#
# Categories (the 10 first):
#
#             Dim1   vtest    cos2      ctr    Dim2   vtest    cos2      ctr  \
# Taille+   0.8511  2.0689  0.1646   4.6421 -1.2317 -2.9941  0.3448  12.1707
# Taille++ -0.8367 -4.7698  0.8750  13.4585 -0.0206 -0.1173  0.0005   0.0102
# Taille-   1.1850  3.5746  0.4914  12.5978  0.9239  2.7870  0.2988   9.5866
# Poids+   -0.3054 -1.6161  0.1004   1.6737 -0.8189 -4.3331  0.7221  15.0621
# Poids++  -1.0151 -2.4677  0.2342   6.6040  0.9739  2.3674  0.2156   7.6089
# Poids-    1.1689  3.8676  0.5753  14.0104  0.8243  2.7275  0.2861   8.7222
# Veloc+    0.6037  1.9974  0.1534   3.7369 -0.8878 -2.9375  0.3319  10.1171
# Veloc++  -0.8921 -3.2165  0.3979   9.1804 -0.3718 -1.3407  0.0691   1.9964
# Veloc-    0.3199  1.2512  0.0602   1.3120  1.0449  4.0864  0.6422  17.5174
# Intell+   0.3694  1.8153  0.1267   2.2742 -0.2855 -1.4028  0.0757   1.7001
#
#             Dim3   vtest    cos2      ctr
# Taille+   1.0161  2.4699  0.2346  15.1042
# Taille++ -0.0512 -0.2920  0.0033   0.1151
# Taille-  -0.6160 -1.8582  0.1328   7.7724
# Poids+   -0.2313 -1.2238  0.0576   2.1911
# Poids++   1.2216  2.9695  0.3392  21.8334
# Poids-   -0.3588 -1.1871  0.0542   3.0131
# Veloc+    0.3563  1.1789  0.0535   2.9720
# Veloc++  -0.7631 -2.7514  0.2912  15.3352
# Veloc-    0.4017  1.5711  0.0949   4.7224
# Intell+   0.4932  2.4234  0.2259   9.2532
#
# Categorical variables:
#                 Dim1      ctr    Dim2      ctr    Dim3      ctr
# Taille        0.8871  30.6984  0.5025  21.7675  0.2910  22.9918
# Poids         0.6440  22.2881  0.7247  31.3932  0.3422  27.0377
# Velocite      0.4112  14.2293  0.6840  29.6309  0.2915  23.0296
# Intelligence  0.1268   4.3868  0.2799  12.1239  0.2337  18.4645
# Affection     0.6477  22.4131  0.0767   3.3242  0.0040   0.3145
# Agressivite   0.1729   5.9843  0.0406   1.7604  0.1033   8.1619
#
# Supplementary continuous variables:
#         Dim1    cos2    Dim2    cos2    Dim3   cos2
# Cote -0.0421  0.0018  0.6013  0.3616  0.2588  0.067
#
# Supplementary categories:
#              Dim1   vtest    cos2    Dim2   vtest    cos2    Dim3   vtest  \
# chasse    -0.3224 -1.1624  0.0520 -0.4324 -1.5592  0.0935 -0.3487 -1.2574
# compagnie  1.0393  4.0646  0.6354  0.0953  0.3728  0.0053 -0.0679 -0.2655
# utilite   -0.9365 -3.0985  0.3693  0.3673  1.2154  0.0568  0.4772  1.5789
#
#              cos2
# chasse     0.0608
# compagnie  0.0027
# utilite    0.0959
#
# Supplementary categorical variables:
#             Dim1    Dim2    Dim3
# Fonction  0.6946  0.1057  0.1097

# %%
# formatting text to markdown
summary(clf,to_markdown=True)
# Out:
#                      Multiple Correspondence Analysis - Results
#
# Importance of components:
#         Eigenvalue    Difference    Proportion (%)    Cumulative (%)
# ----  ------------  ------------  ----------------  ----------------
# Dim1        0.4816        0.0969           28.8964           28.8964
# Dim2        0.3847        0.1738           23.0842           51.9806
# Dim3        0.211         0.0534           12.6572           64.6379
#
# Individuals (the 10 first):
#                 Dim1    cos2     ctr     Dim2    cos2      ctr     Dim3    cos2     ctr
# -----------  -------  ------  ------  -------  ------  -------  -------  ------  ------
# Beauceron    -0.3172  0.0886  0.7738  -0.4177  0.1537   1.6796  -0.1015  0.0091  0.1808
# Basset        0.2541  0.0338  0.4966   1.1012  0.6349  11.6742  -0.1907  0.019   0.6385
# Berger All   -0.4864  0.1537  1.8194  -0.4644  0.1402   2.0766  -0.4981  0.1612  4.3565
# Boxer         0.4474  0.1113  1.5391  -0.8818  0.4325   7.485    0.692   0.2664  8.4078
# Bull-Dog      1.0134  0.6245  7.8971   0.5499  0.1839   2.9108  -0.1634  0.0162  0.4689
# Bull-Mastif  -0.7526  0.2707  4.3556   0.5469  0.143    2.8794   0.4976  0.1183  4.3467
# Caniche       0.9123  0.3852  6.4006  -0.0162  0.0001   0.0025  -0.5766  0.1539  5.8365
# Chihuahua     0.8408  0.3799  5.4366   0.8439  0.3827   6.855   -0.4699  0.1187  3.8775
# Cocker        0.7333  0.2792  4.1353   0.0791  0.0032   0.0602   0.6622  0.2277  7.6996
# Colley       -0.1173  0.0124  0.1059  -0.5261  0.2493   2.6645  -0.3349  0.101   1.9691
#
# Supplementary individuals:
#            Dim1    cos2     Dim2    cos2     Dim3    cos2
# ------  -------  ------  -------  ------  -------  ------
# Medor    0.1773  0.0133   0.1813  0.014    0.3114  0.0412
# Djeck    0.0715  0.0029  -0.183   0.0191   0.5985  0.2045
# Taico   -0.0009  0       -0.2107  0.0236  -0.7031  0.2627
# Rocky    0.4747  0.1133  -0.6962  0.2437   0.1521  0.0116
# Boudog   0.1356  0.0105   0.4266  0.1044  -0.3069  0.054
# Wisky    0.0362  0.0005   0.4132  0.0689   0.9292  0.3481
#
# Categories (the 10 first):
#
#              Dim1    vtest    cos2      ctr     Dim2    vtest    cos2      ctr     Dim3    vtest    cos2      ctr
# --------  -------  -------  ------  -------  -------  -------  ------  -------  -------  -------  ------  -------
# Taille+    0.8511   2.0689  0.1646   4.6421  -1.2317  -2.9941  0.3448  12.1707   1.0161   2.4699  0.2346  15.1042
# Taille++  -0.8367  -4.7698  0.875   13.4585  -0.0206  -0.1173  0.0005   0.0102  -0.0512  -0.292   0.0033   0.1151
# Taille-    1.185    3.5746  0.4914  12.5978   0.9239   2.787   0.2988   9.5866  -0.616   -1.8582  0.1328   7.7724
# Poids+    -0.3054  -1.6161  0.1004   1.6737  -0.8189  -4.3331  0.7221  15.0621  -0.2313  -1.2238  0.0576   2.1911
# Poids++   -1.0151  -2.4677  0.2342   6.604    0.9739   2.3674  0.2156   7.6089   1.2216   2.9695  0.3392  21.8334
# Poids-     1.1689   3.8676  0.5753  14.0104   0.8243   2.7275  0.2861   8.7222  -0.3588  -1.1871  0.0542   3.0131
# Veloc+     0.6037   1.9974  0.1534   3.7369  -0.8878  -2.9375  0.3319  10.1171   0.3563   1.1789  0.0535   2.972
# Veloc++   -0.8921  -3.2165  0.3979   9.1804  -0.3718  -1.3407  0.0691   1.9964  -0.7631  -2.7514  0.2912  15.3352
# Veloc-     0.3199   1.2512  0.0602   1.312    1.0449   4.0864  0.6422  17.5174   0.4017   1.5711  0.0949   4.7224
# Intell+    0.3694   1.8153  0.1267   2.2742  -0.2855  -1.4028  0.0757   1.7001   0.4932   2.4234  0.2259   9.2532
#
# Categorical variables:
#                 Dim1      ctr    Dim2      ctr    Dim3      ctr
# ------------  ------  -------  ------  -------  ------  -------
# Taille        0.8871  30.6984  0.5025  21.7675  0.291   22.9918
# Poids         0.644   22.2881  0.7247  31.3932  0.3422  27.0377
# Velocite      0.4112  14.2293  0.684   29.6309  0.2915  23.0296
# Intelligence  0.1268   4.3868  0.2799  12.1239  0.2337  18.4645
# Affection     0.6477  22.4131  0.0767   3.3242  0.004    0.3145
# Agressivite   0.1729   5.9843  0.0406   1.7604  0.1033   8.1619
#
# Supplementary continuous variables:
#          Dim1    cos2    Dim2    cos2    Dim3    cos2
# ----  -------  ------  ------  ------  ------  ------
# Cote  -0.0421  0.0018  0.6013  0.3616  0.2588   0.067
#
# Supplementary categories:
#               Dim1    vtest    cos2     Dim2    vtest    cos2     Dim3    vtest    cos2
# ---------  -------  -------  ------  -------  -------  ------  -------  -------  ------
# chasse     -0.3224  -1.1624  0.052   -0.4324  -1.5592  0.0935  -0.3487  -1.2574  0.0608
# compagnie   1.0393   4.0646  0.6354   0.0953   0.3728  0.0053  -0.0679  -0.2655  0.0027
# utilite    -0.9365  -3.0985  0.3693   0.3673   1.2154  0.0568   0.4772   1.5789  0.0959
#
# Supplementary categorical variables:
#             Dim1    Dim2    Dim3
# --------  ------  ------  ------
# Fonction  0.6946  0.1057  0.1097

# %% [markdown]
# ### Dimension description - `dimdesc`

# %%
# dimension description
from scientisttools import dimdesc
dim_desc = dimdesc(clf,axis=[0,1])
dim_desc.keys()
# Out:
# dict_keys(['Dim1', 'Dim2'])

# %% [markdown]
# #### `Dim1` dimension

# %%
# Dim1 dimension
dim_desc["Dim1"]._fields
# Out:
# ('call', 'quali', 'category')

# %% [markdown]
# ##### Description of Dim1 by category

# %%
# description of Dim1 by category
dim_desc["Dim1"].category
# Out:
#                      Estimate        pvalue
# Taille=Taille+       0.724872  3.574570e-02
# Taille=Taille++     -1.306428  8.616471e-13
# Taille=Taille-       1.110151  4.642696e-05
# Poids=Poids++       -0.864591  1.053636e-02
# Poids=Poids-         1.152764  4.553328e-06
# Velocite=Veloc+      0.595344  4.330936e-02
# Velocite=Veloc++    -0.928647  4.193918e-04
# Affection=Affec+     1.117754  4.184726e-07
# Affection=Affec-    -1.117754  4.184726e-07
# Agressivite=Agress+ -0.577566  3.098130e-02
# Agressivite=Agress-  0.577566  3.098130e-02
# Fonction=compagnie   1.145563  6.464827e-07
# Fonction=utilite    -0.923544  7.740227e-04

# %% [markdown]
# ##### Description of Dim1 by categorical variables

# %%
# description of Dim1 by categorical variables
dim_desc["Dim1"].quali
# Out:
#                    R2        pvalue
# Taille       0.887073  4.300901e-12
# Fonction     0.694584  6.587193e-07
# Affection    0.647656  4.184726e-07
# Poids        0.644046  4.137327e-06
# Velocite     0.411174  1.737173e-03
# Agressivite  0.172924  3.098130e-02

# %% [markdown]
# ### Data reconstruction - `reconst`

# %%
#disjunctive table reconstitution
from scientisttools import reconst
rec_disj = reconst(clf,clf.call_.ncp-1)
rec_disj
# Out:
#                 Taille+  Taille++  Taille-  Poids+  Poids++  Poids-  Veloc+  \
# Beauceron             0         1        0       1        0       0       0
# Basset                0         0        1       0        0       1       0
# Berger All            0         1        0       1        0       0       1
# Boxer                 1         0        0       1        0       0       1
# Bull-Dog              0         0        1       0        0       1       0
# Bull-Mastif           0         1        0       0        1       0       0
# Caniche               0         0        1       0        0       1       1
# Chihuahua             0         0        1       0        0       1       0
# Cocker                1         0        1       0        0       1       1
# Colley                0         1        0       1        0       0       0
# Dalmatien             1         0        0       1        0       0       1
# Doberman              0         1        0       1        0       0       0
# Dogue All             0         1        0       0        1       0       0
# Epag. Breton          1         0        0       1        0       0       1
# Epag. Français        0         1        0       1        0       0       1
# Fox-Hound             0         1        0       1        0       0       0
# Fox-Terrier           1         0        1       0        0       1       1
# Gd Bleu Gasc          0         1        0       1        0       0       0
# Labrador              1         0        0       1        0       0       1
# Levrier               0         1        0       1        0       0       0
# Mastiff               0         1        0       0        1       0       0
# Pekinois              0         0        1       0        0       1       0
# Pointer               0         1        0       1        0       0       0
# St-Bernard            0         1        0       0        1       0       0
# Setter                0         1        0       1        0       0       0
# Teckel                0         0        1       0        0       1       0
# Terre-Neuve           0         1        0       0        1       0       0
#
#                 Veloc++  Veloc-  Intell+  Intell++  Intell-  Affec+  Affec-  \
# Beauceron             1       0        1         0        0       1       1
# Basset                0       1        0         0        1       1       1
# Berger All            1       0        0         1        0       1       1
# Boxer                 0       0        1         0        0       1       0
# Bull-Dog              0       1        1         0        1       1       0
# Bull-Mastif           0       1        0         1        1       0       1
# Caniche               0       0        0         1        0       1       0
# Chihuahua             0       1        0         0        1       1       0
# Cocker                0       1        1         0        0       1       0
# Colley                1       0        1         0        0       1       1
# Dalmatien             0       0        1         0        0       1       0
# Doberman              1       0        0         1        1       0       1
# Dogue All             1       1        0         0        1       0       1
# Epag. Breton          0       0        1         1        0       1       0
# Epag. Français        1       0        1         0        0       1       1
# Fox-Hound             1       0        0         1        1       0       1
# Fox-Terrier           0       1        1         0        0       1       0
# Gd Bleu Gasc          1       0        0         1        0       0       1
# Labrador              0       0        1         0        0       1       0
# Levrier               1       0        0         0        1       0       1
# Mastiff               0       1        0         0        1       0       1
# Pekinois              0       1        0         0        1       1       0
# Pointer               1       0        0         1        1       0       1
# St-Bernard            0       1        1         0        1       0       1
# Setter                1       0        1         0        0       0       1
# Teckel                0       1        1         0        1       1       0
# Terre-Neuve           0       1        1         0        1       0       1
#
#                 Agress+  Agress-
# Beauceron             0        1
# Basset                1        0
# Berger All            1        0
# Boxer                 1        1
# Bull-Dog              0        1
# Bull-Mastif           1        0
# Caniche               1        1
# Chihuahua             0        1
# Cocker                1        0
# Colley                0        1
# Dalmatien             0        1
# Doberman              1        0
# Dogue All             1        0
# Epag. Breton          1        1
# Epag. Français        0        1
# Fox-Hound             1        1
# Fox-Terrier           1        1
# Gd Bleu Gasc          1        0
# Labrador              0        1
# Levrier               0        1
# Mastiff               1        0
# Pekinois              0        1
# Pointer               1        1
# St-Bernard            1        0
# Setter                0        1
# Teckel                0        1
# Terre-Neuve           1        1
