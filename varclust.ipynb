# %% [markdown]
# # VARCLUS

# %%
# Out:
#        breakfast      tea.time      evening      lunch      dinner  \
# 0      breakfast  Not.tea time  Not.evening  Not.lunch  Not.dinner
# 1      breakfast  Not.tea time  Not.evening  Not.lunch  Not.dinner
# 2  Not.breakfast      tea time      evening  Not.lunch      dinner
# 3  Not.breakfast  Not.tea time  Not.evening  Not.lunch      dinner
# 4      breakfast  Not.tea time      evening  Not.lunch  Not.dinner
#
#        always  home      work      tearoom      friends  ...      diuretic  \
# 0  Not.always  home  Not.work  Not.tearoom  Not.friends  ...  Not.diuretic
# 1  Not.always  home  Not.work  Not.tearoom  Not.friends  ...      diuretic
# 2  Not.always  home      work  Not.tearoom      friends  ...      diuretic
# 3  Not.always  home  Not.work  Not.tearoom  Not.friends  ...  Not.diuretic
# 4      always  home  Not.work  Not.tearoom  Not.friends  ...      diuretic
#
#        friendliness      iron.absorption      feminine      sophisticated  \
# ...
