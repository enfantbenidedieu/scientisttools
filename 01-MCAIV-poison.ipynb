# %% [markdown]
# # Multiple Correspondence Analysis with Instrumental Variables (MCAIV) - `poison` dataset

# %%
#disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=6):
    dt = (GT(data=data.round(digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %% [markdown]
# ## `poison` dataset

# %%
#decathlon dataset
from scientisttools.datasets import poison
(
    GT(poison.rename_axis("Individuals").reset_index())
    .tab_header(title=html("<b>Poison Dataset</b>"))
    .tab_spanner(label=html("<b>Individuals</b>"),columns="Individuals")
    .tab_spanner(label=html("<b>Dependent<br>variables</b>"),columns=poison.columns.tolist()[4:])
    .tab_spanner(label=html("<b>Explanatory (instrumental)<br>variables</b>"),columns=poison.columns.tolist()[:4])
)
# Out:
# GT(_tbl_data=    Individuals  Age  Time    Sick Sex    Nausea Vomiting Abdominals    Fever  \
# 0             1    9    22  Sick_y   F  Nausea_y  Vomit_n     Abdo_y  Fever_y
# 1             2    5     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 2             3    6    16  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 3             4    9     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 4             5    7    14  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 5             6   72     9  Sick_y   M  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 6             7    5    16  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 7             8   10     8  Sick_y   F  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 8             9    5    20  Sick_y   M  Nausea_y  Vomit_n     Abdo_y  Fever_y
# 9            10   11    12  Sick_y   M  Nausea_n  Vomit_y     Abdo_n  Fever_y
# 10           11    7    17  Sick_y   F  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 11           12   10    16  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_n
# 12           13   36    19  Sick_y   F  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 13           14    9     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 14           15    8     0  Sick_n   M  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 15           16    6     6  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 16           17    7    10  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 17           18    5    15  Sick_y   M  Nausea_y  Vomit_y     Abdo_y  Fever_y
# 18           19   11    14  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 19           20   11     0  Sick_n   F  Nausea_n  Vomit_n     Abdo_n  Fever_n
# 20           21   10    18  Sick_y   M  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 21           22    8    14  Sick_y   F  Nausea_n  Vomit_n     Abdo_y  Fever_y
# 22           23    8    21  Sick_y   F  Nausea_n  Vomit_y     Abdo_y  Fever_y
# 23           24   11    13  Sick_y   M  Nausea_n  Vomit_y     Abdo_y  Fever_n
Mayo_y   Courg_y  Cheese_y  Icecream_y
# 6   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 7   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 8   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 9   Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 10  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 11  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 12  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 13  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 14  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_n  Icecream_y
# 15  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 16  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_n  Icecream_y
# 17  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 18  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 19  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 20  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 21  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_n
# 22  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_n  Cheese_y  Icecream_y
# 23  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 24  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_n  Icecream_y
# 25  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 26  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 27  Diarrhea_y  Potato_y  Fish_y  Mayo_n   Courg_n  Cheese_y  Icecream_y
# 28  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 29  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 30  Diarrhea_y  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 31  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_n  Icecream_y
# 32  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 33  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 34  Diarrhea_y  Potato_n  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 35  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 36  Diarrhea_y  Potato_n  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 37  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_n  Cheese_n  Icecream_y
# 38  Diarrhea_y  Potato_n  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 39  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 40  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 41  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 42  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 43  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_n  Cheese_y  Icecream_n
# 44  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_n  Cheese_y  Icecream_y
# 45  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 46  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_n
# 47  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 48  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 49  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 50  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_y  Icecream_y
# 51  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 52  Diarrhea_n  Potato_y  Fish_y  Mayo_n   Courg_y  Cheese_n  Icecream_n
# 53  Diarrhea_n  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y
# 54  Diarrhea_y  Potato_y  Fish_y  Mayo_y   Courg_y  Cheese_y  Icecream_y  , _body=<great_tables._gt_data.Body object at 0x0000023E77E695A0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Age', type=<ColInfoTypeEnum.default: 1>, column_label='Age', column_align='right', column_width=None), ColInfo(var='Time', type=<ColInfoTypeEnum.default: 1>, column_label='Time', column_align='right', column_width=None), ColInfo(var='Sick', type=<ColInfoTypeEnum.default: 1>, column_label='Sick', column_align='left', column_width=None), ColInfo(var='Sex', type=<ColInfoTypeEnum.default: 1>, column_label='Sex', column_align='left', column_width=None), ColInfo(var='Nausea', type=<ColInfoTypeEnum.default: 1>, column_label='Nausea', column_align='left', column_width=None), ColInfo(var='Vomiting', type=<ColInfoTypeEnum.default: 1>, column_label='Vomiting', column_align='left', column_width=None), ColInfo(var='Abdominals', type=<ColInfoTypeEnum.default: 1>, column_label='Abdominals', column_align='left', column_width=None), ColInfo(var='Fever', type=<ColInfoTypeEnum.default: 1>, column_label='Fever', column_align='left', column_width=None), ColInfo(var='Diarrhae', type=<ColInfoTypeEnum.default: 1>, column_label='Diarrhae', column_align='left', column_width=None), ColInfo(var='Potato', type=<ColInfoTypeEnum.default: 1>, column_label='Potato', column_align='left', column_width=None), ColInfo(var='Fish', type=<ColInfoTypeEnum.default: 1>, column_label='Fish', column_align='left', column_width=None), ColInfo(var='Mayo', type=<ColInfoTypeEnum.default: 1>, column_label='Mayo', column_align='left', column_width=None), ColInfo(var='Courgette', type=<ColInfoTypeEnum.default: 1>, column_label='Courgette', column_align='left', column_width=None), ColInfo(var='Cheese', type=<ColInfoTypeEnum.default: 1>, column_label='Cheese', column_align='left', column_width=None), ColInfo(var='Icecream', type=<ColInfoTypeEnum.default: 1>, column_label='Icecream', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E645437F0>, _spanners=Spanners([SpannerInfo(spanner_id='<b>Individuals</b>', spanner_level=0, spanner_label=Html(text='<b>Individuals</b>'), spanner_units=None, spanner_pattern=None, vars=['Individuals'], built=None), SpannerInfo(spanner_id='<b>Dependent<br>variables</b>', spanner_level=0, spanner_label=Html(text='<b>Dependent<br>variables</b>'), spanner_units=None, spanner_pattern=None, vars=['Nausea', 'Vomiting', 'Abdominals', 'Fever', 'Diarrhae', 'Potato', 'Fish', 'Mayo', 'Courgette', 'Cheese', 'Icecream'], built=None), SpannerInfo(spanner_id='<b>Explanatory (instrumental)<br>variables</b>', spanner_level=0, spanner_label=Html(text='<b>Explanatory (instrumental)<br>variables</b>'), spanner_units=None, spanner_pattern=None, vars=['Age', 'Time', 'Sick', 'Sex'], built=None)]), _heading=Heading(title=Html(text='<b>Poison Dataset</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E77F31150>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'Blin ...

# %% [markdown]
# ## Instanciation and training

# %%
from scientisttools import MCAIV
#instanciation
res_mcaiv = MCAIV(iv=(0,1,2,3))

# %% [markdown]
# ## `fit` function

# %%
#fit
res_mcaiv.fit(poison)
# Out:
# MCAIV(iv=(0, 1, 2, 3))

# %% [markdown]
# ## `fit_transform` function

# %%
#fit_transform
print_dt(res_mcaiv.fit_transform(poison),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=    Individuals     Dim.1     Dim.2     Dim.3     Dim.4
# 0             1 -0.387398 -0.184779 -0.180854 -0.046041
# 1             2  0.828516 -0.099682  0.042413 -0.035365
# 2             3 -0.365958 -0.116680  0.008931 -0.039260
# 3             4  0.826542 -0.081367  0.034145 -0.038793
# 4             5 -0.361147  0.012604  0.020568  0.057152
# 5             6 -0.376589  0.378410  0.039197  0.004950
# 6             7 -0.365464 -0.121259  0.010998 -0.038403
# 7             8 -0.341317  0.010748  0.245441 -0.037076
# 8             9 -0.380120 -0.078389 -0.158882  0.054657
# 9            10 -0.356467  0.058197  0.073494  0.055127
# 10           11 -0.369778 -0.125740 -0.023733 -0.040819
# 11           12 -0.367931 -0.098365  0.000663 -0.042689
# 12           13 -0.390742 -0.020239 -0.144872 -0.067078
# 13           14  0.826542 -0.081367  0.034145 -0.038793
# 14           15  0.825687  0.011481 -0.011279  0.057930
# 15           16 -0.332690  0.019712  0.314904 -0.032245
# 16           17 -0.347840  0.067160  0.142957  0.059959
# 17           18 -0.363487 -0.010193 -0.005895  0.058165
# 18           19 -0.361771 -0.066508  0.059791 -0.042143
# 19           20  0.825555 -0.072210  0.030011 -0.040508
# 20           21 -0.375934 -0.028217 -0.108022  0.051775
# 21           22 -0.360291 -0.080244  0.065992 -0.039571
# 22           23 -0.383578 -0.175719 -0.148189 -0.044482
# 23           24 -0.359794  0.044557  0.042897  0.054426
# 24           25 -0.365243  0.143721  0.111901 -0.068477
# 25           26  0.825193  0.016059 -0.013346  0.057073
# 26           27 -0.352157 -0.066702  0.133387 -0.035597
# 27           28 -0.383005  0.437932  0.012326 -0.006193
# 28           29  0.787557  0.280344 -0.129150 -0.106503
# 29           30 -0.405309  0.203920 -0.172559 -0.102529
# 30           31 -0.344151 -0.007470  0.216911 -0.036921
# 31           32  0.826674  0.002323 -0.007145  0.059645
# 32           33  0.827036 -0.085946  0.036212 -0.037936
# 33           34  0.825687  0.011481 -0.011279  0.057930
# 34           35 -0.363124 -0.098462  0.037461 -0.039416
# 35           36 -0.378767 -0.046435 -0.136553  0.051931
# 36           37 -0.352153  0.062679  0.108226  0.057543
# 37           38  0.828023 -0.095103  0.040346 -0.036222
# 38           39 -0.370140 -0.037471 -0.067090  0.056762
# 39           40 -0.367307 -0.019253 -0.038560  0.056606
# 40           41 -0.353013  0.026146  0.087964  0.061127
# 41           42  0.826180  0.006902 -0.009212  0.058788
# 42           43 -0.416769  0.176739 -0.270552 -0.107205
# 43           44 -0.325543  0.042412  0.378166 -0.029985
# 44           45 -0.380120 -0.078389 -0.158882  0.054657
# 45           46 -0.367307 -0.019253 -0.038560  0.056606
# 46           47  0.824700  0.020638 -0.015413  0.056216
# 47           48  0.788675  0.354877 -0.166306 -0.006351
# 48           49  0.827036 -0.085946  0.036212 -0.037936
# 49           50 -0.386412 -0.193936 -0.176720 -0.044327
# 50           51  0.824700  0.020638 -0.015413  0.056216
# 51           52 -0.373101 -0.009999 -0.079492  0.051619
# 52           53  0.828023 -0.095103  0.040346 -0.036222
# 53           54 -0.379261 -0.041856 -0.138620  0.051073
# 54           55 -0.361147  0.012604  0.020568  0.057152, _body=<great_tables._gt_data.Body object at 0x0000023E782C53F0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E7809D540>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E7829E350>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='cente ...

# %% [markdown]
# ## Ratio

# %%
#ratio
res_mcaiv.ratio_
# Out:
# 0.3367862413157026

# %% [markdown]
# ## Eigen values

# %%
#PCA eigen values
from scientisttools import get_eig
print_dt(get_eig(res_mcaiv),rowname="Dimensions",title=html("<b>Eigen values</b>"))
# Out:
# GT(_tbl_data=  Dimensions  Eigenvalue  Difference  Proportion  Cumulative
# 0      Dim.1    0.302475    0.285856   89.812039   89.812039
# 1      Dim.2    0.016619    0.001718    4.934517   94.746556
# 2      Dim.3    0.014901    0.012109    4.424378   99.170933
# 3      Dim.4    0.002792         NaN    0.829067  100.000000, _body=<great_tables._gt_data.Body object at 0x0000023E7829D450>, _boxhead=Boxhead([ColInfo(var='Dimensions', type=<ColInfoTypeEnum.default: 1>, column_label='Dimensions', column_align='left', column_width=None), ColInfo(var='Eigenvalue', type=<ColInfoTypeEnum.default: 1>, column_label='Eigenvalue', column_align='right', column_width=None), ColInfo(var='Difference', type=<ColInfoTypeEnum.default: 1>, column_label='Difference', column_align='right', column_width=None), ColInfo(var='Proportion', type=<ColInfoTypeEnum.default: 1>, column_label='Proportion', column_align='right', column_width=None), ColInfo(var='Cumulative', type=<ColInfoTypeEnum.default: 1>, column_label='Cumulative', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E7829E020>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Eigen values</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E7829E8F0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='headi ...

# %% [markdown]
# ## Individuals informations

# %%
#individuals informations
from scientisttools import get_mcaiv_ind
ind = get_mcaiv_ind(res_mcaiv)
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
#individuals factor coordinates
print_dt(ind.coord,rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=    Individuals     Dim.1     Dim.2     Dim.3     Dim.4
# 0             1 -0.387398 -0.184779 -0.180854 -0.046041
# 1             2  0.828516 -0.099682  0.042413 -0.035365
# 2             3 -0.365958 -0.116680  0.008931 -0.039260
# 3             4  0.826542 -0.081367  0.034145 -0.038793
# 4             5 -0.361147  0.012604  0.020568  0.057152
# 5             6 -0.376589  0.378410  0.039197  0.004950
# 6             7 -0.365464 -0.121259  0.010998 -0.038403
# 7             8 -0.341317  0.010748  0.245441 -0.037076
# 8             9 -0.380120 -0.078389 -0.158882  0.054657
# 9            10 -0.356467  0.058197  0.073494  0.055127
# 10           11 -0.369778 -0.125740 -0.023733 -0.040819
# 11           12 -0.367931 -0.098365  0.000663 -0.042689
# 12           13 -0.390742 -0.020239 -0.144872 -0.067078
# 13           14  0.826542 -0.081367  0.034145 -0.038793
# 14           15  0.825687  0.011481 -0.011279  0.057930
# 15           16 -0.332690  0.019712  0.314904 -0.032245
# 16           17 -0.347840  0.067160  0.142957  0.059959
# 17           18 -0.363487 -0.010193 -0.005895  0.058165
# 18           19 -0.361771 -0.066508  0.059791 -0.042143
# 19           20  0.825555 -0.072210  0.030011 -0.040508
# 20           21 -0.375934 -0.028217 -0.108022  0.051775
# 21           22 -0.360291 -0.080244  0.065992 -0.039571
# 22           23 -0.383578 -0.175719 -0.148189 -0.044482
# 23           24 -0.359794  0.044557  0.042897  0.054426
# 24           25 -0.365243  0.143721  0.111901 -0.068477
# 25           26  0.825193  0.016059 -0.013346  0.057073
# 26           27 -0.352157 -0.066702  0.133387 -0.035597
# 27           28 -0.383005  0.437932  0.012326 -0.006193
# 28           29  0.787557  0.280344 -0.129150 -0.106503
# 29           30 -0.405309  0.203920 -0.172559 -0.102529
# 30           31 -0.344151 -0.007470  0.216911 -0.036921
# 31           32  0.826674  0.002323 -0.007145  0.059645
# 32           33  0.827036 -0.085946  0.036212 -0.037936
# 33           34  0.825687  0.011481 -0.011279  0.057930
# 34           35 -0.363124 -0.098462  0.037461 -0.039416
# 35           36 -0.378767 -0.046435 -0.136553  0.051931
# 36           37 -0.352153  0.062679  0.108226  0.057543
# 37           38  0.828023 -0.095103  0.040346 -0.036222
# 38           39 -0.370140 -0.037471 -0.067090  0.056762
# 39           40 -0.367307 -0.019253 -0.038560  0.056606
# 40           41 -0.353013  0.026146  0.087964  0.061127
# 41           42  0.826180  0.006902 -0.009212  0.058788
# 42           43 -0.416769  0.176739 -0.270552 -0.107205
# 43           44 -0.325543  0.042412  0.378166 -0.029985
# 44           45 -0.380120 -0.078389 -0.158882  0.054657
# 45           46 -0.367307 -0.019253 -0.038560  0.056606
# 46           47  0.824700  0.020638 -0.015413  0.056216
# 47           48  0.788675  0.354877 -0.166306 -0.006351
# 48           49  0.827036 -0.085946  0.036212 -0.037936
# 49           50 -0.386412 -0.193936 -0.176720 -0.044327
# 50           51  0.824700  0.020638 -0.015413  0.056216
# 51           52 -0.373101 -0.009999 -0.079492  0.051619
# 52           53  0.828023 -0.095103  0.040346 -0.036222
# 53           54 -0.379261 -0.041856 -0.138620  0.051073
# 54           55 -0.361147  0.012604  0.020568  0.057152, _body=<great_tables._gt_data.Body object at 0x0000023E7824BC40>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='right', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E7829D870>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78236710>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='cente ...

# %% [markdown]
# ### Individuals contributions

# %%
#individuals contributions
print_dt(ind.contrib,rowname="Individuals",title=html("<b>Individuals contributions</b>"))
# Out:
# GT(_tbl_data=    Individuals     Dim.1      Dim.2      Dim.3     Dim.4
# 0             1  0.902120   3.735463   3.991034  1.380327
# 1             2  4.126203   1.087101   0.219498  0.814411
# 2             3  0.805026   1.489465   0.009733  1.003695
# 3             4  4.106565   0.724332   0.142261  0.979965
# 4             5  0.784000   0.017379   0.051620  2.126982
# 5             6  0.852481  15.666196   0.187477  0.015952
# 6             7  0.802856   1.608655   0.014760  0.960350
# 7             8  0.700270   0.012639   7.350661  0.895127
# 8             9  0.868541   0.672272   3.080198  1.945316
# 9            10  0.763814   0.370538   0.659083  1.978911
# 10           11  0.821921   1.729771   0.068729  1.084971
# 11           12  0.813734   1.058579   0.000054  1.186641
# 12           13  0.917760   0.044814   2.560928  2.929876
# 13           14  4.106565   0.724332   0.142261  0.979965
# 14           15  4.098066   0.014420   0.015522  2.185281
# 15           16  0.665316   0.042511  12.100056  0.677037
# 16           17  0.727289   0.493476   2.493691  2.340983
# 17           18  0.794191   0.011366   0.004241  2.203021
# 18           19  0.786714   0.483940   0.436211  1.156479
# 19           20  4.096764   0.570471   0.109898  1.068482
# 20           21  0.849517   0.087110   1.423828  1.745556
# 21           22  0.780289   0.704476   0.531385  1.019663
# 22           23  0.884416   3.378111   2.679568  1.288452
# 23           24  0.778137   0.217209   0.224537  1.928863
# 24           25  0.801885   2.259860   1.527906  3.053433
# 25           26  4.093169   0.028216   0.021733  2.121096
>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_alig ...

# %% [markdown]
# ## Variables informations

# %%
#variables informations
from scientisttools import get_mcaiv_var
var = get_mcaiv_var(res_mcaiv)
var._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Variables coordinates

# %%
#variables coordinates
print_dt(var.coord,rowname="Variables",title=html("<b>Variables coordinates</b>"))
# Out:
# GT(_tbl_data=   Variables     Dim.1     Dim.2     Dim.3     Dim.4
# 0      Dim.1  0.546290  0.001943  0.003595 -0.001036
# 1      Dim.2 -0.012449 -0.001572  0.062707 -0.033926
# 2      Dim.3  0.010054 -0.073626  0.059343  0.006597
# 3      Dim.4 -0.025106  0.087408  0.044311 -0.010592
# 4      Dim.5 -0.010638  0.009512 -0.000675  0.008401
# 5      Dim.6  0.029464  0.039686 -0.023388  0.001210
# 6      Dim.7  0.043314  0.016182  0.014109 -0.000836
# 7      Dim.8  0.001725  0.034901  0.012564  0.020030
# 8      Dim.9 -0.010865  0.009496  0.066366  0.027002
# 9     Dim.10  0.011290  0.016071  0.011904  0.016397
# 10    Dim.11  0.007056 -0.007596 -0.004476 -0.003536, _body=<great_tables._gt_data.Body object at 0x0000023E78308640>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E78308700>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E7830A590>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), headi ...

# %% [markdown]
# ### Variables contributions

# %%
#variables contributions
print_dt(var.contrib,rowname="Variables",title=html("<b>Variables contributions</b>"))
# Out:
# GT(_tbl_data=   Variables      Dim.1      Dim.2      Dim.3      Dim.4
# 0      Dim.1  98.663684   0.022711   0.086722   0.038449
# 1      Dim.2   0.051233   0.014868  26.388998  41.220180
# 2      Dim.3   0.033421  32.618838  23.634047   1.558815
# 3      Dim.4   0.208392  45.972949  13.176709   4.018329
# 4      Dim.5   0.037411   0.544378   0.003060   2.527817
# 5      Dim.6   0.287010   9.477145   3.670955   0.052472
# 6      Dim.7   0.620239   1.575635   1.335999   0.025039
# 7      Dim.8   0.000984   7.329543   1.059307  14.369286
# 8      Dim.9   0.039025   0.542642  29.558753  26.113348
# 9     Dim.10   0.042142   1.554102   0.951025   9.628541
# 10    Dim.11   0.016460   0.347190   0.134426   0.447724, _body=<great_tables._gt_data.Body object at 0x0000023E7823E560>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E7828B100>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E7823F1C0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), ...

# %% [markdown]
# ### Variables squared cosinus (cos2)

# %%
#variables squared cosinus (cos2)
print_dt(var.cos2,rowname="Variables",title=html("<b>Variables squared cosinus (cos2)</b>"))
# Out:
# GT(_tbl_data=   Variables     Dim.1     Dim.2     Dim.3     Dim.4
# 0      Dim.1  0.999940  0.000013  0.000043  0.000004
# 1      Dim.2  0.029571  0.000471  0.750334  0.219624
# 2      Dim.3  0.011125  0.596543  0.387542  0.004790
# 3      Dim.4  0.060925  0.738457  0.189774  0.010845
# 4      Dim.5  0.411990  0.329379  0.001660  0.256972
# 5      Dim.6  0.290192  0.526473  0.182846  0.000490
# 6      Dim.7  0.802530  0.112013  0.085158  0.000299
# 7      Dim.8  0.001672  0.684270  0.088671  0.225388
# 8      Dim.9  0.022097  0.016882  0.824525  0.136495
# 9     Dim.10  0.160077  0.324342  0.177960  0.337621
# 10    Dim.11  0.355578  0.412082  0.143057  0.089284, _body=<great_tables._gt_data.Body object at 0x0000023E780E6380>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E7823E2F0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables squared cosinus (cos2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E780E4970>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='cent ...

# %% [markdown]
# ### Addtionals informations

# %%
#variables additionals informations
print_dt(var.infos,rowname="Variables",title=html("<b>Variables additionals informations <br> (weight, sq. dist., inertia)</b>"))
# Out:
# GT(_tbl_data=   Variables  Weight  Sq. Dist.   Inertia  % Inertia
# 0      Dim.1     1.0   0.298450  0.298450  88.617142
# 1      Dim.2     1.0   0.005241  0.005241   1.556038
# 2      Dim.3     1.0   0.009087  0.009087   2.698182
# 3      Dim.4     1.0   0.010346  0.010346   3.072006
# 4      Dim.5     1.0   0.000275  0.000275   0.081555
# 5      Dim.6     1.0   0.002992  0.002992   0.888273
# 6      Dim.7     1.0   0.002338  0.002338   0.694117
# 7      Dim.8     1.0   0.001780  0.001780   0.528560
# 8      Dim.9     1.0   0.005342  0.005342   1.586114
# 9     Dim.10     1.0   0.000796  0.000796   0.236440
# 10    Dim.11     1.0   0.000140  0.000140   0.041575, _body=<great_tables._gt_data.Body object at 0x0000023E780E5210>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Weight', type=<ColInfoTypeEnum.default: 1>, column_label='Weight', column_align='right', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None), ColInfo(var='Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='Inertia', column_align='right', column_width=None), ColInfo(var='% Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='% Inertia', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E780E5F90>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables additionals informations <br> (weight, sq. dist., inertia)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E780E5660>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInf ...

# %% [markdown]
# ## Supplementary quantitative variables

# %%
#supplementary quantitative variables
quanti_sup = res_mcaiv.quanti_sup_
quanti_sup._fields
# Out:
# ('coord', 'cos2')

# %% [markdown]
# ### Supplementary quantitative variables coordinates

# %%
#supplementary quantitative variables coordinates
print_dt(quanti_sup.coord,rowname="Variables",title=html("<b>Supplementary quantitative variables <br> coordinates</b>"))
# Out:
# GT(_tbl_data=  Variables     Dim.1     Dim.2     Dim.3     Dim.4
# 0       Age -0.014310  0.842828 -0.333027 -0.422526
# 1      Time -0.889134 -0.214524 -0.404249  0.001473, _body=<great_tables._gt_data.Body object at 0x0000023E780E60E0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E780E6E00>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary quantitative variables <br> coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E780E7F10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type= ...

# %% [markdown]
# ### Supplementary quantitative variables squared cosinus (cos2)

# %%
#supplementary quantitative variables squared cosinus (cos2)
print_dt(quanti_sup.cos2,rowname="Variables",title=html("<b>Supplementary quantitative variables <br> squared cosinus (cos2)</b>"))
# Out:
# GT(_tbl_data=  Variables     Dim.1     Dim.2     Dim.3     Dim.4
# 0       Age  0.000205  0.710360  0.110907  0.178528
# 1      Time  0.790560  0.046021  0.163418  0.000002, _body=<great_tables._gt_data.Body object at 0x0000023E781001F0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E780E70D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary quantitative variables <br> squared cosinus (cos2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78101150>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='head ...

# %% [markdown]
# ## Supplementary qualitative variables/categories

# %%
#supplementary qualitative variables informations
quali_sup = res_mcaiv.quali_sup_
quali_sup._fields
# Out:
# ('barycentre', 'coord', 'cos2', 'vtest', 'dist2', 'eta2')

# %% [markdown]
# ### Supplementary variables/categories coordinates

# %%
#supplementary variables/categories coordinates
print_dt(quali_sup.coord,rowname="Categories",title=html("<b>Supplementary variables/categories <br> coordinates</b>"))
# Out:
# GT(_tbl_data=    Categories     Dim.1     Dim.2     Dim.3     Dim.4
# 0     Nausea_n  0.102031  0.005055 -0.003261 -0.001027
# 1     Nausea_y -0.365610 -0.018112  0.011685  0.003680
# 2      Vomit_n  0.242722  0.001735 -0.019458 -0.001965
# 3      Vomit_y -0.364084 -0.002602  0.029186  0.002947
# 4       Abdo_n  0.756437  0.004790 -0.000623  0.002461
# 5       Abdo_y -0.367996 -0.002330  0.000303 -0.001197
# 6      Fever_n  0.644622  0.001844  0.003354  0.002922
# 7      Fever_y -0.368356 -0.001054 -0.001916 -0.001670
# 8   Diarrhea_n  0.643649 -0.008945 -0.004464 -0.001902
# 9   Diarrhea_y -0.367799  0.005112  0.002551  0.001087
# 10    Potato_n -0.361806 -0.024418  0.026199  0.024963
# 11    Potato_y  0.020873  0.001409 -0.001511 -0.001440
# 12      Fish_n -0.376589  0.378410  0.039197  0.004950
# 13      Fish_y  0.006974 -0.007008 -0.000726 -0.000092
# 14      Mayo_n  0.588127  0.015549  0.031864  0.003258
# 15      Mayo_y -0.130695 -0.003455 -0.007081 -0.000724
# 16     Courg_n -0.128845  0.026227  0.024753 -0.012445
# 17     Courg_y  0.012884 -0.002623 -0.002475  0.001244
# 18    Cheese_n  0.489120 -0.009315  0.051363  0.000178
# 19    Cheese_y -0.071330  0.001358 -0.007490 -0.000026
# 20  Icecream_n  0.241722 -0.028074  0.117273 -0.012390
# 21  Icecream_y -0.018959  0.002202 -0.009198  0.000972
# 22      Sick_n  0.821902  0.001648 -0.004983 -0.000637
# 23      Sick_y -0.367693 -0.000737  0.002229  0.000285
# 24           F  0.014972 -0.041973  0.022562 -0.047948
# 25           M -0.015526  0.043527 -0.023398  0.049724, _body=<great_tables._gt_data.Body object at 0x0000023E78100C70>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E78100C10>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary variables/categories <br> coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78101E40>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', ty ...

# %% [markdown]
# ### Supplementary variables/categories squared cosinus (cos2)

# %%
#supplementary variables/categories squared cosinus (cos2)
print_dt(quali_sup.cos2,rowname="Categories",title=html("<b>Supplementary variables/categories <br> squared cosinus (cos2)</b>"))
# Out:
# GT(_tbl_data=    Categories     Dim.1     Dim.2     Dim.3     Dim.4
# 0     Nausea_n  0.996436  0.002445  0.001018  0.000101
# 1     Nausea_y  0.996436  0.002445  0.001018  0.000101
# 2      Vomit_n  0.993500  0.000051  0.006385  0.000065
# 3      Vomit_y  0.993500  0.000051  0.006385  0.000065
# 4       Abdo_n  0.999949  0.000040  0.000001  0.000011
# 5       Abdo_y  0.999949  0.000040  0.000001  0.000011
# 6      Fever_n  0.999944  0.000008  0.000027  0.000021
# 7      Fever_y  0.999944  0.000008  0.000027  0.000021
# 8   Diarrhea_n  0.999750  0.000193  0.000048  0.000009
# 9   Diarrhea_y  0.999750  0.000193  0.000048  0.000009
# 10    Potato_n  0.985650  0.004490  0.005168  0.004692
# 11    Potato_y  0.985650  0.004490  0.005168  0.004692
# 12      Fish_n  0.494878  0.499675  0.005361  0.000085
# 13      Fish_y  0.494878  0.499675  0.005361  0.000085
# 14      Mayo_n  0.996348  0.000696  0.002925  0.000031
# 15      Mayo_y  0.996348  0.000696  0.002925  0.000031
# 16     Courg_n  0.919395  0.038094  0.033934  0.008577
# 17     Courg_y  0.919395  0.038094  0.033934  0.008577
# 18    Cheese_n  0.988738  0.000359  0.010903  0.000000
# 19    Cheese_y  0.988738  0.000359  0.010903  0.000000
# 20  Icecream_n  0.799046  0.010779  0.188076  0.002099
# 21  Icecream_y  0.799046  0.010779  0.188076  0.002099
# 22      Sick_n  0.999959  0.000004  0.000037  0.000001
# 23      Sick_y  0.999959  0.000004  0.000037  0.000001
# 24           F  0.046757  0.367486  0.106189  0.479568
# 25           M  0.046757  0.367486  0.106189  0.479568, _body=<great_tables._gt_data.Body object at 0x0000023E78103F40>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E78103AF0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary variables/categories <br> squared cosinus (cos2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78211120>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='h ...

# %% [markdown]
# ### Supplementary variables/categories squared distance to origin (dist2)

# %%
#supplementary variables/categories squared distance to origin (dist2)
print_dt(quali_sup.dist2,rowname="Categories",title=html("<b>Supplementary variables/categories <br> squared distance <br> to origin (dist2)</b>"))
# Out:
# GT(_tbl_data=    Categories  Sq. Dist.
# 0     Nausea_n   0.010447
# 1     Nausea_y   0.134149
# 2      Vomit_n   0.059300
# 3      Vomit_y   0.133424
# 4       Abdo_n   0.572226
# 5       Abdo_y   0.135428
# 6      Fever_n   0.415561
# 7      Fever_y   0.135693
# 8   Diarrhea_n   0.414387
# 9   Diarrhea_y   0.135310
# 10    Potato_n   0.132809
# 11    Potato_y   0.000442
# 12      Fish_n   0.286575
# 13      Fish_y   0.000098
# 14      Mayo_n   0.347161
# 15      Mayo_y   0.017144
# 16     Courg_n   0.018056
# 17     Courg_y   0.000181
# 18    Cheese_n   0.241963
# 19    Cheese_y   0.005146
# 20  Icecream_n   0.073124
# 21  Icecream_y   0.000450
# 22      Sick_n   0.675550
# 23      Sick_y   0.135204
# 24           F   0.004794
# 25           M   0.005156, _body=<great_tables._gt_data.Body object at 0x0000023E782132E0>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E780E4F70>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary variables/categories <br> squared distance <br> to origin (dist2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78211EA0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=Option ...

# %% [markdown]
# ### Supplementary variables/categories value-test (vtest)

# %%
#supplementary variables/categories value-test (vtest)
print_dt(quali_sup.vtest,rowname="Categories",title=html("<b>Supplementary variables/categories <br> value-test (vtest)</b>"))
# Out:
# GT(_tbl_data=    Categories     Dim.1     Dim.2     Dim.3     Dim.4
# 0     Nausea_n  2.580635  0.545413 -0.371610 -0.270372
# 1     Nausea_y -2.580635 -0.545413  0.371610  0.270372
# 2      Vomit_n  3.971987  0.121124 -1.434595 -0.334599
# 3      Vomit_y -3.971987 -0.121124  1.434595  0.334599
# 4       Abdo_n  7.049534  0.190434 -0.026165  0.238694
# 5       Abdo_y -7.049534 -0.190434  0.026165 -0.238694
# 6      Fever_n  6.510867  0.079478  0.152617  0.307215
# 7      Fever_y -6.510867 -0.079478 -0.152617 -0.307215
# 8   Diarrhea_n  6.501034 -0.385452 -0.203143 -0.199972
# 9   Diarrhea_y -6.501034  0.385452  0.203143  0.199972
# 10    Potato_n -1.161147 -0.334326  0.378826  0.833837
# 11    Potato_y  1.161147  0.334326 -0.378826 -0.833837
# 12      Fish_n -0.684737  2.935372  0.321111  0.093669
# 13      Fish_y  0.684737 -2.935372 -0.321111 -0.093669
# 14      Mayo_n  3.704393  0.417837  0.904235  0.213569
# 15      Mayo_y -3.704393 -0.417837 -0.904235 -0.213569
# 16     Courg_n -0.544401  0.472760  0.471224 -0.547287
# 17     Courg_y  0.544401 -0.472760 -0.471224  0.547287
# 18    Cheese_n  2.495722 -0.202763  1.180785  0.009460
# 19    Cheese_y -2.495722  0.202763 -1.180785 -0.009460
# 20  Icecream_n  0.904511 -0.448181  1.977131 -0.482567
# 21  Icecream_y -0.904511  0.448181 -1.977131  0.482567
# 22      Sick_n  7.345222  0.062839 -0.200641 -0.059270
# 23      Sick_y -7.345222 -0.062839  0.200641  0.059270
# 24           F  0.203712 -2.436465  1.383172 -6.790359
# 25           M -0.203712  2.436465 -1.383172  6.790359, _body=<great_tables._gt_data.Body object at 0x0000023E78213CA0>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E78211CC0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary variables/categories <br> value-test (vtest)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78211D20>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='headi ...

# %% [markdown]
# ### Squared correlation ratio

# %%
#supplementary qualitative variables squared correlation ratio (eta2)
print_dt(quali_sup.eta2,rowname="Categories",title=html("<b>Supplementary qualitative variables <br> squared correlation ratio (eta2)</b>"))
# Out:
# GT(_tbl_data=    Categories     Dim.1     Dim.2     Dim.3     Dim.4
# 0       Nausea  0.123327  0.005509  0.002557  0.001354
# 1     Vomiting  0.292161  0.000272  0.038112  0.002073
# 2   Abdominals  0.920295  0.000672  0.000013  0.001055
# 3        Fever  0.785026  0.000117  0.000431  0.001748
# 4     Diarrhae  0.782656  0.002751  0.000764  0.000741
# 5       Potato  0.024968  0.002070  0.002658  0.012876
# 6         Fish  0.008683  0.159563  0.001909  0.000162
# 7         Mayo  0.254121  0.003233  0.015141  0.000845
# 8    Courgette  0.005488  0.004139  0.004112  0.005547
# 9       Cheese  0.115345  0.000761  0.025820  0.000002
# 10    Icecream  0.015151  0.003720  0.072390  0.004312
# 11        Sick  0.999116  0.000073  0.000745  0.000065
# 12         Sex  0.000768  0.109933  0.035429  0.853870, _body=<great_tables._gt_data.Body object at 0x0000023E78222320>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E78223370>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Supplementary qualitative variables <br> squared correlation ratio (eta2)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78220460>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True,  ...

# %% [markdown]
# # Descriptive statistiques

# %%
#descriptive statistics for quantitative variables
print_dt(res_mcaiv.summary_quanti_,rowname="",title=html("<b>Descriptive statistics of quantitative variables</b>"))
# Out:
# GT(_tbl_data=     variable  count       mean        std  min  25%   50%   75%   max
# 0  0      Age     55  16.927273  23.779741  4.0  6.0   8.0  10.0  88.0
# 1  1     Time     55  10.163636   7.800199  0.0  0.0  12.0  16.5  22.0, _body=<great_tables._gt_data.Body object at 0x0000023E78221E70>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable', type=<ColInfoTypeEnum.default: 1>, column_label='variable', column_align='left', column_width=None), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='right', column_width=None), ColInfo(var='mean', type=<ColInfoTypeEnum.default: 1>, column_label='mean', column_align='right', column_width=None), ColInfo(var='std', type=<ColInfoTypeEnum.default: 1>, column_label='std', column_align='right', column_width=None), ColInfo(var='min', type=<ColInfoTypeEnum.default: 1>, column_label='min', column_align='right', column_width=None), ColInfo(var='25%', type=<ColInfoTypeEnum.default: 1>, column_label='25%', column_align='right', column_width=None), ColInfo(var='50%', type=<ColInfoTypeEnum.default: 1>, column_label='50%', column_align='right', column_width=None), ColInfo(var='75%', type=<ColInfoTypeEnum.default: 1>, column_label='75%', column_align='right', column_width=None), ColInfo(var='max', type=<ColInfoTypeEnum.default: 1>, column_label='max', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E782214E0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Descriptive statistics of quantitative variables</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78221BA0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, cate ...

# %%
#summary_quali
print_dt(res_mcaiv.summary_quali_,rowname="",title=html("<b>Descriptive statistics of <br> qualitative variables</b>"))
# Out:
# GT(_tbl_data=          variable   categorie  count  proportion
# 0    0        Sick      Sick_y     38    0.690909
# 1    1        Sick      Sick_n     17    0.309091
# 2    2         Sex           F     28    0.509091
# 3    3         Sex           M     27    0.490909
# 4    4      Nausea    Nausea_n     43    0.781818
# 5    5      Nausea    Nausea_y     12    0.218182
# 6    6    Vomiting     Vomit_n     33    0.600000
# 7    7    Vomiting     Vomit_y     22    0.400000
# 8    8  Abdominals      Abdo_y     37    0.672727
# 9    9  Abdominals      Abdo_n     18    0.327273
# 10  10       Fever     Fever_y     35    0.636364
# 11  11       Fever     Fever_n     20    0.363636
# 12  12    Diarrhae  Diarrhea_y     35    0.636364
# 13  13    Diarrhae  Diarrhea_n     20    0.363636
# 14  14      Potato    Potato_y     52    0.945455
# 15  15      Potato    Potato_n      3    0.054545
# 16  16        Fish      Fish_y     54    0.981818
# 17  17        Fish      Fish_n      1    0.018182
# 18  18        Mayo      Mayo_y     45    0.818182
# 19  19        Mayo      Mayo_n     10    0.181818
# 20  20   Courgette     Courg_y     50    0.909091
# 21  21   Courgette     Courg_n      5    0.090909
# 22  22      Cheese    Cheese_y     48    0.872727
# 23  23      Cheese    Cheese_n      7    0.127273
# 24  24    Icecream  Icecream_y     51    0.927273
# 25  25    Icecream  Icecream_n      4    0.072727, _body=<great_tables._gt_data.Body object at 0x0000023E78081FF0>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable', type=<ColInfoTypeEnum.default: 1>, column_label='variable', column_align='left', column_width=None), ColInfo(var='categorie', type=<ColInfoTypeEnum.default: 1>, column_label='categorie', column_align='left', column_width=None), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='right', column_width=None), ColInfo(var='proportion', type=<ColInfoTypeEnum.default: 1>, column_label='proportion', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x0000023E5601DDE0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Descriptive statistics of <br> qualitative variables</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x0000023E78082470>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', typ ...

# %% [markdown]
# # Extractions

# %%
#extract functions
from scientisttools import get_eig, get_mcaiv, summaryMCAIV
eig = get_eig(res_mcaiv)
ind, var = get_mcaiv(res_mcaiv,"ind"), get_mcaiv(res_mcaiv,"var")
summaryMCAIV(res_mcaiv)
# Out:
#          Multiple Correspondence Analysis with Instrumental Variables - Results
#
# Eigenvalues
#                        Dim.1   Dim.2   Dim.3    Dim.4
# Variance               0.302   0.017   0.015    0.003
# Difference             0.286   0.002   0.012      NaN
# % of var.             89.812   4.935   4.424    0.829
# Cumulative % of var.  89.812  94.747  99.171  100.000
#
# Individuals (the 10 first)
#
#     Weight  Sq. Dist.  Inertia  % Inertia  Dim.1    ctr   cos2  Dim.2     ctr  \
# 1    0.018      0.219    0.004      1.183 -0.387  0.902  0.685 -0.185   3.735
# 2    0.018      0.699    0.013      3.776  0.829  4.126  0.981 -0.100   1.087
# 3    0.018      0.149    0.003      0.805 -0.366  0.805  0.898 -0.117   1.489
# 4    0.018      0.692    0.013      3.738  0.827  4.107  0.987 -0.081   0.724
# 5    0.018      0.134    0.002      0.725 -0.361  0.784  0.971  0.013   0.017
# 6    0.018      0.287    0.005      1.547 -0.377  0.852  0.495  0.378  15.666
# 7    0.018      0.150    0.003      0.809 -0.365  0.803  0.891 -0.121   1.609
# 8    0.018      0.178    0.003      0.962 -0.341  0.700  0.654  0.011   0.013
# 9    0.018      0.179    0.003      0.966 -0.380  0.869  0.808 -0.078   0.672
# 10   0.018      0.139    0.003      0.750 -0.356  0.764  0.915  0.058   0.371
#
#      cos2  Dim.3    ctr   cos2
# 1   0.156 -0.181  3.991  0.149
# 2   0.014  0.042  0.219  0.003
# 3   0.091  0.009  0.010  0.001
# 4   0.010  0.034  0.142  0.002
# 5   0.001  0.021  0.052  0.003
# 6   0.500  0.039  0.187  0.005
# 7   0.098  0.011  0.015  0.001
# 8   0.001  0.245  7.351  0.338
# 9   0.034 -0.159  3.080  0.141
# 10  0.024  0.073  0.659  0.039
#
# Variables (the 10 first)
#
#         Dim.1     ctr   cos2  Dim.2     ctr   cos2  Dim.3     ctr   cos2
# Dim.1   0.546  98.664  1.000  0.002   0.023  0.000  0.004   0.087  0.000
# Dim.2  -0.012   0.051  0.030 -0.002   0.015  0.000  0.063  26.389  0.750
# Dim.3   0.010   0.033  0.011 -0.074  32.619  0.597  0.059  23.634  0.388
# Dim.4  -0.025   0.208  0.061  0.087  45.973  0.738  0.044  13.177  0.190
# Dim.5  -0.011   0.037  0.412  0.010   0.544  0.329 -0.001   0.003  0.002
# Dim.6   0.029   0.287  0.290  0.040   9.477  0.526 -0.023   3.671  0.183
# Dim.7   0.043   0.620  0.803  0.016   1.576  0.112  0.014   1.336  0.085
# Dim.8   0.002   0.001  0.002  0.035   7.330  0.684  0.013   1.059  0.089
# Dim.9  -0.011   0.039  0.022  0.009   0.543  0.017  0.066  29.559  0.825
# Dim.10  0.011   0.042  0.160  0.016   1.554  0.324  0.012   0.951  0.178
#
# Supplementary continuous variables
#
#       Dim.1   cos2  Dim.2   cos2  Dim.3   cos2
# Age  -0.014  0.000  0.843  0.710 -0.333  0.111
# Time -0.889  0.791 -0.215  0.046 -0.404  0.163
#
# Supplementary categories (the 10 first)
#
#             Sq. Dist.  Dim.1   cos2  vtest  Dim.2   cos2  vtest  Dim.3   cos2  \
# Nausea_n        0.010  0.102  0.996  2.581  0.005  0.002  0.545 -0.003  0.001
# Nausea_y        0.134 -0.366  0.996 -2.581 -0.018  0.002 -0.545  0.012  0.001
# Vomit_n         0.059  0.243  0.993  3.972  0.002  0.000  0.121 -0.019  0.006
# Vomit_y         0.133 -0.364  0.993 -3.972 -0.003  0.000 -0.121  0.029  0.006
# Abdo_n          0.572  0.756  1.000  7.050  0.005  0.000  0.190 -0.001  0.000
# Abdo_y          0.135 -0.368  1.000 -7.050 -0.002  0.000 -0.190  0.000  0.000
# Fever_n         0.416  0.645  1.000  6.511  0.002  0.000  0.079  0.003  0.000
# Fever_y         0.136 -0.368  1.000 -6.511 -0.001  0.000 -0.079 -0.002  0.000
# Diarrhea_n      0.414  0.644  1.000  6.501 -0.009  0.000 -0.385 -0.004  0.000
# Diarrhea_y      0.135 -0.368  1.000 -6.501  0.005  0.000  0.385  0.003  0.000
#
#             vtest
# Nausea_n   -0.372
# Nausea_y    0.372
# Vomit_n    -1.435
# Vomit_y     1.435
# Abdo_n     -0.026
# Abdo_y      0.026
# Fever_n     0.153
# Fever_y    -0.153
# Diarrhea_n -0.203
# Diarrhea_y  0.203
#
# Supplementary categorical variable (eta2) (the 10 first)
#
#             Dim.1  Dim.2  Dim.3
# Nausea      0.123  0.006  0.003
# Vomiting    0.292  0.000  0.038
# Abdominals  0.920  0.001  0.000
# Fever       0.785  0.000  0.000
# Diarrhae    0.783  0.003  0.001
# Potato      0.025  0.002  0.003
# Fish        0.009  0.160  0.002
# Mayo        0.254  0.003  0.015
# Courgette   0.005  0.004  0.004
# Cheese      0.115  0.001  0.026
