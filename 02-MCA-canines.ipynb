# %% [markdown]
# # MCA - `canines` Dataset

# %%
#disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=4):
    dt = (GT(data=data.round(decimals=digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %% [markdown]
# ## `canines` dataset

# %%
#canines dataset
from scientisttools.datasets import canines
(
    GT(canines.rename_axis("Individuals").reset_index())
    .tab_header(title=html("<b>Canines Dataset</b>"))
    .tab_spanner(label=html("<b>Individuals</b>"),columns="Individuals")
    .tab_spanner(label=html("<b>Active <br>variables</b>"),columns=canines.columns.tolist()[:6])
    .tab_spanner(label=html("<b>Supp. <br>variables</b>"),columns=canines.columns.tolist()[6:])
)
# Out:
# GT(_tbl_data=       Individuals    Taille    Poids Velocite Intelligence Affection  \
# 0        Beauceron  Taille++   Poids+  Veloc++      Intell+    Affec+
# 1           Basset   Taille-   Poids-   Veloc-      Intell-    Affec-
# 2       Berger All  Taille++   Poids+  Veloc++     Intell++    Affec+
# 3            Boxer   Taille+   Poids+   Veloc+      Intell+    Affec+
# 4         Bull-Dog   Taille-   Poids-   Veloc-      Intell+    Affec+
# 5      Bull-Mastif  Taille++  Poids++   Veloc-     Intell++    Affec-
# 6          Caniche   Taille-   Poids-   Veloc+     Intell++    Affec+
# 7        Chihuahua   Taille-   Poids-   Veloc-      Intell-    Affec+
# 8           Cocker   Taille+   Poids-   Veloc-      Intell+    Affec+
# 9           Colley  Taille++   Poids+  Veloc++      Intell+    Affec+
# 10       Dalmatien   Taille+   Poids+   Veloc+      Intell+    Affec+
# 11        Doberman  Taille++   Poids+  Veloc++     Intell++    Affec-
# ...

# %% [markdown]
# ## Instanciation and training

# %%
#instanciation & training
from scientisttools import MCA
res_mca = MCA(ind_sup=(27,28,29,30,31,32),sup_var=(6,7))

# %% [markdown]
# ### `fit` function

# %%
#fit function
res_mca.fit(canines)
# Out:
# MCA(ind_sup=(27, 28, 29, 30, 31, 32), sup_var=(6, 7))

# %% [markdown]
# ### `fit_transform` function

# %%
#fit_transform function
print_dt(res_mca.fit_transform(canines),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0        Beauceron -0.3172 -0.4177 -0.1015 -0.2114 -0.1185
# 1           Basset  0.2541  1.1012 -0.1907  0.2926 -0.5240
# 2       Berger All -0.4864 -0.4644 -0.4981  0.5774  0.2759
# 3            Boxer  0.4474 -0.8818  0.6920  0.2600 -0.4556
# 4         Bull-Dog  1.0134  0.5499 -0.1634 -0.3499  0.3308
# 5      Bull-Mastif -0.7526  0.5469  0.4976  0.6552  0.7219
# 6          Caniche  0.9123 -0.0162 -0.5766  0.6281  0.4340
# 7        Chihuahua  0.8408  0.8439 -0.4699 -0.0863 -0.1773
# 8           Cocker  0.7333  0.0791  0.6622  0.1897 -0.1046
# 9           Colley -0.1173 -0.5261 -0.3349 -0.6578  0.1921
# 10       Dalmatien  0.6472 -0.9902  0.4586 -0.1863 -0.1450
# 11        Doberman -0.8732 -0.3155 -0.4523  0.5101  0.2399
# 12       Dogue All -1.0470  0.5070  0.1650  0.0629 -0.3165
# 13    Epag. Breton  0.4780 -1.0369  0.0619  0.6025  0.2495
# 14  Epag. Français -0.1449 -0.5158  0.1171 -0.4689  0.0008
# ...

# %% [markdown]
# ### `inverse_transform` function

# %%
#inverse_transform function
print_dt(res_mca.inverse_transform(res_mca.ind_.coord),rowname="Chiens",title=html("<b>Canines dataset (active columns)</b>"))
# Out:
# GT(_tbl_data=            Chiens  Taille+  Taille++  Taille-  Poids+  Poids++  Poids-  \
# 0        Beauceron        0         1        0       1        0       0
# 1           Basset        0         0        1       0        0       1
# 2       Berger All        0         1        0       1        0       0
# 3            Boxer        1         0        0       1        0       0
# 4         Bull-Dog        0         0        1       0        0       1
# 5      Bull-Mastif        0         1        0       0        1       0
# 6          Caniche        0         0        1       0        0       1
# 7        Chihuahua        0         0        1       0        0       1
# 8           Cocker        1         0        1       0        0       1
# 9           Colley        0         1        0       1        0       0
# 10       Dalmatien        1         0        0       1        0       0
# 11        Doberman        0         1        0       1        0       0
# ...

# %% [markdown]
# ### `transform` function

# %%
#transform function
print_dt(res_mca.transform(res_mca.call_.X),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0        Beauceron -0.3172 -0.4177 -0.1015 -0.2114 -0.1185
# 1           Basset  0.2541  1.1012 -0.1907  0.2926 -0.5240
# 2       Berger All -0.4864 -0.4644 -0.4981  0.5774  0.2759
# 3            Boxer  0.4474 -0.8818  0.6920  0.2600 -0.4556
# 4         Bull-Dog  1.0134  0.5499 -0.1634 -0.3499  0.3308
# 5      Bull-Mastif -0.7526  0.5469  0.4976  0.6552  0.7219
# 6          Caniche  0.9123 -0.0162 -0.5766  0.6281  0.4340
# 7        Chihuahua  0.8408  0.8439 -0.4699 -0.0863 -0.1773
# 8           Cocker  0.7333  0.0791  0.6622  0.1897 -0.1046
# 9           Colley -0.1173 -0.5261 -0.3349 -0.6578  0.1921
# 10       Dalmatien  0.6472 -0.9902  0.4586 -0.1863 -0.1450
# 11        Doberman -0.8732 -0.3155 -0.4523  0.5101  0.2399
# 12       Dogue All -1.0470  0.5070  0.1650  0.0629 -0.3165
# 13    Epag. Breton  0.4780 -1.0369  0.0619  0.6025  0.2495
# 14  Epag. Français -0.1449 -0.5158  0.1171 -0.4689  0.0008
# ...

# %% [markdown]
# ## Eigenvalues and eigenvalues correction
#
# ### Eigenvalues

# %%
#eigenvalues
from scientisttools import get_eig
print_dt(get_eig(res_mca),rowname="Dimensions",title=html("<b>Eigen values</b>"))
# Out:
# GT(_tbl_data=  Dimensions  Eigenvalue  Difference  Proportion  Cumulative
# 0      Dim.1      0.4816      0.0969     28.8964     28.8964
# 1      Dim.2      0.3847      0.1738     23.0842     51.9806
# 2      Dim.3      0.2110      0.0534     12.6572     64.6379
# 3      Dim.4      0.1576      0.0074      9.4532     74.0911
# 4      Dim.5      0.1501      0.0268      9.0080     83.0991
# 5      Dim.6      0.1233      0.0418      7.3977     90.4968
# 6      Dim.7      0.0815      0.0358      4.8877     95.3845
# 7      Dim.8      0.0457      0.0221      2.7402     98.1247
# 8      Dim.9      0.0235      0.0158      1.4125     99.5372
# ...

# %% [markdown]
# ### Eigenvalues corrections : Benzecri and Greenacre correction

# %%
#benzecri and Greenacre correction
eig_correction = res_mca.eig_correction_
eig_correction._fields
# Out:
# ('benzecri', 'greenacre')

# %% [markdown]
# #### Benzecri correction

# %%
#Benzecri correction
benzecri = eig_correction.benzecri
print_dt(benzecri,rowname="Dimensions",title=html("<b>Benzecri correction</b>"))
# Out:
# GT(_tbl_data=  Dimensions  eigenvalue  proportion  cumulative
# 0      Dim.1      0.1428     66.7013     66.7013
# 1      Dim.2      0.0685     31.9797     98.6810
# ...

# %% [markdown]
# #### Greenacre correction

# %%
#Greenacre correction
greenacre = eig_correction.greenacre
print_dt(greenacre,rowname="Dimensions",title=html("<b>Greenacre correction</b>"))
# Out:
# GT(_tbl_data=  Dimensions  eigenvalue  proportion  cumulative
# 0      Dim.1      0.1428     54.4505     54.4505
# 1      Dim.2      0.0685     26.1061     80.5567
# ...

# %% [markdown]
# ## Individuals informations

# %%
#individuals informations
from scientisttools import get_mca_ind
ind = get_mca_ind(res_mca)
ind._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Individuals coordinates

# %%
#individuals coordinates
print_dt(ind.coord,rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0        Beauceron -0.3172 -0.4177 -0.1015 -0.2114 -0.1185
# 1           Basset  0.2541  1.1012 -0.1907  0.2926 -0.5240
# 2       Berger All -0.4864 -0.4644 -0.4981  0.5774  0.2759
# 3            Boxer  0.4474 -0.8818  0.6920  0.2600 -0.4556
# 4         Bull-Dog  1.0134  0.5499 -0.1634 -0.3499  0.3308
# 5      Bull-Mastif -0.7526  0.5469  0.4976  0.6552  0.7219
# 6          Caniche  0.9123 -0.0162 -0.5766  0.6281  0.4340
# 7        Chihuahua  0.8408  0.8439 -0.4699 -0.0863 -0.1773
# 8           Cocker  0.7333  0.0791  0.6622  0.1897 -0.1046
# 9           Colley -0.1173 -0.5261 -0.3349 -0.6578  0.1921
# 10       Dalmatien  0.6472 -0.9902  0.4586 -0.1863 -0.1450
# 11        Doberman -0.8732 -0.3155 -0.4523  0.5101  0.2399
# 12       Dogue All -1.0470  0.5070  0.1650  0.0629 -0.3165
# 13    Epag. Breton  0.4780 -1.0369  0.0619  0.6025  0.2495
# 14  Epag. Français -0.1449 -0.5158  0.1171 -0.4689  0.0008
# ...

# %% [markdown]
# ### Individuals contributions

# %%
#individuals contributions
print_dt(ind.contrib,rowname="Individuals",title=html("<b>Individuals contributions</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1    Dim.2    Dim.3    Dim.4    Dim.5
# 0        Beauceron  0.7738   1.6796   0.1808   1.0509   0.3465
# 1           Basset  0.4966  11.6742   0.6385   2.0131   6.7739
# 2       Berger All  1.8194   2.0766   4.3565   7.8379   1.8779
# 3            Boxer  1.5391   7.4850   8.4078   1.5891   5.1205
# 4         Bull-Dog  7.8971   2.9108   0.4689   2.8783   2.6993
# 5      Bull-Mastif  4.3556   2.8794   4.3467  10.0900  12.8579
# 6          Caniche  6.4006   0.0025   5.8365   9.2749   4.6470
# 7        Chihuahua  5.4366   6.8550   3.8775   0.1753   0.7759
# 8           Cocker  4.1353   0.0602   7.6996   0.8463   0.2701
# 9           Colley  0.1059   2.6645   1.9691  10.1703   0.9107
# 10       Dalmatien  3.2216   9.4385   3.6923   0.8160   0.5183
# 11        Doberman  5.8638   0.9581   3.5919   6.1164   1.4195
# 12       Dogue All  8.4305   2.4741   0.4782   0.0930   2.4715
# 13    Epag. Breton  1.7574  10.3508   0.0673   8.5347   1.5352
# ...

# %% [markdown]
# ### Individuals cos2

# %%
#individuals squared cosinus
print_dt(ind.cos2,rowname="Individuals",title=html("<b>Individuals cos2</b>"))
# Out:
# GT(_tbl_data=       Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0        Beauceron  0.0886  0.1537  0.0091  0.0394  0.0124
# 1           Basset  0.0338  0.6349  0.0190  0.0448  0.1437
# 2       Berger All  0.1537  0.1402  0.1612  0.2166  0.0495
# 3            Boxer  0.1113  0.4325  0.2664  0.0376  0.1155
# 4         Bull-Dog  0.6245  0.1839  0.0162  0.0745  0.0665
# 5      Bull-Mastif  0.2707  0.1430  0.1183  0.2051  0.2491
# 6          Caniche  0.3852  0.0001  0.1539  0.1826  0.0872
# 7        Chihuahua  0.3799  0.3827  0.1187  0.0040  0.0169
# 8           Cocker  0.2792  0.0032  0.2277  0.0187  0.0057
# 9           Colley  0.0124  0.2493  0.1010  0.3896  0.0332
# 10       Dalmatien  0.2363  0.5530  0.1186  0.0196  0.0119
# 11        Doberman  0.4876  0.0636  0.1308  0.1664  0.0368
# 12       Dogue All  0.5608  0.1315  0.0139  0.0020  0.0513
# 13    Epag. Breton  0.1050  0.4940  0.0018  0.1668  0.0286
# 14  Epag. Français  0.0175  0.2221  0.0115  0.1836  0.0000
# ...

# %% [markdown]
# ### Individuals additional informations

# %%
#individuals addutionals informations
print_dt(ind.infos,rowname="Individuals",title=html("<b>Individuals additionals informations</b>"))
# Out:
# GT(_tbl_data=       Individuals  Weight  Sq. Dist.  Inertia  % Inertia
# 0        Beauceron   0.037     1.1352   0.0420     2.5226
# 1           Basset   0.037     1.9102   0.0707     4.2448
# 2       Berger All   0.037     1.5390   0.0570     3.4200
# 3            Boxer   0.037     1.7977   0.0666     3.9948
# 4         Bull-Dog   0.037     1.6444   0.0609     3.6542
# 5      Bull-Mastif   0.037     2.0923   0.0775     4.6496
# 6          Caniche   0.037     2.1607   0.0800     4.8016
# 7        Chihuahua   0.037     1.8607   0.0689     4.1349
# 8           Cocker   0.037     1.9262   0.0713     4.2805
# 9           Colley   0.037     1.1104   0.0411     2.4676
# 10       Dalmatien   0.037     1.7729   0.0657     3.9399
# 11        Doberman   0.037     1.5637   0.0579     3.4750
# 12       Dogue All   0.037     1.9548   0.0724     4.3440
# 13    Epag. Breton   0.037     2.1768   0.0806     4.8373
# 14  Epag. Français   0.037     1.1977   0.0444     2.6615
# ...

# %% [markdown]
# ## Variables/levels informations

# %%
#variables/levels informations
from scientisttools import get_mca_var
var = get_mca_var(res_mca)
var._fields
# Out:
# ('coord',
#  'cos2',
#  'contrib',
#  'infos',
#  'coord_n',
#  'vtest',
#  'eta2',
#  'var_inertia',
#  'var_contrib')

# %% [markdown]
# ### Variables coordinates

# %%
#variables coordinates
print_dt(var.coord,rowname="Levels",title=html("<b>Variables coordinates</b>"))
# Out:
# GT(_tbl_data=      Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Taille+  0.8511 -1.2317  1.0161  0.3425 -0.3100
# 1   Taille++ -0.8367 -0.0206 -0.0512 -0.1702  0.1127
# 2    Taille-  1.1850  0.9239 -0.6160  0.1201 -0.0200
# 3     Poids+ -0.3054 -0.8189 -0.2313 -0.1184 -0.1902
# 4    Poids++ -1.0151  0.9739  1.2216  0.0676  0.6145
# 5     Poids-  1.1689  0.8243 -0.3588  0.1649 -0.0512
# 6     Veloc+  0.6037 -0.8878  0.3563  0.3702 -0.3710
# 7    Veloc++ -0.8921 -0.3718 -0.7631 -0.2398 -0.0101
# 8     Veloc-  0.3199  1.0449  0.4017 -0.0803  0.3059
# 9    Intell+  0.3694 -0.2855  0.4932 -0.6035  0.1463
# 10  Intell++ -0.3351 -0.4595 -0.5999  1.2752  1.0632
# 11   Intell- -0.3490  0.8086 -0.3515  0.0242 -1.0351
# 12    Affec+  0.7755 -0.2669 -0.0608  0.0772  0.0403
# 13    Affec- -0.8352  0.2875  0.0655 -0.0832 -0.0434
# 14   Agress+ -0.4315  0.2092  0.3335  0.5512 -0.3745
# ...

# %% [markdown]
# ### Variables normalized coordinates

# %%
#variables normalized coordinates
print_dt(var.coord_n,rowname="Levels",title=html("<b>Variables normalized coordinates</b>"))
# Out:
# GT(_tbl_data=      Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Taille+  0.5906 -0.7640  0.4667  0.1359 -0.1201
# 1   Taille++ -0.5806 -0.0128 -0.0235 -0.0676  0.0437
# 2    Taille-  0.8223  0.5731 -0.2829  0.0477 -0.0077
# 3     Poids+ -0.2119 -0.5079 -0.1062 -0.0470 -0.0737
# 4    Poids++ -0.7045  0.6041  0.5611  0.0268  0.2381
# 5     Poids-  0.8112  0.5113 -0.1648  0.0654 -0.0198
# 6     Veloc+  0.4189 -0.5507  0.1637  0.1470 -0.1438
# 7    Veloc++ -0.6191 -0.2306 -0.3505 -0.0952 -0.0039
# 8     Veloc-  0.2220  0.6481  0.1845 -0.0319  0.1185
# 9    Intell+  0.2564 -0.1771  0.2265 -0.2395  0.0567
# 10  Intell++ -0.2325 -0.2850 -0.2755  0.5062  0.4120
# 11   Intell- -0.2422  0.5015 -0.1614  0.0096 -0.4011
# 12    Affec+  0.5382 -0.1656 -0.0279  0.0306  0.0156
# 13    Affec- -0.5796  0.1783  0.0301 -0.0330 -0.0168
# 14   Agress+ -0.2995  0.1298  0.1532  0.2188 -0.1451
# ...

# %% [markdown]
# ### Variables vtest

# %%
#variables vtest
print_dt(var.vtest,rowname="Levels",title=html("<b>Variables vtest</b>"))
# Out:
# GT(_tbl_data=      Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Taille+  2.0689 -2.9941  2.4699  0.8325 -0.7537
# 1   Taille++ -4.7698 -0.1173 -0.2920 -0.9704  0.6423
# 2    Taille-  3.5746  2.7870 -1.8582  0.3624 -0.0602
# 3     Poids+ -1.6161 -4.3331 -1.2238 -0.6263 -1.0065
# 4    Poids++ -2.4677  2.3674  2.9695  0.1643  1.4938
# 5     Poids-  3.8676  2.7275 -1.1871  0.5455 -0.1695
# 6     Veloc+  1.9974 -2.9375  1.1789  1.2250 -1.2276
# 7    Veloc++ -3.2165 -1.3407 -2.7514 -0.8648 -0.0364
# 8     Veloc-  1.2512  4.0864  1.5711 -0.3142  1.1963
# 9    Intell+  1.8153 -1.4028  2.4234 -2.9653  0.7186
# 10  Intell++ -0.9132 -1.2523 -1.6351  3.4757  2.8978
# 11   Intell- -1.1549  2.6752 -1.1630  0.0802 -3.4247
# 12    Affec+  4.1035 -1.4125 -0.3217  0.4086  0.2134
# 13    Affec- -4.1035  1.4125  0.3217 -0.4086 -0.2134
# 14   Agress+ -2.1204  1.0279  1.6389  2.7081 -1.8399
# ...

# %% [markdown]
# ### Variables contributions

# %%
#variables contributions
print_dt(var.contrib,rowname="Levels",title=html("<b>Variables contributions</b>"))
# Out:
# GT(_tbl_data=      Levels    Dim.1    Dim.2    Dim.3    Dim.4    Dim.5
# 0    Taille+   4.6421  12.1707  15.1042   2.2974   1.9761
# 1   Taille++  13.4585   0.0102   0.1151   1.7029   0.7828
# 2    Taille-  12.5978   9.5866   7.7724   0.3959   0.0115
# 3     Poids+   1.6737  15.0621   2.1911   0.7685   2.0824
# 4    Poids++   6.6040   7.6089  21.8334   0.0895   7.7634
# 5     Poids-  14.0104   8.7222   3.0131   0.8521   0.0863
# 6     Veloc+   3.7369  10.1171   2.9720   4.2966   4.5283
# 7    Veloc++   9.1804   1.9964  15.3352   2.0285   0.0038
# 8     Veloc-   1.3120  17.5174   4.7224   0.2528   3.8476
# 9    Intell+   2.2742   1.7001   9.2532  18.5499   1.1434
# 10  Intell++   0.8634   2.0324   6.3189  38.2293  27.8858
# 11   Intell-   1.2492   8.3913   2.8924   0.0184  35.2396
# 12    Affec+  10.7915   1.6005   0.1514   0.3270   0.0936
# 13    Affec-  11.6216   1.7236   0.1631   0.3522   0.1008
# 14   Agress+   3.1030   0.9128   4.2321  15.4721   7.4950
# ...

# %% [markdown]
# ### Variables cos2

# %%
#variables cos2
print_dt(var.cos2,rowname="Levels",title=html("<b>Variables cos2</b>"))
# Out:
# GT(_tbl_data=      Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0    Taille+  0.1646  0.3448  0.2346  0.0267  0.0218
# 1   Taille++  0.8750  0.0005  0.0033  0.0362  0.0159
# 2    Taille-  0.4914  0.2988  0.1328  0.0051  0.0001
# 3     Poids+  0.1004  0.7221  0.0576  0.0151  0.0390
# 4    Poids++  0.2342  0.2156  0.3392  0.0010  0.0858
# 5     Poids-  0.5753  0.2861  0.0542  0.0114  0.0011
# 6     Veloc+  0.1534  0.3319  0.0535  0.0577  0.0580
# 7    Veloc++  0.3979  0.0691  0.2912  0.0288  0.0001
# 8     Veloc-  0.0602  0.6422  0.0949  0.0038  0.0550
# 9    Intell+  0.1267  0.0757  0.2259  0.3382  0.0199
# 10  Intell++  0.0321  0.0603  0.1028  0.4646  0.3230
# 11   Intell-  0.0513  0.2753  0.0520  0.0002  0.4511
# 12    Affec+  0.6477  0.0767  0.0040  0.0064  0.0018
# 13    Affec-  0.6477  0.0767  0.0040  0.0064  0.0018
# 14   Agress+  0.1729  0.0406  0.1033  0.2821  0.1302
# ...

# %% [markdown]
# ### Variables additionals informations

# %%
#variables additionals informations
print_dt(var.infos,rowname="Levels",title=html("<b>Variables additionals informations</b>"))
# Out:
# GT(_tbl_data=      Levels  Weight  Sq. Dist.  Inertia  % Inertia
# 0    Taille+  0.0309     4.4000   0.1358     8.1481
# 1   Taille++  0.0926     0.8000   0.0741     4.4444
# 2    Taille-  0.0432     2.8571   0.1235     7.4074
# 3     Poids+  0.0864     0.9286   0.0802     4.8148
# 4    Poids++  0.0309     4.4000   0.1358     8.1481
# 5     Poids-  0.0494     2.3750   0.1173     7.0370
# 6     Veloc+  0.0494     2.3750   0.1173     7.0370
# 7    Veloc++  0.0556     2.0000   0.1111     6.6667
# 8     Veloc-  0.0617     1.7000   0.1049     6.2963
# 9    Intell+  0.0802     1.0769   0.0864     5.1852
# 10  Intell++  0.0370     3.5000   0.1296     7.7778
# 11   Intell-  0.0494     2.3750   0.1173     7.0370
# 12    Affec+  0.0864     0.9286   0.0802     4.8148
# 13    Affec-  0.0802     1.0769   0.0864     5.1852
# 14   Agress+  0.0802     1.0769   0.0864     5.1852
# ...

# %% [markdown]
# ### Qualitative variables inertia

# %%
#qualitative variables inertia
print_dt(var.var_inertia,rowname="Variables",title=html("<b>Qualitative variables inertia</b>"))
# Out:
# GT(_tbl_data=      Variables  inertia
# 0        Taille   0.0741
# 1         Poids   0.0741
# 2      Velocite   0.0741
# 3  Intelligence   0.0741
# 4     Affection   0.0370
# ...

# %% [markdown]
# ### Qualitative variables eta2

# %%
#qualitative variables eta2
print_dt(var.eta2,rowname="Variables",title=html("<b>Qualitative variables eta2</b>"))
# Out:
# GT(_tbl_data=      Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0        Taille  0.8871  0.5025  0.2910  0.0416  0.0250
# 1         Poids  0.6440  0.7247  0.3422  0.0162  0.0895
# 2      Velocite  0.4112  0.6840  0.2915  0.0622  0.0755
# 3  Intelligence  0.1268  0.2799  0.2337  0.5369  0.5789
# 4     Affection  0.6477  0.0767  0.0040  0.0064  0.0018
# ...

# %% [markdown]
# ### Qualitative variables contributions

# %%
#qualitative variables contributions
print_dt(var.var_contrib,rowname="Variables",title=html("<b>Qualitative variables contributions</b>"))
# Out:
# GT(_tbl_data=      Variables    Dim.1    Dim.2    Dim.3    Dim.4    Dim.5
# 0        Taille  30.6984  21.7675  22.9918   4.3962   2.7704
# 1         Poids  22.2881  31.3932  27.0377   1.7101   9.9321
# 2      Velocite  14.2293  29.6309  23.0296   6.5779   8.3796
# 3  Intelligence   4.3868  12.1239  18.4645  56.7976  64.2688
# 4     Affection  22.4131   3.3242   0.3145   0.6792   0.1944
# ...

# %% [markdown]
# ## Supplementary elements
#
# ### Supplementary individuals

# %%
#supplementary individuals
ind_sup = res_mca.ind_sup_
ind_sup._fields
# Out:
# ('coord', 'cos2', 'dist2')

# %% [markdown]
# #### Supplementary individuals coordinates

# %%
#supplementary individuals coordinates
print_dt(ind_sup.coord,rowname="Individuals",title=html("<b>Supplementary individuals coordinates</b>"))
# Out:
# GT(_tbl_data=  Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       Medor  0.1773  0.1813  0.3114  0.9113  0.2538
# 1       Djeck  0.0715 -0.1830  0.5985 -0.3235  0.3830
# 2       Taico -0.0009 -0.2107 -0.7031  0.6993  0.2189
# 3       Rocky  0.4747 -0.6962  0.1521  0.0773 -0.6531
# 4      Boudog  0.1356  0.4266 -0.3069 -0.0379 -0.1518
# ...

# %% [markdown]
# ### Supplementary individuals dist2

# %%
#supplementary individuals dist2
print_dt(ind_sup.dist2,rowname="Individuals",title=html("<b>Supplementary individuals dist2</b>"))
# Out:
# GT(_tbl_data=  Individuals  Sq. Dist.
# 0       Medor     2.3548
# 1       Djeck     1.7515
# 2       Taico     1.8819
# 3       Rocky     1.9893
# 4      Boudog     1.7438
# ...

# %% [markdown]
# #### Supplementary individuals cos2

# %%
#supplementary individuals cos2
print_dt(ind_sup.cos2,rowname="Individuals",title=html("<b>Supplementary individuals cos2</b>"))
# Out:
# GT(_tbl_data=  Individuals   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0       Medor  0.0133  0.0140  0.0412  0.3526  0.0273
# 1       Djeck  0.0029  0.0191  0.2045  0.0597  0.0838
# 2       Taico  0.0000  0.0236  0.2627  0.2599  0.0255
# 3       Rocky  0.1133  0.2437  0.0116  0.0030  0.2144
# 4      Boudog  0.0105  0.1044  0.0540  0.0008  0.0132
# ...

# %% [markdown]
# ### Supplementary quantitatives variables

# %%
#supplementary quantitative variables
quanti_sup = res_mca.quanti_sup_
quanti_sup._fields
# Out:
# ('coord', 'cos2')

# %% [markdown]
# #### Supplementary quantitative variables coordinates

# %%
#supplementary quantitative variables coordinates
print_dt(quanti_sup.coord,rowname="Variables",title=html("<b>Supplementary quantitative variables coordinates</b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# ...

# %% [markdown]
# #### Supplementary quantitative variables cos2

# %%
#supplementary quantitative variables cos2
print_dt(quanti_sup.cos2,rowname="Variables",title=html("<b>Supplementary quantitative variables Cos2</b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2  Dim.3   Dim.4   Dim.5
# ...

# %% [markdown]
# ### Supplementary qualitative variables

# %%
#supplementary qualitative variables informations
quali_sup = res_mca.quali_sup_
quali_sup._fields
# Out:
# ('coord', 'cos2', 'vtest', 'dist2', 'eta2')

# %% [markdown]
# #### Supplementary levels coordinates

# %%
#supplementary levels coordinates
print_dt(quali_sup.coord,rowname="Levels",title=html("<b>Supplementary levels coordinates</b>"))
# Out:
# GT(_tbl_data=      Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0     chasse -0.3224 -0.4324 -0.3487 -0.1839 -0.4429
# 1  compagnie  1.0393  0.0953 -0.0679 -0.0890 -0.0111
# ...

# %% [markdown]
# #### Supplementary levels cos2

# %%
#supplementary levels cos2
print_dt(quali_sup.cos2,rowname="Levels",title=html("<b>Supplementary levels Cos2</b>"))
# Out:
# GT(_tbl_data=      Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0     chasse  0.0520  0.0935  0.0608  0.0169  0.0981
# 1  compagnie  0.6354  0.0053  0.0027  0.0047  0.0001
# ...

# %% [markdown]
# #### Supplementary levels dist2

# %%
#supplementary levels dist2
print_dt(quali_sup.dist2,rowname="Levels",title=html("<b>Supplementary levels dist2</b>"))
# Out:
# GT(_tbl_data=      Levels  Sq. Dist.
# 0     chasse      2.000
# 1  compagnie      1.700
# ...

# %% [markdown]
# #### Supplementary levels vtest

# %%
#supplementary levels
print_dt(quali_sup.vtest,rowname="Levels",title=html("<b>Supplementary levels vtest</b>"))
# Out:
# GT(_tbl_data=      Levels   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# 0     chasse -1.1624 -1.5592 -1.2574 -0.6632 -1.5970
# 1  compagnie  4.0646  0.3728 -0.2655 -0.3479 -0.0436
# ...

# %% [markdown]
# ### Supplementary qualitative variables eta2

# %%
#supplementary qualitative variables eta2
print_dt(quali_sup.eta2,rowname="Variables",title=html("<b>Supplementary qualitative variables eta2</b>"))
# Out:
# GT(_tbl_data=  Variables   Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# ...

# %% [markdown]
# ## Summary
#
# ### Frequencies distribution of levels

# %%
#frequencies distribution of levels
print_dt(res_mca.summary_quali_,rowname="",title=html("<b>Frequencies distribution of levels</b>"))
# Out:
# GT(_tbl_data=            variable  categorie  count  proportion
# 0    0        Taille   Taille++     15      0.5556
# 1    1        Taille    Taille-      7      0.2593
# 2    2        Taille    Taille+      5      0.1852
# 3    3         Poids     Poids+     14      0.5185
# 4    4         Poids     Poids-      8      0.2963
# 5    5         Poids    Poids++      5      0.1852
# 6    6      Velocite     Veloc-     10      0.3704
# 7    7      Velocite    Veloc++      9      0.3333
# 8    8      Velocite     Veloc+      8      0.2963
# 9    9  Intelligence    Intell+     13      0.4815
# 10  10  Intelligence    Intell-      8      0.2963
# 11  11  Intelligence   Intell++      6      0.2222
# 12  12     Affection     Affec+     14      0.5185
# 13  13     Affection     Affec-     13      0.4815
# 14  14   Agressivite    Agress-     14      0.5185
# 15  15   Agressivite    Agress+     13      0.4815
# 16  16      Fonction  compagnie     10      0.3704
# ...

# %% [markdown]
# ### Multivariate goodness of fit

# %%
#multivariate goodness of fit
goodness = res_mca.goodness_
goodness._fields
# Out:
# ('association', 'chi2', 'gtest')

# %% [markdown]
# #### Association tests

# %%
#association
print_dt(goodness.association,rowname="",title=html("<b>Association tests</b>"))
# Out:
# GT(_tbl_data=           variable1     variable2  cramer  tschuprow  pearson
# 0    0        Taille         Poids  0.6849     0.6849   0.6957
# 1    1        Taille      Velocite  0.5425     0.5425   0.6087
# 2    2        Taille  Intelligence  0.2585     0.2585   0.3433
# 3    3        Taille     Affection  0.7189     0.6045   0.5837
# 4    4        Taille   Agressivite  0.2756     0.2318   0.2657
# 5    5        Taille      Fonction  0.5503     0.5503   0.6142
# 6    6         Poids      Velocite  0.5848     0.5848   0.6373
# 7    7         Poids  Intelligence  0.1585     0.1585   0.2187
# 8    8         Poids     Affection  0.5924     0.4982   0.5097
# 9    9         Poids   Agressivite  0.3074     0.2585   0.2939
# 10  10         Poids      Fonction  0.6723     0.6723   0.6890
# 11  11      Velocite  Intelligence  0.2418     0.2418   0.3235
# 12  12      Velocite     Affection  0.3315     0.2788   0.3147
# 13  13      Velocite   Agressivite  0.1459     0.1227   0.1444
# ...

# %% [markdown]
# #### Chi-squared test

# %%
#chi2 test
print_dt(goodness.chi2,rowname="",title=html("<b>Association test</b>"))
# Out:
# GT(_tbl_data=           variable1     variable2  statistic  dof   value  pvalue  \
# 0    0        Taille         Poids    25.3286    4  9.4877  0.0000
# 1    1        Taille      Velocite    15.8914    4  9.4877  0.0032
# 2    2        Taille  Intelligence     3.6082    4  9.4877  0.4616
# 3    3        Taille     Affection    13.9535    2  5.9915  0.0009
# 4    4        Taille   Agressivite     2.0515    2  5.9915  0.3585
# 5    5        Taille      Fonction    16.3543    4  9.4877  0.0026
# 6    6         Poids      Velocite    18.4704    4  9.4877  0.0010
# 7    7         Poids  Intelligence     1.3565    4  9.4877  0.8517
# 8    8         Poids     Affection     9.4760    2  5.9915  0.0088
# 9    9         Poids   Agressivite     2.5522    2  5.9915  0.2791
# 10  10         Poids      Fonction    24.4071    4  9.4877  0.0001
# 11  11      Velocite  Intelligence     3.1565    4  9.4877  0.5320
# 12  12      Velocite     Affection     2.9670    2  5.9915  0.2268
# ...

# %% [markdown]
# #### log-likelihood test (g-test)

# %%
#log-likelihood test
print_dt(goodness.gtest,rowname="",title=html("<b>Loglikelihood test (gtest)</b>"))
# Out:
# GT(_tbl_data=           variable1     variable2  statistic  dof   value  pvalue  \
# 0    0        Taille         Poids    30.6167    4  9.4877  0.0000
# 1    1        Taille      Velocite    17.8941    4  9.4877  0.0013
# 2    2        Taille  Intelligence     4.8953    4  9.4877  0.2982
# 3    3        Taille     Affection    16.6392    2  5.9915  0.0002
# 4    4        Taille   Agressivite     2.0967    2  5.9915  0.3505
# 5    5        Taille      Fonction    20.1613    4  9.4877  0.0005
# 6    6         Poids      Velocite    25.9796    4  9.4877  0.0000
# 7    7         Poids  Intelligence     1.4073    4  9.4877  0.8429
# 8    8         Poids     Affection    11.9565    2  5.9915  0.0025
# 9    9         Poids   Agressivite     2.6824    2  5.9915  0.2615
# 10  10         Poids      Fonction    25.6349    4  9.4877  0.0000
# 11  11      Velocite  Intelligence     3.4682    4  9.4877  0.4827
# 12  12      Velocite     Affection     3.0753    2  5.9915  0.2149
# ...

# %% [markdown]
# ### Descriptive statistics of quantitative variables

# %%
#descriptive statistics of quantitative variables
print_dt(res_mca.summary_quanti_,rowname="",title=html("<b>Descriptive statistics of quantitative variables</b>"))
# Out:
# GT(_tbl_data=     variable  count    mean     std  min  25%  50%  75%  max
# ...

# %% [markdown]
# ## Extractions functions

# %%
from scientisttools import get_eig, get_mca
eig = get_eig(res_mca)
ind = get_mca(res_mca,"ind")
var = get_mca(res_mca,"var")

# %% [markdown]
# ### Summary MCA

# %%
from scientisttools import summaryMCA
summaryMCA(res_mca)
# Out:
#                      Multiple Correspondance Analysis - Results
#
# Importance of components
#                           Dim.1   Dim.2   Dim.3   Dim.4   Dim.5   Dim.6  \
# Variance                  0.482   0.385   0.211   0.158   0.150   0.123
# Difference                0.097   0.174   0.053   0.007   0.027   0.042
# % of var.                28.896  23.084  12.657   9.453   9.008   7.398
# Cumulative of % of var.  28.896  51.981  64.638  74.091  83.099  90.497
#
#                           Dim.7   Dim.8   Dim.9   Dim.10
# Variance                  0.081   0.046   0.024    0.008
# Difference                0.036   0.022   0.016      NaN
# % of var.                 4.888   2.740   1.413    0.463
# Cumulative of % of var.  95.385  98.125  99.537  100.000
#
# Individuals (the 10 first)
#
#              Weight  Sq. Dist.  Inertia  % Inertia  Dim.1    ctr   cos2  \
# Beauceron     0.037      1.135    0.042      2.523 -0.317  0.774  0.089
# ...

# %%
summaryMCA(res_mca,to_markdown=True)
# Out:
#                      Multiple Correspondance Analysis - Results
#
# Importance of components
# |                         |   Dim.1 |   Dim.2 |   Dim.3 |   Dim.4 |   Dim.5 |   Dim.6 |   Dim.7 |   Dim.8 |   Dim.9 |   Dim.10 |
# |:------------------------|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|---------:|
# | Variance                |   0.482 |   0.385 |   0.211 |   0.158 |   0.15  |   0.123 |   0.081 |   0.046 |   0.024 |    0.008 |
# | Difference              |   0.097 |   0.174 |   0.053 |   0.007 |   0.027 |   0.042 |   0.036 |   0.022 |   0.016 |  nan     |
# | % of var.               |  28.896 |  23.084 |  12.657 |   9.453 |   9.008 |   7.398 |   4.888 |   2.74  |   1.413 |    0.463 |
# | Cumulative of % of var. |  28.896 |  51.981 |  64.638 |  74.091 |  83.099 |  90.497 |  95.385 |  98.125 |  99.537 |  100     |
#
# Individuals (the 10 first)
#
# ...

# %%
from scientisttools import dimdesc
dimDesc = dimdesc(res_mca)
dimDesc.keys()
# Out:
# dict_keys(['Dim.1', 'Dim.2', 'Dim.3', 'Dim.4', 'Dim.5'])

# %%
dimDesc["Dim.1"]
# Out:
# {'quali':                    R2        pvalue
#  Taille       0.887073  4.300901e-12
#  Fonction     0.694584  6.587193e-07
#  Affection    0.647656  4.184726e-07
#  Poids        0.644046  4.137327e-06
#  Velocite     0.411174  1.737173e-03
#  Agressivite  0.172924  3.098130e-02,
#  'category':                      Estimate        pvalue
#  Taille=Taille+       0.724872  3.574570e-02
#  Taille=Taille++     -1.306428  8.616471e-13
#  Taille=Taille-       1.110151  4.642696e-05
#  Poids=Poids++       -0.864591  1.053636e-02
#  Poids=Poids-         1.152764  4.553328e-06
#  Velocite=Veloc+      0.595344  4.330936e-02
#  Velocite=Veloc++    -0.928647  4.193918e-04
#  Affection=Affec+     1.117754  4.184726e-07
#  Affection=Affec-    -1.117754  4.184726e-07
#  Agressivite=Agress+ -0.577566  3.098130e-02
#  Agressivite=Agress-  0.577566  3.098130e-02
#  Fonction=compagnie   1.145563  6.464827e-07
#  Fonction=utilite    -0.923544  7.740227e-04}

# %%
dimDesc["Dim.2"]
# Out:
# {'quanti':       correlation    pvalue
#  Cote     0.601291  0.000909,
#  'quali':                     R2        pvalue
#  Poids         0.724688  1.896299e-07
#  Velocite      0.684007  9.911136e-07
#  Taille        0.502486  2.299680e-04
#  Intelligence  0.279870  1.945048e-02,
#  'category':                       Estimate        pvalue
#  Taille=Taille+       -0.937638  1.281728e-03
#  Taille=Taille-        0.773641  3.178556e-03
#  Poids=Poids+         -1.054922  2.047241e-08
#  Poids=Poids++         0.741375  1.470012e-02
#  Poids=Poids-          0.726610  4.043759e-03
#  Velocite=Veloc+      -0.782554  1.662406e-03
#  Velocite=Veloc-       1.029371  5.081985e-07
#  Intelligence=Intell-  0.712692  4.960456e-03}

# %%
dimDesc["Dim.3"]
# Out:
# {'quali':                     R2    pvalue
#  Poids         0.342223  0.006561
#  Velocite      0.291491  0.016001
#  Taille        0.291013  0.016131
#  Intelligence  0.233710  0.040994,
#  'category':                       Estimate    pvalue
#  Taille=Taille+        0.572731  0.010456
#  Poids=Poids++         0.688592  0.001437
#  Velocite=Veloc++     -0.525726  0.003676
#  Intelligence=Intell+  0.436873  0.012235}

# %%
dimDesc["Dim.4"]
# Out:
# {'quali':                     R2    pvalue
#  Intelligence  0.536922  0.000097
#  Agressivite   0.282075  0.004365,
#  'category':                        Estimate    pvalue
#  Intelligence=Intell+  -0.461979  0.001465
#  Intelligence=Intell++  0.650810  0.000090
#  Agressivite=Agress+    0.421915  0.004365
#  Agressivite=Agress-   -0.421915  0.004365}

# %% [markdown]
# # Data reconstruction

# %%
#data reconstruction
from scientisttools import reconst
rec = reconst(res_mca,res_mca.call_.n_components)
print_dt(rec,rowname="Individuals",title=html("<b>Canines dataset (active columns)</b>"))
# Out:
# GT(_tbl_data=       Individuals  Taille+  Taille++  Taille-  Poids+  Poids++  Poids-  \
# 0        Beauceron        0         1        0       1        0       0
# 1           Basset        0         0        1       0        0       1
# 2       Berger All        0         1        0       1        0       0
# 3            Boxer        1         0        0       1        0       0
# 4         Bull-Dog        0         0        1       0        0       1
# 5      Bull-Mastif        0         1        0       0        1       0
# 6          Caniche        0         0        1       0        0       1
# 7        Chihuahua        0         0        1       0        0       1
# 8           Cocker        1         0        1       0        0       1
# 9           Colley        0         1        0       1        0       0
# 10       Dalmatien        1         0        0       1        0       0
# 11        Doberman        0         1        0       1        0       0
# ...
