# %% [markdown]
# # Factor Analysis of Mixed Data (FAMD) - `wine` Dataset

# %%
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=6):
    dt = (GT(data=data.round(digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %%
#wine dataset
from scientisttools import wine
(
    GT(wine.rename_axis("Individuals").reset_index())
    .tab_header(title=html("<b>Wine Dataset</b>"))
)
# Out:
# GT(_tbl_data=   Individuals       Label       Soil  Odor.Intensity.before.shaking  \
# 0         2EL       Saumur       Env1                          3.074
# 1         1CHA      Saumur       Env1                          2.964
# 2         1FON  Bourgueuil       Env1                          2.857
# 3         1VAU      Chinon       Env2                          2.808
# 4         1DAM      Saumur  Reference                          3.607
# 5         2BOU  Bourgueuil  Reference                          2.857
# 6         1BOI  Bourgueuil  Reference                          3.214
# 7         3EL       Saumur       Env1                          3.120
# 8         DOM1      Chinon       Env1                          2.857
# 9         1TUR      Saumur       Env2                          2.893
# 10        4EL       Saumur       Env2                          3.250
# 11        PER1      Saumur       Env2                          3.393
# 12        2DAM      Saumur  Reference                          3.179
# 13        1POY      Saumur  Reference                          3.071
# 14        1ING  Bourgueuil       Env1                          3.107
# 15        1BEN  Bourgueuil  Reference                          2.929
# 16        2BEA      Chinon  Reference                          3.036
# 17        1ROC      Chinon       Env2                          3.071
# 18        2ING  Bourgueuil       Env1                          2.643
# 19        T1        Saumur       Env4                          3.696
# 20        T2        Saumur       Env4                          3.708
#
#     Aroma.quality.before.shaking  Fruity.before.shaking  \
# 0                          3.000                  2.714
# 1                          2.821                  2.375
# 2                          2.929                  2.560
# 3                          2.593                  2.417
# 4                          3.429                  3.154
# 5                          3.111                  2.577
# 6                          3.222                  2.962
# 7                          2.852                  2.500
# 8                          2.815                  2.808
# 9                          3.000                  2.571
# 10                         3.286                  2.714
# 11                         3.179                  2.769
# 12                         3.286                  2.778
# 13                         3.107                  2.731
# 14                         3.143                  2.846
# 15                         3.179                  2.852
# 16                         3.179                  3.037
# 17                         2.926                  2.741
# 18                         2.786                  2.536
# 19                         3.192                  2.833
# 20                         2.926                  2.520
#
#     Flower.before.shaking  Spice.before.shaking  Visual.intensity  Nuance  \
# 0                   2.280                 1.960             4.321   4.000
# 1                   2.280                 1.680             3.222   3.000
# 2                   1.960                 2.077             3.536   3.393
# 3                   1.913                 2.160             2.893   2.786
# 4                   2.154                 2.040             4.393   4.036
# 5                   2.040                 2.077             4.464   4.259
# 6                   2.115                 2.040             4.143   3.929
# 7                   2.200                 2.185             4.214   3.857
# 8                   1.923                 2.074             4.037   3.893
# 9                   1.846                 1.680             3.704   3.407
# 10                  1.926                 1.962             3.857   3.643
# 11                  2.038                 1.920             4.714   4.500
# 12                  2.231                 1.760             4.222   4.071
# 13                  2.120                 1.800             4.714   4.536
# 14                  2.185                 1.962             4.071   3.893
# 15                  2.000                 2.037             3.889   3.429
# 16                  2.231                 1.667             3.786   3.607
# 17                  2.000                 1.880             3.679   3.393
# 18                  1.889                 1.808             2.607   2.536
# 19                  1.826                 2.385             4.321   4.000
# 20                  2.040                 2.667             4.321   4.107
#
#     ...  Acidity  Astringency  Alcohol  Balance  Smooth  Bitterness  \
# 0   ...    2.107        2.429    2.500    3.250   2.731       1.926
# 1   ...    2.107        2.179    2.654    2.926   2.500       1.926
# 2   ...    2.179        2.250    2.643    3.321   2.679       2.000
# 3   ...    3.179        2.185    2.500    2.333   1.680       1.963
# 4   ...    2.571        2.536    2.786    3.464   3.036       2.071
# 5   ...    2.393        2.643    2.857    3.286   2.857       2.179
# 6   ...    2.607        2.607    2.778    3.464   2.857       1.929
# 7   ...    2.179        2.630    2.778    3.179   2.786       2.000
# 8   ...    2.286        2.407    2.741    3.143   2.821       1.964
# 9   ...    2.357        2.250    2.704    3.214   2.500       2.185
# 10  ...    2.429        2.571    2.893    3.192   2.857       2.214
# 11  ...    2.429        2.607    2.821    3.107   2.889       2.037
# 12  ...    2.286        2.500    2.821    3.500   3.286       2.000
# 13  ...    2.111        2.536    2.778    3.444   3.231       2.071
# 14  ...    2.286        2.643    2.929    3.286   2.821       2.107
# 15  ...    2.393        2.357    2.704    3.321   3.000       2.000
# 16  ...    2.571        2.321    2.929    3.333   2.821       2.143
# 17  ...    2.393        2.321    2.821    3.143   2.607       2.143
# 18  ...    2.250        1.964    2.250    2.464   1.821       1.679
# 19  ...    2.407        2.643    2.963    2.571   2.071       2.222
# 20  ...    2.571        2.667    2.704    2.769   2.308       2.667
#
#     Intensity  Harmony  Overall.quality  Typical
# 0       2.857    3.143            3.393    3.250
# 1       2.893    2.964            3.214    3.036
# 2       3.074    3.143            3.536    3.179
# 3       2.462    2.038            2.464    2.250
# 4       3.643    3.643            3.741    3.444
# 5       3.464    3.500            3.643    3.393
# 6       3.643    3.556            3.714    3.357
# 7       3.321    3.296            3.393    3.071
# 8       3.148    3.286            3.200    3.500
# 9       2.857    2.963            3.179    2.964
# 10      3.357    3.071            3.571    3.500
# 11      3.250    3.393            3.148    3.556
# 12      3.407    3.643            3.571    3.929
# 13      3.667    3.786            3.929    3.481
# 14      3.321    3.296            3.643    3.296
# 15      3.214    3.214            3.750    3.571
# 16      3.321    3.250            3.536    3.269
# 17      3.037    3.074            3.464    3.444
# 18      2.179    2.107            2.370    2.321
# 19      3.037    2.741            2.643    2.571
# 20      3.333    3.000            2.852    2.750
#
# [21 rows x 32 columns], _body=<great_tables._gt_data.Body object at 0x000001CC24120040>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Label', type=<ColInfoTypeEnum.default: 1>, column_label='Label', column_align='center', column_width=None), ColInfo(var='Soil', type=<ColInfoTypeEnum.default: 1>, column_label='Soil', column_align='center', column_width=None), ColInfo(var='Odor.Intensity.before.shaking', type=<ColInfoTypeEnum.default: 1>, column_label='Odor.Intensity.before.shaking', column_align='right', column_width=None), ColInfo(var='Aroma.quality.before.shaking', type=<ColInfoTypeEnum.default: 1>, column_label='Aroma.quality.before.shaking', column_align='right', column_width=None), ColInfo(var='Fruity.before.shaking', type=<ColInfoTypeEnum.default: 1>, column_label='Fruity.before.shaking', column_align='right', column_width=None), ColInfo(var='Flower.before.shaking', type=<ColInfoTypeEnum.default: 1>, column_label='Flower.before.shaking', column_align='right', column_width=None), ColInfo(var='Spice.before.shaking', type=<ColInfoTypeEnum.default: 1>, column_label='Spice.before.shaking', column_align='right', column_width=None), ColInfo(var='Visual.intensity', type=<ColInfoTypeEnum.default: 1>, column_label='Visual.intensity', column_align='right', column_width=None), ColInfo(var='Nuance', type=<ColInfoTypeEnum.default: 1>, column_label='Nuance', column_align='right', column_width=None), ColInfo(var='Surface.feeling', type=<ColInfoTypeEnum.default: 1>, column_label='Surface.feeling', column_align='right', column_width=None), ColInfo(var='Odor.Intensity', type=<ColInfoTypeEnum.default: 1>, column_label='Odor.Intensity', column_align='right', column_width=None), ColInfo(var='Quality.of.odour', type=<ColInfoTypeEnum.default: 1>, column_label='Quality.of.odour', column_align='right', column_width=None), ColInfo(var='Fruity', type=<ColInfoTypeEnum.default: 1>, column_label='Fruity', column_align='right', column_width=None), ColInfo(var='Flower', type=<ColInfoTypeEnum.default: 1>, column_label='Flower', column_align='right', column_width=None), ColInfo(var='Spice', type=<ColInfoTypeEnum.default: 1>, column_label='Spice', column_align='right', column_width=None), ColInfo(var='Plante', type=<ColInfoTypeEnum.default: 1>, column_label='Plante', column_align='right', column_width=None), ColInfo(var='Phenolic', type=<ColInfoTypeEnum.default: 1>, column_label='Phenolic', column_align='right', column_width=None), ColInfo(var='Aroma.intensity', type=<ColInfoTypeEnum.default: 1>, column_label='Aroma.intensity', column_align='right', column_width=None), ColInfo(var='Aroma.persistency', type=<ColInfoTypeEnum.default: 1>, column_label='Aroma.persistency', column_align='right', column_width=None), ColInfo(var='Aroma.quality', type=<ColInfoTypeEnum.default: 1>, column_label='Aroma.quality', column_align='right', column_width=None), ColInfo(var='Attack.intensity', type=<ColInfoTypeEnum.default: 1>, column_label='Attack.intensity', column_align='right', column_width=None), ColInfo(var='Acidity', type=<ColInfoTypeEnum.default: 1>, column_label='Acidity', column_align='right', column_width=None), ColInfo(var='Astringency', type=<ColInfoTypeEnum.default: 1>, column_label='Astringency', column_align='right', column_width=None), ColInfo(var='Alcohol', type=<ColInfoTypeEnum.default: 1>, column_label='Alcohol', column_align='right', column_width=None), ColInfo(var='Balance', type=<ColInfoTypeEnum.default: 1>, column_label='Balance', column_align='right', column_width=None), ColInfo(var='Smooth', type=<ColInfoTypeEnum.default: 1>, column_label='Smooth', column_align='right', column_width=None), ColInfo(var='Bitterness', type=<ColInfoTypeEnum.default: 1>, column_label='Bitterness', column_align='right', column_width=None), ColInfo(var='Intensity', type=<ColInfoTypeEnum.default: 1>, column_label='Intensity', column_align='right', column_width ...

# %%
from scientisttools import FAMD
res_famd = FAMD()
res_famd.fit(wine)
# Out:
# FAMD()

# %% [markdown]
# ## Others functions
#
# ### `fit_transform`

# %%
#fit_transform
print_dt(res_famd.fit_transform(wine),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=   Individuals      Dim.1     Dim.2     Dim.3     Dim.4     Dim.5
# 0         2EL    0.198477 -1.512808 -2.113443  1.808266 -1.118888
# 1         1CHA  -3.540549 -2.674165 -2.895503  1.916068  0.249935
# 2         1FON  -1.815741 -2.149922 -1.398919 -2.486194  0.119577
# 3         1VAU  -9.499231  1.281334  2.200877  0.760833  2.779669
# 4         1DAM   5.213173  0.059018  0.919782 -0.104890 -0.284949
# 5         2BOU   2.450057 -1.068744 -0.261388 -1.969844  1.155831
# 6         1BOI   3.414361 -0.793806  0.916614 -2.090484  0.915714
# 7         3EL    0.474080  1.524485 -3.484140  1.516153  1.107220
# 8         DOM1   0.106161 -1.041672  0.744694 -0.139086 -0.052508
# 9         1TUR  -2.285563 -0.256804  1.367165  1.696984 -1.458322
# 10        4EL    1.690926  0.917458  1.113086  0.931600 -0.406941
# 11        PER1   2.171458  1.386702  0.884361  0.888758 -1.267405
# 12        2DAM   4.192096 -1.083790 -0.384767  0.997206 -0.330048
# 13        1POY   4.004004 -0.686665 -0.813099 -0.306817 -0.396323
# 14        1ING   2.339847 -0.978930 -0.839113 -1.286382  0.111773
# 15        1BEN   1.054588 -2.331939  0.873186 -1.626735  0.328853
# 16        2BEA   2.877978 -0.980502  2.534460  1.316121  0.752364
# 17        1ROC  -0.674619 -1.065117  1.828929  1.673534  0.815557
# 18        2ING -10.491315 -2.429993 -0.138200 -1.793875 -2.103998
# 19        T1    -1.107265  6.746014  0.804686 -0.891207 -2.417148
# 20        T2    -0.772924  7.139846 -1.859268 -0.810009  1.500038, _body=<great_tables._gt_data.Body object at 0x000001CC2422F7F0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2422D0F0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC263C93C0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, c ...

# %% [markdown]
# ### `transform`

# %%
#transform
print_dt(res_famd.transform(res_famd.call_.X),rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=   Individuals      Dim.1     Dim.2     Dim.3     Dim.4     Dim.5
# 0         2EL    0.198477 -1.512808 -2.113443  1.808266 -1.118888
# 1         1CHA  -3.540549 -2.674165 -2.895503  1.916068  0.249935
# 2         1FON  -1.815741 -2.149922 -1.398919 -2.486194  0.119577
# 3         1VAU  -9.499231  1.281334  2.200877  0.760833  2.779669
# 4         1DAM   5.213173  0.059018  0.919782 -0.104890 -0.284949
# 5         2BOU   2.450057 -1.068744 -0.261388 -1.969844  1.155831
# 6         1BOI   3.414361 -0.793806  0.916614 -2.090484  0.915714
# 7         3EL    0.474080  1.524485 -3.484140  1.516153  1.107220
# 8         DOM1   0.106161 -1.041672  0.744694 -0.139086 -0.052508
# 9         1TUR  -2.285563 -0.256804  1.367165  1.696984 -1.458322
# 10        4EL    1.690926  0.917458  1.113086  0.931600 -0.406941
# 11        PER1   2.171458  1.386702  0.884361  0.888758 -1.267405
# 12        2DAM   4.192096 -1.083790 -0.384767  0.997206 -0.330048
# 13        1POY   4.004004 -0.686665 -0.813099 -0.306817 -0.396323
# 14        1ING   2.339847 -0.978930 -0.839113 -1.286382  0.111773
# 15        1BEN   1.054588 -2.331939  0.873186 -1.626735  0.328853
# 16        2BEA   2.877978 -0.980502  2.534460  1.316121  0.752364
# 17        1ROC  -0.674619 -1.065117  1.828929  1.673534  0.815557
# 18        2ING -10.491315 -2.429993 -0.138200 -1.793875 -2.103998
# 19        T1    -1.107265  6.746014  0.804686 -0.891207 -2.417148
# 20        T2    -0.772924  7.139846 -1.859268 -0.810009  1.500038, _body=<great_tables._gt_data.Body object at 0x000001CC263C9CC0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2420E320>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC24181840>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, c ...

# %% [markdown]
# ## Eigenvalues

# %%
#eigenvalues
from scientisttools import get_eig
print_dt(get_eig(res_famd),rowname="Dimensions",title=html("<b>Eigen values</b>"))
# Out:
# GT(_tbl_data=   Dimensions  Eigenvalue  Difference  Proportion  Cumulative
# 0       Dim.1   15.466717    8.978694   45.490344   45.490344
# 1       Dim.2    6.488023    3.909089   19.082421   64.572764
# 2       Dim.3    2.578934    0.511839    7.585100   72.157865
# 3       Dim.4    2.067096    0.611116    6.079693   78.237558
# 4       Dim.5    1.455980    0.213716    4.282294   82.519852
# 5       Dim.6    1.242263    0.277295    3.653716   86.173567
# 6       Dim.7    0.964969    0.107389    2.838143   89.011711
# 7       Dim.8    0.857580    0.239209    2.522294   91.534005
# 8       Dim.9    0.618371    0.062589    1.818737   93.352742
# 9      Dim.10    0.555781    0.120269    1.634651   94.987393
# 10     Dim.11    0.435512    0.040967    1.280918   96.268311
# 11     Dim.12    0.394546    0.133299    1.160428   97.428739
# 12     Dim.13    0.261246    0.095949    0.768371   98.197110
# 13     Dim.14    0.165297    0.032747    0.486168   98.683279
# 14     Dim.15    0.132550    0.026079    0.389853   99.073132
# 15     Dim.16    0.106471    0.032566    0.313150   99.386282
# 16     Dim.17    0.073905    0.023577    0.217368   99.603650
# 17     Dim.18    0.050329    0.004876    0.148025   99.751675
# 18     Dim.19    0.045453    0.006475    0.133684   99.885360
# 19     Dim.20    0.038978         NaN    0.114640  100.000000, _body=<great_tables._gt_data.Body object at 0x000001CC263A9ED0>, _boxhead=Boxhead([ColInfo(var='Dimensions', type=<ColInfoTypeEnum.default: 1>, column_label='Dimensions', column_align='left', column_width=None), ColInfo(var='Eigenvalue', type=<ColInfoTypeEnum.default: 1>, column_label='Eigenvalue', column_align='right', column_width=None), ColInfo(var='Difference', type=<ColInfoTypeEnum.default: 1>, column_label='Difference', column_align='right', column_width=None), ColInfo(var='Proportion', type=<ColInfoTypeEnum.default: 1>, column_label='Proportion', column_align='right', column_width=None), ColInfo(var='Cumulative', type=<ColInfoTypeEnum.default: 1>, column_label='Cumulative', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2420D900>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Eigen values</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC263ABC10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='head ...

# %% [markdown]
# ## Active elements
#
# ### Individuals informations

# %%
#individuals informations
from scientisttools import get_famd_ind
ind = get_famd_ind(res_famd)
ind._fields
# Out:
# ('coord', 'contrib', 'cos2', 'infos')

# %% [markdown]
# #### Individuals factor coordinates

# %%
#individuals factor coordinates
print_dt(ind.coord,rowname="Individuals",title=html("<b>Individuals coordinates</b>"))
# Out:
# GT(_tbl_data=   Individuals      Dim.1     Dim.2     Dim.3     Dim.4     Dim.5
# 0         2EL    0.198477 -1.512808 -2.113443  1.808266 -1.118888
# 1         1CHA  -3.540549 -2.674165 -2.895503  1.916068  0.249935
# 2         1FON  -1.815741 -2.149922 -1.398919 -2.486194  0.119577
# 3         1VAU  -9.499231  1.281334  2.200877  0.760833  2.779669
# 4         1DAM   5.213173  0.059018  0.919782 -0.104890 -0.284949
# 5         2BOU   2.450057 -1.068744 -0.261388 -1.969844  1.155831
# 6         1BOI   3.414361 -0.793806  0.916614 -2.090484  0.915714
# 7         3EL    0.474080  1.524485 -3.484140  1.516153  1.107220
# 8         DOM1   0.106161 -1.041672  0.744694 -0.139086 -0.052508
# 9         1TUR  -2.285563 -0.256804  1.367165  1.696984 -1.458322
# 10        4EL    1.690926  0.917458  1.113086  0.931600 -0.406941
# 11        PER1   2.171458  1.386702  0.884361  0.888758 -1.267405
# 12        2DAM   4.192096 -1.083790 -0.384767  0.997206 -0.330048
# 13        1POY   4.004004 -0.686665 -0.813099 -0.306817 -0.396323
# 14        1ING   2.339847 -0.978930 -0.839113 -1.286382  0.111773
# 15        1BEN   1.054588 -2.331939  0.873186 -1.626735  0.328853
# 16        2BEA   2.877978 -0.980502  2.534460  1.316121  0.752364
# 17        1ROC  -0.674619 -1.065117  1.828929  1.673534  0.815557
# 18        2ING -10.491315 -2.429993 -0.138200 -1.793875 -2.103998
# 19        T1    -1.107265  6.746014  0.804686 -0.891207 -2.417148
# 20        T2    -0.772924  7.139846 -1.859268 -0.810009  1.500038, _body=<great_tables._gt_data.Body object at 0x000001CC263AACE0>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC263CBDC0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC26359450>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, c ...

# %% [markdown]
# #### Individuals squared cosinus (cos2)

# %%
#individuals squared cosinus
print_dt(ind.cos2,rowname="Individuals",title=html("<b>Individuals Cos2</b>"))
# Out:
# GT(_tbl_data=   Individuals     Dim.1     Dim.2     Dim.3     Dim.4     Dim.5
# 0         2EL   0.002336  0.135699  0.264844  0.193880  0.074230
# 1         1CHA  0.334056  0.190570  0.223422  0.097836  0.001665
# 2         1FON  0.159643  0.223814  0.094760  0.299303  0.000692
# 3         1VAU  0.840821  0.015299  0.045136  0.005394  0.071997
# 4         1DAM  0.752147  0.000096  0.023414  0.000304  0.002247
# 5         2BOU  0.321495  0.061174  0.003659  0.207819  0.071550
# 6         1BOI  0.534901  0.028912  0.038550  0.200515  0.038475
# 7         3EL   0.009194  0.095076  0.496609  0.094039  0.050152
# 8         DOM1  0.000794  0.076483  0.039089  0.001364  0.000194
# 9         1TUR  0.250846  0.003167  0.089756  0.138285  0.102124
# 10        4EL   0.223301  0.065738  0.096761  0.067780  0.012933
# 11        PER1  0.289968  0.118253  0.048096  0.048575  0.098782
# 12        2DAM  0.740627  0.049503  0.006239  0.041909  0.004591
# 13        1POY  0.648266  0.019066  0.026733  0.003806  0.006351
# 14        1ING  0.357732  0.062616  0.046007  0.108124  0.000816
# 15        1BEN  0.073416  0.358969  0.050331  0.174685  0.007139
# 16        2BEA  0.292593  0.033961  0.226914  0.061190  0.019996
# 17        1ROC  0.030652  0.076408  0.225288  0.188631  0.044797
# 18        2ING  0.872121  0.046787  0.000151  0.025498  0.035076
# 19        T1    0.021447  0.796098  0.011327  0.013894  0.102207
# 20        T2    0.009781  0.834600  0.056596  0.010742  0.036839, _body=<great_tables._gt_data.Body object at 0x000001CC263C9900>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC263CA230>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals Cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC7E311C30>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category= ...

# %% [markdown]
# #### Individuals contributions

# %%
#individuals contributions
print_dt(ind.contrib,rowname="Individuals",title=html("<b>Individuals contributions</b>"))
# Out:
# GT(_tbl_data=   Individuals      Dim.1      Dim.2      Dim.3      Dim.4      Dim.5
# 0         2EL    0.012128   1.679717   8.247485   7.532596   4.094478
# 1         1CHA   3.859436   5.248616  15.480627   8.457499   0.204306
# 2         1FON   1.015057   3.392453   3.613477  14.239346   0.046765
# 3         1VAU  27.781744   1.205017   8.944004   1.333517  25.270364
# 4         1DAM   8.367329   0.002556   1.562106   0.025345   0.265558
# 5         2BOU   1.848141   0.838332   0.126158   8.938893   4.369323
# 6         1BOI   3.589231   0.462484   1.551362  10.067315   2.742493
# 7         3EL    0.069197   1.705748  22.414630   5.295488   4.009524
# 8         DOM1   0.003470   0.796398   1.023991   0.044565   0.009017
# 9         1TUR   1.608307   0.048403   3.451295   6.634005   6.955561
# 10        4EL    0.880303   0.617790   2.287694   1.999305   0.541613
# 11        PER1   1.451728   1.411350   1.444108   1.819647   5.253587
# 12        2DAM   5.410594   0.862103   0.273360   2.290814   0.356271
# 13        1POY   4.935960   0.346065   1.220751   0.216860   0.513716
# 14        1ING   1.685611   0.703350   1.300115   3.812062   0.040860
# 15        1BEN   0.342411   3.991192   1.407842   6.096122   0.353695
# 16        2BEA   2.550103   0.705611  11.860732   3.990359   1.851317
# 17        1ROC   0.140120   0.832651   6.176382   6.451923   2.175373
# 18        2ING  33.887725   4.333894   0.035266   7.413178  14.478252
# 19        T1     0.377473  33.401252   1.195620   1.829689  19.108737
# 20        T2     0.183932  37.415019   6.382993   1.511471   7.359191, _body=<great_tables._gt_data.Body object at 0x000001CC263A8A60>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC263A9DE0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC263589A0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=T ...

# %% [markdown]
# #### Individuals additional informations

# %%
#individuals additionals informations
print_dt(ind.infos,rowname="Individuals",title=html("<b>Individuals additionals informations</b>"))
# Out:
# GT(_tbl_data=   Individuals    Weight   Sq. Dist.   Inertia  % Inertia
# 0         2EL   0.047619   16.865194  0.803104   2.362072
# 1         1CHA  0.047619   37.525064  1.786908   5.255611
# 2         1FON  0.047619   20.651821  0.983420   2.892412
# 3         1VAU  0.047619  107.318168  5.110389  15.030556
# 4         1DAM  0.047619   36.132811  1.720610   5.060618
# 5         2BOU  0.047619   18.671433  0.889116   2.615047
# 6         1BOI  0.047619   21.794439  1.037830   3.052442
# 7         3EL   0.047619   24.444244  1.164012   3.423564
# 8         DOM1  0.047619   14.187208  0.675581   1.987004
# 9         1TUR  0.047619   20.824747  0.991655   2.916631
# 10        4EL   0.047619   12.804370  0.609732   1.793329
# 11        PER1  0.047619   16.261202  0.774343   2.277479
# 12        2DAM  0.047619   23.728087  1.129909   3.323261
# 13        1POY  0.047619   24.730679  1.177651   3.463680
# 14        1ING  0.047619   15.304437  0.728783   2.143479
# 15        1BEN  0.047619   15.148764  0.721370   2.121676
# 16        2BEA  0.047619   28.308095  1.348005   3.964719
# 17        1ROC  0.047619   14.847610  0.707029   2.079497
# 18        2ING  0.047619  126.206887  6.009852  17.676035
# 19        T1    0.047619   57.164707  2.722129   8.006262
# 20        T2    0.047619   61.080034  2.908573   8.554627, _body=<great_tables._gt_data.Body object at 0x000001CC263C8910>, _boxhead=Boxhead([ColInfo(var='Individuals', type=<ColInfoTypeEnum.default: 1>, column_label='Individuals', column_align='left', column_width=None), ColInfo(var='Weight', type=<ColInfoTypeEnum.default: 1>, column_label='Weight', column_align='right', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None), ColInfo(var='Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='Inertia', column_align='right', column_width=None), ColInfo(var='% Inertia', type=<ColInfoTypeEnum.default: 1>, column_label='% Inertia', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC263587F0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Individuals additionals informations</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC2420F400>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category=' ...

# %% [markdown]
# #### Individuals distance to origin

# %%
#individuals distance to origin
from numpy import sqrt
sqrt(ind.infos.iloc[:,1])
# Out:
# 2EL      4.106725
# 1CHA     6.125771
# 1FON     4.544427
# 1VAU    10.359448
# 1DAM     6.011057
# 2BOU     4.321045
# 1BOI     4.668451
# 3EL      4.944112
# DOM1     3.766591
# 1TUR     4.563414
# 4EL      3.578319
# PER1     4.032518
# 2DAM     4.871148
# 1POY     4.972995
# 1ING     3.912089
# 1BEN     3.892141
# 2BEA     5.320535
# 1ROC     3.853260
# 2ING    11.234184
# T1       7.560735
# T2       7.815372
# Name: Sq. Dist., dtype: float64

# %% [markdown]
# ### Quantitatives variables informations

# %%
#quantitative variables informations
from scientisttools import get_famd_var
quanti_var = get_famd_var(res_famd,"quanti_var")
quanti_var._fields
# Out:
# ('coord', 'contrib', 'cos2', 'infos')

# %% [markdown]
# #### Quantitatives variables factor coordinates

# %%
#quantitative variables factor coordinates
print_dt(quanti_var.coord,rowname="Variables",title=html("<b>Quantitative variables coordinates</b>"))
# Out:
# GT(_tbl_data=                        Variables     Dim.1     Dim.2     Dim.3     Dim.4  \
# 0   Odor.Intensity.before.shaking  0.472630  0.762627 -0.030667  0.046289
# 1    Aroma.quality.before.shaking  0.813516  0.052852  0.240061 -0.134555
# 2           Fruity.before.shaking  0.681922 -0.048210  0.483720 -0.137372
# 3           Flower.before.shaking  0.477437 -0.303123 -0.480369  0.316597
# 4            Spice.before.shaking -0.055582  0.768472 -0.187539 -0.388203
# 5                Visual.intensity  0.844312  0.336891 -0.143231 -0.019101
# 6                          Nuance  0.825798  0.329670 -0.137063 -0.053002
# 7                 Surface.feeling  0.930044  0.184492  0.047938 -0.002523
# 8                  Odor.Intensity  0.544804  0.685482 -0.176463  0.263008
# 9                Quality.of.odour  0.826498 -0.273865  0.361146  0.145962
# 10                         Fruity  0.746195 -0.217436  0.488855 -0.011038
# 11                         Flower  0.279402 -0.558496 -0.430558  0.261479
# 12                          Spice  0.207070  0.681688 -0.057738 -0.421442
# 13                         Plante -0.602431  0.620399  0.055050  0.347918
# 14                       Phenolic  0.344164  0.404193 -0.073418  0.545531
# 15                Aroma.intensity  0.885003  0.152565  0.044602  0.139494
# 16              Aroma.persistency  0.918552  0.202632 -0.040049  0.067166
# 17                  Aroma.quality  0.811761 -0.480471  0.077137 -0.070977
# 18               Attack.intensity  0.874586  0.094582 -0.101075 -0.069975
# 19                        Acidity -0.223608  0.346200  0.636052 -0.036029
# 20                    Astringency  0.738717  0.528693 -0.160123 -0.124582
# 21                        Alcohol  0.756856  0.298914  0.210657  0.067768
# 22                        Balance  0.856242 -0.436118 -0.056565 -0.000800
# 23                         Smooth  0.902555 -0.339062 -0.106213  0.049268
# 24                     Bitterness  0.308631  0.715620  0.032443  0.025786
# 25                      Intensity  0.939783  0.117616 -0.047087 -0.137527
# 26                        Harmony  0.949400 -0.162581 -0.154749 -0.030258
# 27                Overall.quality  0.837404 -0.431514 -0.070233 -0.049812
# 28                        Typical  0.839954 -0.377760  0.030843  0.099208
#
#        Dim.5
# 0  -0.135668
# 1  -0.311705
# 2  -0.200200
# 3   0.235027
# 4   0.271543
# 5  -0.109080
# 6  -0.095895
# 7  -0.100050
# 8   0.019339
# 9  -0.052540
# 10 -0.224619
# 11  0.469733
# 12  0.150352
# 13 -0.038533
# 14  0.022201
# 15 -0.231021
# 16  0.231101
# 17  0.039964
# 18  0.249638
# 19  0.525425
# 20  0.082658
# 21  0.064871
# 22  0.018978
# 23 -0.010799
# 24  0.223142
# 25  0.195300
# 26  0.022932
# 27  0.152340
# 28 -0.009884  , _body=<great_tables._gt_data.Body object at 0x000001CC241CADD0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2420D750>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Quantitative variables coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC24197B20>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None) ...

# %% [markdown]
# #### Quantitatives variables square cosinus (cos2)

# %%
#quantitative variables square cosinus (cos2)
print_dt(quanti_var.cos2,rowname="Variables",title=html("<b>Quantitative variables Cos2</b>"))
# Out:
# GT(_tbl_data=                        Variables     Dim.1     Dim.2     Dim.3     Dim.4  \
# 0   Odor.Intensity.before.shaking  0.223379  0.581600  0.000940  0.002143
# 1    Aroma.quality.before.shaking  0.661808  0.002793  0.057629  0.018105
# 2           Fruity.before.shaking  0.465017  0.002324  0.233985  0.018871
# 3           Flower.before.shaking  0.227946  0.091884  0.230754  0.100234
# 4            Spice.before.shaking  0.003089  0.590549  0.035171  0.150702
# 5                Visual.intensity  0.712863  0.113496  0.020515  0.000365
# 6                          Nuance  0.681942  0.108682  0.018786  0.002809
# 7                 Surface.feeling  0.864982  0.034037  0.002298  0.000006
# 8                  Odor.Intensity  0.296812  0.469885  0.031139  0.069173
# 9                Quality.of.odour  0.683100  0.075002  0.130427  0.021305
# 10                         Fruity  0.556807  0.047278  0.238979  0.000122
# 11                         Flower  0.078065  0.311918  0.185380  0.068371
# 12                          Spice  0.042878  0.464699  0.003334  0.177614
# 13                         Plante  0.362923  0.384895  0.003030  0.121047
# 14                       Phenolic  0.118449  0.163372  0.005390  0.297604
# 15                Aroma.intensity  0.783231  0.023276  0.001989  0.019459
# 16              Aroma.persistency  0.843737  0.041060  0.001604  0.004511
# 17                  Aroma.quality  0.658955  0.230853  0.005950  0.005038
# 18               Attack.intensity  0.764900  0.008946  0.010216  0.004896
# 19                        Acidity  0.050001  0.119854  0.404562  0.001298
# 20                    Astringency  0.545702  0.279517  0.025639  0.015521
# 21                        Alcohol  0.572831  0.089350  0.044376  0.004593
# 22                        Balance  0.733150  0.190199  0.003200  0.000001
# 23                         Smooth  0.814605  0.114963  0.011281  0.002427
# 24                     Bitterness  0.095253  0.512111  0.001053  0.000665
# 25                      Intensity  0.883192  0.013834  0.002217  0.018914
# 26                        Harmony  0.901361  0.026433  0.023947  0.000916
# 27                Overall.quality  0.701245  0.186204  0.004933  0.002481
# 28                        Typical  0.705523  0.142703  0.000951  0.009842
#
#        Dim.5
# 0   0.018406
# 1   0.097160
# 2   0.040080
# 3   0.055237
# 4   0.073736
# 5   0.011898
# 6   0.009196
# 7   0.010010
# 8   0.000374
# 9   0.002760
# 10  0.050454
# 11  0.220649
# 12  0.022606
# 13  0.001485
# 14  0.000493
# 15  0.053371
# 16  0.053408
# 17  0.001597
# 18  0.062319
# 19  0.276071
# 20  0.006832
# 21  0.004208
# 22  0.000360
# 23  0.000117
# 24  0.049792
# 25  0.038142
# 26  0.000526
# 27  0.023208
# 28  0.000098  , _body=<great_tables._gt_data.Body object at 0x000001CC24196AA0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC24194910>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Quantitative variables Cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC23F97F10>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), headi ...

# %% [markdown]
# #### Quantitatives variables contributions

# %%
#quantitative variables contributions
print_dt(quanti_var.contrib,rowname="Variables",title=html("<b>Quantitative variables contributions</b>"))
# Out:
# GT(_tbl_data=                        Variables     Dim.1     Dim.2      Dim.3      Dim.4  \
# 0   Odor.Intensity.before.shaking  1.444258  8.964209   0.036467   0.103657
# 1    Aroma.quality.before.shaking  4.278914  0.043054   2.234614   0.875875
# 2           Fruity.before.shaking  3.006566  0.035824   9.072953   0.912928
# 3           Flower.before.shaking  1.473785  1.416204   8.947668   4.849010
# 4            Spice.before.shaking  0.019974  9.102144   1.363773   7.290504
# 5                Visual.intensity  4.609012  1.749312   0.795491   0.017650
# 6                          Nuance  4.409093  1.675119   0.728454   0.135901
# 7                 Surface.feeling  5.592537  0.524620   0.089108   0.000308
# 8                  Odor.Intensity  1.919036  7.242345   1.207443   3.346404
# 9                Quality.of.odour  4.416578  1.156007   5.057380   1.030670
# 10                         Fruity  3.600035  0.728701   9.266588   0.005894
# 11                         Flower  0.504731  4.807602   7.188244   3.307603
# 12                          Spice  0.277227  7.162412   0.129264   8.592423
# 13                         Plante  2.346477  5.932398   0.117509   5.855886
# 14                       Phenolic  0.765830  2.518053   0.209010  14.397197
# 15                Aroma.intensity  5.063974  0.358755   0.077138   0.941349
# 16              Aroma.persistency  5.455180  0.632853   0.062193   0.218245
# 17                  Aroma.quality  4.260473  3.558136   0.230718   0.243708
# 18               Attack.intensity  4.945459  0.137880   0.396139   0.236878
# 19                        Acidity  0.323279  1.847316  15.687183   0.062797
# 20                    Astringency  3.528235  4.308194   0.994187   0.750843
# 21                        Alcohol  3.703637  1.377149   1.720726   0.222175
# 22                        Balance  4.740179  2.931537   0.124068   0.000031
# 23                         Smooth  5.266823  1.771932   0.437441   0.117429
# 24                     Bitterness  0.615857  7.893182   0.040812   0.032167
# 25                      Intensity  5.710278  0.213216   0.085975   0.914986
# 26                        Harmony  5.827744  0.407405   0.928570   0.044292
# 27                Overall.quality  4.533899  2.869970   0.191269   0.120034
# 28                        Typical  4.561559  2.199483   0.036886   0.476136
#
#         Dim.5
# 0    1.264149
# 1    6.673161
# 2    2.752777
# 3    3.793836
# 4    5.064339
# 5    0.817205
# 6    0.631595
# 7    0.687509
# 8    0.025687
# 9    0.189597
# 10   3.465262
# 11  15.154681
# 12   1.552617
# 13   0.101979
# 14   0.033851
# 15   3.665621
# 16   3.668176
# 17   0.109694
# 18   4.280227
# 19  18.961196
# 20   0.469261
# 21   0.289033
# 22   0.024738
# 23   0.008010
# 24   3.419838
# 25   2.619681
# 26   0.036117
# 27   1.593944
# 28   0.006710  , _body=<great_tables._gt_data.Body object at 0x000001CC2408C7C0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2408E140>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Quantitative variables contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC2408EF20>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=No ...

# %% [markdown]
# ## Qualitatives variables informations

# %%
#qualitative variables informations
quali_var = get_famd_var(res_famd,"quali_var")
quali_var._fields
# Out:
# ('coord', 'contrib', 'cos2', 'vtest', 'dist')

# %% [markdown]
# ### Qualitatives variables factor coordinates

# %%
#qualitative variables factor coordinates
print_dt(quali_var.coord,rowname="Categories",title=html("<b>Variables/categories coordinates</b>"))
# Out:
# GT(_tbl_data=   Categories     Dim.1     Dim.2     Dim.3     Dim.4     Dim.5
# 0  Bourgueuil -0.508034 -1.625556 -0.141303 -1.875585  0.087958
# 1      Chinon -1.797428 -0.451489  1.827240  0.902850  1.073770
# 2      Saumur  0.930719  1.050845 -0.587376  0.694737 -0.438439
# 3        Env1 -1.818434 -1.323286 -1.446375 -0.066436 -0.240984
# 4        Env2 -1.719406  0.452715  1.478884  1.190342  0.092512
# 5        Env4 -0.940094  6.942930 -0.527291 -0.850608 -0.458555
# 6   Reference  3.315180 -0.983775  0.540684 -0.540778  0.305920, _body=<great_tables._gt_data.Body object at 0x000001CC2635AC50>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2408CA30>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/categories coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC23FC0B50>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=Tr ...

# %% [markdown]
# #### Qualitatives variables square cosinus (cos2)

# %%
#qualitative variables square cosinus (cos2)
print_dt(quali_var.cos2,rowname="Categories",title=html("<b>Variables/categories Cos2</b>"))
# Out:
# GT(_tbl_data=   Categories     Dim.1     Dim.2     Dim.3     Dim.4     Dim.5
# 0  Bourgueuil  0.039085  0.400154  0.003024  0.532718  0.001172
# 1      Chinon  0.320671  0.020233  0.331396  0.080907  0.114440
# 2      Saumur  0.276343  0.352279  0.110063  0.153976  0.061324
# 3        Env1  0.424908  0.225013  0.268820  0.000567  0.007462
# 4        Env2  0.358899  0.024881  0.265512  0.172012  0.001039
# 5        Env4  0.017231  0.939847  0.005421  0.014107  0.004100
# 6   Reference  0.826419  0.072774  0.021982  0.021990  0.007037, _body=<great_tables._gt_data.Body object at 0x000001CC23FC1540>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC23FC2EF0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/categories Cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC2422EC80>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, cat ...

# %% [markdown]
# #### Qualitatives variables contributions

# %%
#qualitative variables contributions
print_dt(quali_var.contrib,rowname="Categories",title=html("<b>Variables/categories contributions</b>"))
# Out:
# GT(_tbl_data=   Categories     Dim.1      Dim.2      Dim.3      Dim.4      Dim.5
# 0  Bourgueuil  0.030826   1.793539   0.085774  23.522558   0.104274
# 1      Chinon  0.257245   0.092238   9.562059   3.633717  10.359830
# 2      Saumur  0.189677   1.374123   2.717226   5.916891   4.749866
# 3        Env1  0.460763   1.386633  10.484796   0.034432   0.913157
# 4        Env2  0.294246   0.115924   7.829575   7.895379   0.096124
# 5        Env4  0.035185  10.906150   0.398136   1.612681   0.944676
# 6   Reference  1.531428   0.766383   1.465161   2.281366   1.471583, _body=<great_tables._gt_data.Body object at 0x000001CC2422EA70>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2422ED70>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/categories contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC2422F5B0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(s ...

# %% [markdown]
# #### Qualitatives variables value-test (vtest)

# %%
#qualitative variables value-test (vtest)
print_dt(quali_var.vtest,rowname="Categories",title=html("<b>Variables/categories vtest</b>"))
# Out:
# GT(_tbl_data=   Categories     Dim.1     Dim.2     Dim.3     Dim.4     Dim.5
# 0  Bourgueuil -0.365375 -1.805056 -0.248873 -3.689789  0.206179
# 1      Chinon -0.991455 -0.384514  2.468289  1.362248  1.930431
# 2      Saumur  1.110021  1.935056 -1.715567  2.266479 -1.704288
# 3        Env1 -1.462172 -1.642849 -2.848136 -0.146124 -0.631555
# 4        Env2 -1.092998  0.444333  2.302257  2.069814  0.191672
# 5        Env4 -0.346837  3.954939 -0.476413 -0.858425 -0.551400
# 6   Reference  2.665680 -1.221349  1.064691 -1.189429  0.801735, _body=<great_tables._gt_data.Body object at 0x000001CC24183940>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2422C2E0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/categories vtest</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC24183550>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, ca ...

# %% [markdown]
# #### Qualitative variables square distance to origin (dist)

# %%
#qualitative variables additionals informations
print_dt(quali_var.dist,rowname="Categories",title=html("<b>Variables/categories dist2</b>"))
# Out:
# GT(_tbl_data=   Categories  Sq. Dist.
# 0  Bourgueuil   6.603527
# 1      Chinon  10.074970
# 2      Saumur   3.134654
# 3        Env1   7.782170
# 4        Env2   8.237291
# 5        Env4  51.289486
# 6   Reference  13.298846, _body=<great_tables._gt_data.Body object at 0x000001CC24180F70>, _boxhead=Boxhead([ColInfo(var='Categories', type=<ColInfoTypeEnum.default: 1>, column_label='Categories', column_align='left', column_width=None), ColInfo(var='Sq. Dist.', type=<ColInfoTypeEnum.default: 1>, column_label='Sq. Dist.', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC24183970>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables/categories dist2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC24181C00>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_title_font_size=OptionsInfo(scss=True, category='heading', type='px', value='125%'), heading_title_font_weight=OptionsInfo(scss=True, category='heading', type='value', value='initial'), heading_subtitle_font_size=OptionsInfo(scss=True, category='heading', type='px', value='85%'), heading_subtitle_font_weight=OptionsInfo(scss=True, category='heading', type='value', val ...

# %% [markdown]
# ### Variables informations

# %%
#variables informations
var = get_famd_var(res_famd,"var")
var._fields
# Out:
# ('coord', 'contrib', 'cos2')

# %% [markdown]
# #### Variables coordinates

# %%
#variables factor coordinates
print_dt(var.coord,rowname="Variables",title=html("<b>Variables coordinates</b>"))
# Out:
# GT(_tbl_data=                        Variables     Dim.1     Dim.2     Dim.3     Dim.4  \
# 0   Odor.Intensity.before.shaking  0.223379  0.581600  0.000940  0.002143
# 1    Aroma.quality.before.shaking  0.661808  0.002793  0.057629  0.018105
# 2           Fruity.before.shaking  0.465017  0.002324  0.233985  0.018871
# 3           Flower.before.shaking  0.227946  0.091884  0.230754  0.100234
# 4            Spice.before.shaking  0.003089  0.590549  0.035171  0.150702
# 5                Visual.intensity  0.712863  0.113496  0.020515  0.000365
# 6                          Nuance  0.681942  0.108682  0.018786  0.002809
# 7                 Surface.feeling  0.864982  0.034037  0.002298  0.000006
# 8                  Odor.Intensity  0.296812  0.469885  0.031139  0.069173
# 9                Quality.of.odour  0.683100  0.075002  0.130427  0.021305
# 10                         Fruity  0.556807  0.047278  0.238979  0.000122
# 11                         Flower  0.078065  0.311918  0.185380  0.068371
# 12                          Spice  0.042878  0.464699  0.003334  0.177614
# 13                         Plante  0.362923  0.384895  0.003030  0.121047
# 14                       Phenolic  0.118449  0.163372  0.005390  0.297604
# 15                Aroma.intensity  0.783231  0.023276  0.001989  0.019459
# 16              Aroma.persistency  0.843737  0.041060  0.001604  0.004511
# 17                  Aroma.quality  0.658955  0.230853  0.005950  0.005038
# 18               Attack.intensity  0.764900  0.008946  0.010216  0.004896
# 19                        Acidity  0.050001  0.119854  0.404562  0.001298
# 20                    Astringency  0.545702  0.279517  0.025639  0.015521
# 21                        Alcohol  0.572831  0.089350  0.044376  0.004593
# 22                        Balance  0.733150  0.190199  0.003200  0.000001
# 23                         Smooth  0.814605  0.114963  0.011281  0.002427
# 24                     Bitterness  0.095253  0.512111  0.001053  0.000665
# 25                      Intensity  0.883192  0.013834  0.002217  0.018914
# 26                        Harmony  0.901361  0.026433  0.023947  0.000916
# 27                Overall.quality  0.701245  0.186204  0.004933  0.002481
# 28                        Typical  0.705523  0.142703  0.000951  0.009842
# 29                          Label  0.073892  0.211503  0.318887  0.683654
# 30                           Soil  0.359079  0.854803  0.520369  0.244410
#
#        Dim.5
# 0   0.018406
# 1   0.097160
# 2   0.040080
# 3   0.055237
# 4   0.073736
# 5   0.011898
# 6   0.009196
# 7   0.010010
# 8   0.000374
# 9   0.002760
# 10  0.050454
# 11  0.220649
# 12  0.022606
# 13  0.001485
# 14  0.000493
# 15  0.053371
# 16  0.053408
# 17  0.001597
# 18  0.062319
# 19  0.276071
# 20  0.006832
# 21  0.004208
# 22  0.000360
# 23  0.000117
# 24  0.049792
# 25  0.038142
# 26  0.000526
# 27  0.023208
# 28  0.000098
# 29  0.221512
# 30  0.049875  , _body=<great_tables._gt_data.Body object at 0x000001CC24188880>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC24181C90>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables coordinates</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC2418B2B0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_ali ...

# %% [markdown]
# #### Variables contributions

# %%
#variables contributions
print_dt(var.contrib,rowname="Variables",title=html("<b>Variables contributions</b>"))
# Out:
# GT(_tbl_data=                        Variables     Dim.1      Dim.2      Dim.3      Dim.4  \
# 0   Odor.Intensity.before.shaking  1.444258   8.964209   0.036467   0.103657
# 1    Aroma.quality.before.shaking  4.278914   0.043054   2.234614   0.875875
# 2           Fruity.before.shaking  3.006566   0.035824   9.072953   0.912928
# 3           Flower.before.shaking  1.473785   1.416204   8.947668   4.849010
# 4            Spice.before.shaking  0.019974   9.102144   1.363773   7.290504
# 5                Visual.intensity  4.609012   1.749312   0.795491   0.017650
# 6                          Nuance  4.409093   1.675119   0.728454   0.135901
# 7                 Surface.feeling  5.592537   0.524620   0.089108   0.000308
# 8                  Odor.Intensity  1.919036   7.242345   1.207443   3.346404
# 9                Quality.of.odour  4.416578   1.156007   5.057380   1.030670
# 10                         Fruity  3.600035   0.728701   9.266588   0.005894
# 11                         Flower  0.504731   4.807602   7.188244   3.307603
# 12                          Spice  0.277227   7.162412   0.129264   8.592423
# 13                         Plante  2.346477   5.932398   0.117509   5.855886
# 14                       Phenolic  0.765830   2.518053   0.209010  14.397197
# 15                Aroma.intensity  5.063974   0.358755   0.077138   0.941349
# 16              Aroma.persistency  5.455180   0.632853   0.062193   0.218245
# 17                  Aroma.quality  4.260473   3.558136   0.230718   0.243708
# 18               Attack.intensity  4.945459   0.137880   0.396139   0.236878
# 19                        Acidity  0.323279   1.847316  15.687183   0.062797
# 20                    Astringency  3.528235   4.308194   0.994187   0.750843
# 21                        Alcohol  3.703637   1.377149   1.720726   0.222175
# 22                        Balance  4.740179   2.931537   0.124068   0.000031
# 23                         Smooth  5.266823   1.771932   0.437441   0.117429
# 24                     Bitterness  0.615857   7.893182   0.040812   0.032167
# 25                      Intensity  5.710278   0.213216   0.085975   0.914986
# 26                        Harmony  5.827744   0.407405   0.928570   0.044292
# 27                Overall.quality  4.533899   2.869970   0.191269   0.120034
# 28                        Typical  4.561559   2.199483   0.036886   0.476136
# 29                          Label  0.477748   3.259900  12.365059  33.073167
# 30                           Soil  2.321623  13.175091  20.177668  11.823857
#
#         Dim.5
# 0    1.264149
# 1    6.673161
# 2    2.752777
# 3    3.793836
# 4    5.064339
# 5    0.817205
# 6    0.631595
# 7    0.687509
# 8    0.025687
# 9    0.189597
# 10   3.465262
# 11  15.154681
# 12   1.552617
# 13   0.101979
# 14   0.033851
# 15   3.665621
# 16   3.668176
# 17   0.109694
# 18   4.280227
# 19  18.961196
# 20   0.469261
# 21   0.289033
# 22   0.024738
# 23   0.008010
# 24   3.419838
# 25   2.619681
# 26   0.036117
# 27   1.593944
# 28   0.006710
# 29  15.213970
# 30   3.425539  , _body=<great_tables._gt_data.Body object at 0x000001CC24188F70>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC241889D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables contributions</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC24218B20>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_ ...

# %% [markdown]
# #### Variables square cosinus (cos2)

# %%
#variables square cosinus (cos2)
print_dt(var.cos2,rowname="Variables",title=html("<b>Variables Cos2</b>"))
# Out:
# GT(_tbl_data=                        Variables     Dim.1     Dim.2     Dim.3     Dim.4  \
# 0   Odor.Intensity.before.shaking  0.049898  0.338258  0.000001  0.000005
# 1    Aroma.quality.before.shaking  0.437989  0.000008  0.003321  0.000328
# 2           Fruity.before.shaking  0.216241  0.000005  0.054749  0.000356
# 3           Flower.before.shaking  0.051959  0.008443  0.053248  0.010047
# 4            Spice.before.shaking  0.000010  0.348748  0.001237  0.022711
# 5                Visual.intensity  0.508173  0.012881  0.000421  0.000000
# 6                          Nuance  0.465045  0.011812  0.000353  0.000008
# 7                 Surface.feeling  0.748194  0.001159  0.000005  0.000000
# 8                  Odor.Intensity  0.088097  0.220792  0.000970  0.004785
# 9                Quality.of.odour  0.466625  0.005625  0.017011  0.000454
# 10                         Fruity  0.310034  0.002235  0.057111  0.000000
# 11                         Flower  0.006094  0.097293  0.034366  0.004675
# 12                          Spice  0.001839  0.215945  0.000011  0.031547
# 13                         Plante  0.131713  0.148144  0.000009  0.014652
# 14                       Phenolic  0.014030  0.026690  0.000029  0.088568
# 15                Aroma.intensity  0.613450  0.000542  0.000004  0.000379
# 16              Aroma.persistency  0.711893  0.001686  0.000003  0.000020
# 17                  Aroma.quality  0.434222  0.053293  0.000035  0.000025
# 18               Attack.intensity  0.585072  0.000080  0.000104  0.000024
# 19                        Acidity  0.002500  0.014365  0.163670  0.000002
# 20                    Astringency  0.297791  0.078130  0.000657  0.000241
# 21                        Alcohol  0.328135  0.007983  0.001969  0.000021
# 22                        Balance  0.537509  0.036176  0.000010  0.000000
# 23                         Smooth  0.663581  0.013217  0.000127  0.000006
# 24                     Bitterness  0.009073  0.262258  0.000001  0.000000
# 25                      Intensity  0.780029  0.000191  0.000005  0.000358
# 26                        Harmony  0.812451  0.000699  0.000573  0.000001
# 27                Overall.quality  0.491745  0.034672  0.000024  0.000006
# 28                        Typical  0.497763  0.020364  0.000001  0.000097
# 29                          Label  0.002730  0.022367  0.050844  0.233691
# 30                           Soil  0.042979  0.243563  0.090261  0.019912
#
#        Dim.5
# 0   0.000339
# 1   0.009440
# 2   0.001606
# 3   0.003051
# 4   0.005437
# 5   0.000142
# 6   0.000085
# 7   0.000100
# 8   0.000000
# 9   0.000008
# 10  0.002546
# 11  0.048686
# 12  0.000511
# 13  0.000002
# 14  0.000000
# 15  0.002848
# 16  0.002852
# 17  0.000003
# 18  0.003884
# 19  0.076215
# 20  0.000047
# 21  0.000018
# 22  0.000000
# 23  0.000000
# 24  0.002479
# 25  0.001455
# 26  0.000000
# 27  0.000539
# 28  0.000000
# 29  0.024534
# 30  0.000829  , _body=<great_tables._gt_data.Body object at 0x000001CC242196F0>, _boxhead=Boxhead([ColInfo(var='Variables', type=<ColInfoTypeEnum.default: 1>, column_label='Variables', column_align='left', column_width=None), ColInfo(var='Dim.1', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.1', column_align='right', column_width=None), ColInfo(var='Dim.2', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.2', column_align='right', column_width=None), ColInfo(var='Dim.3', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.3', column_align='right', column_width=None), ColInfo(var='Dim.4', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.4', column_align='right', column_width=None), ColInfo(var='Dim.5', type=<ColInfoTypeEnum.default: 1>, column_label='Dim.5', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2421A680>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Variables Cos2</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC2421A0B0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=Opti ...

# %% [markdown]
# ## Summary

# %%
from scientisttools import summaryFAMD
summaryFAMD(res_famd)
# Out:
#                      Factor Analysis of Mixed Data - Results
#
# Importance of components
#                           Dim.1   Dim.2   Dim.3   Dim.4   Dim.5
# Variance                 15.467   6.488   2.579   2.067   1.456
# Difference                8.979   3.909   0.512   0.611   0.214
# % of var.                45.490  19.082   7.585   6.080   4.282
# Cumulative of % of var.  45.490  64.573  72.158  78.238  82.520
#
# Individuals (the 10 first)
#
#       Weight  Sq. Dist.  Inertia  % Inertia  Dim.1     ctr   cos2  Dim.2  \
# 2EL    0.048     16.865    0.803      2.362  0.198   0.012  0.002 -1.513
# 1CHA   0.048     37.525    1.787      5.256 -3.541   3.859  0.334 -2.674
# 1FON   0.048     20.652    0.983      2.892 -1.816   1.015  0.160 -2.150
# 1VAU   0.048    107.318    5.110     15.031 -9.499  27.782  0.841  1.281
# 1DAM   0.048     36.133    1.721      5.061  5.213   8.367  0.752  0.059
# 2BOU   0.048     18.671    0.889      2.615  2.450   1.848  0.321 -1.069
# 1BOI   0.048     21.794    1.038      3.052  3.414   3.589  0.535 -0.794
# 3EL    0.048     24.444    1.164      3.424  0.474   0.069  0.009  1.524
# DOM1   0.048     14.187    0.676      1.987  0.106   0.003  0.001 -1.042
# 1TUR   0.048     20.825    0.992      2.917 -2.286   1.608  0.251 -0.257
#
#         ctr   cos2  Dim.3     ctr   cos2
# 2EL   1.680  0.136 -2.113   8.247  0.265
# 1CHA  5.249  0.191 -2.896  15.481  0.223
# 1FON  3.392  0.224 -1.399   3.613  0.095
# 1VAU  1.205  0.015  2.201   8.944  0.045
# 1DAM  0.003  0.000  0.920   1.562  0.023
# 2BOU  0.838  0.061 -0.261   0.126  0.004
# 1BOI  0.462  0.029  0.917   1.551  0.039
# 3EL   1.706  0.095 -3.484  22.415  0.497
# DOM1  0.796  0.076  0.745   1.024  0.039
# 1TUR  0.048  0.003  1.367   3.451  0.090
#
# Continuous variables (the 10 first)
#
#                                Dim.1    ctr   cos2  Dim.2    ctr   cos2  \
# Odor.Intensity.before.shaking  0.473  1.444  0.223  0.763  8.964  0.582
# Aroma.quality.before.shaking   0.814  4.279  0.662  0.053  0.043  0.003
# Fruity.before.shaking          0.682  3.007  0.465 -0.048  0.036  0.002
# Flower.before.shaking          0.477  1.474  0.228 -0.303  1.416  0.092
# Spice.before.shaking          -0.056  0.020  0.003  0.768  9.102  0.591
# Visual.intensity               0.844  4.609  0.713  0.337  1.749  0.113
# Nuance                         0.826  4.409  0.682  0.330  1.675  0.109
# Surface.feeling                0.930  5.593  0.865  0.184  0.525  0.034
# Odor.Intensity                 0.545  1.919  0.297  0.685  7.242  0.470
# Quality.of.odour               0.826  4.417  0.683 -0.274  1.156  0.075
#
#                                Dim.3    ctr   cos2
# Odor.Intensity.before.shaking -0.031  0.036  0.001
# Aroma.quality.before.shaking   0.240  2.235  0.058
# Fruity.before.shaking          0.484  9.073  0.234
# Flower.before.shaking         -0.480  8.948  0.231
# Spice.before.shaking          -0.188  1.364  0.035
# Visual.intensity              -0.143  0.795  0.021
# Nuance                        -0.137  0.728  0.019
# Surface.feeling                0.048  0.089  0.002
# Odor.Intensity                -0.176  1.207  0.031
# Quality.of.odour               0.361  5.057  0.130
#
# Categories
#
#             Sq. Dist.  Dim.1    ctr   cos2  vtest  Dim.2     ctr   cos2  \
# Bourgueuil      6.604 -0.508  0.031  0.039 -0.365 -1.626   1.794  0.400
# Chinon         10.075 -1.797  0.257  0.321 -0.991 -0.451   0.092  0.020
# Saumur          3.135  0.931  0.190  0.276  1.110  1.051   1.374  0.352
# Env1            7.782 -1.818  0.461  0.425 -1.462 -1.323   1.387  0.225
# Env2            8.237 -1.719  0.294  0.359 -1.093  0.453   0.116  0.025
# Env4           51.289 -0.940  0.035  0.017 -0.347  6.943  10.906  0.940
# Reference      13.299  3.315  1.531  0.826  2.666 -0.984   0.766  0.073
#
#             vtest  Dim.3     ctr   cos2  vtest
# Bourgueuil -1.805 -0.141   0.086  0.003 -0.249
# Chinon     -0.385  1.827   9.562  0.331  2.468
# Saumur      1.935 -0.587   2.717  0.110 -1.716
# Env1       -1.643 -1.446  10.485  0.269 -2.848
# Env2        0.444  1.479   7.830  0.266  2.302
# Env4        3.955 -0.527   0.398  0.005 -0.476
# Reference  -1.221  0.541   1.465  0.022  1.065
#
# Categoricals variables (eta2)
#
#        Dim.1  Dim.2  Dim.3
# Label  0.074  0.212  0.319
# Soil   0.359  0.855  0.520

# %%
#summary quali
print_dt(res_famd.summary_quali_,rowname="",title=html("<b>Table qualitative</b>"))
# Out:
# GT(_tbl_data=     variable   categorie  count  proportion
# 0  0    Label      Saumur     11    0.523810
# 1  1    Label  Bourgueuil      6    0.285714
# 2  2    Label      Chinon      4    0.190476
# 3  3     Soil        Env1      7    0.333333
# 4  4     Soil   Reference      7    0.333333
# 5  5     Soil        Env2      5    0.238095
# 6  6     Soil        Env4      2    0.095238, _body=<great_tables._gt_data.Body object at 0x000001CC242191B0>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable', type=<ColInfoTypeEnum.default: 1>, column_label='variable', column_align='left', column_width=None), ColInfo(var='categorie', type=<ColInfoTypeEnum.default: 1>, column_label='categorie', column_align='left', column_width=None), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='right', column_width=None), ColInfo(var='proportion', type=<ColInfoTypeEnum.default: 1>, column_label='proportion', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2421BF70>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Table qualitative</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC242189A0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='heading', type='value', value=None), heading_align=OptionsInfo(scss=True, category='heading', type='value', value='center'), heading_titl ...

# %%
#summary quantitative
print_dt(res_famd.summary_quanti_,rowname="",title=html("<b>Descriptive statistics for quantitative variables</b>"))
# Out:
# GT(_tbl_data=                             variable  count      mean       std    min  \
# 0    0  Odor.Intensity.before.shaking     21  3.111143  0.289453  2.643
# 1    1   Aroma.quality.before.shaking     21  3.045762  0.205640  2.593
# 2    2          Fruity.before.shaking     21  2.714048  0.201024  2.375
# 3    3          Flower.before.shaking     21  2.057000  0.143595  1.826
# 4    4           Spice.before.shaking     21  1.991476  0.239662  1.667
# 5    5               Visual.intensity     21  3.957524  0.549464  2.607
# 6    6                         Nuance     21  3.727381  0.520739  2.536
# 7    7                Surface.feeling     21  3.180286  0.279826  2.444
# 8    8                 Odor.Intensity     21  3.395238  0.200489  2.889
# 9    9               Quality.of.odour     21  3.237333  0.223102  2.800
# 10  10                         Fruity     21  2.847143  0.221596  2.391
# 11  11                         Flower     21  2.162143  0.150747  1.773
# 12  12                          Spice     21  2.178333  0.206341  1.739
# 13  13                         Plante     21  1.964429  0.163493  1.750
# 14  14                       Phenolic     21  1.542381  0.152592  1.250
# 15  15                Aroma.intensity     21  3.196952  0.254825  2.542
# 16  16              Aroma.persistency     21  2.982762  0.245487  2.308
# 17  17                  Aroma.quality     21  3.063619  0.315995  2.478
# 18  18               Attack.intensity     21  3.156286  0.306045  2.179
# 19  19                        Acidity     21  2.385286  0.239894  2.107
# 20  20                    Astringency     21  2.440286  0.196795  1.964
# 21  21                        Alcohol     21  2.740667  0.167389  2.250
# 22  22                        Balance     21  3.129048  0.332655  2.333
# 23  23                         Smooth     21  2.674238  0.413987  1.680
# 24  24                     Bitterness     21  2.067905  0.186400  1.679
# 25  25                      Intensity     21  3.165952  0.372565  2.179
# 26  26                        Harmony     21  3.147952  0.442039  2.038
# 27  27                Overall.quality     21  3.331143  0.432013  2.370
# 28  28                        Typical     21  3.196762  0.425732  2.250
#
#       25%    50%    75%    max
# 0   2.893  3.071  3.214  3.708
# 1   2.926  3.107  3.179  3.429
# 2   2.560  2.731  2.833  3.154
# 3   1.926  2.040  2.185  2.280
# 4   1.808  1.962  2.077  2.667
# 5   3.704  4.071  4.321  4.714
# 6   3.407  3.893  4.036  4.536
# 7   3.111  3.259  3.357  3.462
# 8   3.286  3.370  3.481  3.737
# 9   3.077  3.346  3.385  3.500
# 10  2.769  2.885  2.963  3.185
# 11  2.083  2.192  2.269  2.440
# 12  2.111  2.160  2.280  2.609
# 13  1.826  1.957  2.042  2.304
# 14  1.476  1.545  1.600  1.905
# 15  3.077  3.250  3.321  3.615
# 16  2.893  3.036  3.148  3.296
# 17  2.880  3.192  3.308  3.462
# 18  3.036  3.250  3.357  3.519
# 19  2.250  2.393  2.429  3.179
# 20  2.321  2.500  2.607  2.667
# 21  2.704  2.778  2.821  2.963
# 22  3.107  3.214  3.321  3.500
# 23  2.500  2.821  2.857  3.286
# 24  1.964  2.037  2.143  2.667
# 25  3.037  3.250  3.357  3.667
# 26  3.000  3.214  3.393  3.786
# 27  3.179  3.464  3.643  3.929
# 28  3.036  3.296  3.481  3.929  , _body=<great_tables._gt_data.Body object at 0x000001CC2409F940>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable', type=<ColInfoTypeEnum.default: 1>, column_label='variable', column_align='left', column_width=None), ColInfo(var='count', type=<ColInfoTypeEnum.default: 1>, column_label='count', column_align='right', column_width=None), ColInfo(var='mean', type=<ColInfoTypeEnum.default: 1>, column_label='mean', column_align='right', column_width=None), ColInfo(var='std', type=<ColInfoTypeEnum.default: 1>, column_label='std', column_align='right', column_width=None), ColInfo(var='min', type=<ColInfoTypeEnum.default: 1>, column_label='min', column_align='right', column_width=None), ColInfo(var='25%', type=<ColInfoTypeEnum.default: 1>, column_label='25%', column_align='right', column_width=None), ColInfo(var='50%', type=<ColInfoTypeEnum.default: 1>, column_label='50%', column_align='right', column_width=None), ColInfo(var='75%', type=<ColInfoTypeEnum.default: 1>, column_label='75%', column_align='right', column_width=None), ColInfo(var='max', type=<ColInfoTypeEnum.default: 1>, column_label='max', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC2409F6D0>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Descriptive statistics for quantitative variables</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC263DE080>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px') ...

# %% [markdown]
# ### Goodness

# %%
#goodness
goodness = res_famd.goodness_
goodness._fields
# Out:
# ('association', 'chi2', 'gtest')

# %% [markdown]
# #### Association

# %%
#association
print_dt(goodness.association,rowname="",title=html("<b>Association test</b>"))
# Out:
# GT(_tbl_data=     variable1 variable2    cramer  tschuprow   pearson
# 0  0     Label      Soil  0.373645   0.337626  0.467198, _body=<great_tables._gt_data.Body object at 0x000001CC263DD780>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable1', type=<ColInfoTypeEnum.default: 1>, column_label='variable1', column_align='left', column_width=None), ColInfo(var='variable2', type=<ColInfoTypeEnum.default: 1>, column_label='variable2', column_align='left', column_width=None), ColInfo(var='cramer', type=<ColInfoTypeEnum.default: 1>, column_label='cramer', column_align='right', column_width=None), ColInfo(var='tschuprow', type=<ColInfoTypeEnum.default: 1>, column_label='tschuprow', column_align='right', column_width=None), ColInfo(var='pearson', type=<ColInfoTypeEnum.default: 1>, column_label='pearson', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC263DE500>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Association test</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC263DCCD0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_left_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), heading_background_color=OptionsInfo(scss=True, category='h ...

# %% [markdown]
# #### Chi-squared test

# %%
#chi2 test
print_dt(goodness.chi2,rowname="",title=html("<b>Association test</b>"))
# Out:
# GT(_tbl_data=     variable1 variable2  statistic  dof      value    pvalue  \
# 0  0     Label      Soil   5.863636    6  12.591587  0.438638
#
#                     conclusion
# 0  Independent (H0 holds true)  , _body=<great_tables._gt_data.Body object at 0x000001CC263DF100>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable1', type=<ColInfoTypeEnum.default: 1>, column_label='variable1', column_align='left', column_width=None), ColInfo(var='variable2', type=<ColInfoTypeEnum.default: 1>, column_label='variable2', column_align='left', column_width=None), ColInfo(var='statistic', type=<ColInfoTypeEnum.default: 1>, column_label='statistic', column_align='right', column_width=None), ColInfo(var='dof', type=<ColInfoTypeEnum.default: 1>, column_label='dof', column_align='right', column_width=None), ColInfo(var='value', type=<ColInfoTypeEnum.default: 1>, column_label='value', column_align='right', column_width=None), ColInfo(var='pvalue', type=<ColInfoTypeEnum.default: 1>, column_label='pvalue', column_align='right', column_width=None), ColInfo(var='conclusion', type=<ColInfoTypeEnum.default: 1>, column_label='conclusion', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC263DF160>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Association test</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC24110370>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_width=Opti ...

# %% [markdown]
# #### Loglikelihood test (g-test)

# %%
#log-likelihood test
print_dt(goodness.gtest,rowname="",title=html("<b>Loglikelihood test (gtest)</b>"))
# Out:
# GT(_tbl_data=     variable1 variable2  statistic  dof      value    pvalue  \
# 0  0     Label      Soil   7.675872    6  12.591587  0.262824
#
#                     conclusion
# 0  Independent (H0 holds true)  , _body=<great_tables._gt_data.Body object at 0x000001CC24110D00>, _boxhead=Boxhead([ColInfo(var='', type=<ColInfoTypeEnum.default: 1>, column_label='', column_align='right', column_width=None), ColInfo(var='variable1', type=<ColInfoTypeEnum.default: 1>, column_label='variable1', column_align='left', column_width=None), ColInfo(var='variable2', type=<ColInfoTypeEnum.default: 1>, column_label='variable2', column_align='left', column_width=None), ColInfo(var='statistic', type=<ColInfoTypeEnum.default: 1>, column_label='statistic', column_align='right', column_width=None), ColInfo(var='dof', type=<ColInfoTypeEnum.default: 1>, column_label='dof', column_align='right', column_width=None), ColInfo(var='value', type=<ColInfoTypeEnum.default: 1>, column_label='value', column_align='right', column_width=None), ColInfo(var='pvalue', type=<ColInfoTypeEnum.default: 1>, column_label='pvalue', column_align='right', column_width=None), ColInfo(var='conclusion', type=<ColInfoTypeEnum.default: 1>, column_label='conclusion', column_align='left', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x000001CC24111150>, _spanners=Spanners([]), _heading=Heading(title=Html(text='<b>Loglikelihood test (gtest)</b>'), subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[], _locale=<great_tables._gt_data.Locale object at 0x000001CC24111EA0>, _formats=[], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values', value=['-apple-system', 'BlinkMacSystemFont', 'Segoe UI', 'Roboto', 'Oxygen', 'Ubuntu', 'Cantarell', 'Helvetica Neue', 'Fira Sans', 'Droid Sans', 'Arial', 'sans-serif']), table_font_size=OptionsInfo(scss=True, category='table', type='px', value='16px'), table_font_weight=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_style=OptionsInfo(scss=True, category='table', type='value', value='normal'), table_font_color=OptionsInfo(scss=True, category='table', type='value', value='#333333'), table_font_color_light=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_border_top_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_top_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_top_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_top_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_right_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_right_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_right_color=OptionsInfo(scss=True, category='table', type='value', value='#D3D3D3'), table_border_bottom_include=OptionsInfo(scss=False, category='table', type='boolean', value=True), table_border_bottom_style=OptionsInfo(scss=True, category='table', type='value', value='solid'), table_border_bottom_width=OptionsInfo(scss=True, category='table', type='px', value='2px'), table_border_bottom_color=OptionsInfo(scss=True, category='table', type='value', value='#A8A8A8'), table_border_left_style=OptionsInfo(scss=True, category='table', type='value', value='none'), table_border_left_ ...

# %% [markdown]
# ## Description automatique des axes

# %%
from scientisttools import dimdesc
dimDesc = dimdesc(res_famd)
dimDesc.keys()
# Out:
# dict_keys(['Dim.1', 'Dim.2', 'Dim.3', 'Dim.4', 'Dim.5'])

# %%
dimDesc["Dim.1"]
# Out:
# {'quanti':                                correlation        pvalue
#  Harmony                           0.949400  5.255840e-11
#  Intensity                         0.939783  2.643017e-10
#  Surface.feeling                   0.930044  1.056564e-09
#  Aroma.persistency                 0.918552  4.281721e-09
#  Smooth                            0.902555  2.206577e-08
#  Aroma.intensity                   0.885003  9.915754e-08
#  Attack.intensity                  0.874586  2.166644e-07
#  Balance                           0.856242  7.354269e-07
#  Visual.intensity                  0.844312  1.493481e-06
#  Typical                           0.839954  1.906789e-06
#  Overall.quality                   0.837404  2.192635e-06
#  Quality.of.odour                  0.826498  3.883447e-06
#  Nuance                            0.825798  4.023321e-06
#  Aroma.quality.before.shaking      0.813516  7.302980e-06
#  Aroma.quality                     0.811761  7.924409e-06
#  Alcohol                           0.756856  7.148093e-05
#  Fruity                            0.746195  1.026566e-04
#  Astringency                       0.738717  1.309840e-04
#  Fruity.before.shaking             0.681922  6.621663e-04
#  Odor.Intensity                    0.544804  1.065514e-02
#  Flower.before.shaking             0.477437  2.861723e-02
#  Odor.Intensity.before.shaking     0.472630  3.049407e-02
#  Plante                           -0.602431  3.851628e-03,
#  'category':                 Estimate   pvalue
#  Soil=Reference   4.97277  0.00435}

# %%
dimDesc["Dim.2"]
# Out:
# {'quanti':                                correlation    pvalue
#  Spice.before.shaking              0.768472  0.000047
#  Odor.Intensity.before.shaking     0.762627  0.000058
#  Bitterness                        0.715620  0.000265
#  Odor.Intensity                    0.685482  0.000604
#  Spice                             0.681688  0.000666
#  Plante                            0.620399  0.002695
#  Astringency                       0.528693  0.013737
#  Balance                          -0.436118  0.048110
#  Aroma.quality                    -0.480471  0.027480
#  Flower                           -0.558496  0.008502,
#  'quali':             R2        pvalue
#  Soil  0.854803  2.409988e-07,
#  'category':            Estimate        pvalue
#  Soil=Env4  7.673764  1.043530e-07}
