# %% [markdown]
# # Correspondence Analysis (CA) - `children` Dataset

# %%
#disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=4):
    dt = (GT(data=data.round(decimals=digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %%
#load children dataset
from scientisttools import children
(
    GT(children.rename_axis("Rows points").reset_index())
    .tab_header(title=html("<b>Children Dataset</b>"))
    .tab_spanner(label=html("<b>Rows <br>points</b>"),columns="Rows points")
    .tab_spanner(label=html("<b>Active <br>columns</b>"),columns=children.columns.tolist()[:5])
    .tab_spanner(label=html("<b>Supplementary <br>columns</b>"),columns=children.columns.tolist()[5:8])
    .tab_spanner(label=html("<b>Supplementary <br>qualitative</b>"),columns=children.columns.tolist()[-1])
)
# Out:
# GT(_tbl_data=      Rows points  unqualified  cep  bepc  high_school_diploma  university  \
# 0           money           51   64    32                   29          17
# 1          future           53   90    78                   75          22
# 2    unemployment           71  111    50                   40          11
# 3   circumstances            1    7     5                    5           4
# 4            hard            7   11     4                    3           2
# 5        economic            7   13    12                   11          11
# 6          egoism           21   37    14                   26           9
# 7      employment           12   35    19                    6           7
# 8        finances           10    7     7                    3           1
# 9             war            4    7     7                    6           2
# 10        housing            8   22     7                   10           5
# ...

# %%
from scientisttools import CA
#with supplementary columns
res_ca = CA(row_sup=(14,15,16,17),col_sup=(5,6,7),quali_sup=8)
res_ca.fit(children)
# Out:
# CA(col_sup=(5, 6, 7), quali_sup=8, row_sup=(14, 15, 16, 17))

# %%
#with supplementary quantitative variables
res_ca2 = CA(row_sup=(14,15,16,17),quanti_sup=(5,6,7),quali_sup=8)
res_ca2.fit(children)
# Out:
# CA(quali_sup=8, quanti_sup=(5, 6, 7), row_sup=(14, 15, 16, 17))

# %% [markdown]
# ## Others functions
#
# ### `fit_transform`

# %%
#fit_transform
print_dt(res_ca.fit_transform(children),rowname="Rows points",title=html("<b>Rows points coordinates</b>"))
# Out:
# GT(_tbl_data=      Rows points   Dim.1   Dim.2   Dim.3   Dim.4
# 0           money -0.1153  0.0200  0.1008  0.0846
# 1          future  0.1764 -0.0979 -0.0526 -0.0054
# 2    unemployment -0.2122 -0.0707 -0.0044 -0.0377
# 3   circumstances  0.4009  0.3310 -0.0156 -0.0687
# 4            hard -0.2500  0.0677  0.0603 -0.0032
# 5        economic  0.3540  0.3207  0.0840  0.1544
# 6          egoism  0.0599 -0.0257  0.1790 -0.1123
# 7      employment -0.1368  0.2154 -0.2129 -0.0582
# 8        finances -0.2370 -0.2060 -0.0441  0.3206
# 9             war  0.2168 -0.0747 -0.0978  0.0247
# 10        housing -0.0067  0.1282  0.0879 -0.1924
# 11           fear  0.2033 -0.0581 -0.0331 -0.0096
# 12         health  0.1117  0.0043  0.0228  0.0509
# ...

# %% [markdown]
# ### `inverse_transform`

# %%
#inverse transform
print_dt(res_ca.inverse_transform(res_ca.row_.coord),rowname="Rows points",title=html("<b>Reproduced Children Dataset</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified    cep  bepc  high_school_diploma  university
# 0           money         51.0   64.0  32.0                 29.0        17.0
# 1          future         53.0   90.0  78.0                 75.0        22.0
# 2    unemployment         71.0  111.0  50.0                 40.0        11.0
# 3   circumstances          1.0    7.0   5.0                  5.0         4.0
# 4            hard          7.0   11.0   4.0                  3.0         2.0
# 5        economic          7.0   13.0  12.0                 11.0        11.0
# 6          egoism         21.0   37.0  14.0                 26.0         9.0
# 7      employment         12.0   35.0  19.0                  6.0         7.0
# 8        finances         10.0    7.0   7.0                  3.0         1.0
# 9             war          4.0    7.0   7.0                  6.0         2.0
# 10        housing          8.0   22.0   7.0                 10.0         5.0
# ...

# %% [markdown]
# ### `transform`

# %%
print_dt(res_ca.transform(res_ca.call_.X),rowname="Rows points",title=html("<b>Rows points coordinates</b>"))
# Out:
# GT(_tbl_data=      Rows points   Dim.1   Dim.2   Dim.3   Dim.4
# 0           money -0.1153  0.0200  0.1008  0.0846
# 1          future  0.1764 -0.0979 -0.0526 -0.0054
# 2    unemployment -0.2122 -0.0707 -0.0044 -0.0377
# 3   circumstances  0.4009  0.3310 -0.0156 -0.0687
# 4            hard -0.2500  0.0677  0.0603 -0.0032
# 5        economic  0.3540  0.3207  0.0840  0.1544
# 6          egoism  0.0599 -0.0257  0.1790 -0.1123
# 7      employment -0.1368  0.2154 -0.2129 -0.0582
# 8        finances -0.2370 -0.2060 -0.0441  0.3206
# 9             war  0.2168 -0.0747 -0.0978  0.0247
# 10        housing -0.0067  0.1282  0.0879 -0.1924
# 11           fear  0.2033 -0.0581 -0.0331 -0.0096
# 12         health  0.1117  0.0043  0.0228  0.0509
# ...

# %% [markdown]
# ## Active elements
#
# ### Eigenvalues

# %%
#eigen values
from scientisttools import get_eig
print_dt(get_eig(res_ca),rowname="Dimensions",title=html("<b>Eigen values</b>"))
# Out:
# GT(_tbl_data=  Dimensions  Eigenvalue  Difference  Proportion  Cumulative
# 0      Dim.1      0.0354      0.0223     57.0429     57.0429
# 1      Dim.2      0.0131      0.0058     21.1319     78.1748
# 2      Dim.3      0.0073      0.0011     11.7644     89.9391
# ...

# %% [markdown]
# ### Row informations

# %%
#rows points informations
from scientisttools import get_ca_row
row = get_ca_row(res_ca)
row._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# #### Row coordinates

# %%
#rows points coordinates
print_dt(row.coord,rowname="Rows points",title=html("<b>Rows points coordinates</b>"))
# Out:
# GT(_tbl_data=      Rows points   Dim.1   Dim.2   Dim.3   Dim.4
# 0           money -0.1153  0.0200  0.1008  0.0846
# 1          future  0.1764 -0.0979 -0.0526 -0.0054
# 2    unemployment -0.2122 -0.0707 -0.0044 -0.0377
# 3   circumstances  0.4009  0.3310 -0.0156 -0.0687
# 4            hard -0.2500  0.0677  0.0603 -0.0032
# 5        economic  0.3540  0.3207  0.0840  0.1544
# 6          egoism  0.0599 -0.0257  0.1790 -0.1123
# 7      employment -0.1368  0.2154 -0.2129 -0.0582
# 8        finances -0.2370 -0.2060 -0.0441  0.3206
# 9             war  0.2168 -0.0747 -0.0978  0.0247
# 10        housing -0.0067  0.1282  0.0879 -0.1924
# 11           fear  0.2033 -0.0581 -0.0331 -0.0096
# 12         health  0.1117  0.0043  0.0228  0.0509
# ...

# %% [markdown]
# ### Row contributions

# %%
#rows points contributions
print_dt(row.contrib,rowname="Rows points",title=html("<b>Rows points contributions</b>"))
# Out:
# GT(_tbl_data=      Rows points    Dim.1    Dim.2    Dim.3    Dim.4
# 0           money   4.5499   0.3715  16.8836  13.8908
# 1          future  17.5672  14.5869   7.5678   0.0923
# 2    unemployment  22.6165   6.7786   0.0461   4.0403
# 3   circumstances   6.2745  11.5436   0.0463   1.0443
# 4            hard   2.9938   0.5918   0.8452   0.0027
# 5        economic  12.0046  26.6044   3.2798  12.9580
# 6          egoism   0.6810   0.3376  29.4956  13.5845
# 7      employment   2.6215  17.5546  30.8151   2.6942
# 8        finances   2.7904   5.6902   0.4695  28.9544
# 9             war   2.1688   0.6942   2.1392   0.1598
# 10        housing   0.0041   4.0960   3.4530  19.3683
# 11           fear  11.6657   2.5678   1.4992   0.1463
# 12         health   2.0571   0.0082   0.4170   2.4272
# ...

# %% [markdown]
# ### Row Cos2

# %%
#rows points cos2
print_dt(row.cos2,rowname="Rows points",title=html("<b>Rows points Cos2</b>"))
# Out:
# GT(_tbl_data=      Rows points   Dim.1   Dim.2   Dim.3   Dim.4
# 0           money  0.4284  0.0130  0.3279  0.2307
# 1          future  0.7156  0.2201  0.0636  0.0007
# 2    unemployment  0.8749  0.0971  0.0004  0.0276
# 3   circumstances  0.5840  0.3980  0.0009  0.0171
# 4            hard  0.8837  0.0647  0.0515  0.0001
# 5        economic  0.4836  0.3971  0.0273  0.0921
# 6          egoism  0.0733  0.0135  0.6551  0.2580
# 7      employment  0.1643  0.4076  0.3983  0.0298
# 8        finances  0.2762  0.2087  0.0096  0.5055
# 9             war  0.7491  0.0888  0.1524  0.0097
# 10        housing  0.0007  0.2686  0.1260  0.6046
# 11           fear  0.9007  0.0734  0.0239  0.0020
# 12         health  0.7991  0.0012  0.0334  0.1663
# ...

# %% [markdown]
# ### Row additionals informations

# %%
#rows points additionals informations
print_dt(row.infos,rowname="Rows points",title=html("<b>Rows points additionals informations</b>"))
# Out:
# GT(_tbl_data=      Rows points  Weight  Margin  Sq. Dist.  Inertia  % Inertia
# 0           money     1.0  0.1212     0.0310   0.0038     6.0577
# 1          future     1.0  0.1997     0.0435   0.0087    14.0029
# 2    unemployment     1.0  0.1778     0.0515   0.0092    14.7454
# 3   circumstances     1.0  0.0138     0.2753   0.0038     6.1290
# 4            hard     1.0  0.0170     0.0707   0.0012     1.9325
# 5        economic     1.0  0.0339     0.2591   0.0088    14.1593
# 6          egoism     1.0  0.0672     0.0489   0.0033     5.2965
# 7      employment     1.0  0.0496     0.1138   0.0056     9.1012
# 8        finances     1.0  0.0176     0.2033   0.0036     5.7625
# 9             war     1.0  0.0163     0.0628   0.0010     1.6516
# 10        housing     1.0  0.0327     0.0612   0.0020     3.2228
# 11           fear     1.0  0.0999     0.0459   0.0046     7.3882
# 12         health     1.0  0.0584     0.0156   0.0009     1.4684
# ...

# %% [markdown]
# ## Columns informations

# %%
from scientisttools import get_ca_col
col = get_ca_col(res_ca)
col._fields
# Out:
# ('coord', 'cos2', 'contrib', 'infos')

# %% [markdown]
# ### Columns coordinates

# %%
#columns points coordinates
print_dt(col.coord,rowname="Columns points",title=html("<b>Columns points coordinates</b>"))
# Out:
# GT(_tbl_data=        Columns points   Dim.1   Dim.2   Dim.3   Dim.4
# 0          unqualified -0.2093 -0.0807  0.0726  0.0959
# 1                  cep -0.1386  0.0560 -0.0181 -0.0843
# 2                 bepc  0.1088 -0.0285 -0.1470  0.0606
# 3  high_school_diploma  0.2740 -0.1213  0.0767 -0.0579
# ...

# %% [markdown]
# ### Columns contributions

# %%
#columns points contributions
print_dt(col.contrib,rowname="Columns points",title=html("<b>Columns points contributions</b>"))
# Out:
# GT(_tbl_data=        Columns points    Dim.1    Dim.2    Dim.3    Dim.4
# 0          unqualified  25.1102  10.0819  14.6588  29.8601
# 1                  cep  18.2974   8.0794   1.5201  38.3721
# 2                 bepc   6.7579   1.2512  59.8739  11.8909
# 3  high_school_diploma  37.9757  20.0991  14.4068   9.6164
# ...

# %% [markdown]
# ### Columns Cos2

# %%
#columns points cos2
print_dt(col.cos2,rowname="Columns points",title=html("<b>Columns points Cos2</b>"))
# Out:
# GT(_tbl_data=        Columns points   Dim.1   Dim.2   Dim.3   Dim.4
# 0          unqualified  0.6762  0.1006  0.0814  0.1418
# 1                  cep  0.6449  0.1055  0.0110  0.2385
# 2                 bepc  0.3119  0.0214  0.5699  0.0968
# 3  high_school_diploma  0.7582  0.1487  0.0593  0.0339
# ...

# %% [markdown]
# ### Columns additionals informations

# %%
#columns points additionals informations
print_dt(col.infos,rowname="Columns points",title=html("<b>Columns points additionals informations</b>"))
# Out:
# GT(_tbl_data=        Columns points  Margin  Sq. Dist.  Inertia  % Inertia
# 0          unqualified  0.2029     0.0648   0.0131    21.1828
# 1                  cep  0.3373     0.0298   0.0100    16.1841
# 2                 bepc  0.2023     0.0379   0.0077    12.3594
# 3  high_school_diploma  0.1790     0.0991   0.0177    28.5721
# ...

# %% [markdown]
# ## Multivariate goodness of fit

# %%
#multivariate goodness of fit
goodness = res_ca.goodness_
goodness._fields
# Out:
# ('chi2', 'gtest', 'association')

# %% [markdown]
# ### Pearson's Chi-squared test

# %%
#pearson's chi-squared test
print_dt(goodness.chi2,rowname="Test",title=html("<b>Pearson's Chi-squared test</b>"))
# Out:
# GT(_tbl_data=                        Test  statistic  dof  critical value  pvalue  \
# 0  Pearson's Chi-Square Test    98.8016   52         69.8322  0.0001
#
#               conclusion
# ...

# %% [markdown]
# ### Log-likelihood test

# %%
#log-likelihood test
print_dt(goodness.gtest,rowname="Test",title=html("<b>Likelihood test (G-test)</b>"))
# Out:
# GT(_tbl_data=     Test  statistic  dof  critical value  pvalue             conclusion
# ...

# %% [markdown]
# ### Others association test

# %%
#association tests
print_dt(goodness.association,rowname="Test",title=html("<b>Association tests</b>"))
# Out:
# GT(_tbl_data=        Test  cramer  tschuprow  pearson
# ...

# %% [markdown]
# ## Residuals

# %%
#residuals
residual = res_ca.residuals_
residual._fields
# Out:
# ('resid', 'rstandard', 'radjusted', 'contrib', 'att_rep_ind')

# %% [markdown]
# ### Model residduals

# %%
#model residuals
print_dt(residual.resid,rowname="Rows points",title=html("<b>Model residuals</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified      cep     bepc  high_school_diploma  \
# 0           money      11.8423  -1.1011  -7.0364              -5.5509
# 1          future     -11.5188 -17.2651  13.6809              18.0716
# 2    unemployment      13.5823  15.5408  -7.2399             -10.6627
# 3   circumstances      -3.4636  -0.4209   0.5503               1.0616
# 4            hard       1.5220   1.8926  -1.4611              -1.8335
# 5        economic      -3.9560  -5.2148   1.0779               1.3329
# 6          egoism      -0.7092   0.9077  -7.6420               6.8448
# 7      employment      -4.0283   8.3524   3.0214              -8.1426
# 8        finances       4.3191  -2.4447   1.3367              -2.0126
# 9             war      -1.2751  -1.7701   1.7412               1.3455
# 10        housing      -2.5503   4.4598  -3.5176               0.6910
# 11           fear      -7.2594  -8.6325   5.8405               9.5358
# ...

# %% [markdown]
# ### Standardized residuals

# %%
#standardized residuals
print_dt(residual.rstandard,rowname="Rows points",title=html("<b>Model standardized residuals</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified     cep    bepc  high_school_diploma  \
# 0           money       1.8925 -0.1365 -1.1262              -0.9443
# 1          future      -1.4341 -1.6670  1.7059               2.3951
# 2    unemployment       1.7925  1.5906 -0.9569              -1.4980
# 3   circumstances      -1.6394 -0.1545  0.2609               0.5349
# 4            hard       0.6503  0.6271 -0.6252              -0.8340
# 5        economic      -1.1952 -1.2219  0.3262               0.4287
# 6          egoism      -0.1522  0.1511 -1.6427               1.5639
# 7      employment      -1.0062  1.6180  0.7558              -2.1652
# 8        finances       1.8121 -0.7955  0.5617              -0.8989
# 9             war      -0.5552 -0.5977  0.7593               0.6236
# 10        housing      -0.7851  1.0649 -1.0846               0.2265
# 11           fear      -1.2781 -1.1788  1.0299               1.7873
# 12         health      -0.2000 -0.7802  0.2743               0.5762
# ...

# %% [markdown]
# ### Adjusted residuals

# %%
#adjusted residuals
print_dt(residual.radjusted,rowname="Rows points",title=html("<b>Model adjusted residuals</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified     cep    bepc  high_school_diploma  \
# 0           money       2.2612 -0.1788 -1.3451              -1.1118
# 1          future      -1.7955 -2.2891  2.1350               2.9550
# 2    unemployment       2.2141  2.1548 -1.1816              -1.8233
# 3   circumstances      -1.8490 -0.1911  0.2941               0.5945
# 4            hard       0.7346  0.7770 -0.7060              -0.9283
# 5        economic      -1.3620 -1.5271  0.3715               0.4814
# 6          egoism      -0.1765  0.1922 -1.9043               1.7872
# 7      employment      -1.1560  2.0388  0.8681              -2.4512
# 8        finances       2.0478 -0.9859  0.6345              -1.0009
# 9             war      -0.6270 -0.7403  0.8571               0.6940
# 10        housing      -0.8941  1.3300 -1.2347               0.2541
# 11           fear      -1.5089 -1.5262  1.2154               2.0792
# 12         health      -0.2308 -0.9877  0.3165               0.6554
# ...

# %% [markdown]
# ### Contributions to $\chi^{2}$

# %%
#contribution to chi-squared
print_dt(residual.contrib,rowname="Rows points",title=html("<b>Model residual contribution to chi-squared</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified     cep    bepc  high_school_diploma  \
# 0           money       3.6249  0.0189  1.2837               0.9026
# 1          future       2.0815  2.8126  2.9453               5.8063
# 2    unemployment       3.2519  2.5607  0.9268               2.2713
# 3   circumstances       2.7202  0.0242  0.0689               0.2896
# 4            hard       0.4280  0.3981  0.3956               0.7040
# 5        economic       1.4458  1.5111  0.1077               0.1860
# 6          egoism       0.0234  0.0231  2.7312               2.4756
# 7      employment       1.0247  2.6497  0.5782               4.7450
# 8        finances       3.3236  0.6405  0.3193               0.8179
# 9             war       0.3120  0.3616  0.5835               0.3937
# 10        housing       0.6239  1.1477  1.1907               0.0519
# 11           fear       1.6534  1.4063  1.0735               3.2333
# 12         health       0.0405  0.6161  0.0762               0.3361
# ...

# %% [markdown]
# ### Attraction repulsion index

# %%
#attraction repulsion index
print_dt(residual.att_rep_ind,rowname="Rows points",title=html("<b>Model attraction repulsion index</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified     cep    bepc  high_school_diploma  \
# 0           money       1.3024  0.9831  0.8197               0.8393
# 1          future       0.8215  0.8390  1.2127               1.3174
# 2    unemployment       1.2366  1.1628  0.8735               0.7895
# 3   circumstances       0.2240  0.9433  1.1237               1.2695
# 4            hard       1.2778  1.2078  0.7325               0.6207
# 5        economic       0.6389  0.7137  1.0987               1.1379
# 6          egoism       0.9673  1.0251  0.6469               1.3573
# 7      employment       0.7487  1.3134  1.1891               0.4243
# 8        finances       1.7603  0.7412  1.2360               0.5985
# 9             war       0.7583  0.7982  1.3311               1.2891
# 10        housing       0.7583  1.2543  0.6656               1.0742
# 11           fear       0.7750  0.8390  1.1816               1.3350
# 12         health       0.9540  0.8607  1.0632               1.1412
# ...

# %% [markdown]
# ### Others statistics

# %%
#others statistics
others = res_ca.others_
others._fields
# Out:
# ('kaiser',)

# %%
#kaiser threshold
others.kaiser.threshold
# Out:
# 0.015515325403520212

# %%
#kaiser thresdold proportion
others.kaiser.proportion
# Out:
# 25.0

# %% [markdown]
# ## Supplementary elements
#
# ### Supplementary rows

# %%
#supplementary rows
row_sup = res_ca.row_sup_
row_sup._fields
# Out:
# ('coord', 'cos2', 'dist')

# %% [markdown]
# #### Supplementary rows factor coordinates

# %%
#supplementary rows factor coordinates
print_dt(row_sup.coord,rowname="Rows points",title=html("<b>Supplementary rows points coordinates</b>"))
# Out:
# GT(_tbl_data=    Rows points   Dim.1   Dim.2   Dim.3   Dim.4
# 0       comfort  0.2097  0.7032  0.0711  0.3071
# 1  disagreement  0.1463  0.1190  0.1711 -0.3132
# 2         world  0.5233  0.1430  0.0840 -0.1064
# ...

# %% [markdown]
# #### Supplementary rows square cosinus

# %%
#supplementary rows square cosinus
print_dt(row_sup.cos2,rowname="Rows points",title=html("<b>Supplementary rows points Cos2</b>"))
# Out:
# GT(_tbl_data=    Rows points   Dim.1   Dim.2   Dim.3   Dim.4
# 0       comfort  0.0689  0.7752  0.0079  0.1479
# 1  disagreement  0.1313  0.0869  0.1796  0.6021
# 2         world  0.8759  0.0654  0.0226  0.0362
# ...

# %% [markdown]
# #### Supplementary rows squared distance to origin

# %%
#supplementary rows squared distance to origin
print_dt(row_sup.dist,rowname="Rows points",title=html("<b>Supplementary rows points squared distance to origin</b>"))
# Out:
# GT(_tbl_data=    Rows points  Sq. Dist.
# 0       comfort     0.6378
# 1  disagreement     0.1629
# 2         world     0.3127
# ...

# %% [markdown]
# ### Supplementary columns

# %%
#supplementary columns informations
col_sup = res_ca.col_sup_
col_sup._fields
# Out:
# ('coord', 'cos2', 'dist')

# %% [markdown]
# #### Supplementary columns factor coordinates

# %%
#supplementary columns factor coordinates
print_dt(col_sup.coord,rowname="Columns points",title=html("<b>Supplementary columns points coordinates</b>"))
# Out:
# GT(_tbl_data=  Columns points   Dim.1   Dim.2   Dim.3   Dim.4
# 0         thirty  0.1054 -0.0597 -0.1032  0.0698
# 1          fifty -0.0171  0.0491 -0.0157 -0.0131
# ...

# %% [markdown]
# #### Supplementary columns square cosinus (cos2)

# %%
#supplementary columns square cosinus (cos2)
print_dt(col_sup.cos2,rowname="Columns points",title=html("<b>Supplementary columns points Cos2</b>"))
# Out:
# GT(_tbl_data=  Columns points   Dim.1   Dim.2   Dim.3   Dim.4
# 0         thirty  0.1376  0.0441  0.1319  0.0603
# 1          fifty  0.0109  0.0899  0.0092  0.0064
# ...

# %% [markdown]
# #### Supplementary columns square distance to origin

# %%
#supplementary columns square distance to origin
print_dt(col_sup.dist,rowname="Columns points",title=html("<b>Supplementary columns points squared distance to origin</b>"))
# Out:
# GT(_tbl_data=  Columns points  Sq. Dist.
# 0         thirty     0.0808
# 1          fifty     0.0268
# ...

# %% [markdown]
# ### Supplementary quantitative variables

# %%
#supplementary quantitative variables informations
quanti_sup = res_ca2.quanti_sup_
quanti_sup._fields
# Out:
# ('coord', 'cos2')

# %% [markdown]
# #### Supplementary quantitative variables factor coordinates

# %%
#supplementary quantitative variables factor coordinates
print_dt(quanti_sup.coord,rowname="Variables",title=html("<b>Supplementary quantitative variables coordinates</b>"))
# Out:
# GT(_tbl_data=    Variables   Dim.1   Dim.2   Dim.3   Dim.4
# 0      thirty  0.1219 -0.6056 -0.2534 -0.0308
# 1       fifty  0.0162 -0.6011 -0.2474 -0.0889
# ...

# %% [markdown]
# #### Supplementary quantitative variables square cosinus (cos2)

# %%
#supplementary quantitative variables square cosinus
print_dt(quanti_sup.cos2,rowname="Variables",title=html("<b>Supplementary quantitative variables Cos2</b>"))
# Out:
# GT(_tbl_data=    Variables   Dim.1   Dim.2   Dim.3   Dim.4
# 0      thirty  0.0149  0.3668  0.0642  0.0010
# 1       fifty  0.0003  0.3613  0.0612  0.0079
# ...

# %% [markdown]
# ### Supplementary qualitative variables

# %%
#supplementary qualitative variables informations
quali_sup = res_ca.quali_sup_
quali_sup._fields
# Out:
# ('coord', 'cos2', 'vtest', 'dist', 'eta2')

# %% [markdown]
# #### Supplementary categories factor coordinates

# %%
#supplementary categories factor coordinates
print_dt(quali_sup.coord,rowname="Modalities",title=html("<b>Supplementary categories coordinates</b>"))
# Out:
# GT(_tbl_data=   Modalities   Dim.1   Dim.2   Dim.3   Dim.4
# 0    economic -0.0355  0.0561  0.0828  0.1223
# 1      labour -0.2004  0.0262 -0.0494 -0.0237
# 2      others  0.1180 -0.0379  0.0407 -0.0407
# ...

# %% [markdown]
# #### Supplementary categories square cosinus (cos2)

# %%
#supplementary categories square cosinus (cos2)
print_dt(quali_sup.cos2,rowname="Modalities",title=html("<b>Supplementary categories Cos2</b>"))
# Out:
# GT(_tbl_data=   Modalities   Dim.1   Dim.2   Dim.3   Dim.4
# 0    economic  0.0481  0.1199  0.2613  0.5707
# 1      labour  0.9158  0.0157  0.0557  0.0128
# 2      others  0.7456  0.0770  0.0887  0.0888
# ...

# %% [markdown]
# #### Supplementary categories square distance to origin

# %%
#supplementary categories square distance to origin
print_dt(quali_sup.dist,rowname="Modalities",title=html("<b>Supplementary categories squared distance to origin</b>"))
# Out:
# GT(_tbl_data=   Modalities  Sq. Dist.
# 0    economic     0.0262
# 1      labour     0.0439
# 2      others     0.0187
# ...

# %% [markdown]
# #### Supplementary categories value-test (vtest)

# %%
#supplementary categories valeu-test (vtest)
print_dt(quali_sup.vtest,rowname="Modalities",title=html("<b>Supplementary categories value-test (vtest)</b>"))
# Out:
# GT(_tbl_data=   Modalities   Dim.1   Dim.2   Dim.3   Dim.4
# 0    economic -0.6474  1.0221  1.5087  2.2297
# 1      labour -5.5128  0.7208 -1.3596 -0.6524
# 2      others  2.3553 -0.7570  0.8122 -0.8127
# ...

# %% [markdown]
# #### Supplementary qualitative variables square correlation ratio (eta2)

# %%
#supplementary qualitative variables square correlation ratio (eta2)
print_dt(quali_sup.eta2,rowname="Variables",title=html("<b>Supplementary qualitative variables eta<sup>2</sup></b>"))
# Out:
# GT(_tbl_data=   Variables   Dim.1  Dim.2   Dim.3   Dim.4
# ...

# %% [markdown]
# ## Others
#
# ### Extractions functions

# %%
from scientisttools import get_ca
row = get_ca(res_ca,element="row")
col = get_ca(res_ca,element="col")

# %% [markdown]
# ### Summary

# %%
from scientisttools import summaryCA
summaryCA(res_ca)
# Out:
#                      Correspondence Analysis - Results
#
# Eigenvalues
#                           Dim.1   Dim.2   Dim.3    Dim.4
# Variance                  0.035   0.013   0.007    0.006
# Difference                0.022   0.006   0.001      NaN
# % of var.                57.043  21.132  11.764   10.061
# Cumulative of % of var.  57.043  78.175  89.939  100.000
#
# Chi-squared test
#
#                            statistic  dof  critical value    pvalue  \
# Pearson's Chi-Square Test  98.801592   52        69.83216  0.000097
#
#                                       conclusion
# Pearson's Chi-Square Test  Dependent (reject H0)
#
# log-likelihood test
#
#         statistic  dof  critical value    pvalue             conclusion
# g-test  99.063566   52        69.83216  0.000091  Dependent (reject H0)
#
# Others measure of association
#
#            cramer  tschuprow  pearson
# statistic   0.125      0.093    0.242
#
# Rows (the 10 first)
#
# ...

# %%
summaryCA(res_ca2)
# Out:
#                      Correspondence Analysis - Results
#
# Eigenvalues
#                           Dim.1   Dim.2   Dim.3    Dim.4
# Variance                  0.035   0.013   0.007    0.006
# Difference                0.022   0.006   0.001      NaN
# % of var.                57.043  21.132  11.764   10.061
# Cumulative of % of var.  57.043  78.175  89.939  100.000
#
# Chi-squared test
#
#                            statistic  dof  critical value    pvalue  \
# Pearson's Chi-Square Test  98.801592   52        69.83216  0.000097
#
#                                       conclusion
# Pearson's Chi-Square Test  Dependent (reject H0)
#
# log-likelihood test
#
#         statistic  dof  critical value    pvalue             conclusion
# g-test  99.063566   52        69.83216  0.000091  Dependent (reject H0)
#
# Others measure of association
#
#            cramer  tschuprow  pearson
# statistic   0.125      0.093    0.242
#
# Rows (the 10 first)
#
# ...

# %% [markdown]
# ### Dimension description

# %%
from scientisttools import dimdesc
dimDesc = dimdesc(res_ca)
dimDesc.keys()
# Out:
# dict_keys(['Dim.1', 'Dim.2', 'Dim.3', 'Dim.4'])

# %%
dimDesc["Dim.1"]
# Out:
# {'row':                   coord
#  hard          -0.249984
#  finances      -0.236996
#  unemployment  -0.212228
#  work          -0.211677
#  employment    -0.136755
#  money         -0.115267
#  housing       -0.006681
#  egoism         0.059889
#  health         0.111652
#  disagreement   0.146278
#  future         0.176449
#  fear           0.203348
#  comfort        0.209670
#  war            0.216824
#  to_live        0.308307
#  economic       0.353964
#  circumstances  0.400922
#  world          0.523304,
#  'col':                         coord
#  unqualified         -0.209318
#  more_fifty          -0.177068
#  cep                 -0.138577
#  fifty               -0.017064
#  thirty               0.105413
#  bepc                 0.108758
#  university           0.231233
#  high_school_diploma  0.274039}

# %% [markdown]
# # Data reconstruction

# %%
from scientisttools import reconst
#n_components = 1
res_rec1 = reconst(res_ca,1)
print_dt(res_rec1,rowname="Rows points",title=html("<b>Reproduced Children Dataset (ncp = 1)</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified       cep     bepc  high_school_diploma  \
# 0           money      44.1790   70.6279  36.4355              28.7504
# 1          future      51.8539   93.3253  70.8792              71.5586
# 2    unemployment      70.9741  110.3802  50.2181              35.0027
# 3   circumstances       2.4727    5.2296   5.4810               6.2382
# 4            hard       7.0015   10.7842   4.6719               3.0737
# 5        economic       6.6418   13.4663  13.1568              14.6508
# 6          egoism      20.2628   34.5003  22.3912              20.8260
# 7      employment      18.4668   29.3316  14.7156              11.3257
# 8        finances       7.1787   11.0933   4.8875               3.2823
# 9             war       4.0027    7.3696   5.9179               6.1244
# 10        housing      10.6287   17.6265  10.4770               9.2185
# 11           fear      24.9616   45.6001  35.9396              36.8944
# ...

# %%
#n_components = 2
res_rec2 = reconst(res_ca,2)
print_dt(res_rec2,rowname="Rows points",title=html("<b>Reproduced Children Dataset (ncp = 2)</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified       cep     bepc  high_school_diploma  \
# 0           money      43.6257   71.2666  36.2409              28.0165
# 1          future      56.3048   88.1878  72.4447              77.4618
# 2    unemployment      73.8364  107.0764  51.2249              38.7989
# 3   circumstances       1.4313    6.4317   5.1146               4.8570
# 4            hard       6.7402   11.0858   4.5801               2.7272
# 5        economic       4.1648   16.3254  12.2855              11.3656
# 6          egoism      20.6556   34.0469  22.5293              21.3470
# 7      employment      16.0331   32.1407  13.8596               8.0979
# 8        finances       8.0036   10.1412   5.1776               4.3764
# 9             war       4.2803    7.0491   6.0155               6.4926
# 10        housing       9.6749   18.7274  10.1415               7.9535
# 11           fear      26.2821   44.0759  36.4041              38.6458
# ...

# %%
#n_components = max_components
res_rec5 = reconst(res_ca,res_ca.eig_.shape[0])
print_dt(res_rec5,rowname="Rows points",title=html("<b>Reproduced Children Dataset (ncp = 5)</b>"))
# Out:
# GT(_tbl_data=      Rows points  unqualified    cep  bepc  high_school_diploma  university
# 0           money         51.0   64.0  32.0                 29.0        17.0
# 1          future         53.0   90.0  78.0                 75.0        22.0
# 2    unemployment         71.0  111.0  50.0                 40.0        11.0
# 3   circumstances          1.0    7.0   5.0                  5.0         4.0
# 4            hard          7.0   11.0   4.0                  3.0         2.0
# 5        economic          7.0   13.0  12.0                 11.0        11.0
# 6          egoism         21.0   37.0  14.0                 26.0         9.0
# 7      employment         12.0   35.0  19.0                  6.0         7.0
# 8        finances         10.0    7.0   7.0                  3.0         1.0
# 9             war          4.0    7.0   7.0                  6.0         2.0
# 10        housing          8.0   22.0   7.0                 10.0         5.0
# ...
