# %% [markdown]
# # Analyse en Facteurs principaux

# %%
# Chargement des librairies
import numpy as np
import pandas as pd
from plydata import *
import matplotlib.pyplot as plt
from scientisttools.decomposition import EFA
from scientisttools.pyplot import plot_eigenvalues,plotEFA
from scientisttools.extractfactor import summaryEFA
from scientisttools.ggplot import fviz_efa_ind,fviz_efa_var

import os
os.chdir("d:/Bureau/PythonProject/packages/scientisttools/data/")

# %%
# Chargement des données
D = pd.read_excel("Data_Methodes_Factorielles.xlsx",sheet_name="AUTOS_AFP",index_col=0)
display(D >> head(6))
# Out:
#                   CYL  PUISS  LONG  LARG  POIDS  VMAX   RND1   RND2   RND3  \
# Modele
# Alfasud TI       1350     79   393   161    870   165  1.029  0.109  0.267
# Audi 100         1588     85   468   177   1110   160  0.379  0.367 -1.054
# Simca 1300       1294     68   424   168   1050   152 -0.346  0.737 -0.056
# Citroen GS Club  1222     59   412   161    930   151  0.849  0.494 -0.320
# Fiat 132         1585     98   439   164   1105   165 -1.425 -0.210  0.535
# Lancia Beta      1297     82   429   169   1080   160  0.890  0.071 -1.308
#
#                   RND4   RND5   RND6
# Modele
# Alfasud TI      -0.949  0.053 -1.144
# Audi 100         0.106  1.316  1.632
# Simca 1300      -0.430  0.274  1.044
# Citroen GS Club  0.729  0.637  0.793
# Fiat 132        -0.200 -1.983  0.832
# Lancia Beta     -0.971 -0.131 -1.134

# %%
# Instanciation
my_efa = EFA(normalize=True,
            n_components=None,
            row_labels=D.index,
            col_labels=D.columns,
            method="principal",
            row_sup_labels=None,
            quanti_sup_labels=None,
            quali_sup_labels=None)

my_efa.fit(D)
# Out:
# d:\Bureau\PythonProject\packages\scientisttools\scientisttools\decomposition.py:1557: RuntimeWarning: invalid value encountered in sqrt
# EFA(col_labels=Index(['CYL', 'PUISS', 'LONG', 'LARG', 'POIDS', 'VMAX', 'RND1', 'RND2', 'RND3',
#        'RND4', 'RND5', 'RND6'],
#       dtype='object'),
#     row_labels=Index(['Alfasud TI', 'Audi 100', 'Simca 1300', 'Citroen GS Club', 'Fiat 132',
#        'Lancia Beta', 'Peugeot 504', 'Renault 16 TL', 'Renault 30',
#        'Toyota Corolla', 'Alfetta 1.66', 'Princess 1800', 'Datsun 200L',
#        'Taunus 2000', 'Rancho', 'Mazda 9295', 'Opel Rekord', 'Lada 1300'],
#       dtype='object', name='Modele'))

# %%
p = fviz_efa_ind(my_efa,repel=True)
print(p)

# %%
p = fviz_efa_var(my_efa,color="blue",repel=False)
print(p)

# %% [markdown]
# ### Correlation matrix

# %%
# Matrice des corrélations
my_efa.correlation_matrix_
# Out:
#             CYL     PUISS      LONG      LARG     POIDS      VMAX      RND1  \
# CYL    1.000000  0.796628  0.701462  0.629757  0.788952  0.664934 -0.282458
# PUISS  0.796628  1.000000  0.641362  0.520832  0.765293  0.844379 -0.377348
# LONG   0.701462  0.641362  1.000000  0.849266  0.868090  0.475928 -0.288895
# LARG   0.629757  0.520832  0.849266  1.000000  0.716874  0.472945 -0.190303
# POIDS  0.788952  0.765293  0.868090  0.716874  1.000000  0.477596 -0.355129
# VMAX   0.664934  0.844379  0.475928  0.472945  0.477596  1.000000 -0.313810
# RND1  -0.282458 -0.377348 -0.288895 -0.190303 -0.355129 -0.313810  1.000000
# RND2   0.235575  0.348786  0.218247  0.245769  0.274051  0.265883 -0.440786
# RND3  -0.059791 -0.108438 -0.013946 -0.192400 -0.012082 -0.193767  0.021014
# RND4   0.566765  0.431745  0.308515  0.483533  0.352751  0.375915 -0.176500
# RND5  -0.549617 -0.576086 -0.481575 -0.261919 -0.618620 -0.453435  0.371941
# RND6  -0.126223  0.071292  0.308955  0.110979  0.093659  0.111810 -0.020128
#
#            RND2      RND3      RND4      RND5      RND6
# CYL    0.235575 -0.059791  0.566765 -0.549617 -0.126223
# PUISS  0.348786 -0.108438  0.431745 -0.576086  0.071292
# LONG   0.218247 -0.013946  0.308515 -0.481575  0.308955
# LARG   0.245769 -0.192400  0.483533 -0.261919  0.110979
# POIDS  0.274051 -0.012082  0.352751 -0.618620  0.093659
# VMAX   0.265883 -0.193767  0.375915 -0.453435  0.111810
# RND1  -0.440786  0.021014 -0.176500  0.371941 -0.020128
# RND2   1.000000  0.083100  0.428733 -0.248758  0.012274
# RND3   0.083100  1.000000 -0.027545 -0.383219 -0.018782
# RND4   0.428733 -0.027545  1.000000 -0.139412 -0.241340
# RND5  -0.248758 -0.383219 -0.139412  1.000000 -0.015091
# RND6   0.012274 -0.018782 -0.241340 -0.015091  1.000000

# %%
# Communalités initiales
pd.DataFrame(my_efa.initial_communality_,index=D.columns,columns=["initial"])
# Out:
#         initial
# CYL    0.843053
# PUISS  0.922937
# LONG   0.925902
# LARG   0.879876
# POIDS  0.923971
# VMAX   0.882288
# RND1   0.336690
# RND2   0.394369
# RND3   0.450844
# RND4   0.610068
# RND5   0.688055
# RND6   0.506320

# %%
# Inertie totale
my_efa.inertia_
# Out:
# 8.364373071752013

# %%
# Valeur propres
pd.DataFrame(my_efa.eig_.T,columns=["eigenvalue","difference","proportion","cumulative"],index=my_efa.dim_index_)
# Out:
#        eigenvalue  difference  proportion  cumulative
# Dim.1    5.229521    4.218050   62.521371   62.521371
# Dim.2    1.011471    0.035886   12.092609   74.613980
# Dim.3    0.975585    0.252347   11.663576   86.277556
# Dim.4    0.723238    0.184633    8.646650   94.924207
# Dim.5    0.538606    0.275195    6.439281  101.363488
# Dim.6    0.263410    0.167558    3.149191  104.512679
# Dim.7    0.095852    0.089953    1.145956  105.658635
# Dim.8    0.005899    0.049727    0.070530  105.729165

# %%
fig, axe = plt.subplots(figsize=(10,6))
plot_eigenvalues(my_efa,choice="eigenvalue",add_kaiser=True,ax=axe)

# %%
# Broken stick
my_efa.broken_stick_threshold_
# Out:
# array([3.10321068, 2.10321068, 1.60321068, 1.26987734, 1.01987734,
#        0.81987734, 0.65321068, 0.51035354])

# %%
# Coordonnées des variables
pd.DataFrame(my_efa.col_coord_,index=D.columns)
# Out:
#               0         1         2         3         4         5         6  \
# CYL    0.874463  0.084990 -0.152994 -0.088167  0.264709 -0.004500  0.038756
# PUISS  0.893121  0.117049 -0.063503  0.311513  0.089056  0.027141  0.136213
# LONG   0.850778 -0.367295  0.265757 -0.169450 -0.040122 -0.032241 -0.005522
# LARG   0.768420 -0.423811 -0.125322 -0.273809 -0.087620 -0.086367 -0.144601
# POIDS  0.894371 -0.094914  0.204898 -0.169556  0.095826  0.225432  0.084302
# VMAX   0.749973  0.058408 -0.189538  0.504833  0.063120 -0.177884 -0.108603
# RND1  -0.414234 -0.231072 -0.055922 -0.102837  0.317637 -0.236208  0.085191
# RND2   0.391899  0.284307 -0.090675 -0.040309 -0.480103  0.019038  0.025142
# RND3  -0.046057  0.417174  0.443544 -0.251489  0.003919 -0.247458  0.020835
# RND4   0.524426  0.181777 -0.469907 -0.269048 -0.145371 -0.177666  0.087434
# RND5  -0.618223 -0.401492 -0.431948 -0.011085 -0.120049  0.010678  0.098641
# RND6   0.077452 -0.401383  0.410406  0.288406 -0.266830 -0.150402  0.101273
#
#               7
# CYL   -0.045990
# PUISS  0.030580
# LONG  -0.027719
# LARG   0.030604
# POIDS  0.022486
# VMAX   0.000249
# RND1   0.020099
# RND2   0.003468
# RND3   0.007888
# RND4  -0.004061
# RND5  -0.004826
# RND6  -0.010979

# %%
fig, axe = plt.subplots(figsize=(10,10))
plotEFA(my_efa,choice="var",repel=True,ax=axe)

# %%
# Variance restituée
my_efa.explained_variance_
# Out:
# array([5.22952071, 1.01147097, 0.97558499, 0.7232381 , 0.53860551,
#        0.26341008, 0.09585205, 0.00589936])

# %%
# Communalités estimées
pd.DataFrame(my_efa.estimated_communality_,index=D.columns,columns=["estimated"])
# Out:
#        estimated
# CYL     0.876798
# PUISS   0.940594
# LONG    0.961517
# LARG    0.897745
# POIDS   0.947255
# VMAX    0.904074
# RND1    0.403035
# RND2    0.475767
# RND3    0.497881
# RND4    0.661624
# RND5    0.754376
# RND6    0.522914

# %%
# Qualité de la représentation des variables
pd.DataFrame(my_efa.percentage_variance_,index=D.columns,columns=["% var."])
# Out:
#          % var.
# CYL    1.040027
# PUISS  1.019131
# LONG   1.038466
# LARG   1.020308
# POIDS  1.025200
# VMAX   1.024693
# RND1   1.197050
# RND2   1.206402
# RND3   1.104331
# RND4   1.084509
# RND5   1.096389
# RND6   1.032775

# %%
# Factor scores
pd.DataFrame(my_efa.factor_score_,index=D.columns)
# Out:
#               0         1         2         3         4         5         6  \
# CYL    0.098976  0.257383 -0.614904 -0.358634  0.724245 -0.120129  0.054561
# PUISS  0.200054  0.268495 -0.502700  0.472290 -0.075685 -0.242808  1.114154
# LONG   0.217457 -0.737828  1.241743  0.092864 -0.482853 -0.644497  0.115430
# LARG   0.101000 -0.188740 -0.943707 -0.460943 -0.028095 -0.229901 -0.418312
# POIDS  0.240592 -0.041291  0.402047 -0.211347  0.309958  1.405726 -0.086877
# VMAX   0.190469 -0.152789  0.213810  0.706092  0.066309 -0.078366 -0.826305
# RND1  -0.035438 -0.128374  0.093124 -0.027899  0.255338 -0.221107  0.106449
# RND2   0.054243  0.146876  0.000456 -0.044169 -0.367213  0.040489 -0.029128
# RND3   0.027593  0.218099  0.085709 -0.137419  0.060197 -0.249791  0.021864
# RND4   0.068207  0.151815 -0.085991 -0.213755 -0.318784 -0.217308  0.201675
# RND5  -0.035918 -0.417231 -0.376616  0.096036  0.006827  0.232967  0.280694
# RND6  -0.031482 -0.088133  0.005198  0.120039 -0.120220 -0.105085  0.195837
#
#               7
# CYL   -0.212714
# PUISS  0.358805
# LONG  -0.556340
# LARG   0.439364
# POIDS  0.173584
# VMAX  -0.153091
# RND1   0.007036
# RND2  -0.054381
# RND3   0.079094
# RND4  -0.046797
# RND5  -0.021495
# RND6   0.051251

# %%
# Contribution des variables par facteurs
pd.DataFrame(my_efa.col_contrib_,index=D.columns)
# Out:
#               0         1             2         3         4         5  \
# CYL    0.045914  0.064073  1.100442e-01  0.106566  0.442845  0.005249
# PUISS  0.187575  0.069725  7.354775e-02  0.184813  0.004836  0.021444
# LONG   0.221630  0.526533  4.487613e-01  0.007145  0.196839  0.151085
# LARG   0.047810  0.034454  2.591951e-01  0.176039  0.000666  0.019225
# POIDS  0.271297  0.001649  4.704411e-02  0.037009  0.081112  0.718756
# VMAX   0.170033  0.022579  1.330483e-02  0.413083  0.003712  0.002234
# RND1   0.005886  0.015939  2.523934e-03  0.000645  0.055044  0.017782
# RND2   0.013790  0.020865  6.044163e-08  0.001616  0.113846  0.000596
# RND3   0.003568  0.046007  2.138003e-03  0.015646  0.003059  0.022695
# RND4   0.021804  0.022292  2.152060e-03  0.037857  0.085797  0.017176
# RND5   0.006047  0.168372  4.128084e-02  0.007642  0.000039  0.019741
# RND6   0.004645  0.007513  7.863966e-06  0.011939  0.012202  0.004017
#
#               6         7
# CYL    0.001298  0.060763
# PUISS  0.541260  0.172888
# LONG   0.005810  0.415649
# LARG   0.076298  0.259236
# POIDS  0.003291  0.040464
# VMAX   0.297712  0.031474
# RND1   0.004941  0.000066
# RND2   0.000370  0.003971
# RND3   0.000208  0.008401
# RND4   0.017735  0.002941
# RND5   0.034354  0.000620
# RND6   0.016723  0.003527

# %%
fig, axe = plt.subplots(figsize=(10,10))
plotEFA(my_efa,choice="var",color="contrib",repel=True,ax=axe)

# %%
#Fidelité des facteurs
pd.DataFrame(my_efa.factor_fidelity_,index=my_efa.dim_index_).T
# Out:
#      Dim.1     Dim.2     Dim.3     Dim.4     Dim.5     Dim.6     Dim.7  \
# 0  0.97607  0.792181  0.854107  0.811786  0.575937  0.537133  0.370088
#
#       Dim.8
# 0  0.053796

# %%
#Coordonnées des individus
pd.DataFrame(my_efa.row_coord_,index=D.index)
# Out:
#                         0         1         2         3         4         5  \
# Modele
# Alfasud TI      -0.986199  1.119263 -1.139469  1.136237  0.785169 -0.707775
# Audi 100         0.523302 -2.582756 -0.424237 -0.343694 -1.052671 -0.828028
# Simca 1300      -0.472979 -0.182853 -0.240356 -0.453100 -0.863533  0.423931
# Citroen GS Club -1.081071  0.098957  0.167190 -0.102785 -0.823887 -0.399895
# Fiat 132         0.368924  0.960006  1.306899  0.799801 -0.229934 -0.379263
# Lancia Beta     -0.198631 -0.755777 -0.075183  0.336737  0.147129  0.575347
# Peugeot 504      0.183672 -0.602165  0.597942 -0.473108  0.362699  0.596208
# Renault 16 TL   -1.270892 -1.110566  0.374392 -0.926558  2.110316  0.152032
# Renault 30       2.096801  0.904822 -1.905163 -0.218124  1.105184  0.659583
# Toyota Corolla  -1.787926  0.814933 -0.014127 -0.176486 -0.047461 -0.312991
# Alfetta 1.66     0.069678 -0.654304  0.037095  2.960605  0.141028  0.500129
# Princess 1800    0.454170  0.045963  0.172077 -0.970388  0.106613 -0.005156
# Datsun 200L      1.499793  0.440714  1.987313 -0.507305  0.397208  0.371859
# Taunus 2000      0.659626  0.217548 -1.638553 -0.177856 -0.304363 -0.546920
# Rancho          -0.211494  0.056303  0.026422 -0.703697 -0.830031  1.576455
# Mazda 9295       0.299261  0.510391  0.973527  0.386743 -0.336081  0.191514
# Opel Rekord      1.038765 -0.153442  0.305636  0.085033 -0.214677 -1.883090
# Lada 1300       -1.184801  0.872964 -0.511406 -0.652055 -0.452708  0.016059
#
#                         6         7
# Modele
# Alfasud TI      -0.552847  0.341822
# Audi 100         0.012167 -0.015207
# Simca 1300      -0.473295  0.330536
# Citroen GS Club  0.104267 -0.285677
# Fiat 132         0.020360  0.048807
# Lancia Beta     -0.746940  0.365304
# Peugeot 504     -0.361182 -0.096182
# Renault 16 TL    0.213160 -0.231993
# Renault 30       0.273435 -0.037670
# Toyota Corolla   0.124900 -0.284616
# Alfetta 1.66     0.770475 -0.012255
# Princess 1800   -0.909017  0.097496
# Datsun 200L      1.142958  0.169215
# Taunus 2000      0.284871 -0.106296
# Rancho           0.445727  0.093603
# Mazda 9295      -0.957073 -0.485714
# Opel Rekord     -0.467142 -0.144164
# Lada 1300        1.075175  0.252990

# %%
fig, axe = plt.subplots(figsize=(10,10))
plotEFA(my_efa,choice="ind",repel=True,xlim=(-3,3),ylim=(-3,3),ax=axe)

# %% [markdown]
# ## Analyse de Harris

# %%
# Instanciation
my_efa2 = EFA(normalize=True,
            n_components=D.shape[1],
            row_labels=D.index,
            col_labels=D.columns,
            method="harris",
            row_sup_labels=None,
            quanti_sup_labels=None,
            quali_sup_labels=None)
my_efa2.fit(D)
# Out:
# EFA(col_labels=Index(['CYL', 'PUISS', 'LONG', 'LARG', 'POIDS', 'VMAX', 'RND1', 'RND2', 'RND3',
#        'RND4', 'RND5', 'RND6'],
#       dtype='object'),
#     method='harris', n_components=12,
#     row_labels=Index(['Alfasud TI', 'Audi 100', 'Simca 1300', 'Citroen GS Club', 'Fiat 132',
#        'Lancia Beta', 'Peugeot 504', 'Renault 16 TL', 'Renault 30',
#        'Toyota Corolla', 'Alfetta 1.66', 'Princess 1800', 'Datsun 200L',
#        'Taunus 2000', 'Rancho', 'Mazda 9295', 'Opel Rekord', 'Lada 1300'],
#       dtype='object', name='Modele'))

# %%
pd.DataFrame(my_efa2.eig_.T)
# Out:
#             0          1          2           3
# 0   48.363500  40.296952  76.052629   76.052629
# 1    8.066548   4.333778  12.684818   88.737447
# 2    3.732770   1.044507   5.869860   94.607306
# 3    2.688263   1.378686   4.227351   98.834657
# 4    1.309577   0.335533   2.059338  100.893995
# 5    0.974045   0.611522   1.531706  102.425701
# 6    0.362522   0.327260   0.570074  102.995775
# 7    0.035262   0.315022   0.055450  103.051225
# 8   -0.279760   0.094832  -0.439929  102.611297
# 9   -0.374592   0.209262  -0.589054  102.022243
# 10  -0.583854   0.118280  -0.918123  101.104120
# 11  -0.702134        NaN  -1.104120  100.000000

# %%
summaryEFA(my_efa,to_markdown=True)
# Out:
#                      Exploratory Factor Analysis - Results
#
# Importance of components
# |                         |   Dim.1 |   Dim.2 |   Dim.3 |   Dim.4 |   Dim.5 |   Dim.6 |   Dim.7 |   Dim.8 |
# |:------------------------|--------:|--------:|--------:|--------:|--------:|--------:|--------:|--------:|
# | Variance                |   5.23  |   1.011 |   0.976 |   0.723 |   0.539 |   0.263 |   0.096 |   0.006 |
# | Difference              |   4.218 |   0.036 |   0.252 |   0.185 |   0.275 |   0.168 |   0.09  |   0.05  |
# | % of var.               |  62.521 |  12.093 |  11.664 |   8.647 |   6.439 |   3.149 |   1.146 |   0.071 |
# | Cumulative of % of var. |  62.521 |  74.614 |  86.278 |  94.924 | 101.363 | 104.513 | 105.659 | 105.729 |
#
# Individuals (the 10 first)
#
# | Modele          |   Dim.1 |   Dim.2 |   Dim.3 |
# |:----------------|--------:|--------:|--------:|
# | Alfasud TI      |  -0.986 |   1.119 |  -1.139 |
# | Audi 100        |   0.523 |  -2.583 |  -0.424 |
# | Simca 1300      |  -0.473 |  -0.183 |  -0.24  |
# | Citroen GS Club |  -1.081 |   0.099 |   0.167 |
# | Fiat 132        |   0.369 |   0.96  |   1.307 |
# | Lancia Beta     |  -0.199 |  -0.756 |  -0.075 |
# | Peugeot 504     |   0.184 |  -0.602 |   0.598 |
# | Renault 16 TL   |  -1.271 |  -1.111 |   0.374 |
# | Renault 30      |   2.097 |   0.905 |  -1.905 |
# | Toyota Corolla  |  -1.788 |   0.815 |  -0.014 |
#
# Continues Variables
#
# |       |   Dim.1 |   ctr |   Dim.2 |   ctr |   Dim.3 |   ctr |
# |:------|--------:|------:|--------:|------:|--------:|------:|
# | CYL   |   0.874 | 0.046 |   0.085 | 0.064 |  -0.153 | 0.11  |
# | PUISS |   0.893 | 0.188 |   0.117 | 0.07  |  -0.064 | 0.074 |
# | LONG  |   0.851 | 0.222 |  -0.367 | 0.527 |   0.266 | 0.449 |
# | LARG  |   0.768 | 0.048 |  -0.424 | 0.034 |  -0.125 | 0.259 |
# | POIDS |   0.894 | 0.271 |  -0.095 | 0.002 |   0.205 | 0.047 |
# | VMAX  |   0.75  | 0.17  |   0.058 | 0.023 |  -0.19  | 0.013 |
# | RND1  |  -0.414 | 0.006 |  -0.231 | 0.016 |  -0.056 | 0.003 |
# | RND2  |   0.392 | 0.014 |   0.284 | 0.021 |  -0.091 | 0     |
# | RND3  |  -0.046 | 0.004 |   0.417 | 0.046 |   0.444 | 0.002 |
# | RND4  |   0.524 | 0.022 |   0.182 | 0.022 |  -0.47  | 0.002 |
