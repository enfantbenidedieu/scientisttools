# %% [markdown]
# # Hierarchical clustering Analysis of Qualitatives variables (VARQUALHCA)

# %%
#changement de dossier
import os
os.chdir("d:/Bureau/PythonProject/packages/scientisttools/data/")

#importation des données
import pandas as pd
vote = pd.read_excel("vote_clustering.xlsx")
vote.head()
# Out:
#   affiliation budget physician salvador nicaraguan missile education
# 0  republican      n         y        y          n       n         y
# 1  republican      n         y        y          n       n         y
# 2    democrat      y   neither        y          n       n         n
# 3    democrat      y         n  neither          n       n         n
# 4    democrat      y         n        y          n       n   neither

# %%
#variables actives
X = vote.iloc[:,1:]
print(X.columns)
# Out:
# Index(['budget', 'physician', 'salvador', 'nicaraguan', 'missile',
#        'education'],
#       dtype='object')

# %%
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 435 entries, 0 to 434
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   budget      435 non-null    object
#  1   physician   435 non-null    object
#  2   salvador    435 non-null    object
#  3   nicaraguan  435 non-null    object
#  4   missile     435 non-null    object
#  5   education   435 non-null    object
# dtypes: object(6)
# memory usage: 20.5+ KB

# %%
# Importation de la fonction
from scientisttools.clustering import CATVARHCA
from scientisttools.pyplot import plot_dendrogram
import matplotlib.pyplot as plt
# Set figure size
plt.rcParams['figure.figsize'] = [16,16]

# %% [markdown]
# ### CAH sur les variables : V de Cramer
#
# #### Matrice originale

# %%
# Construction du model
catvarhca = CATVARHCA(n_clusters=2,
                      var_labels=list(X.columns),
                      diss_metric="cramer",
                      matrix_type="completed",
                      metric="euclidean",
                      method="ward",
                      parallelize=True)
# Instanciation
catvarhca.fit(X)
# Out:
# CATVARHCA(n_clusters=2, parallelize=True,
#           var_labels=['budget', 'physician', 'salvador', 'nicaraguan',
#                       'missile', 'education'])

# %%
#Dissimilarity matrix
catvarhca.diss_matrix_
# Out:
#               budget  physician  salvador  nicaraguan   missile  education
# budget      0.000000   0.360782  0.493170    0.482666  0.561172   0.524634
# physician   0.360782   0.000000  0.423504    0.482176  0.528899   0.491124
# salvador    0.493170   0.423504  0.000000    0.388881  0.442139   0.530398
# nicaraguan  0.482666   0.482176  0.388881    0.000000  0.454786   0.531160
# missile     0.561172   0.528899  0.442139    0.454786  0.000000   0.573338
# education   0.524634   0.491124  0.530398    0.531160  0.573338   0.000000

# %%
plot_dendrogram(catvarhca,orientation='top',leaf_rotation=90,color_threshold=0.6)
plt.show()

# %%
# Positionner les variables supplémentaires
Xsup =  vote.iloc[:,0]
catvarhca.transform(Xsup)
# Out:
#            affiliation
# cluster
# cluster_1     0.780505
# cluster_2     0.666967

# %% [markdown]
# #### Matrice Disjonctif

# %%
# Dummies DataFrame
disj = pd.get_dummies(X,prefix_sep='_',drop_first=False)
catvarhca2 = CATVARHCA(n_clusters=2,
                       var_labels=list(X.columns),
                       diss_metric="cramer",
                       matrix_type="disjonctif",
                       metric="euclidean",
                       method="ward",
                       parallelize=True)
# Instanciation
catvarhca2.fit(disj)
# Out:
# CATVARHCA(matrix_type='disjonctif', n_clusters=2, parallelize=True,
#           var_labels=['budget', 'physician', 'salvador', 'nicaraguan',
#                       'missile', 'education'])

# %%
#
catvarhca2.diss_matrix_
# Out:
#               budget  physician  salvador  nicaraguan   missile  education
# budget      0.000000   0.360782  0.493170    0.482666  0.561172   0.524634
# physician   0.360782   0.000000  0.423504    0.482176  0.528899   0.491124
# salvador    0.493170   0.423504  0.000000    0.388881  0.442139   0.530398
# nicaraguan  0.482666   0.482176  0.388881    0.000000  0.454786   0.531160
# missile     0.561172   0.528899  0.442139    0.454786  0.000000   0.573338
# education   0.524634   0.491124  0.530398    0.531160  0.573338   0.000000

# %% [markdown]
# Les matrices de dissimilarité sont identiques

# %%
Xsupdisj = pd.get_dummies(Xsup,prefix=Xsup.name,prefix_sep='_',drop_first=False)
catvarhca2.transform(Xsupdisj)
# Out:
#            affiliation
# cluster
# cluster_1     0.780505
# cluster_2     0.666967

# %% [markdown]
# ### CAH sur les modalités : Indice de Dice
#
# #### Matrice originale

# %%
catvarhca3 = CATVARHCA(n_clusters=3,
                       var_labels=list(X.columns),
                       diss_metric="dice",
                       matrix_type="completed",
                       metric="euclidean",
                       method="average",
                       parallelize=True)
# Instanciation
catvarhca3.fit(X)
# Out:
# CATVARHCA(diss_metric='dice', method='average', n_clusters=3, parallelize=True,
#           var_labels=['budget', 'physician', 'salvador', 'nicaraguan',
#                       'missile', 'education'])

# %%
catvarhca3.diss_matrix_.iloc[:5,:5]
# Out:
#                     budget_n  budget_neither   budget_y  physician_n  \
# budget_n            0.000000        9.539392  14.560220    13.564660
# budget_neither      9.539392        0.000000  11.489125    11.224972
# budget_y           14.560220       11.489125   0.000000     5.567764
# physician_n        13.564660       11.224972   5.567764     0.000000
# physician_neither   9.539392        2.236068  11.269428    11.357817
#
#                    physician_neither
# budget_n                    9.539392
# budget_neither              2.236068
# budget_y                   11.269428
# physician_n                11.357817
# physician_neither           0.000000

# %%
catvarhca3.cluster_infos_
# Out:
#            n(k)      p(k)
# cluster
# cluster_1     6  0.333333
# cluster_2     6  0.333333
# cluster_3     6  0.333333

# %%
plot_dendrogram(catvarhca3,orientation='top',leaf_rotation=90,color_threshold=10)

# %%
catvarhca3.distances_
# Out:
# array([ 2.23606798,  3.        ,  3.2137267 ,  3.87141972,  4.24975336,
#         4.58257569,  4.79583152,  5.23861279,  5.29150262,  5.51970813,
#         5.56776436,  5.95448832,  6.18592755,  6.27259959,  6.56721213,
#         9.85037614, 12.20101371])

# %%
catvarhca3.cluster_
# Out:
#                       cluster
# budget_n            cluster_1
# budget_neither      cluster_2
# budget_y            cluster_3
# physician_n         cluster_3
# physician_neither   cluster_2
# physician_y         cluster_1
# salvador_n          cluster_3
# salvador_neither    cluster_2
# salvador_y          cluster_1
# nicaraguan_n        cluster_1
# nicaraguan_neither  cluster_2
# nicaraguan_y        cluster_3
# missile_n           cluster_1
# missile_neither     cluster_2
# missile_y           cluster_3
# education_n         cluster_3
# education_neither   cluster_2
# education_y         cluster_1

# %%
# Position de la variable supplémentaire
import numpy as np
np.sqrt(catvarhca3.transform(Xsup))
# Out:
#            affiliation_democrat  affiliation_republican
# cluster
# cluster_1             13.659551                5.560276
# cluster_2             11.441882                9.305017
# cluster_3              5.787918               13.564660

# %% [markdown]
# #### Tableau disjonctif complet

# %%
catvarhca4 = CATVARHCA(n_clusters=3,
                       var_labels=list(X.columns),
                       diss_metric="dice",
                       matrix_type="disjonctif",
                       metric="euclidean",
                       method="ward",
                       parallelize=True)
# Instanciation
catvarhca4.fit(disj)
# Out:
# CATVARHCA(diss_metric='dice', matrix_type='disjonctif', n_clusters=3,
#           parallelize=True,
#           var_labels=['budget', 'physician', 'salvador', 'nicaraguan',
#                       'missile', 'education'])

# %%
# Projection de la variable supplémentaire
catvarhca4.transform(Xsupdisj)
# Out:
#            affiliation_democrat  affiliation_republican
# cluster
# cluster_1            186.583333               30.916667
# cluster_2            130.916667               86.583333
# cluster_3             33.500000              184.000000

# %% [markdown]
# ### CAH sur les modalités : bothpos
#
# #### Matrice originale

# %%
catvarhca5 = CATVARHCA(n_clusters=3,
                       var_labels=list(X.columns),
                       diss_metric="bothpos",
                       matrix_type="completed",
                       metric="euclidean",
                       method="average",
                       parallelize=True)
# Instanciation
catvarhca5.fit(X)
# Out:
# CATVARHCA(diss_metric='bothpos', method='average', n_clusters=3,
#           parallelize=True,
#           var_labels=['budget', 'physician', 'salvador', 'nicaraguan',
#                       'missile', 'education'])

# %%
catvarhca5.diss_matrix_
# Out:
#                     budget_n  budget_neither  budget_y  physician_n  \
# budget_n            0.000000        1.000000  1.000000     0.942529
# budget_neither      1.000000        0.000000  1.000000     0.993103
# budget_y            1.000000        1.000000  0.000000     0.496552
# physician_n         0.942529        0.993103  0.496552     0.000000
# physician_neither   1.000000        0.986207  0.988506     1.000000
# physician_y         0.664368        0.995402  0.933333     1.000000
# salvador_n          0.963218        0.990805  0.567816     0.551724
# salvador_neither    0.995402        0.990805  0.979310     0.977011
# salvador_y          0.648276        0.993103  0.871264     0.903448
# nicaraguan_n        0.678161        0.990805  0.921839     0.924138
# nicaraguan_neither  0.981609        0.993103  0.990805     0.993103
# nicaraguan_y        0.947126        0.990805  0.505747     0.514943
# missile_n           0.664368        0.993103  0.868966     0.889655
# missile_neither     0.990805        0.995402  0.963218     0.956322
# missile_y           0.951724        0.986207  0.586207     0.586207
# education_n         0.935632        0.990805  0.537931     0.535632
# education_neither   0.977011        0.990805  0.960920     0.963218
# education_y         0.694253        0.993103  0.919540     0.933333
#
#                     physician_neither  physician_y  salvador_n  \
# budget_n                     1.000000     0.664368    0.963218
# budget_neither               0.986207     0.995402    0.990805
# budget_y                     0.988506     0.933333    0.567816
# physician_n                  1.000000     1.000000    0.551724
# physician_neither            0.000000     1.000000    0.988506
# physician_y                  1.000000     0.000000    0.981609
# salvador_n                   0.988506     0.981609    0.000000
# salvador_neither             0.990805     0.997701    1.000000
# salvador_y                   0.995402     0.613793    1.000000
# nicaraguan_n                 0.995402     0.671264    0.995402
# nicaraguan_neither           0.993103     0.979310    0.995402
# nicaraguan_y                 0.986207     0.942529    0.531034
# missile_n                    0.990805     0.645977    0.963218
# missile_neither              0.995402     0.997701    0.970115
# missile_y                    0.988506     0.949425    0.588506
# education_n                  0.986207     0.942529    0.593103
# education_neither            0.990805     0.974713    0.972414
# education_y                  0.997701     0.675862    0.956322
#
#                     salvador_neither  salvador_y  nicaraguan_n  \
# budget_n                    0.995402    0.648276      0.678161
# budget_neither              0.990805    0.993103      0.990805
# budget_y                    0.979310    0.871264      0.921839
# physician_n                 0.977011    0.903448      0.924138
# physician_neither           0.990805    0.995402      0.995402
# physician_y                 0.997701    0.613793      0.671264
# salvador_n                  1.000000    1.000000      0.995402
# salvador_neither            0.000000    1.000000      0.990805
# salvador_y                  1.000000    0.000000      0.604598
# nicaraguan_n                0.990805    0.604598      0.000000
# nicaraguan_neither          0.990805    0.979310      1.000000
# nicaraguan_y                0.983908    0.928736      1.000000
# missile_n                   0.986207    0.577011      0.627586
# missile_neither             0.995402    0.983908      0.990805
# missile_y                   0.983908    0.951724      0.972414
# education_n                 0.983908    0.887356      0.917241
# education_neither           0.988506    0.967816      0.977011
# education_y                 0.993103    0.657471      0.696552
#
#                     nicaraguan_neither  nicaraguan_y  missile_n  \
# budget_n                      0.981609      0.947126   0.664368
# budget_neither                0.993103      0.990805   0.993103
# budget_y                      0.990805      0.505747   0.868966
# physician_n                   0.993103      0.514943   0.889655
# physician_neither             0.993103      0.986207   0.990805
# physician_y                   0.979310      0.942529   0.645977
# salvador_n                    0.995402      0.531034   0.963218
# salvador_neither              0.990805      0.983908   0.986207
# salvador_y                    0.979310      0.928736   0.577011
# nicaraguan_n                  1.000000      1.000000   0.627586
# nicaraguan_neither            0.000000      1.000000   0.981609
# nicaraguan_y                  1.000000      0.000000   0.917241
# missile_n                     0.981609      0.917241   0.000000
# missile_neither               0.990805      0.967816   1.000000
# missile_y                     0.993103      0.558621   1.000000
# education_n                   0.993103      0.554023   0.882759
# education_neither             0.986207      0.965517   0.967816
# education_y                   0.986207      0.924138   0.675862
#
#                     missile_neither  missile_y  education_n  \
# budget_n                   0.990805   0.951724     0.935632
# budget_neither             0.995402   0.986207     0.990805
# budget_y                   0.963218   0.586207     0.537931
# physician_n                0.956322   0.586207     0.535632
# physician_neither          0.995402   0.988506     0.986207
# physician_y                0.997701   0.949425     0.942529
# salvador_n                 0.970115   0.588506     0.593103
# salvador_neither           0.995402   0.983908     0.983908
# salvador_y                 0.983908   0.951724     0.887356
# nicaraguan_n               0.990805   0.972414     0.917241
# nicaraguan_neither         0.990805   0.993103     0.993103
# nicaraguan_y               0.967816   0.558621     0.554023
# missile_n                  1.000000   1.000000     0.882759
# missile_neither            0.000000   1.000000     0.974713
# missile_y                  1.000000   0.000000     0.606897
# education_n                0.974713   0.606897     0.000000
# education_neither          0.988506   0.972414     1.000000
# education_y                0.986207   0.944828     1.000000
#
#                     education_neither  education_y
# budget_n                     0.977011     0.694253
# budget_neither               0.990805     0.993103
# budget_y                     0.960920     0.919540
# physician_n                  0.963218     0.933333
# physician_neither            0.990805     0.997701
# physician_y                  0.974713     0.675862
# salvador_n                   0.972414     0.956322
# salvador_neither             0.988506     0.993103
# salvador_y                   0.967816     0.657471
# nicaraguan_n                 0.977011     0.696552
# nicaraguan_neither           0.986207     0.986207
# nicaraguan_y                 0.965517     0.924138
# missile_n                    0.967816     0.675862
# missile_neither              0.988506     0.986207
# missile_y                    0.972414     0.944828
# education_n                  1.000000     1.000000
# education_neither            0.000000     1.000000
# education_y                  1.000000     0.000000

# %%
plot_dendrogram(catvarhca5,orientation='top',leaf_rotation=90)

# %%
# Position de la variable supplémentaire
catvarhca5.transform(Xsup)
# Out:
#            affiliation_democrat  affiliation_republican
# cluster
# cluster_1              0.758621                0.847050
# cluster_2              0.982759                0.991954
# cluster_3              0.972414                0.993103

# %% [markdown]
# #### Matrice disjonctif

# %%
catvarhca6 = CATVARHCA(n_clusters=3,
                       var_labels=list(X.columns),
                       diss_metric="bothpos",
                       matrix_type="disjonctif",
                       metric="euclidean",
                       method="ward",
                       parallelize=True)
# Instanciation
catvarhca6.fit(disj)
# Out:
# CATVARHCA(diss_metric='bothpos', matrix_type='disjonctif', n_clusters=3,
#           parallelize=True,
#           var_labels=['budget', 'physician', 'salvador', 'nicaraguan',
#                       'missile', 'education'])

# %%
# Position de la variable supplémentaire
catvarhca6.transform(Xsupdisj)
# Out:
#            affiliation_democrat  affiliation_republican
# cluster
# cluster_1              0.908429                0.664368
# cluster_2              0.973946                0.985824
# cluster_3              0.503831                0.963602
