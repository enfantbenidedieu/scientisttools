# %% [markdown]
# # Multiple Correspondence Analysis (MCA) - `music` Dataset

# %%
#disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")
from great_tables import GT, html
def print_dt(data,title=None,subtitle=None,rowname=None,digits=6):
    dt = (GT(data=data.round(digits).rename_axis(rowname).reset_index())
          .tab_header(title=title, subtitle=subtitle))
    return dt

# %%
#mushroom dataset
from scientisttools import mushroom
(
    GT(mushroom.head(10).rename_axis("Individuals").reset_index())
    .tab_header(title=html("<b>Mushroom Dataset</b>"))
)
# Out:
# GT(_tbl_data=   Individuals capshape capsurface capcolor bruises gillattachment  \
# 0            0        f          s        g       f              f
# 1            1        f          y        n       t              f
# 2            2        x          f        g       f              f
# 3            3        f          s        n       f              a
# 4            4        f          f        y       f              f
# 5            5        f          y        n       f              f
# 6            6        x          s        e       f              f
# 7            7        k          s        n       f              f
# 8            8        b          y        w       t              f
# 9            9        x          y        e       f              f
#
#   gillspacing gillsize gillcolor stalkshape stalksurfaceabove  \
# 0           w        b         k          t                 f
# 1           c        b         n          t                 s
# ...

# %%
from scientisttools import MCA
res_mca = MCA()
res_mca.fit(mushroom)
# Out:
# MCA()

# %%
#eigenvalues
from scientisttools import get_eig
print_dt(get_eig(res_mca),rowname="Dimensions",title=html("<b>Eigen values</b>"))
# Out:
# GT(_tbl_data=   Dimensions  Eigenvalue  Difference  Proportion  Cumulative
# 0       Dim.1    0.337993    0.023850    7.737192    7.737192
# 1       Dim.2    0.314143    0.036264    7.191235   14.928427
# 2       Dim.3    0.277879    0.032619    6.361084   21.289511
# 3       Dim.4    0.245260    0.020282    5.614380   26.903891
# 4       Dim.5    0.224978    0.013780    5.150096   32.053987
# ..        ...         ...         ...         ...         ...
# 72     Dim.73    0.001879    0.000392    0.043023   99.921993
# 73     Dim.74    0.001487    0.000610    0.034050   99.956043
# 74     Dim.75    0.000878    0.000073    0.020090   99.976133
# 75     Dim.76    0.000804    0.000566    0.018414   99.994547
# 76     Dim.77    0.000238         NaN    0.005453  100.000000
#
# ...
