# %% [markdown]
# # MCA `racescanines` - graphics

# %%
#disable warnings
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
from scientisttools import racescanines, MCA
res_mca = MCA(ind_sup=(27,28,29,30,31,32),quali_sup=6,quanti_sup=7)
res_mca.fit(racescanines)
# Out:
# MCA(ind_sup=(27, 28, 29, 30, 31, 32), quali_sup=6, quanti_sup=7)

# %% [markdown]
# ## Eigenvalues
#
# ### Eigenvalue

# %%
from scientisttools import fviz_screeplot
p = fviz_screeplot(res_mca,element="eigenvalue")
print(p)

# %% [markdown]
# ### Proportion

# %%
p = fviz_screeplot(res_mca,element="proportion")
print(p)

# %% [markdown]
# ### Cumulative

# %%
p = fviz_screeplot(res_mca,element="cumulative")
print(p)

# %% [markdown]
# ## Individuals
#
# ### Color by RGB
#
# #### Only active elements

# %%
from scientisttools import fviz_mca_ind
p = fviz_mca_ind(res_mca,repel=True)
print(p)
# Out:
# 7 [ 0.15672017 -0.49487157]
# 21 [-0.63191408 -0.01285867]
# 4 [-0.87075982 -0.92778349]
# 25 [ 0.87570901 -0.73820841]

# %% [markdown]
# #### With supplementary individuals

# %%
p = fviz_mca_ind(res_mca,ind_sup=True,repel=True)
print(p)
# Out:
# 7 [-0.61094481 -0.55779298]
# 21 [0.44041575 0.56833602]
# 4 [-0.56229657 -0.50918608]
# 25 [0.62478204 0.72740428]

# %% [markdown]
# ### Color by cos2

# %%
p = fviz_mca_ind(res_mca,col_ind="cos2",repel=True)
print(p)
# Out:
# 7 [-0.38586668  0.08300505]
# 21 [ 0.44163068 -0.50481891]
# 4 [-0.16179606 -0.43702994]
# 25 [ 0.88424198 -0.21376996]

# %%
from scientisttools import fviz_corrplot
p = fviz_corrplot(res_mca.ind_.cos2,x_label="Individuals",legend_title="Cos2",title="Individuals Cos2")
print(p)

# %%
from scientisttools import fviz_cos2
print(fviz_cos2(res_mca,element="ind"))

# %% [markdown]
# ### Color by contrib

# %%
p = fviz_mca_ind(res_mca,col_ind="contrib",repel=True)
print(p)
# Out:
# 7 [0.17113586 0.53745088]
# 21 [ 0.94069481 -0.08014394]
# 4 [-0.95482544 -0.81233981]
# 25 [-0.11905383 -0.81122519]

# %%
p = fviz_corrplot(res_mca.ind_.contrib,x_label="Individuals",legend_title="Contrib",title="Individuals Contributions")
print(p)

# %%
from scientisttools import fviz_contrib
print(fviz_contrib(res_mca,element="ind"))

# %% [markdown]
# ## Color by quantitatives variables

# %%
#color by quantitative variable
p = fviz_mca_ind(res_mca,col_ind="Cote",repel=True)
print(p)
# Out:
# 7 [0.67084853 0.56673838]
# 21 [-0.48241392 -0.54583515]
# 4 [0.92246607 0.64181485]
# 25 [-0.1316907  -0.97192485]

# %% [markdown]
# ### Color by `coord`

# %%
#color by coord
p = fviz_mca_ind(res_mca,col_ind="coord",repel=True)
print(p)
# Out:
# 7 [-0.68200994  0.60693069]
# 21 [-0.76736826 -0.93733633]
# 4 [ 0.40576038 -0.549073  ]
# 25 [-0.78563409  0.99953695]

# %% [markdown]
# ### Color by active qualitatives columns

# %%
p = fviz_mca_ind(res_mca,habillage=racescanines.columns.tolist()[1],repel=True)
print(p)

# %% [markdown]
# ### Color by supplementary qualitatives columns

# %%
p = fviz_mca_ind(res_mca,habillage=racescanines.columns.tolist()[6],repel=True)
print(p)

# %% [markdown]
# ### Color by numpy array

# %%
import numpy as np
np.random.seed(123)
color_numpy = np.random.normal(size=res_mca.call_.X.shape[0])
p = fviz_mca_ind(res_mca,col_ind=color_numpy,repel=True)
print(p)
# Out:
# 7 [-0.81579012 -0.13259765]
# 21 [-0.13827447 -0.0126298 ]
# 4 [-0.14833942 -0.37547755]
# 25 [-0.14729739  0.78677833]

# %% [markdown]
# ### Color by kmeans clustering

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(res_mca.ind_.coord)
p = fviz_mca_ind(res_mca,col_ind=kmeans,repel=True)
print(p)

# %% [markdown]
# ### set limits
#
# #### limit cos2

# %%
p = fviz_mca_ind(res_mca,lim_cos2=0.5,repel=True)
print(p)
# Out:
# 2 [ 0.36965948 -0.0381362 ]
# 3 [-0.21576496 -0.31364397]
# 4 [ 0.45809941 -0.12285551]
# 5 [-0.88064421 -0.20391149]
# 0 [ 0.47599081 -0.63501654]
# 1 [-0.64909649  0.06310275]

# %% [markdown]
# #### limit contrib

# %%
p = fviz_mca_ind(res_mca,lim_contrib=20,repel=True)
print(p)
# Out:
# 7 [0.06365517 0.26880192]
# 21 [0.69886359 0.44891065]
# 4 [0.22204702 0.44488677]
# 25 [-0.35408217 -0.27642269]

# %% [markdown]
# ## Variables
#
# ### Color by RGB colors
#
# #### Only active elements

# %%
from scientisttools import fviz_mca_var
p = fviz_mca_var(res_mca,repel=True)
print(p)

# %% [markdown]
# #### With supplementary elements

# %%
p = fviz_mca_var(res_mca,repel=True,quali_sup=True)
print(p)

# %% [markdown]
# ### Color by cos2

# %%
p = fviz_mca_var(res_mca,col_var="cos2",repel=True)
print(p)

# %%
p = fviz_corrplot(res_mca.var_.cos2,x_label="Categories",legend_title="Cos2",title="Categories Cos2")
print(p)

# %%
print(fviz_cos2(res_mca,element="var"))

# %% [markdown]
# ### Color by contrib

# %%
p = fviz_mca_var(res_mca,col_var="contrib",repel=True)
print(p)

# %%
p = fviz_corrplot(res_mca.var_.contrib,x_label="Categories",legend_title="Contrib",title="Categories Contributions")
print(p)

# %%
print(fviz_contrib(res_mca,element="var"))

# %% [markdown]
# ### Color by numpy array

# %%
np.random.seed(123)
color_numpy = np.random.normal(size=res_mca.var_.coord.shape[0])
p = fviz_mca_var(res_mca,col_var=color_numpy,repel=True)
print(p)

# %% [markdown]
# ### Color by kmeans clustering

# %%
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(res_mca.var_.coord)
p = fviz_mca_var(res_mca,col_var=kmeans,repel=True)
print(p)

# %% [markdown]
# ### Set tlimits
#
# #### limit cos2

# %%
p = fviz_mca_var(res_mca,lim_cos2=0.3,repel=True)
print(p)

# %% [markdown]
# #### limit contrib

# %%
p = fviz_mca_var(res_mca,lim_contrib=20,repel=True)
print(p)

# %% [markdown]
# ## Global variables

# %%
from scientisttools import fviz_mca_quali_var
p  = fviz_mca_quali_var(res_mca,repel=True)
print(p)

# %%
p  = fviz_mca_quali_var(res_mca,repel=True,quali_sup=True,quanti_sup=True)
print(p)

# %% [markdown]
# ### Correlation circle

# %%
from scientisttools import fviz_corrcircle
p = fviz_corrcircle(res_mca)
print(p)

# %% [markdown]
# ## Biplot

# %%
from scientisttools import fviz_mca_biplot
p = fviz_mca_biplot(res_mca,repel_ind=True,repel_var=True,habillage="Fonction")
print(p)

# %% [markdown]
# ## Biplot

# %%
from scientisttools import fviz_mca_biplot
p = fviz_mca_biplot(res_mca,repel_ind=True,repel_var=True)
print(p)
# Out:
# 7 [-0.17815125  0.15938859]
# 21 [-0.72009847 -0.19796489]
# 4 [ 0.25463402 -0.35169821]
# 25 [-0.51048145  0.38951035]
