# %% [markdown]
# # PartialPCA  - `autos2006` Dataset

# %%
#disable warnings
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %%
# Chargement des librairies
from scientisttools import autos2006,PartialPCA, fviz_screeplot,fviz_partialpca_ind
res_ppca = PartialPCA(partial=0,ind_sup=(18,19),quanti_sup=(6,7),quali_sup=8)
res_ppca.fit(autos2006)
# Out:
# PartialPCA(ind_sup=(18, 19), partial=0, quali_sup=8, quanti_sup=(6, 7))

# %% [markdown]
# ## Eigenvalues
#
# ### `absolute`

# %%
p = fviz_screeplot(res_ppca,element="eigenvalue",add_labels=True)
print(p)

# %% [markdown]
# ### `percentage`

# %%
p = fviz_screeplot(res_ppca,element="proportion",add_labels=True)
print(p)

# %% [markdown]
# ### `cumulative`

# %%
p = fviz_screeplot(res_ppca,element="cumulative",add_labels=True)
print(p)

# %% [markdown]
# ## Individuals
#
# ### Color by RGB color
#
# #### Only active elements

# %%
p = fviz_partialpca_ind(res_ppca,repel=True)
print(p)

# %% [markdown]
# #### with supplementary elements

# %%
p = fviz_partialpca_ind(res_ppca,repel=True,ind_sup=True,quali_sup=True)
print(p)

# %% [markdown]
# ### Color by cos2

# %%
p = fviz_partialpca_ind(res_ppca,col_ind="cos2",repel=True)
print(p)

# %%
from scientisttools import fviz_corrplot
p = fviz_corrplot(res_ppca.ind_.cos2,title="Individuals cos2",legend_title="Cos2",x_label="Individuals")
print(p)

# %%
from scientisttools import fviz_cos2
p = fviz_cos2(res_ppca,element="ind")
print(p)

# %%
p = fviz_cos2(res_ppca,element="ind",sort="asc")
print(p)

# %%
p = fviz_cos2(res_ppca,element="ind",sort=None)
print(p)

# %% [markdown]
# ### Color by Contributions

# %%
p = fviz_partialpca_ind(res_ppca,col_ind="contrib",repel=True)
print(p)

# %%
p = fviz_corrplot(res_ppca.ind_.contrib,title="Individuals contributions",legend_title="Contrib",gradient_cols=("red","blue","green"),x_label="Individuals")
print(p)

# %%
from scientisttools import fviz_contrib
p = fviz_contrib(res_ppca,element="ind")
print(p)

# %%
p = fviz_contrib(res_ppca,element="ind",sort="asc")
print(p)

# %%
p = fviz_contrib(res_ppca,element="ind",sort=None)
print(p)

# %% [markdown]
# ### Color by coordinates

# %%
p = fviz_partialpca_ind(res_ppca,col_ind="coord",repel=True)
print(p)

# %% [markdown]
# ### Color by quantitative columns

# %%
p = fviz_partialpca_ind(res_ppca,col_ind="PUISS",repel=True)
print(p)

# %% [markdown]
# ### Color by numpy array

# %%
import numpy as np
np.random.seed(123)
color_numpy = np.random.normal(size=res_ppca.call_.X.shape[0])
p = fviz_partialpca_ind(res_ppca,col_ind=color_numpy,repel=True,ind_sup=False,quali_sup=False)
print(p)

# %% [markdown]
# ### Color by kmeans clustering

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(res_ppca.ind_.coord)
p = fviz_partialpca_ind(res_ppca,col_ind=kmeans,repel=True,palette=("blue","red","darkgreen"))
print(p)

# %% [markdown]
# ### Color by qualitative variables

# %%
p = fviz_partialpca_ind(res_ppca,habillage="FINITION",repel=True,palette=("blue","red","darkgreen"))
print(p)

# %% [markdown]
# ### Set limit
#
# #### limit cos2

# %%
p = fviz_partialpca_ind(res_ppca,lim_cos2=0.8,repel=True)
print(p)

# %% [markdown]
# #### limit contrib

# %%
p = fviz_partialpca_ind(res_ppca,lim_contrib=10,repel=True)
print(p)

# %% [markdown]
# ## Variables Factor Map
#
# ### Color by RGB color
#
# #### Only active elements

# %%
from scientisttools import fviz_partialpca_var
p = fviz_partialpca_var(res_ppca,repel=True)
print(p)

# %% [markdown]
# #### With supplementary elements

# %%
p = fviz_partialpca_var(res_ppca,quanti_sup=True,repel=True)
print(p)

# %% [markdown]
# ### Color by cos2

# %%
p = fviz_partialpca_var(res_ppca,col_var="cos2",repel=True)
print(p)

# %%
p = fviz_corrplot(res_ppca.var_.cos2,title="Variables cos2",legend_title="Cos2")
print(p)

# %%
p = fviz_cos2(res_ppca,"var",0)
print(p)

# %% [markdown]
# ### Color by contrib

# %%
p = fviz_partialpca_var(res_ppca,col_var="contrib",repel=True)
print(p)

# %%
p = fviz_corrplot(res_ppca.var_.contrib,title="Variables contributions",legend_title="Contrib")
print(p)

# %%
p = fviz_contrib(res_ppca,"var",0)
print(p)

# %% [markdown]
# ### Color by numpy array

# %%
np.random.seed(123)
color_numpy = np.random.normal(size=res_ppca.var_.coord.shape[0])
p = fviz_partialpca_var(res_ppca,col_var=color_numpy,repel=True)
print(p)

# %% [markdown]
# ### Color by kmeans clustering

# %%
kmeans = KMeans(n_clusters=2, random_state=np.random.seed(123), n_init="auto").fit(res_ppca.var_.coord)
p = fviz_partialpca_var(res_ppca,col_var=kmeans,repel=True)
print(p)

# %% [markdown]
# ### Set limit
#
# #### limit cos2

# %%
p = fviz_partialpca_var(res_ppca,lim_cos2=0.85,repel=True)
print(p)

# %% [markdown]
# #### Limit contrib

# %%
p = fviz_partialpca_var(res_ppca,lim_contrib=40,repel=True)
print(p)

# %% [markdown]
# #### `fviz_corrcircle`

# %%
from scientisttools import fviz_corrcircle
p = fviz_corrcircle(res_ppca,repel=True)
print(p)

# %% [markdown]
# ## Biplot

# %%
from scientisttools import fviz_partialpca_biplot
p = fviz_partialpca_biplot(res_ppca,repel_ind=True,habillage="FINITION",palette=("darkblue","darkred","darkgreen"),repel_var=True)
print(p)
