# %% [markdown]
# # CA with Matplotlib

# %%
import pandas as pd
url = "http://factominer.free.fr/factomethods/datasets/women_work.txt"
women_work = pd.read_table(url,header=0)

# %%
# Modèle avec colonnes supplémentaires
from scientisttools.decomposition import CA
my_ca = CA(n_components=None,
            row_labels=women_work.index.values,
            col_labels=women_work.columns[:3].values,
            row_sup_labels=None,
            col_sup_labels=women_work.columns[3:].values).fit(women_work)

# %% [markdown]
# ## Row points - CA

# %%
import matplotlib.pyplot as plt
from scientisttools.pyplot import plot_ca_row
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_row(my_ca,axis=(0,1),repel=True)
plt.show()

# %%
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_row(my_ca,axis=(0,1),color="cos2",repel=True)
plt.show()

# %%
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_row(my_ca,axis=(0,1),color="contrib",repel=True)
plt.show()

# %%
# Using  numpy color
import numpy as np
np.random.seed(123)
color_numpy = np.random.normal(size=3)
color_numpy
# Out:
# array([-1.0856306 ,  0.99734545,  0.2829785 ])

# %%
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_row(my_ca,axis=(0,1),color=color_numpy,repel=True)
plt.show()

# %%
# Using KMeans
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(my_ca.row_coord_)
kmeans.labels_
# Out:
# array([2, 1, 0])

# %%
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_row(my_ca,axis=(0,1),color=kmeans,repel=True)
plt.show()

# %% [markdown]
# ## Columns points

# %%
from scientisttools.pyplot import plot_ca_col
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_col(my_ca,axis=(0,1),repel=False)
plt.show()

# %%
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_col(my_ca,axis=(0,1),color="cos2",repel=False)
plt.show()

# %%
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_col(my_ca,axis=(0,1),color="contrib",repel=False)
plt.show()

# %%
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_col(my_ca,axis=(0,1),color=color_numpy,repel=False)
plt.show()

# %%
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(my_ca.col_coord_)
kmeans.labels_
# Out:
# array([1, 2, 0])

# %%
fig, axe = plt.subplots(figsize=(8,8))
plot_ca_col(my_ca,axis=(0,1),color=kmeans,repel=False)
plt.show()

# %%
from scientisttools.pyplot import plotCA
fig, axe = plt.subplots(figsize=(8,8))
plotCA(my_ca,choice="row")
plt.show()

# %%
fig, axe = plt.subplots(figsize=(8,8))
plotCA(my_ca,choice="col")
plt.show()

# %% [markdown]
# ## Contributions

# %%
from scientisttools.pyplot import plot_contrib
fig, axe = plt.subplots(figsize=(16,6))
plot_contrib(my_ca,choice="ind",ax=axe)
plt.show()

# %%
from scientisttools.pyplot import plot_contrib
fig, axe = plt.subplots(figsize=(16,6))
plot_contrib(my_ca,choice="var",ax=axe)
plt.show()

# %% [markdown]
# ## Cos2

# %%
from scientisttools.pyplot import plot_cosines
fig, axe = plt.subplots(figsize=(16,6))
plot_cosines(my_ca,choice="ind",ax=axe)
plt.show()

# %%
fig, axe = plt.subplots(figsize=(16,6))
plot_cosines(my_ca,choice="var",ax=axe)
plt.show()
