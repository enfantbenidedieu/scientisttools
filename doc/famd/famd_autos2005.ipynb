# %% [markdown]
# # FAMD

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
from scientisttools import load_autos
autos = load_autos()
autos
# Out:
#                 puissance  cylindree  vitesse  longueur  largeur  hauteur  \
# ROW_LABEL
# ALFA 156              250       3179      250       443      175      141
# AUDIA3                102       1595      185       421      177      143
# AUDIA8                280       3697      250       506      203      145
# AVENSIS               115       1995      195       463      176      148
# BMW X5                218       2993      210       467      188      172
# BMW530                231       2979      250       485      185      147
# CHRYS300              340       5654      250       502      188      148
# CITRONC2               61       1124      158       367      166      147
# CITRONC4              138       1997      207       426      178      146
# CITRONC5              210       2496      230       475      178      148
# CLIO                  100       1461      185       382      164      142
# ...

# %%
autos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 40 entries, ALFA 156     to YARIS
# Data columns (total 15 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   puissance     40 non-null     int64
#  1   cylindree     40 non-null     int64
#  2   vitesse       40 non-null     int64
#  3   longueur      40 non-null     int64
#  4   largeur       40 non-null     int64
#  5   hauteur       40 non-null     int64
#  6   poids         40 non-null     int64
#  7   coffre        40 non-null     int64
#  8   reservoir     40 non-null     int64
#  9   consommation  40 non-null     float64
#  10  CO2           40 non-null     int64
#  11  prix          40 non-null     int64
#  12  origine       40 non-null     object
#  13  Carburant     40 non-null     object
#  14  type4X4       40 non-null     object
# dtypes: float64(1), int64(11), object(3)
# memory usage: 5.0+ KB

# %%
#instanciation
from scientisttools import FAMD
res_afdm = FAMD(quanti_sup=[10,11],quali_sup=14,parallelize=False)
res_afdm.fit(autos)
# Out:
# FAMD(quali_sup=14, quanti_sup=[10, 11])

# %%
from scientisttools import fviz_famd_col
print(fviz_famd_col(res_afdm))

# %%
from scientisttools import dimdesc
DimDesc = dimdesc(res_afdm)
DimDesc.keys()
# Out:
# dict_keys(['Dim.1', 'Dim.2', 'Dim.3', 'Dim.4', 'Dim.5'])

# %%
DimDesc["Dim.1"]["quanti"]
# Out:
#               correlation        pvalue
# poids            0.912082  2.220446e-16
# reservoir        0.911757  2.220446e-16
# prix             0.908988  4.440892e-16
# longueur         0.897620  4.218847e-15
# CO2              0.893628  8.659740e-15
# largeur          0.892081  1.110223e-14
# puissance        0.879796  7.727152e-14
# cylindree        0.871037  2.717826e-13
# consommation     0.850555  3.709477e-12
# coffre           0.605352  3.498286e-05
# vitesse          0.595451  5.053595e-05
# hauteur          0.330353  3.734847e-02

# %%
DimDesc["Dim.1"]["quali"]
# Out:
#                R2    pvalue
# origine  0.216848  0.010868
# type4X4  0.189313  0.005018
