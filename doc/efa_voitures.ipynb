# %% [markdown]
# # Analyse en Facteurs principaux

# %%
# Chargement des librairies
import pandas as pd

from scientisttools import summaryEFA
import os
os.chdir("d:/Bureau/PythonProject/packages/scientisttools/data/")

# %%
# Chargement des données
D = pd.read_excel("Data_Methodes_Factorielles.xlsx",sheet_name="AUTOS_AFP",index_col=0)
display(D.head(6))
# Out:
#                   CYL  PUISS  LONG  LARG  POIDS  VMAX   RND1   RND2   RND3  \
# Modele
# Alfasud TI       1350     79   393   161    870   165  1.029  0.109  0.267
# Audi 100         1588     85   468   177   1110   160  0.379  0.367 -1.054
# Simca 1300       1294     68   424   168   1050   152 -0.346  0.737 -0.056
# Citroen GS Club  1222     59   412   161    930   151  0.849  0.494 -0.320
# Fiat 132         1585     98   439   164   1105   165 -1.425 -0.210  0.535
# Lancia Beta      1297     82   429   169   1080   160  0.890  0.071 -1.308
#
#                   RND4   RND5   RND6
# Modele
# Alfasud TI      -0.949  0.053 -1.144
# Audi 100         0.106  1.316  1.632
# Simca 1300      -0.430  0.274  1.044
# Citroen GS Club  0.729  0.637  0.793
# Fiat 132        -0.200 -1.983  0.832
# Lancia Beta     -0.971 -0.131 -1.134

# %%
# Instanciation
from scientisttools import EFA
res_efa = EFA(standardize=True,n_components=None)
res_efa.fit(D)
# Out:
# EFA()

# %% [markdown]
# ## fit transform

# %%
res_efa.fit_transform(D).iloc[:6,:]
# Out:
#                     Dim.1     Dim.2     Dim.3     Dim.4     Dim.5     Dim.6  \
# Alfasud TI      -0.986199 -1.119263  1.139469  1.136237  0.785169 -0.707775
# Audi 100         0.523302  2.582756  0.424237 -0.343694 -1.052671 -0.828028
# Simca 1300      -0.472979  0.182853  0.240356 -0.453100 -0.863533  0.423931
# Citroen GS Club -1.081071 -0.098957 -0.167190 -0.102785 -0.823887 -0.399895
# Fiat 132         0.368924 -0.960006 -1.306899  0.799801 -0.229934 -0.379263
# Lancia Beta     -0.198631  0.755777  0.075183  0.336737  0.147129  0.575347
#
#                     Dim.7     Dim.8
# Alfasud TI       0.552847  0.341822
# Audi 100        -0.012167 -0.015207
# Simca 1300       0.473295  0.330536
# Citroen GS Club -0.104267 -0.285677
# Fiat 132        -0.020360  0.048807
# Lancia Beta      0.746940  0.365304

# %% [markdown]
# ## transform

# %%
res_efa.transform(res_efa.call_["X"]).iloc[:6,:]
# Out:
#                     Dim.1     Dim.2     Dim.3     Dim.4     Dim.5     Dim.6  \
# Modele
# Alfasud TI      -0.986199 -1.119263  1.139469  1.136237  0.785169 -0.707775
# Audi 100         0.523302  2.582756  0.424237 -0.343694 -1.052671 -0.828028
# Simca 1300      -0.472979  0.182853  0.240356 -0.453100 -0.863533  0.423931
# Citroen GS Club -1.081071 -0.098957 -0.167190 -0.102785 -0.823887 -0.399895
# Fiat 132         0.368924 -0.960006 -1.306899  0.799801 -0.229934 -0.379263
# Lancia Beta     -0.198631  0.755777  0.075183  0.336737  0.147129  0.575347
#
#                     Dim.7     Dim.8
# Modele
# Alfasud TI       0.552847  0.341822
# Audi 100        -0.012167 -0.015207
# Simca 1300       0.473295  0.330536
# Citroen GS Club -0.104267 -0.285677
# Fiat 132        -0.020360  0.048807
# Lancia Beta      0.746940  0.365304

# %% [markdown]
# ## Eigenvalues

# %%
from scientisttools import get_eigenvalue
eig = get_eigenvalue(res_efa)
eig
# Out:
#         eigenvalue  difference  proportion  cumulative
# Dim.1     5.229521    4.218050   62.521371   62.521371
# Dim.2     1.011471    0.035886   12.092609   74.613980
# Dim.3     0.975585    0.252347   11.663576   86.277556
# Dim.4     0.723238    0.184633    8.646650   94.924207
# Dim.5     0.538606    0.275195    6.439281  101.363488
# Dim.6     0.263410    0.167558    3.149191  104.512679
# Dim.7     0.095852    0.089953    1.145956  105.658635
# Dim.8     0.005899    0.049727    0.070530  105.729165
# Dim.9    -0.043828    0.047582   -0.523979  105.205185
# Dim.10   -0.091409    0.060599   -1.092843  104.112343
# Dim.11   -0.152009    0.039954   -1.817335  102.295008
# Dim.12   -0.191963         NaN   -2.295008  100.000000

# %% [markdown]
# ## Individuals

# %%
ind = res_efa.ind_
ind.keys()
# Out:
# dict_keys(['coord'])

# %% [markdown]
# ### Individus coordinates

# %%
ind["coord"].head(6)
# Out:
#                     Dim.1     Dim.2     Dim.3     Dim.4     Dim.5     Dim.6  \
# Alfasud TI      -0.986199 -1.119263  1.139469  1.136237  0.785169 -0.707775
# Audi 100         0.523302  2.582756  0.424237 -0.343694 -1.052671 -0.828028
# Simca 1300      -0.472979  0.182853  0.240356 -0.453100 -0.863533  0.423931
# Citroen GS Club -1.081071 -0.098957 -0.167190 -0.102785 -0.823887 -0.399895
# Fiat 132         0.368924 -0.960006 -1.306899  0.799801 -0.229934 -0.379263
# Lancia Beta     -0.198631  0.755777  0.075183  0.336737  0.147129  0.575347
#
#                     Dim.7     Dim.8
# Alfasud TI       0.552847  0.341822
# Audi 100        -0.012167 -0.015207
# Simca 1300       0.473295  0.330536
# Citroen GS Club -0.104267 -0.285677
# Fiat 132        -0.020360  0.048807
# Lancia Beta      0.746940  0.365304

# %% [markdown]
# ## Variables informations

# %%
var = res_efa.var_
var.keys()
# Out:
# dict_keys(['coord', 'contrib', 'normalized_score_coef', 'fidelity'])

# %% [markdown]
# ### Variables coordinates

# %%
var["coord"].head(6)
# Out:
#           Dim.1     Dim.2     Dim.3     Dim.4     Dim.5     Dim.6     Dim.7  \
# CYL    0.874463 -0.084990  0.152994 -0.088167  0.264709 -0.004500 -0.038756
# PUISS  0.893121 -0.117049  0.063503  0.311513  0.089056  0.027141 -0.136213
# LONG   0.850778  0.367295 -0.265757 -0.169450 -0.040122 -0.032241  0.005522
# LARG   0.768420  0.423811  0.125322 -0.273809 -0.087620 -0.086367  0.144601
# POIDS  0.894371  0.094914 -0.204898 -0.169556  0.095826  0.225432 -0.084302
# VMAX   0.749973 -0.058408  0.189538  0.504833  0.063120 -0.177884  0.108603
#
#           Dim.8
# CYL   -0.045990
# PUISS  0.030580
# LONG  -0.027719
# LARG   0.030604
# POIDS  0.022486
# VMAX   0.000249

# %% [markdown]
# ### Variables contributions

# %%
var["contrib"].head(6)
# Out:
#            Dim.1      Dim.2      Dim.3      Dim.4      Dim.5      Dim.6  \
# CYL     4.591390   6.407311  11.004417  10.656568  44.284547   0.524902
# PUISS  18.757510   6.972512   7.354775  18.481265   0.483613   2.144399
# LONG   22.163003  52.653268  44.876131   0.714512  19.683902  15.108520
# LARG    4.781047   3.445412  25.919507  17.603941   0.066639   1.922472
# POIDS  27.129689   0.164904   4.704411   3.700912   8.111242  71.875567
# VMAX   17.003294   2.257864   1.330483  41.308298   0.371210   0.223374
#
#            Dim.7      Dim.8
# CYL     0.129802   6.076279
# PUISS  54.126040  17.288758
# LONG    0.580974  41.564884
# LARG    7.629846  25.923551
# POIDS   0.329095   4.046387
# VMAX   29.771180   3.147364

# %% [markdown]
# ### Coefficients du score normalisés

# %%
var["normalized_score_coef"]
# Out:
#           Dim.1     Dim.2     Dim.3     Dim.4     Dim.5     Dim.6     Dim.7  \
# CYL    0.098976 -0.257383  0.614904 -0.358634  0.724245 -0.120129 -0.054561
# PUISS  0.200054 -0.268495  0.502700  0.472290 -0.075685 -0.242808 -1.114154
# LONG   0.217457  0.737828 -1.241743  0.092864 -0.482853 -0.644497 -0.115430
# LARG   0.101000  0.188740  0.943707 -0.460943 -0.028095 -0.229901  0.418312
# POIDS  0.240592  0.041291 -0.402047 -0.211347  0.309958  1.405726  0.086877
# VMAX   0.190469  0.152789 -0.213810  0.706092  0.066309 -0.078366  0.826305
# RND1  -0.035438  0.128374 -0.093124 -0.027899  0.255338 -0.221107 -0.106449
# RND2   0.054243 -0.146876 -0.000456 -0.044169 -0.367213  0.040489  0.029128
# RND3   0.027593 -0.218099 -0.085709 -0.137419  0.060197 -0.249791 -0.021864
# RND4   0.068207 -0.151815  0.085991 -0.213755 -0.318784 -0.217308 -0.201675
# RND5  -0.035918  0.417231  0.376616  0.096036  0.006827  0.232967 -0.280694
# ...

# %% [markdown]
# ### Fidélité des facteirs

# %%
var["fidelity"]
# Out:
# Dim.1    0.976070
# Dim.2    0.792181
# Dim.3    0.854107
# Dim.4    0.811786
# Dim.5    0.575937
# Dim.6    0.537133
# Dim.7    0.370088
# Dim.8    0.053796
# Name: fidelity, dtype: float64

# %% [markdown]
# ## Autres

# %%
others = res_efa.others_
others.keys()
# Out:
# dict_keys(['communality', 'explained_variance', 'inertia'])

# %% [markdown]
# ### Communalités

# %%
others["communality"]
# Out:
#         initial  estimated  percentage_variance
# CYL    0.843053   0.876798             1.040027
# PUISS  0.922937   0.940594             1.019131
# LONG   0.925902   0.961517             1.038466
# LARG   0.879876   0.897745             1.020308
# POIDS  0.923971   0.947255             1.025200
# VMAX   0.882288   0.904074             1.024693
# RND1   0.336690   0.403035             1.197050
# RND2   0.394369   0.475767             1.206402
# RND3   0.450844   0.497881             1.104331
# RND4   0.610068   0.661624             1.084509
# RND5   0.688055   0.754376             1.096389
# RND6   0.506320   0.522914             1.032775

# %% [markdown]
# ### Variance

# %%
others["explained_variance"]
# Out:
# Dim.1    5.229521
# Dim.2    1.011471
# Dim.3    0.975585
# Dim.4    0.723238
# Dim.5    0.538606
# Dim.6    0.263410
# Dim.7    0.095852
# Dim.8    0.005899
# Name: variance, dtype: float64

# %% [markdown]
# ### Inertia

# %%
others["inertia"]
# Out:
# 8.364373071754493

# %% [markdown]
# ## Extractions

# %%
from scientisttools import get_efa
ind = get_efa(res_efa,choice="ind")
var = get_efa(res_efa,choice="var")

# %% [markdown]
# ### Summary

# %%
summaryEFA(res_efa)
# Out:
#                      Exploratory Factor Analysis - Results
#
#                           Dim.1   Dim.2   Dim.3   Dim.4    Dim.5    Dim.6  \
# Variance                  5.230   1.011   0.976   0.723    0.539    0.263
# Difference                4.218   0.036   0.252   0.185    0.275    0.168
# % of var.                62.521  12.093  11.664   8.647    6.439    3.149
# Cumulative of % of var.  62.521  74.614  86.278  94.924  101.363  104.513
#
#                            Dim.7    Dim.8
# Variance                   0.096    0.006
# Difference                 0.090    0.050
# % of var.                  1.146    0.071
# Cumulative of % of var.  105.659  105.729
#
# Individuals (the 10 first)
#
#                  Dim.1  Dim.2  Dim.3
# Alfasud TI      -0.986 -1.119  1.139
# Audi 100         0.523  2.583  0.424
# Simca 1300      -0.473  0.183  0.240
# Citroen GS Club -1.081 -0.099 -0.167
# Fiat 132         0.369 -0.960 -1.307
# Lancia Beta     -0.199  0.756  0.075
# ...
