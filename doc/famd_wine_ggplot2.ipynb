# %% [markdown]
# # FAMD wine ggplot2

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
#importation des données
import pandas as pd
url = "http://factominer.free.fr/factomethods/datasets/wine.txt"
wine = pd.read_table(url,sep="\t")

# %%
from scientisttools import FAMD
res_famd = FAMD(n_components=5)
res_famd.fit(wine)
# Out:
# FAMD(n_components=5)

# %% [markdown]
# ## Eigenvalues

# %%
from scientisttools import fviz_screeplot
p = fviz_screeplot(res_famd)
print(p)

# %% [markdown]
# ## Individuals Factor Map
#
# ### Color by RGB colors

# %%
from scientisttools import fviz_famd_ind
p = fviz_famd_ind(res_famd,repel=True)
print(p)

# %% [markdown]
# ### Color by Cos2

# %%
p = fviz_famd_ind(res_famd,color="cos2",repel=True)
print(p)

# %%
from scientisttools import fviz_corrplot
p = fviz_corrplot(res_famd.ind_["cos2"],method="circle",colors=["#00AFBB", "#E7B800", "#FC4E07"])
print(p)

# %% [markdown]
# ### Color by contrib

# %%
p = fviz_famd_ind(res_famd,color="contrib",repel=True)
print(p)

# %% [markdown]
# ### Color by quantitatives columns

# %%
p = fviz_famd_ind(res_famd,color="Nuance",repel=True)
print(p)

# %% [markdown]
# ### Color by actives qualitatives columns

# %%
p = fviz_famd_ind(res_famd,habillage="Soil",repel=True)
print(p)

# %% [markdown]
# ### Color by supplementary qualitatives columns

# %%
p = fviz_famd_ind(res_famd,habillage="Label",repel=True,add_ellipses=True)
print(p)

# %% [markdown]
# ### Color by numpy array

# %%
import numpy as np
np.random.seed(123)
color_numpy = np.random.normal(size=res_famd.call_["X"].shape[0])
p = fviz_famd_ind(res_famd,color=color_numpy,repel=True)
print(p)

# %% [markdown]
# ### Color by kmeans clustering

# %%
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(res_famd.ind_["coord"])
p = fviz_famd_ind(res_famd,color=kmeans,repel=True)
print(p)

# %% [markdown]
# ### Set limits
#
# #### Limit cos2

# %%
p = fviz_famd_ind(res_famd,lim_cos2=0.50,repel=True)
print(p)

# %% [markdown]
# #### limit contrib

# %%
p = fviz_famd_ind(res_famd,lim_contrib=20,repel=True)
print(p)

# %% [markdown]
# ## Quantitatives variables informations
#
# ### Color by RGB colors

# %%
from scientisttools import fviz_famd_col
p = fviz_famd_col(res_famd)
print(p)

# %% [markdown]
# ### Color by cos2

# %%
p = fviz_famd_col(res_famd,color="cos2")
print(p)

# %%
p = fviz_corrplot(res_famd.quanti_var_["cos2"],method="circle",colors=["#00AFBB", "#E7B800", "#FC4E07"])
print(p)

# %% [markdown]
# ## Color by contrib

# %%
p = fviz_famd_col(res_famd,color="contrib")
print(p)

# %% [markdown]
# ### Coloor by numpy array

# %%
np.random.seed(123)
color_numpy = np.random.normal(size=res_famd.quanti_var_["coord"].shape[0])
p = fviz_famd_col(res_famd,color=color_numpy)
print(p)

# %% [markdown]
# ### Color by kmeans clustering

# %%
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(res_famd.quanti_var_["coord"])
p = fviz_famd_col(res_famd,color=kmeans)
print(p)

# %% [markdown]
# ## Set limit
#
# ### limit cos2

# %%
p = fviz_famd_col(res_famd,lim_cos2=0.8)
print(p)

# %% [markdown]
# ### limit contrib

# %%
p = fviz_famd_col(res_famd,lim_contrib=8)
print(p)

# %% [markdown]
# ## Qualitatives variables - Categories
#
# ### Color by RGB colors

# %%
from scientisttools import fviz_famd_mod
p = fviz_famd_mod(res_famd,repel=True)
print(p)

# %% [markdown]
# ### Color by cos2

# %%
p = fviz_famd_mod(res_famd,color="cos2",repel=True)
print(p)

# %%
p = fviz_corrplot(res_famd.quali_var_["cos2"],method="circle",colors=["#00AFBB", "#E7B800", "#FC4E07"])
print(p)

# %% [markdown]
# ### Color by contrib

# %%
p = fviz_famd_mod(res_famd,color="contrib",repel=True)
print(p)

# %% [markdown]
# ### Color by numpy array

# %%
np.random.seed(123)
color_numpy = np.random.normal(size=res_famd.quali_var_["coord"].shape[0])
p = fviz_famd_mod(res_famd,color=color_numpy,repel=True)
print(p)

# %% [markdown]
# ### Color by kmeans clustering

# %%
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(res_famd.quali_var_["coord"])
p = fviz_famd_mod(res_famd,color=kmeans,repel=True)
print(p)

# %% [markdown]
# ## Set limit
#
# ### limit cos2

# %%
p = fviz_famd_mod(res_famd,lim_cos2=0.1,repel=True) # à corriger
print(p)

# %% [markdown]
# ### limit contrib

# %%
p = fviz_famd_mod(res_famd,lim_contrib=8,repel=True)
print(p)

# %% [markdown]
# ## Variables

# %%
from scientisttools import fviz_famd_var
p = fviz_famd_var(res_famd,repel=True)
print(p)

# %%
p = fviz_corrplot(res_famd.var_["cos2"],method="circle",colors=["#00AFBB", "#E7B800", "#FC4E07"])
print(p)

# %% [markdown]
# ## Plot contributions

# %%
from scientisttools import fviz_contrib
p = fviz_contrib(res_famd,choice="ind")
print(p)

# %%
p = fviz_contrib(res_famd,choice="quanti_var")
print(p)

# %%
p = fviz_contrib(res_famd,choice="quali_var")
print(p)

# %% [markdown]
# ## Plot cos2

# %%
from scientisttools import fviz_cos2
p = fviz_cos2(res_famd)
print(p)

# %%
p = fviz_cos2(res_famd,choice="quanti_var")
print(p)

# %%
p = fviz_cos2(res_famd,choice="quali_var")
print(p)

# %% [markdown]
# ## Corrcircle

# %%
from scientisttools import fviz_corrcircle
p = fviz_corrcircle(res_famd)
print(p)
