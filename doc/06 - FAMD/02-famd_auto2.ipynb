# %% [markdown]
# # FAMD

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.filterwarnings("ignore")

# %%
import pandas as pd
# Chargement des données
A = pd.read_excel("./data/Data_Methodes_Factorielles.xlsx",sheet_name="AFDM_AUTOS",index_col=0)
display(A)
# Out:
#               puissance  longueur  hauteur  poids  CO2 origine carburant  4X4
# Modele
# GOLF                 75       421      149   1217  143  Europe    Diesel  non
# CITRONC4            138       426      146   1381  142  France    Diesel  non
# P607                204       491      145   1723  223  France    Diesel  non
# VELSATIS            150       486      158   1735  188  France    Diesel  non
# CITRONC2             61       367      147    932  141  France   Essence  non
# CHRYS300            340       502      148   1835  291  Autres   Essence  non
# AUDIA3              102       421      143   1205  168  Europe   Essence  non
# OUTLAND             202       455      167   1595  237  Autres    Diesel  oui
# PTCRUISER           223       429      154   1595  235  Autres   Essence  non
# SANTA_FE            125       450      173   1757  197  Autres    Diesel  oui

# %%
B = pd.DataFrame([136,446,168,1520,190,"Autres","Diesel","oui"],index=A.columns,columns=["X-TRAIL"]).T
C  = pd.DataFrame({
    "prix" : [19140,23400,40550,38250,10700,54900,21630,29990,27400,27990],
    "surtaxe" : ["non","non","oui","oui","non","oui","non","oui","oui","oui"]
},index=A.index)
D = pd.concat([pd.concat([A,B],axis=0),C],axis=1)
D
# Out:
#              puissance longueur hauteur poids  CO2 origine carburant  4X4  \
# GOLF                75      421     149  1217  143  Europe    Diesel  non
# CITRONC4           138      426     146  1381  142  France    Diesel  non
# P607               204      491     145  1723  223  France    Diesel  non
# VELSATIS           150      486     158  1735  188  France    Diesel  non
# CITRONC2            61      367     147   932  141  France   Essence  non
# CHRYS300           340      502     148  1835  291  Autres   Essence  non
# AUDIA3             102      421     143  1205  168  Europe   Essence  non
# OUTLAND            202      455     167  1595  237  Autres    Diesel  oui
# PTCRUISER          223      429     154  1595  235  Autres   Essence  non
# SANTA_FE           125      450     173  1757  197  Autres    Diesel  oui
# X-TRAIL            136      446     168  1520  190  Autres    Diesel  oui
#
#                  prix surtaxe
# GOLF          19140.0     non
# CITRONC4      23400.0     non
# P607          40550.0     oui
# VELSATIS      38250.0     oui
# CITRONC2      10700.0     non
# CHRYS300      54900.0     oui
# AUDIA3        21630.0     non
# OUTLAND       29990.0     oui
# PTCRUISER     27400.0     oui
# SANTA_FE      27990.0     oui
# X-TRAIL           NaN     NaN

# %%
D.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 11 entries, GOLF         to X-TRAIL
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   puissance  11 non-null     object
#  1   longueur   11 non-null     object
#  2   hauteur    11 non-null     object
#  3   poids      11 non-null     object
#  4   CO2        11 non-null     object
#  5   origine    11 non-null     object
#  6   carburant  11 non-null     object
#  7   4X4        11 non-null     object
#  8   prix       10 non-null     float64
#  9   surtaxe    10 non-null     object
# dtypes: float64(1), object(9)
# memory usage: 1.2+ KB

# %%
for col in ['puissance','longueur','hauteur','poids',"CO2","prix"]:
    D[col] = D[col].astype("float")

# %%
from scientisttools import FAMD
res_afdm = FAMD(ind_sup=10,quanti_sup=8,quali_sup=9,parallelize=False).fit(D)

# %%
from scientisttools import fviz_famd_var
p = fviz_famd_var(res_afdm,repel=True)
print(p)

# %%
from scientisttools import fviz_famd_ind
p = fviz_famd_ind(res_afdm,color="puissance",habillage="surtaxe",repel=True)
print(p)

# %%
from scientisttools import fviz_famd_col
p = fviz_famd_col(res_afdm,color="contrib")
print(p)

# %%
from scientisttools import fviz_corrcircle
p = fviz_corrcircle(res_afdm)
print(p)

# %%
from scientisttools import summaryFAMD
summaryFAMD(res_afdm,to_markdown=True)
# Out:
#                      Factor Analysis of Mixed Data - Results
#
# Importance of components
# |                         |   Dim.1 |   Dim.2 |   Dim.3 |   Dim.4 |   Dim.5 |
# |:------------------------|--------:|--------:|--------:|--------:|--------:|
# | Variance                |   4.273 |   2.122 |   1.439 |   0.836 |   0.164 |
# | Difference              |   2.151 |   0.683 |   0.602 |   0.672 |   0.05  |
# | % of var.               |  47.479 |  23.577 |  15.986 |   9.293 |   1.823 |
# | Cumulative of % of var. |  47.479 |  71.056 |  87.042 |  96.335 |  98.157 |
#
# Individuals
#
# |           |   Weight |   Sq. Dist. |   Inertia |   Dim.1 |    ctr |   cos2 |   Dim.2 |    ctr |   cos2 |   Dim.3 |    ctr |   cos2 |
# |:----------|---------:|------------:|----------:|--------:|-------:|-------:|--------:|-------:|-------:|--------:|-------:|-------:|
# | GOLF      |      0.1 |       8.932 |     0.893 |  -2.318 | 12.572 |  0.601 |  -0.687 |  2.226 |  0.053 |  -0.078 |  0.043 |  0.001 |
# | CITRONC4  |      0.1 |       4.767 |     0.477 |  -1.445 |  4.889 |  0.438 |  -0.122 |  0.07  |  0.003 |   1.371 | 13.057 |  0.394 |
# | P607      |      0.1 |       5.766 |     0.577 |   0.78  |  1.423 |  0.105 |   1.019 |  4.889 |  0.18  |   1.963 | 26.77  |  0.668 |
# | VELSATIS  |      0.1 |       4.576 |     0.458 |   0.541 |  0.685 |  0.064 |  -0.16  |  0.121 |  0.006 |   1.894 | 24.937 |  0.784 |
# | CITRONC2  |      0.1 |      14.651 |     1.465 |  -3.276 | 25.113 |  0.732 |   0.025 |  0.003 |  0     |  -0.654 |  2.971 |  0.029 |
# | CHRYS300  |      0.1 |      16.168 |     1.617 |   2.958 | 20.472 |  0.541 |   2.628 | 32.551 |  0.427 |  -0.668 |  3.098 |  0.028 |
# | AUDIA3    |      0.1 |       9.225 |     0.922 |  -2.316 | 12.554 |  0.582 |   0.795 |  2.981 |  0.069 |  -1.246 | 10.791 |  0.168 |
# | OUTLAND   |      0.1 |       9.488 |     0.949 |   2.256 | 11.91  |  0.536 |  -1.84  | 15.963 |  0.357 |  -0.686 |  3.272 |  0.05  |
# | PTCRUISER |      0.1 |       4.8   |     0.48  |   0.932 |  2.032 |  0.181 |   1.091 |  5.608 |  0.248 |  -1.378 | 13.203 |  0.396 |
# | SANTA_FE  |      0.1 |      11.627 |     1.163 |   1.889 |  8.35  |  0.307 |  -2.748 | 35.587 |  0.649 |  -0.517 |  1.858 |  0.023 |
#
# Supplementary individuals
#
# |         |   Sq. Dist. |   Dim.1 |   cos2 |   Dim.2 |   cos2 |   Dim.3 |   cos2 |
# |:--------|------------:|--------:|-------:|--------:|-------:|--------:|-------:|
# | X-TRAIL |       8.768 |   1.319 |  0.198 |  -2.513 |   0.72 |   -0.66 |   0.05 |
#
# Continuous variables
#
# |           |   Dim.1 |    ctr |   cos2 |   Dim.2 |    ctr |   cos2 |   Dim.3 |    ctr |   cos2 |
# |:----------|--------:|-------:|-------:|--------:|-------:|-------:|--------:|-------:|-------:|
# | puissance |   0.819 | 15.71  |  0.671 |   0.539 | 13.701 |  0.291 |  -0.039 |  0.105 |  0.002 |
# | longueur  |   0.796 | 14.835 |  0.634 |   0.245 |  2.826 |  0.06  |   0.429 | 12.763 |  0.184 |
# | hauteur   |   0.578 |  7.828 |  0.335 |  -0.764 | 27.478 |  0.583 |  -0.149 |  1.551 |  0.022 |
# | poids     |   0.93  | 20.219 |  0.864 |   0.061 |  0.176 |  0.004 |   0.273 |  5.169 |  0.074 |
# | CO2       |   0.891 | 18.564 |  0.793 |   0.379 |  6.769 |  0.144 |  -0.188 |  2.453 |  0.035 |
#
# Supplementary continuous variables
#
# |      |   Dim.1 |   cos2 |   Dim.2 |   cos2 |   Dim.3 |   cos2 |
# |:-----|--------:|-------:|--------:|-------:|--------:|-------:|
# | prix |   0.804 |  0.647 |   0.455 |  0.207 |   0.275 |  0.076 |
#
# Categories
#
# |         |   Weight |   Sq. Dist. |   Inertia |   Dim.1 |   ctr |   cos2 |   vtest |   Dim.2 |    ctr |   cos2 |   vtest |   Dim.3 |    ctr |   cos2 |   vtest |
# |:--------|---------:|------------:|----------:|--------:|------:|-------:|--------:|--------:|-------:|-------:|--------:|--------:|-------:|-------:|--------:|
# | Autres  |        1 |         0.6 |       0.6 |   2.009 | 8.838 |  0.846 |   2.38  |  -0.217 |  0.42  |  0.01  |  -0.365 |  -0.812 | 12.75  |  0.138 |  -1.659 |
# | Europe  |        1 |         0.8 |       0.8 |  -2.317 | 5.88  |  0.685 |  -1.681 |   0.054 |  0.013 |  0     |   0.056 |  -0.662 |  4.237 |  0.056 |  -0.828 |
# | France  |        1 |         0.6 |       0.6 |  -0.85  | 1.583 |  0.303 |  -1.007 |   0.19  |  0.322 |  0.015 |   0.32  |   1.143 | 25.263 |  0.548 |   2.335 |
# | Diesel  |        1 |         0.4 |       0.4 |   0.284 | 0.265 |  0.071 |   0.504 |  -0.757 |  7.628 |  0.508 |  -1.908 |   0.658 | 12.536 |  0.384 |   2.014 |
# | Essence |        1 |         0.6 |       0.6 |  -0.426 | 0.397 |  0.071 |  -0.504 |   1.135 | 11.442 |  0.508 |   1.908 |  -0.986 | 18.803 |  0.384 |  -2.014 |
# | non     |        1 |         0.2 |       0.2 |  -0.518 | 1.176 |  0.431 |  -1.504 |   0.574 |  5.845 |  0.529 |   2.362 |   0.15  |  0.874 |  0.036 |   0.752 |
# | oui     |        1 |         0.8 |       0.8 |   2.072 | 4.704 |  0.431 |   1.504 |  -2.294 | 23.38  |  0.529 |  -2.362 |  -0.602 |  3.497 |  0.036 |  -0.752 |
#
# Categoricals variables (eta2)
#
# |           |   Dim.1 |   Dim.2 |   Dim.3 |
# |:----------|--------:|--------:|--------:|
# | origine   |   0.697 |   0.016 |   0.608 |
# | carburant |   0.028 |   0.405 |   0.451 |
# | 4X4       |   0.251 |   0.62  |   0.063 |
#
# Supplementary categories
#
# |     |   Sq. Dist. |   Dim.1 |   cos2 |   v.test |   Dim.2 |   cos2 |   v.test |   Dim.3 |   cos2 |   v.test |
# |:----|------------:|--------:|-------:|---------:|--------:|-------:|---------:|--------:|-------:|---------:|
# | non |       5.519 |  -2.339 |  0.991 |   -2.771 |   0.003 |      0 |    0.005 |  -0.152 |  0.004 |    -0.31 |
# | oui |       2.453 |   1.559 |  0.991 |    2.771 |  -0.002 |      0 |   -0.005 |   0.101 |  0.004 |     0.31 |
#
# Supplementary categorical variables (eta2)
#
# |         |   Dim.1 |   Dim.2 |   Dim.3 |
# |:--------|--------:|--------:|--------:|
# | surtaxe |   0.853 |       0 |   0.011 |
