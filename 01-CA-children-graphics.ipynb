# %% [markdown]
# # Correspondence Analysis (CA) - `Children` Dataset graphs

# %%
from warnings import simplefilter, filterwarnings
simplefilter(action='ignore', category=FutureWarning)
filterwarnings("ignore")

# %%
from scientisttools import children, CA
#with supplementary columns
res_ca = CA(n_components=None,row_sup=(14,15,16,17),col_sup=(5,6,7),quali_sup=8)
res_ca.fit(children)
# Out:
# CA(col_sup=(5, 6, 7), n_components=None, quali_sup=8, row_sup=(14, 15, 16, 17))

# %%
#with supplementary quantitative variables
res_ca2 = CA(n_components=None,row_sup=(14,15,16,17),quanti_sup=(5,6,7),quali_sup=8)
res_ca2.fit(children)
# Out:
# CA(n_components=None, quali_sup=8, quanti_sup=(5, 6, 7),
#    row_sup=(14, 15, 16, 17))

# %%
from scientisttools import fviz_eig
p = fviz_eig(res_ca,add_labels=True)
print(p)

# %% [markdown]
# ## Row factor map
#
# ### Color by RGB color
#
# #### Only active elements

# %%
#color by RGB color
from scientisttools import fviz_ca_row
print(fviz_ca_row(res_ca,repel=True))

# %% [markdown]
# #### With supplementary elements

# %%
print(fviz_ca_row(res_ca,repel=True,row_sup=True,quali_sup=True))

# %% [markdown]
# ### Color by `cos2`

# %%
#color by cos2
print(fviz_ca_row(res_ca,col_row="cos2",repel=True))

# %%
from scientisttools import fviz_corrplot
print(fviz_corrplot(res_ca.row_.cos2,x_label="Rows points",title="Rows Cos2",legend_title="Cos2"))

# %%
from scientisttools import fviz_cos2
print(fviz_cos2(res_ca,element="row",axis=0))

# %% [markdown]
# ### Color by `contrib`

# %%
#color by contrib
print(fviz_ca_row(res_ca,col_row="contrib",repel=True))

# %%
print(fviz_corrplot(res_ca.row_.contrib,x_label="Rows points",title="Rows contributions",legend_title="Contrib"))

# %%
from scientisttools import fviz_contrib
print(fviz_contrib(res_ca,element="row",axis=0))

# %% [markdown]
# ### Color by `coord`

# %%
#color by coord
print(fviz_ca_row(res_ca,col_row="coord",repel=True))

# %% [markdown]
# ### Color by quantitatives columns

# %%
#color by quantitative variables
print(fviz_ca_row(res_ca,col_row="unqualified",repel=True))

# %% [markdown]
# ### Color by numpy array

# %%
#color using numpy array
import numpy as np
np.random.seed(123)
color_numpy = np.random.normal(size=res_ca.call_.X.shape[0])
print(fviz_ca_row(res_ca,col_row=color_numpy,repel=True))

# %% [markdown]
# ### Color by Kmeans

# %%
#color using kmeans clustering
from sklearn.cluster import KMeans
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(res_ca.row_.coord)
print(fviz_ca_row(res_ca,col_row=kmeans,repel=True,palette=("darkblue","darkred","darkgreen")))

# %% [markdown]
# ### Color by qualitative

# %%
#color using qualitative variable
print(fviz_ca_row(res_ca,repel=True,habillage="categorie",add_ellipses=False,palette=("darkblue","darkred","darkgreen","magenta")))

# %% [markdown]
# ### Set limits

# %%
p = fviz_ca_row(res_ca,repel=True,lim_cos2=0.9)
print(p)

# %%
p = fviz_ca_row(res_ca,repel=True,lim_contrib=20)
print(p)

# %% [markdown]
# ## Columns Factor Map
#
# ### Color by RGB
#
# #### Only active elements

# %%
from scientisttools import fviz_ca_col
p = fviz_ca_col(res_ca,repel=True)
print(p)

# %% [markdown]
# #### With supplementary elements

# %%
p = fviz_ca_col(res_ca,repel=True,col_sup=True)
print(p)

# %% [markdown]
# ## Color by `cos2`

# %%
#color by cos2
print(fviz_ca_col(res_ca,col_col="cos2",repel=True))

# %%
print(fviz_corrplot(res_ca.col_.cos2,x_label="Columns points",title="Columns Cos2",legend_title="Cos2"))

# %%
print(fviz_cos2(res_ca,element="col",axis=0))

# %% [markdown]
# ## Color by `contrib`

# %%
#color by contrib
print(fviz_ca_col(res_ca,col_col="contrib",repel=True))

# %%
#
print(fviz_corrplot(res_ca.col_.cos2,x_label="Columns points",title="Columns Contrib",legend_title="Contrib"))

# %%
#
print(fviz_contrib(res_ca,element="col",axis=0))

# %% [markdown]
# ### Color by `coord`

# %%
#color by coord
p = fviz_ca_col(res_ca,col_col="coord",repel=True)
print(p)

# %% [markdown]
# ### Color by numpy array

# %%
np.random.seed(123)
color_numpy = np.random.normal(size=res_ca.call_.X.shape[1])
p = fviz_ca_col(res_ca,col_col=color_numpy,repel=True)
print(p)

# %% [markdown]
# ### Color by kmeans

# %%
kmeans = KMeans(n_clusters=3, random_state=np.random.seed(123), n_init="auto").fit(res_ca.col_.coord)
p = fviz_ca_col(res_ca,col_col=kmeans,repel=True,palette=("darkblue","darkred","darkgreen"))
print(p)

# %% [markdown]
# ## Biplot
#
# ### Color by RGB
#
# #### Only active elements

# %%
from scientisttools import fviz_ca_biplot
p = fviz_ca_biplot(res_ca,repel_col=True,repel_row=True)
print(p)

# %% [markdown]
# #### With supplementary elements

# %%
p = fviz_ca_biplot(res_ca,repel_col=True,repel_row=True,row_sup=True,quali_sup=True,col_sup=True)
print(p)

# %% [markdown]
# ### Color by `cos2`

# %%
#color by cos2
p = fviz_ca_biplot(res_ca,col_row="cos2",repel_col=True,repel_row=True)
print(p)

# %% [markdown]
# ### Color by `contrib`

# %%
#color by contrib
p = fviz_ca_biplot(res_ca,col_row="contrib",repel_col=True,repel_row=True)
print(p)

# %% [markdown]
# ### Color by `coord`

# %%
#color by coord
p = fviz_ca_biplot(res_ca,col_row="coord",repel_col=True,repel_row=True)
print(p)

# %% [markdown]
# ### Color by categorie

# %%
p = fviz_ca_biplot(res_ca,habillage="categorie",palette=("darkblue","darkred","darkgreen","magenta"),repel_col=True,repel_row=True)
print(p)

# %% [markdown]
# ## Plot supplementary quantitative variables

# %%
from scientisttools import fviz_corrcircle
print(fviz_corrcircle(res_ca2))
